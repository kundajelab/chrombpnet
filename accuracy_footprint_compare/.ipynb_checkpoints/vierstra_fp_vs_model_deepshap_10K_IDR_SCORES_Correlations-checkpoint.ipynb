# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import pandas as pd
import h5py
import pickle 
import numpy as np 
import pyBigWig
from helpers import * 
from kerasAC.helpers.format_interpretations import * 
from sklearn.metrics import average_precision_score
from scipy.stats import pearsonr, spearmanr
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cell_line="K562"
fold=0

# %%
vierstra=pyBigWig.open('/srv/scratch/annashch/chrombpnet/accuracy_footprint_compare/vierstra/K562.DS16924.interval.all.fpr.bw','r')

# %%
tobias=pyBigWig.open("/oak/stanford/groups/akundaje/projects/enzymatic_bias_correction/tobias/dnase/footprints/K562_idr_footprints.bw",'r')

# %%
cur_shap=pickle.load(open("/srv/scratch/annashch/chrombpnet/k562_dnase/bpnet/interpret/K562.10k.DNASE.bias_corrected_bpnet_tobias.fold"+str(fold)+".deepSHAP",'rb'))

# %%
cur_shap.keys()
# Out:
# dict_keys(['label_prof', 'label_sum', 'pred_prof', 'pred_sum', 'profile_shap', 'count_shap', 'seq'])

# %%
class_shap=format_binary_deepshap("/srv/scratch/annashch/bias_correction/uncorrected/classification/K562/interpretation/10k.DNASE.K562."+str(fold)+".deepSHAP.interp.npz")

# %%
reg_shap=format_binary_deepshap("/srv/scratch/annashch/bias_correction/uncorrected/regression/K562/interpretation/10k.DNASE.K562."+str(fold)+".deepSHAP.interp.npz")

# %%
gkm_scores=format_gkm_scores("/oak/stanford/groups/akundaje/projects/enzymatic_bias_correction/svm/aggregate/gkmexplain.K562."+str(fold)+".txt")

# %%
coords=list(gkm_scores.keys())

# %%
cor_dict={} 
cor_dict['tobias_spearman']={}
cor_dict['tobias_pearson']={}
cor_dict['vierstra_spearman']={}
cor_dict['vierstra_pearson']={}
for key in cor_dict: 
    cor_dict[key]['profile']=[]
    cor_dict[key]['counts']=[]
    cor_dict[key]['class']=[]
    cor_dict[key]['reg']=[]
    cor_dict[key]['gkm']=[]
    

i=0
for coord in coords: 
    i+=1
    if i%100==0: 
        print(str(i))
    #get the tobias footprint scores 
    tobias_vals=np.nan_to_num(tobias.values(coord[0],coord[1]-500,coord[1]+500))
    #get the vierstra footprint scores 
    vierstra_vals=np.nan_to_num(vierstra.values(coord[0],coord[1]-500,coord[1]+500))
    print(np.sum(tobias_vals-vierstra_vals))
    #get the bpnet profile & count shap values 
    label_prob, label_sum, pred_prob, pred_sum, profile_shap, count_shap, seq, minval_perf, maxval_perf, minval_shap, maxval_shap=extract_region(coord,cur_shap)
    try:
        #classification shap 
        binary_class_shap=class_shap[coord]
    except:
        continue 
    #regression shap 
    binary_reg_shap=reg_shap[coord]

    #gkm explain score 
    gkm_score=gkm_scores[coord]
    
    #get observed deepSHAP scores 
    profile_shap_observed=project_scores(profile_shap,seq)
    count_shap_observed=project_scores(count_shap,seq)
    class_shap_observed=project_scores(binary_class_shap,seq)
    reg_shap_observed=project_scores(binary_reg_shap,seq)
    gkm_observed=project_scores(gkm_score,seq)
    
    #get pearson & spearman 
    cor_dict['tobias_spearman']['profile'].append(spearmanr(profile_shap_observed,tobias_vals)[0])
    cor_dict['tobias_pearson']['profile'].append(pearsonr(profile_shap_observed,vierstra_vals)[0])
    cor_dict['vierstra_spearman']['profile'].append(spearmanr(profile_shap_observed,tobias_vals)[0])
    cor_dict['vierstra_pearson']['profile'].append(pearsonr(profile_shap_observed,vierstra_vals)[0])
    
    
    cor_dict['tobias_spearman']['counts'].append(spearmanr(count_shap_observed,tobias_vals)[0])
    cor_dict['tobias_pearson']['counts'].append(pearsonr(count_shap_observed,vierstra_vals)[0])
    cor_dict['vierstra_spearman']['counts'].append(spearmanr(count_shap_observed,tobias_vals)[0])
    cor_dict['vierstra_pearson']['counts'].append(pearsonr(count_shap_observed,vierstra_vals)[0])
    
    
    cor_dict['tobias_spearman']['class'].append(spearmanr(class_shap_observed,tobias_vals)[0])
    cor_dict['tobias_pearson']['class'].append(pearsonr(class_shap_observed,vierstra_vals)[0])
    cor_dict['vierstra_spearman']['class'].append(spearmanr(class_shap_observed,tobias_vals)[0])
    cor_dict['vierstra_pearson']['class'].append(pearsonr(class_shap_observed,vierstra_vals)[0])
    
    
    cor_dict['tobias_spearman']['reg'].append(spearmanr(reg_shap_observed,tobias_vals)[0])
    cor_dict['tobias_pearson']['reg'].append(pearsonr(reg_shap_observed,vierstra_vals)[0])
    cor_dict['vierstra_spearman']['reg'].append(spearmanr(reg_shap_observed,tobias_vals)[0])
    cor_dict['vierstra_pearson']['reg'].append(pearsonr(reg_shap_observed,vierstra_vals)[0])
    
    
    cor_dict['tobias_spearman']['gkm'].append(spearmanr(gkm_observed,tobias_vals)[0])
    cor_dict['tobias_pearson']['gkm'].append(pearsonr(gkm_observed,vierstra_vals)[0])
    cor_dict['vierstra_spearman']['gkm'].append(spearmanr(gkm_observed,tobias_vals)[0])
    cor_dict['vierstra_pearson']['gkm'].append(pearsonr(gkm_observed,vierstra_vals)[0])
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000

# %%
tb_spear_df=pd.DataFrame.from_dict(cor_dict['tobias_spearman'])
tb_spear_df['cortype']='spearman'
tb_spear_df['motifs']='tobias'

vr_spear_df=pd.DataFrame.from_dict(cor_dict['vierstra_spearman'])
vr_spear_df['cortype']='spearman'
vr_spear_df['motifs']='vierstra'

tb_pearson_df=pd.DataFrame.from_dict(cor_dict['tobias_pearson'])
tb_pearson_df['cortype']='pearson'
tb_pearson_df['motifs']='tobias'

vr_pearson_df=pd.DataFrame.from_dict(cor_dict['vierstra_pearson'])
vr_pearson_df['cortype']='pearson'
vr_pearson_df['motifs']='vierstra'

#concatenate the dataframes
all_df=pd.concat([tb_spear_df,vr_spear_df,tb_pearson_df,vr_pearson_df],axis=0)
#export to csv for visualization in R (better ggridges package )
all_df.to_csv("Tobias_Vierstra_Cor.K562.DNASE.10k.txt",header=True,index=False,sep='\t')

# %%
all_df.head()
# Out:
#     profile    counts     class       reg       gkm   cortype  motifs
# 0 -0.055709  0.005686  0.100152 -0.123441  0.054584  spearman  tobias
# 1  0.141329  0.057514  0.239912 -0.007796  0.241229  spearman  tobias
# 2 -0.080534  0.085327  0.058815  0.118478  0.158951  spearman  tobias
# 3  0.162918  0.032847  0.353832  0.317857  0.082761  spearman  tobias
# 4 -0.008432  0.113699  0.142373  0.017546  0.374535  spearman  tobias

# %%
import joypy
fig, axes = joypy.joyplot(all_df)

# %%
plt.rcParams["figure.figsize"]=12,12
fig,axes=plt.subplots(5,2)

axes[0,0].hist(infp_profile_shap_all,color='b',alpha=0.3,label='In Footprint',density=True,bins=50)
axes[0,0].hist(outsidefp_profile_shap_all,color='r',alpha=0.3,label='Outside Footprint',density=True,bins=50)
axes[0,0].set_title("BPNET Profile Loss SHAP CDF")
axes[0,0].legend()
axes[0,0].set_xlim(-0.1,0.1)
axes[0,1].hist(auprc_profile_shap_all,color='k',density=True,bins=50)
axes[0,1].set_title('BPNET Profile Loss SHAP auPRC')

axes[1,0].hist(infp_count_shap_all,color='b',alpha=0.3,label='In Footprint',density=True,bins=50)
axes[1,0].hist(outsidefp_count_shap_all,color='r',alpha=0.3,label='Outside Footprint',density=True,bins=50)
axes[1,0].set_title("BPNET Count Loss SHAP CDF")
axes[1,0].set_xlim(-0.1,0.1)

axes[1,1].hist(auprc_count_shap_all,color='k',density=True,bins=50)
axes[1,1].set_title('BPNET Count Loss SHAP auPRC')

axes[2,0].hist(infp_binary_class_shap_all,color='b',alpha=0.3,label='In Footprint',density=True,bins=50)
axes[2,0].hist(outsidefp_binary_class_shap_all,color='r',alpha=0.3,label='Outside Footprint',density=True,bins=50)
axes[2,0].set_title(" Binary Class. SHAP CDF")
axes[2,0].set_xlim(-0.1,0.5)

axes[2,1].hist(auprc_binary_class_shap_all,color='k',density=True,bins=50)
axes[2,1].set_title('Binary Class. SHAP auPRC')

axes[3,0].hist(infp_binary_reg_shap_all,color='b',alpha=0.3,label='In Footprint',density=True,bins=50)
axes[3,0].hist(outsidefp_binary_reg_shap_all,color='r',alpha=0.3,label='Outside Footprint',density=True,bins=50)
axes[3,0].set_title(" Binary Reg. SHAP CDF")
axes[3,0].set_xlim(-0.1,0.1)

axes[3,1].hist(auprc_binary_reg_shap_all,color='k',density=True,bins=50)
axes[3,1].set_title('Binary Reg. SHAP auPRC')

axes[4,0].hist(infp_gkm_score_all,color='b',alpha=0.3,label='In Footprint',density=True,bins=50)
axes[4,0].hist(outsidefp_gkm_score_all,color='r',alpha=0.3,label='Outside Footprint',density=True,bins=50)
axes[4,0].set_title("GKMExplain CDF")
axes[4,0].set_xlim(-0.1,0.1)

axes[4,1].hist(auprc_gkm_score_all,color='k',density=True,bins=50)
axes[4,1].set_title('GKMExplain auPRC')

plt.subplots_adjust(hspace=0.6)
plt.show()

# %%
from scipy.stats import ranksums

# %%
print(np.mean(auprc_profile_shap_all))
print(np.std(auprc_profile_shap_all))
# Out:
# 0.3585298804780877
# 0.26606710298423586

# %%
print(np.mean(auprc_count_shap_all))
print(np.std(auprc_count_shap_all))
# Out:
# 0.26622111553784855
# 0.22416343575310416

# %%
print(np.mean(auprc_binary_class_shap_all))
print(np.std(auprc_binary_class_shap_all))
# Out:
# 0.3180876494023905
# 0.2962158553403792

# %%
print(np.mean(auprc_binary_reg_shap_all))
print(np.std(auprc_binary_reg_shap_all))
# Out:
# 0.3158266932270916
# 0.2940902201946961

# %%
print(np.mean(auprc_gkm_score_all))
print(np.std(auprc_gkm_score_all))
# Out:
# 0.2834402390438247
# 0.3003113547224641
