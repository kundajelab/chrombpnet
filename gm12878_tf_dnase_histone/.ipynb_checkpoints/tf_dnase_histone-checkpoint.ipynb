# %%
# %load_ext autoreload
# %reload_ext autoreload

# %autoreload 2
# %matplotlib inline
import tensorflow
from tensorflow.compat.v1.keras.backend import get_session
tensorflow.compat.v1.disable_v2_behavior()
import math
import kerasAC 
from scipy.special import softmax,expit
from kerasAC.interpret.deepshap import * 
from kerasAC.interpret.profile_shap import * 
from kerasAC.vis import * 
from kerasAC.helpers.transform_bpnet_io import * 
from kerasAC.util import * 
import pandas as pd

## for plotting 

import matplotlib 
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"]=10,5
plt.rcParams['axes.xmargin'] = 0

font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 10}

matplotlib.rc('font', **font)
# Out:
# WARNING:tensorflow:From /users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Using TensorFlow backend.
# /users/annashch/kerasAC/kerasAC/vis/plot_letters.py:172: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   min_coords = np.vstack(data.min(0) for data in polygons_data).min(0)
# /users/annashch/kerasAC/kerasAC/vis/plot_letters.py:173: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   max_coords = np.vstack(data.max(0) for data in polygons_data).max(0)

# %%
import pysam 
ref=pysam.FastaFile("/mnt/data/GRCh38_no_alt_analysis_set_GCA_000001405.15.fasta")

# %%
#load the model! 
from keras.models import load_model, model_from_json
from keras.utils.generic_utils import get_custom_objects
from kerasAC.metrics import * 
from kerasAC.custom_losses import * 
from keras_genomics.layers.convolutional import RevCompConv1D
import tensorflow_probability as tfp

custom_objects={"recall":recall,
                "sensitivity":recall,
                "specificity":specificity,
                "fpr":fpr,
                "fnr":fnr,
                "precision":precision,
                "f1":f1,
                "ambig_binary_crossentropy":ambig_binary_crossentropy,
                "ambig_mean_absolute_error":ambig_mean_absolute_error,
                "ambig_mean_squared_error":ambig_mean_squared_error,
                "MultichannelMultinomialNLL":MultichannelMultinomialNLL,
                "MultichannelMultinomialMSE":MultichannelMultinomialMSE,                
                "RevCompConv1D": RevCompConv1D}
get_custom_objects().update(custom_objects)
#load dnase model from architecture and trained weights 
import json 
dnase_model=model_from_json(open("gm12878.dnase.with.bpnet.tobias.bias.0.arch",'r').read())
dnase_model.load_weights("gm12878.dnase.with.bpnet.tobias.bias.0.weights")
#dnase_model=load_model("gm12878.dnase.with.bpnet.tobias.bias.0.hdf5")
tf_model=load_model("Spi1ProfileModel_RevComp_9layers.h5")
histone_model=load_model("patience_6_5K_out_12_gm12878.h3k27ac.seed.2345.cs.25.filters.300.naive.range.4.6.to.11.5.0.hdf5")

# %%
histone_model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           [(None, 22000, 4)]   0
# __________________________________________________________________________________________________
# 1st_conv (Conv1D)               (None, 21980, 300)   25500       sequence[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_1th_dconv (Croppin (None, 21976, 300)   0           1st_conv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv (Conv1D)              (None, 21976, 300)   270300      1st_conv[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 21976, 300)   0           1stconv-crop_1th_dconv[0][0]
#                                                                  0_dilconv[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_2th_dconv (Croppin (None, 21968, 300)   0           1stconv-crop_1th_dconv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv-crop_2th_dconv (Cropp (None, 21968, 300)   0           0_dilconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv (Conv1D)              (None, 21968, 300)   270300      add_2[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 21968, 300)   0           1stconv-crop_2th_dconv[0][0]
#                                                                  0_dilconv-crop_2th_dconv[0][0]
#                                                                  1_dilconv[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_3th_dconv (Croppin (None, 21952, 300)   0           1stconv-crop_2th_dconv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv-crop_3th_dconv (Cropp (None, 21952, 300)   0           0_dilconv-crop_2th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_3th_dconv (Cropp (None, 21952, 300)   0           1_dilconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv (Conv1D)              (None, 21952, 300)   270300      add_3[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 21952, 300)   0           1stconv-crop_3th_dconv[0][0]
#                                                                  0_dilconv-crop_3th_dconv[0][0]
#                                                                  1_dilconv-crop_3th_dconv[0][0]
#                                                                  2_dilconv[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_4th_dconv (Croppin (None, 21920, 300)   0           1stconv-crop_3th_dconv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv-crop_4th_dconv (Cropp (None, 21920, 300)   0           0_dilconv-crop_3th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_4th_dconv (Cropp (None, 21920, 300)   0           1_dilconv-crop_3th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_4th_dconv (Cropp (None, 21920, 300)   0           2_dilconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv (Conv1D)              (None, 21920, 300)   270300      add_4[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 21920, 300)   0           1stconv-crop_4th_dconv[0][0]
#                                                                  0_dilconv-crop_4th_dconv[0][0]
#                                                                  1_dilconv-crop_4th_dconv[0][0]
#                                                                  2_dilconv-crop_4th_dconv[0][0]
#                                                                  3_dilconv[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_5th_dconv (Croppin (None, 21856, 300)   0           1stconv-crop_4th_dconv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv-crop_5th_dconv (Cropp (None, 21856, 300)   0           0_dilconv-crop_4th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_5th_dconv (Cropp (None, 21856, 300)   0           1_dilconv-crop_4th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_5th_dconv (Cropp (None, 21856, 300)   0           2_dilconv-crop_4th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_5th_dconv (Cropp (None, 21856, 300)   0           3_dilconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv (Conv1D)              (None, 21856, 300)   270300      add_5[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 21856, 300)   0           1stconv-crop_5th_dconv[0][0]
#                                                                  0_dilconv-crop_5th_dconv[0][0]
#                                                                  1_dilconv-crop_5th_dconv[0][0]
#                                                                  2_dilconv-crop_5th_dconv[0][0]
#                                                                  3_dilconv-crop_5th_dconv[0][0]
#                                                                  4_dilconv[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_6th_dconv (Croppin (None, 21728, 300)   0           1stconv-crop_5th_dconv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv-crop_6th_dconv (Cropp (None, 21728, 300)   0           0_dilconv-crop_5th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_6th_dconv (Cropp (None, 21728, 300)   0           1_dilconv-crop_5th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_6th_dconv (Cropp (None, 21728, 300)   0           2_dilconv-crop_5th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_6th_dconv (Cropp (None, 21728, 300)   0           3_dilconv-crop_5th_dconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv-crop_6th_dconv (Cropp (None, 21728, 300)   0           4_dilconv[0][0]
# __________________________________________________________________________________________________
# 5_dilconv (Conv1D)              (None, 21728, 300)   270300      add_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 21728, 300)   0           1stconv-crop_6th_dconv[0][0]
#                                                                  0_dilconv-crop_6th_dconv[0][0]
#                                                                  1_dilconv-crop_6th_dconv[0][0]
#                                                                  2_dilconv-crop_6th_dconv[0][0]
#                                                                  3_dilconv-crop_6th_dconv[0][0]
#                                                                  4_dilconv-crop_6th_dconv[0][0]
#                                                                  5_dilconv[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_7th_dconv (Croppin (None, 21472, 300)   0           1stconv-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv-crop_7th_dconv (Cropp (None, 21472, 300)   0           0_dilconv-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_7th_dconv (Cropp (None, 21472, 300)   0           1_dilconv-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_7th_dconv (Cropp (None, 21472, 300)   0           2_dilconv-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_7th_dconv (Cropp (None, 21472, 300)   0           3_dilconv-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv-crop_7th_dconv (Cropp (None, 21472, 300)   0           4_dilconv-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 5_dilconv-crop_7th_dconv (Cropp (None, 21472, 300)   0           5_dilconv[0][0]
# __________________________________________________________________________________________________
# 6_dilconv (Conv1D)              (None, 21472, 300)   270300      add_7[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 21472, 300)   0           1stconv-crop_7th_dconv[0][0]
#                                                                  0_dilconv-crop_7th_dconv[0][0]
#                                                                  1_dilconv-crop_7th_dconv[0][0]
#                                                                  2_dilconv-crop_7th_dconv[0][0]
#                                                                  3_dilconv-crop_7th_dconv[0][0]
#                                                                  4_dilconv-crop_7th_dconv[0][0]
#                                                                  5_dilconv-crop_7th_dconv[0][0]
#                                                                  6_dilconv[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_8th_dconv (Croppin (None, 20960, 300)   0           1stconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv-crop_8th_dconv (Cropp (None, 20960, 300)   0           0_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_8th_dconv (Cropp (None, 20960, 300)   0           1_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_8th_dconv (Cropp (None, 20960, 300)   0           2_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_8th_dconv (Cropp (None, 20960, 300)   0           3_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv-crop_8th_dconv (Cropp (None, 20960, 300)   0           4_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 5_dilconv-crop_8th_dconv (Cropp (None, 20960, 300)   0           5_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 6_dilconv-crop_8th_dconv (Cropp (None, 20960, 300)   0           6_dilconv[0][0]
# __________________________________________________________________________________________________
# 7_dilconv (Conv1D)              (None, 20960, 300)   270300      add_8[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 20960, 300)   0           1stconv-crop_8th_dconv[0][0]
#                                                                  0_dilconv-crop_8th_dconv[0][0]
#                                                                  1_dilconv-crop_8th_dconv[0][0]
#                                                                  2_dilconv-crop_8th_dconv[0][0]
#                                                                  3_dilconv-crop_8th_dconv[0][0]
#                                                                  4_dilconv-crop_8th_dconv[0][0]
#                                                                  5_dilconv-crop_8th_dconv[0][0]
#                                                                  6_dilconv-crop_8th_dconv[0][0]
#                                                                  7_dilconv[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_9th_dconv (Croppin (None, 19936, 300)   0           1stconv-crop_8th_dconv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv-crop_9th_dconv (Cropp (None, 19936, 300)   0           0_dilconv-crop_8th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_9th_dconv (Cropp (None, 19936, 300)   0           1_dilconv-crop_8th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_9th_dconv (Cropp (None, 19936, 300)   0           2_dilconv-crop_8th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_9th_dconv (Cropp (None, 19936, 300)   0           3_dilconv-crop_8th_dconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv-crop_9th_dconv (Cropp (None, 19936, 300)   0           4_dilconv-crop_8th_dconv[0][0]
# __________________________________________________________________________________________________
# 5_dilconv-crop_9th_dconv (Cropp (None, 19936, 300)   0           5_dilconv-crop_8th_dconv[0][0]
# __________________________________________________________________________________________________
# 6_dilconv-crop_9th_dconv (Cropp (None, 19936, 300)   0           6_dilconv-crop_8th_dconv[0][0]
# __________________________________________________________________________________________________
# 7_dilconv-crop_9th_dconv (Cropp (None, 19936, 300)   0           7_dilconv[0][0]
# __________________________________________________________________________________________________
# 8_dilconv (Conv1D)              (None, 19936, 300)   270300      add_9[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 19936, 300)   0           1stconv-crop_9th_dconv[0][0]
#                                                                  0_dilconv-crop_9th_dconv[0][0]
#                                                                  1_dilconv-crop_9th_dconv[0][0]
#                                                                  2_dilconv-crop_9th_dconv[0][0]
#                                                                  3_dilconv-crop_9th_dconv[0][0]
#                                                                  4_dilconv-crop_9th_dconv[0][0]
#                                                                  5_dilconv-crop_9th_dconv[0][0]
#                                                                  6_dilconv-crop_9th_dconv[0][0]
#                                                                  7_dilconv-crop_9th_dconv[0][0]
#                                                                  8_dilconv[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_10th_dconv (Croppi (None, 17888, 300)   0           1stconv-crop_9th_dconv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv-crop_10th_dconv (Crop (None, 17888, 300)   0           0_dilconv-crop_9th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_10th_dconv (Crop (None, 17888, 300)   0           1_dilconv-crop_9th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_10th_dconv (Crop (None, 17888, 300)   0           2_dilconv-crop_9th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_10th_dconv (Crop (None, 17888, 300)   0           3_dilconv-crop_9th_dconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv-crop_10th_dconv (Crop (None, 17888, 300)   0           4_dilconv-crop_9th_dconv[0][0]
# __________________________________________________________________________________________________
# 5_dilconv-crop_10th_dconv (Crop (None, 17888, 300)   0           5_dilconv-crop_9th_dconv[0][0]
# __________________________________________________________________________________________________
# 6_dilconv-crop_10th_dconv (Crop (None, 17888, 300)   0           6_dilconv-crop_9th_dconv[0][0]
# __________________________________________________________________________________________________
# 7_dilconv-crop_10th_dconv (Crop (None, 17888, 300)   0           7_dilconv-crop_9th_dconv[0][0]
# __________________________________________________________________________________________________
# 8_dilconv-crop_10th_dconv (Crop (None, 17888, 300)   0           8_dilconv[0][0]
# __________________________________________________________________________________________________
# 9_dilconv (Conv1D)              (None, 17888, 300)   270300      add_10[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 17888, 300)   0           1stconv-crop_10th_dconv[0][0]
#                                                                  0_dilconv-crop_10th_dconv[0][0]
#                                                                  1_dilconv-crop_10th_dconv[0][0]
#                                                                  2_dilconv-crop_10th_dconv[0][0]
#                                                                  3_dilconv-crop_10th_dconv[0][0]
#                                                                  4_dilconv-crop_10th_dconv[0][0]
#                                                                  5_dilconv-crop_10th_dconv[0][0]
#                                                                  6_dilconv-crop_10th_dconv[0][0]
#                                                                  7_dilconv-crop_10th_dconv[0][0]
#                                                                  8_dilconv-crop_10th_dconv[0][0]
#                                                                  9_dilconv[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_11th_dconv (Croppi (None, 13792, 300)   0           1stconv-crop_10th_dconv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv-crop_11th_dconv (Crop (None, 13792, 300)   0           0_dilconv-crop_10th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_11th_dconv (Crop (None, 13792, 300)   0           1_dilconv-crop_10th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_11th_dconv (Crop (None, 13792, 300)   0           2_dilconv-crop_10th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_11th_dconv (Crop (None, 13792, 300)   0           3_dilconv-crop_10th_dconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv-crop_11th_dconv (Crop (None, 13792, 300)   0           4_dilconv-crop_10th_dconv[0][0]
# __________________________________________________________________________________________________
# 5_dilconv-crop_11th_dconv (Crop (None, 13792, 300)   0           5_dilconv-crop_10th_dconv[0][0]
# __________________________________________________________________________________________________
# 6_dilconv-crop_11th_dconv (Crop (None, 13792, 300)   0           6_dilconv-crop_10th_dconv[0][0]
# __________________________________________________________________________________________________
# 7_dilconv-crop_11th_dconv (Crop (None, 13792, 300)   0           7_dilconv-crop_10th_dconv[0][0]
# __________________________________________________________________________________________________
# 8_dilconv-crop_11th_dconv (Crop (None, 13792, 300)   0           8_dilconv-crop_10th_dconv[0][0]
# __________________________________________________________________________________________________
# 9_dilconv-crop_11th_dconv (Crop (None, 13792, 300)   0           9_dilconv[0][0]
# __________________________________________________________________________________________________
# 10_dilconv (Conv1D)             (None, 13792, 300)   270300      add_11[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 13792, 300)   0           1stconv-crop_11th_dconv[0][0]
#                                                                  0_dilconv-crop_11th_dconv[0][0]
#                                                                  1_dilconv-crop_11th_dconv[0][0]
#                                                                  2_dilconv-crop_11th_dconv[0][0]
#                                                                  3_dilconv-crop_11th_dconv[0][0]
#                                                                  4_dilconv-crop_11th_dconv[0][0]
#                                                                  5_dilconv-crop_11th_dconv[0][0]
#                                                                  6_dilconv-crop_11th_dconv[0][0]
#                                                                  7_dilconv-crop_11th_dconv[0][0]
#                                                                  8_dilconv-crop_11th_dconv[0][0]
#                                                                  9_dilconv-crop_11th_dconv[0][0]
#                                                                  10_dilconv[0][0]
# __________________________________________________________________________________________________
# 1stconv-crop_12th_dconv (Croppi (None, 5600, 300)    0           1stconv-crop_11th_dconv[0][0]
# __________________________________________________________________________________________________
# 0_dilconv-crop_12th_dconv (Crop (None, 5600, 300)    0           0_dilconv-crop_11th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_12th_dconv (Crop (None, 5600, 300)    0           1_dilconv-crop_11th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_12th_dconv (Crop (None, 5600, 300)    0           2_dilconv-crop_11th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_12th_dconv (Crop (None, 5600, 300)    0           3_dilconv-crop_11th_dconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv-crop_12th_dconv (Crop (None, 5600, 300)    0           4_dilconv-crop_11th_dconv[0][0]
# __________________________________________________________________________________________________
# 5_dilconv-crop_12th_dconv (Crop (None, 5600, 300)    0           5_dilconv-crop_11th_dconv[0][0]
# __________________________________________________________________________________________________
# 6_dilconv-crop_12th_dconv (Crop (None, 5600, 300)    0           6_dilconv-crop_11th_dconv[0][0]
# __________________________________________________________________________________________________
# 7_dilconv-crop_12th_dconv (Crop (None, 5600, 300)    0           7_dilconv-crop_11th_dconv[0][0]
# __________________________________________________________________________________________________
# 8_dilconv-crop_12th_dconv (Crop (None, 5600, 300)    0           8_dilconv-crop_11th_dconv[0][0]
# __________________________________________________________________________________________________
# 9_dilconv-crop_12th_dconv (Crop (None, 5600, 300)    0           9_dilconv-crop_11th_dconv[0][0]
# __________________________________________________________________________________________________
# 10_dilconv-crop_12th_dconv (Cro (None, 5600, 300)    0           10_dilconv[0][0]
# __________________________________________________________________________________________________
# 11_dilconv (Conv1D)             (None, 5600, 300)    270300      add_12[0][0]
# __________________________________________________________________________________________________
# combined_conv (Add)             (None, 5600, 300)    0           1stconv-crop_12th_dconv[0][0]
#                                                                  0_dilconv-crop_12th_dconv[0][0]
#                                                                  1_dilconv-crop_12th_dconv[0][0]
#                                                                  2_dilconv-crop_12th_dconv[0][0]
#                                                                  3_dilconv-crop_12th_dconv[0][0]
#                                                                  4_dilconv-crop_12th_dconv[0][0]
#                                                                  5_dilconv-crop_12th_dconv[0][0]
#                                                                  6_dilconv-crop_12th_dconv[0][0]
#                                                                  7_dilconv-crop_12th_dconv[0][0]
#                                                                  8_dilconv-crop_12th_dconv[0][0]
#                                                                  9_dilconv-crop_12th_dconv[0][0]
#                                                                  10_dilconv-crop_12th_dconv[0][0]
#                                                                  11_dilconv[0][0]
# __________________________________________________________________________________________________
# profile_out_prebias (Conv1D)    (None, 5526, 2)      45002       combined_conv[0][0]
# __________________________________________________________________________________________________
# prof_out_crop2match_output (Cro (None, 5000, 2)      0           profile_out_prebias[0][0]
# __________________________________________________________________________________________________
# control_profile (InputLayer)    [(None, 5000, 2)]    0
# __________________________________________________________________________________________________
# gap (GlobalAveragePooling1D)    (None, 300)          0           combined_conv[0][0]
# __________________________________________________________________________________________________
# control_logcount (InputLayer)   [(None, 2)]          0
# __________________________________________________________________________________________________
# concat_with_bias_prof (Concaten (None, 5000, 4)      0           prof_out_crop2match_output[0][0]
#                                                                  control_profile[0][0]
# __________________________________________________________________________________________________
# concat_with_bias_cnts (Concaten (None, 302)          0           gap[0][0]
#                                                                  control_logcount[0][0]
# __________________________________________________________________________________________________
# profile_predictions (Conv1D)    (None, 5000, 2)      10          concat_with_bias_prof[0][0]
# __________________________________________________________________________________________________
# logcount_predictions (Dense)    (None, 2)            606         concat_with_bias_cnts[0][0]
# ==================================================================================================
# Total params: 3,314,718
# Trainable params: 3,314,718
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import shap
from deeplift.dinuc_shuffle import dinuc_shuffle

def combine_mult_and_diffref(mult, orig_inp, bg_data):
    to_return = []
    for l in [0]:
        projected_hypothetical_contribs = np.zeros_like(bg_data[l]).astype("float")
        assert len(orig_inp[l].shape)==2
        for i in range(orig_inp[l].shape[-1]):
            hypothetical_input = np.zeros_like(orig_inp[l]).astype("float")
            hypothetical_input[:,i] = 1.0
            hypothetical_difference_from_reference = (hypothetical_input[None,:,:]-bg_data[l])
            hypothetical_contribs = hypothetical_difference_from_reference*mult[l]
            projected_hypothetical_contribs[:,:,i] = np.sum(hypothetical_contribs,axis=-1) 
        to_return.append(np.mean(projected_hypothetical_contribs,axis=0))
    to_return.append(np.zeros_like(orig_inp[1]))
    return to_return

def shuffle_several_times(s):
    numshuffles=20
    return [np.array([dinuc_shuffle(s[0]) for i in range(numshuffles)]),
            np.array([s[1] for i in range(numshuffles)])]

tf_counts_explainer = shap.explainers.deep.TFDeepExplainer(
    ([tf_model.input[0], tf_model.input[1]],
     tf.reduce_sum(tf_model.outputs[0],axis=-1)),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)

meannormed_logits = (
    tf_model.outputs[1]-
    tf.reduce_mean(tf_model.outputs[1],axis=1)[:,None,:])
stopgrad_meannormed_logits = tf.stop_gradient(meannormed_logits)
softmax_out = tf.nn.softmax(stopgrad_meannormed_logits,axis=1)
weightedsum_meannormed_logits = tf.reduce_sum(softmax_out*meannormed_logits,
                                              axis=(1,2))
tf_profile_explainer = shap.explainers.deep.TFDeepExplainer(
    ([tf_model.input[0], tf_model.input[2]],
     weightedsum_meannormed_logits),
    shuffle_several_times,
    combine_mult_and_diffref=combine_mult_and_diffref)
# Out:
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  StopGradient used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients

# %%
#Histone chip 
histone_wrapper=([histone_model.input[0],histone_model.input[2]],histone_model.outputs[1][:,0:1])
histone_count_explainer=shap.DeepExplainer(histone_wrapper,
                                     data=create_background_counts_chip,
                                     combine_mult_and_diffref=combine_mult_and_diffref_chip)
histone_prof_explainer=create_explainer(histone_model,ischip=True,task_index=0)
# Out:
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  StopGradient used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients

# %%
#DNASE
dnase_wrapper=(dnase_model.input,dnase_model.outputs[1][:,0:1])
dnase_count_explainer=shap.DeepExplainer(dnase_wrapper,
                                        data=create_background_atac,
                                        combine_mult_and_diffref=combine_mult_and_diffref_atac)
dnase_prof_explainer=create_explainer(dnase_model,ischip=False,task_index=0)
# Out:
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  StopGradient used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  AddV2 used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  SpaceToBatchND used in model but handling of op is not specified by shap; will use original  gradients
# Warning:  BatchToSpaceND used in model but handling of op is not specified by shap; will use original  gradients

# %%
## source signal tracks 
import pyBigWig
#DNASE 
dnase_bw=pyBigWig.open("/oak/stanford/groups/akundaje/projects/atlas/dnase_processed/dnase/13da5ebe-0941-4855-8599-40bbcc5c58b4/call-bowtie2/shard-0/execution/ENCSR000EMT.merged.bam.bpnet.unstranded.bw",'r')

#SPI1 TF 
tf_pos=pyBigWig.open("/srv/scratch/annashch/chrombpnet/gm12878_tf_dnase_histone/spi1_tf/pos_strand.bw")
tf_neg=pyBigWig.open("/srv/scratch/annashch/chrombpnet/gm12878_tf_dnase_histone/spi1_tf/neg_strand.bw")
tf_control_pos=pyBigWig.open("/srv/scratch/annashch/chrombpnet/gm12878_tf_dnase_histone/spi1_tf/control_neg_strand.bw")
tf_control_neg=pyBigWig.open("/srv/scratch/annashch/chrombpnet/gm12878_tf_dnase_histone/spi1_tf/control_pos_strand.bw")

#H3K27AC 
chip_pos=pyBigWig.open("/srv/scratch/annashch/chrombpnet/gm12878_tf_dnase_histone/h3k27ac/K562.merged.ENCSR000APK.gz.bam.bpnet.plus.bw")
chip_neg=pyBigWig.open("/srv/scratch/annashch/chrombpnet/gm12878_tf_dnase_histone/h3k27ac/K562.merged.ENCSR000APK.gz.bam.bpnet.minus.bw")
chip_control_pos=pyBigWig.open("/srv/scratch/annashch/chrombpnet/gm12878_tf_dnase_histone/h3k27ac/K562.merged.control.ENCSR000AKY.gz.bam.bpnet.plus.bw")
chip_control_neg=pyBigWig.open("/srv/scratch/annashch/chrombpnet/gm12878_tf_dnase_histone/h3k27ac/K562.merged.control.ENCSR000AKY.gz.bam.bpnet.minus.bw")

# %%
#USE HG38 
regions=pd.read_csv("bQTL.for.ism.csv",header=0,sep='\t')
#regions=pd.read_csv("bQTL.intersection.csv",header=0,sep='\t')
regions
# Out:
#     Chrom   hg19pos0   hg38pos0 Major Minor       Group           Rsid
# 0   chr14   22590585   22122627     T     A  StrongbQTL     rs11157420
# 1   chr22   44116809   43720929     C     G  StrongbQTL      rs5764238
# 2    chr4   37814568   37812946     C     T  StrongbQTL    rs116009584
# 3    chr7  157313211  157520517     A     G  StrongbQTL      rs4716753
# 4    chr8   25242971   25385455     T     C  StrongbQTL       rs925032
# 5    chr1   64029605   63563934     G     A  StrongbQTL       rs217474
# 6    chr7  100230863  100633240     G     C  StrongbQTL     rs34242818
# 7    chr1  144534082  149162899     T     C  StrongbQTL  rs1184471061
# 8    chr6   26660654   26660426     G     C  StrongbQTL      rs2451713
# 9   chr15   52536308   52244111     G     A          Av      rs4774616
# 10   chr1   21754995   21428502     T     C          Av     rs12024079
# 11   chr2  216195280  215330557     G     A          Av      rs1983462
# 12   chr3   94265356   94546512     A     G          Av     rs60436144
# 13  chr11   60240729   60473256     A     C          Av     rs11230337

# %%
def get_preds(model,inputs):
    preds=model.predict(inputs)
    prof=np.squeeze(preds[0])
    probs=softmax(prof,axis=0)
    count=np.squeeze(preds[1])  
    count_track=probs*np.exp(count) 
    return prof,count,probs,count_track

# %%
def analyze_dnase(ref,
            chrom,
            summit,
            ref_allele,
            alt_allele,
            rsid,
            model,
            count_explainer,
            prof_explainer,
            flank=1057,
            output_bp=1000,
            bigwig_unstranded=None):
    #get the reference and alternate one-hot-encoded sequences 
    seq=ref.fetch(chrom,summit-flank,summit+flank)
    
    ref_seq=seq[0:flank]+ref_allele+seq[flank+1::]
    assert len(ref_seq)==2*flank
    ref_onehot=one_hot_encode([ref_seq])
    
    alt_seq=seq[0:flank]+alt_allele+seq[flank+1::]
    assert len(alt_seq)==2*flank
    alt_onehot=one_hot_encode([alt_seq])
    
    #get the bigwig labels 
    labels_unstranded=np.nan_to_num(bigwig_unstranded.values(chrom,summit-flank,summit+flank))
    model_input_ref=ref_onehot
    model_input_alt=alt_onehot
    #get predictions for reference & alternate allele 
    prof_ref,count_ref,probs_ref,count_track_ref=get_preds(model,model_input_ref)
    prof_alt,count_alt,probs_alt,count_track_alt=get_preds(model,model_input_alt)

        
    #get the log odds blast radius track 
    blast_radius_track=np.log(probs_ref)-np.log(probs_alt)
    blast_radius_count_track=np.log2(count_track_ref)-np.log2(count_track_alt)
    #get deepSHAP scores for ref & alt alleles     
    profile_explanations_ref=prof_explainer(ref_onehot,None)*ref_onehot
    count_explanations_ref=np.squeeze(count_explainer.shap_values(ref_onehot)[0])*ref_onehot 

    profile_explanations_alt=prof_explainer(alt_onehot,None)*alt_onehot
    count_explanations_alt=np.squeeze(count_explainer.shap_values(alt_onehot)[0])*alt_onehot  
    
    #look at dimensions of size 1000 
    offset=int((2*flank-output_bp)/2)
    labels_unstranded=labels_unstranded[offset:offset+output_bp]
    profile_explanations_ref=np.squeeze(profile_explanations_ref)[offset:offset+output_bp,:]
    profile_explanations_alt=np.squeeze(profile_explanations_alt)[offset:offset+output_bp,:]
    count_explanations_ref=np.squeeze(count_explanations_ref)[offset:offset+output_bp,:]
    count_explanations_alt=np.squeeze(count_explanations_alt)[offset:offset+output_bp,:]
    
    
    return labels_unstranded,count_track_ref,count_track_alt,blast_radius_track, blast_radius_count_track, profile_explanations_ref,count_explanations_ref, profile_explanations_alt, count_explanations_alt

# %%
def analyze_histone(ref,
            chrom,
            summit,
            ref_allele,
            alt_allele,
            rsid,
            model,
            count_explainer,
            prof_explainer,
            bigwig_plus,
            bigwig_minus,
            control_plus,
            control_minus,
            flank=11000,
            output_bp=1000):
    #get the reference and alternate one-hot-encoded sequences 
    seq=ref.fetch(chrom,summit-flank,summit+flank)
    
    ref_seq=seq[0:flank]+ref_allele+seq[flank+1::]
    assert len(ref_seq)==2*flank
    ref_onehot=one_hot_encode([ref_seq])
    
    alt_seq=seq[0:flank]+alt_allele+seq[flank+1::]
    assert len(alt_seq)==2*flank
    alt_onehot=one_hot_encode([alt_seq])
    
    #stranded inputs mean we are using chipseq
    labels_plus=np.nan_to_num(bigwig_plus.values(chrom,summit-flank,summit+flank))
    labels_minus=np.nan_to_num(bigwig_minus.values(chrom,summit-flank,summit+flank))
    control_labels_plus=np.expand_dims(np.nan_to_num(control_plus.values(chrom,summit-2500,summit+2500)),axis=1)
    control_labels_minus=np.expand_dims(np.nan_to_num(control_minus.values(chrom,summit-2500,summit+2500)),axis=1)
    control_input_profile=np.expand_dims(np.concatenate((control_labels_plus,control_labels_minus),axis=-1),axis=0)
    #print("histone_control_input_profile"+str(control_input_profile.shape))
    control_count_plus=np.expand_dims(np.expand_dims(np.array(np.log(np.sum(control_labels_plus))),axis=0),axis=1)
    control_count_minus=np.expand_dims(np.expand_dims(np.array(np.log(np.sum(control_labels_minus))),axis=0),axis=1)    
    control_input_count=np.concatenate((control_count_plus,control_count_minus),axis=-1)
    #print("histone_control_input_count:"+str(control_input_count.shape))
    
    model_input_ref=[ref_onehot, control_input_profile, control_input_count]
    model_input_alt=[alt_onehot, control_input_profile, control_input_count]
        
    #get predictions for reference & alternate allele 
    prof_ref,count_ref,probs_ref,count_track_ref=get_preds(model,model_input_ref)
    prof_alt,count_alt,probs_alt,count_track_alt=get_preds(model,model_input_alt)

    #get the log odds blast radius track 
    blast_radius_track_plus=np.log(probs_ref[:,0])-np.log(probs_alt[:,0])
    blast_radius_track_minus=np.log(probs_ref[:,1])-np.log(probs_alt[:,1])
    blast_radius_counts_track_plus=np.log2(count_track_ref[:,0])-np.log2(count_track_alt[:,0])
    blast_radius_counts_track_minus=np.log2(count_track_ref[:,1])-np.log2(count_track_alt[:,1])
    

    #get deepSHAP scores for ref & alt alleles 
    count_explanations_ref=count_explainer.shap_values([ref_onehot,control_input_count])[0][0]*ref_onehot
    profile_explanations_ref=prof_explainer(ref_onehot,control_input_profile)[0]*ref_onehot
    
    count_explanations_alt=count_explainer.shap_values([alt_onehot,control_input_count])[0][0]*alt_onehot
    profile_explanations_alt=prof_explainer(alt_onehot,control_input_profile)[0]*alt_onehot
    
        
    #look at dimensions of size 5000 (we will also truncate to a 1kb region during the plotting phase) 
    labels_plus=labels_plus[8500:13500]
    labels_minus=labels_minus[8500:13500]
    
    profile_explanations_ref=np.squeeze(profile_explanations_ref)[10500:11500,:]
    profile_explanations_alt=np.squeeze(profile_explanations_alt)[10500:11500,:]

    count_explanations_ref=np.squeeze(count_explanations_ref)[10500:11500,:]
    count_explanations_alt=np.squeeze(count_explanations_alt)[10500:11500,:]
    
    #return outputs 
    return labels_plus,labels_minus,count_track_ref,count_track_alt,blast_radius_track_plus,blast_radius_track_minus,blast_radius_counts_track_plus, blast_radius_counts_track_minus, profile_explanations_ref,count_explanations_ref, profile_explanations_alt, count_explanations_alt

# %%
def rolling_window(a, window):
    shape = a.shape[:-1] + (a.shape[-1] - window + 1, window)
    strides = a.strides + (a.strides[-1],)
    return np.lib.stride_tricks.as_strided(a, shape=shape, strides=strides)

def smooth_profiles(profiles, smoothing_window):
    assert len(profiles.shape)==3
    leftpadlen = int((smoothing_window-1)/2)
    rightpadlen =\
        (smoothing_window-1)-int((smoothing_window-1)/2)
    padded_profiles = np.pad(
        array=profiles,
        pad_width=((0,0),(leftpadlen, rightpadlen), (0,0)),
        mode='edge')
    smoothed_profiles = np.mean(rolling_window(
                        a=padded_profiles.transpose(0,2,1),
                        window=smoothing_window), axis=-1).transpose((0,2,1))
    return smoothed_profiles

def get_preds_tf(model,inputs):
    preds=model.predict(inputs)
    prof=np.squeeze(preds[1])
    probs=softmax(prof,axis=0)
    count=np.squeeze(preds[0])  
    count_track=probs*np.exp(count)
    return prof,count,probs,count_track

def analyze_tf(ref,
            chrom,
            summit,
            ref_allele,
            alt_allele,
            rsid,
            model,
            count_explainer,
            prof_explainer,
            bigwig_plus,
            bigwig_minus,
            control_plus,
            control_minus,
            flank=1057,
            output_bp=1000):
    #get the reference and alternate one-hot-encoded sequences 
    seq=ref.fetch(chrom,summit-flank,summit+flank)
    
    ref_seq=seq[0:flank]+ref_allele+seq[flank+1::]
    assert len(ref_seq)==2*flank
    ref_onehot=one_hot_encode([ref_seq])
    
    alt_seq=seq[0:flank]+alt_allele+seq[flank+1::]
    assert len(alt_seq)==2*flank
    alt_onehot=one_hot_encode([alt_seq])
    
    #stranded inputs mean we are using chipseq
    labels_plus=np.nan_to_num(bigwig_plus.values(chrom,summit-flank,summit+flank))
    labels_minus=np.nan_to_num(bigwig_minus.values(chrom,summit-flank,summit+flank))
    control_labels_plus=np.nan_to_num(control_plus.values(chrom,summit-int(output_bp/2),summit+int(output_bp/2)))
    control_labels_minus=np.nan_to_num(control_minus.values(chrom,summit-int(output_bp/2),summit+int(output_bp/2)))
    control_labels=np.expand_dims(np.expand_dims(control_labels_plus+control_labels_minus,axis=0),axis=2)
    control_input_profile=np.concatenate((control_labels,smooth_profiles(profiles=control_labels,smoothing_window=50)),axis=2)    
    control_input_count=np.expand_dims(np.expand_dims(np.array(np.log(np.sum(control_labels_plus)+np.sum(control_labels_minus)+1)),axis=0),axis=1)
    model_input_ref=[ref_onehot, control_input_count, control_input_profile]
    model_input_alt=[alt_onehot, control_input_count, control_input_profile]
        
    #get predictions for reference & alternate allele     
    prof_ref,count_ref,probs_ref,count_track_ref=get_preds_tf(model,model_input_ref)
    prof_alt,count_alt,probs_alt,count_track_alt=get_preds_tf(model,model_input_alt)
  
    #get the log odds blast radius track 
    blast_radius_track_plus=np.log(probs_ref[:,0])-np.log(probs_alt[:,0])
    blast_radius_track_minus=np.log(probs_ref[:,1])-np.log(probs_alt[:,1])
    blast_radius_counts_track_plus=np.log2(count_track_ref[:,0])-np.log2(count_track_alt[:,0])
    blast_radius_counts_track_minus=np.log2(count_track_ref[:,1])-np.log2(count_track_alt[:,1])
    
    #get deepSHAP scores for ref & alt alleles 
    count_explanations_ref=count_explainer.shap_values([ref_onehot,control_input_count])[0]*ref_onehot
    profile_explanations_ref=prof_explainer.shap_values([ref_onehot,control_input_profile])[0]*ref_onehot
    
    count_explanations_alt=count_explainer.shap_values([alt_onehot,control_input_count])[0]*alt_onehot
    profile_explanations_alt=prof_explainer.shap_values([alt_onehot,control_input_profile])[0]*alt_onehot
    
    #look at dimensions of size 1000 
    offset=int((2*flank-output_bp)/2)
    labels_plus=labels_plus[offset:offset+output_bp]
    labels_minus=labels_minus[offset:offset+output_bp]
    profile_explanations_ref=np.squeeze(profile_explanations_ref)[offset:offset+output_bp,:]
    profile_explanations_alt=np.squeeze(profile_explanations_alt)[offset:offset+output_bp,:]
    count_explanations_ref=np.squeeze(count_explanations_ref)[offset:offset+output_bp,:]
    count_explanations_alt=np.squeeze(count_explanations_alt)[offset:offset+output_bp,:]
        
    #return outputs 
    return labels_plus,labels_minus,count_track_ref,count_track_alt,blast_radius_track_plus,blast_radius_track_minus,blast_radius_counts_track_plus, blast_radius_counts_track_minus,profile_explanations_ref,count_explanations_ref, profile_explanations_alt, count_explanations_alt

# %%
from scipy.special import softmax 
def make_plot(dnase_labels_unstranded,
              dnase_count_track_ref,
              dnase_count_track_alt,
              dnase_blast_radius_track,
              dnase_blat_radius_counts_track,
              dnase_profile_explanations_ref, 
              dnase_count_explanations_ref, 
              dnase_profile_explanations_alt, 
              dnase_count_explanations_alt,
              tf_labels_plus,
              tf_labels_minus,
              tf_count_track_ref,
              tf_count_track_alt,
              tf_blast_radius_track_plus,
              tf_blast_radius_track_minus,
              tf_blast_radius_counts_track_plus,
              tf_blast_radius_counts_track_minus,
              tf_profile_explanations_ref,
              tf_count_explanations_ref, 
              tf_profile_explanations_alt, 
              tf_count_explanations_alt,
              histone_labels_plus,
              histone_labels_minus, 
              histone_count_track_ref, 
              histone_count_track_alt, 
              histone_blast_radius_track_plus, 
              histone_blast_radius_track_minus, 
              histone_blast_radius_counts_track_plus,
              histone_blast_radius_counts_track_minus,
              histone_profile_explanations_ref,
              histone_count_explanations_ref, 
              histone_profile_explanations_alt, 
              histone_count_explanations_alt,
              title,
              xmin=0,
              xmax=1000): 
    plt.rcParams["figure.figsize"]=45,35
    f,axes=plt.subplots(8, 4,gridspec_kw={
                           'width_ratios': [1, 1, 1, 1],
                           'height_ratios': [1, 2, 1,1, 1, 1, 1,1]})
    #labels count track 
    axes[0,0].plot(dnase_labels_unstranded)  
    axes[0,0].set_title("DNASE labels",fontsize=20)
    axes[0,1].plot(tf_labels_plus)
    axes[0,1].plot(tf_labels_minus*-1)
    axes[0,1].set_title("SPI1 TF Chip-seq labels",fontsize=20)
    axes[0,2].plot(histone_labels_plus[2000:3000])
    axes[0,2].plot(histone_labels_minus[2000:3000]*-1)
    axes[0,2].set_title("H3K27ac Chip-seq labels",fontsize=20)
    axes[0,3].plot(histone_labels_plus)
    axes[0,3].plot(histone_labels_minus*-1)
    axes[0,3].set_title("H3K27ac Chip-seq labels",fontsize=20)
    
    #ref vs alt preds 
    axes[1,0].plot(dnase_count_track_ref,linewidth=0.25,label='ref',color='b')
    axes[1,0].plot(dnase_count_track_alt,linewidth=0.25,label='alt',color='r')    
    axes[1,0].set_title("DNASE Predicted Count Track (Ref vs Alt)",fontsize=20)
    axes[1,0].legend()
    axes[1,1].plot(tf_count_track_ref[:,0],linewidth=0.25,label='ref',color='b')
    axes[1,1].plot(tf_count_track_ref[:,1]*-1,linewidth=0.25,label='ref',color='b')
    axes[1,1].plot(tf_count_track_alt[:,0],linewidth=0.25,label='alt',color='r')
    axes[1,1].plot(tf_count_track_alt[:,1]*-1,linewidth=0.25,label='alt',color='r')
    axes[1,1].set_title("SPI1 TF Predicted Count Track (Ref vs Alt)",fontsize=20)    
    axes[1,2].plot(histone_count_track_ref[:,0][2000:3000],linewidth=0.25,label='ref',color='b')
    axes[1,2].plot(histone_count_track_ref[:,1][2000:3000]*-1,linewidth=0.25,label='ref',color='b')
    axes[1,2].plot(histone_count_track_alt[:,0][2000:3000],linewidth=0.25,label='alt',color='r')
    axes[1,2].plot(histone_count_track_alt[:,1][2000:3000]*-1,linewidth=0.25,label='alt',color='r')
    axes[1,2].set_title("H3K27ac Predicted Count Track (Ref vs Alt)",fontsize=20)    
    axes[1,3].plot(histone_count_track_ref[:,0],linewidth=0.25,label='ref',color='b')
    axes[1,3].plot(histone_count_track_ref[:,1]*-1,linewidth=0.25,label='ref',color='b')
    axes[1,3].plot(histone_count_track_alt[:,0],linewidth=0.25,label='alt',color='r')
    axes[1,3].plot(histone_count_track_alt[:,1]*-1,linewidth=0.25,label='alt',color='r')
    axes[1,3].set_title("H3K27ac Predicted Count Track (Ref vs Alt)",fontsize=20)
  
    #log2 counts per base ref - log2 counts per base alt 
    axes[2,0].plot(dnase_blast_radius_counts_track)
    axes[2,0].set_title("DNASE Counts Blast Radius log2(base counts(ref))-log2(base counts(alt))",fontsize=20)
    axes[2,1].plot(tf_blast_radius_counts_track_plus)
    axes[2,1].plot(tf_blast_radius_counts_track_minus)
    axes[2,1].set_title("SPI1 TF Counts Blast Radius",fontsize=20)
    axes[2,2].plot(histone_blast_radius_counts_track_plus[2000:3000])
    axes[2,2].plot(histone_blast_radius_counts_track_minus[2000:3000])
    axes[2,2].set_title("H3K27ac Counts Blast Radius",fontsize=20)
    axes[2,3].plot(histone_blast_radius_counts_track_plus)
    axes[2,3].plot(histone_blast_radius_counts_track_minus)
    axes[2,3].set_title("H3K27ac Counts Blast Radius",fontsize=20)
    
    # Blast radius 
    axes[3,0].plot(dnase_blast_radius_track)
    axes[3,0].set_title("DNASE Blast Radius log(prob(ref))-log(prob(alt))",fontsize=20)
    axes[3,1].plot(tf_blast_radius_track_plus)
    axes[3,1].plot(tf_blast_radius_track_minus)
    axes[3,1].set_title("SPI1 TF Blast Radius",fontsize=20)
    axes[3,2].plot(histone_blast_radius_track_plus[2000:3000])
    axes[3,2].plot(histone_blast_radius_track_minus[2000:3000])
    axes[3,2].set_title("H3K27ac Blast Radius",fontsize=20)
    axes[3,3].plot(histone_blast_radius_track_plus)
    axes[3,3].plot(histone_blast_radius_track_minus)
    axes[3,3].set_title("H3K27ac Blast Radius",fontsize=20)
    
    #DeepSHAP Profile Ref 
    axes[4,0]=plot_bases_on_ax(dnase_profile_explanations_ref[400:600],axes[4,0],show_ticks=False)
    axes[4,0].set_title("DNASE Ref Prof SHAP",fontsize=20)
    axes[4,1]=plot_bases_on_ax(tf_profile_explanations_ref[400:600],axes[4,1],show_ticks=False)
    axes[4,1].set_title("TF Ref Prof SHAP",fontsize=20)
    axes[4,2]=plot_bases_on_ax(histone_profile_explanations_ref[400:600],axes[4,2],show_ticks=False)
    axes[4,2].set_title("H3K27ac Ref Prof SHAP",fontsize=20)
    axes[4,3]=plot_bases_on_ax(histone_profile_explanations_ref[400:600],axes[4,3],show_ticks=False)
    axes[4,3].set_title("H3K27ac Ref Prof SHAP",fontsize=20)
    
    #DeepSHAP Profile Alt 
    axes[5,0]=plot_bases_on_ax(dnase_profile_explanations_alt[400:600],axes[5,0],show_ticks=False)
    axes[5,0].set_title("DNASE Alt Prof SHAP",fontsize=20)
    axes[5,1]=plot_bases_on_ax(tf_profile_explanations_alt[400:600],axes[5,1],show_ticks=False)
    axes[5,1].set_title("TF Alt Prof SHAP",fontsize=20)
    axes[5,2]=plot_bases_on_ax(histone_profile_explanations_alt[400:600],axes[5,2],show_ticks=False)
    axes[5,2].set_title("H3K27ac Alt Prof SHAP",fontsize=20)  
    axes[5,3]=plot_bases_on_ax(histone_profile_explanations_alt[400:600],axes[5,3],show_ticks=False)
    axes[5,3].set_title("H3K27ac Alt Prof SHAP",fontsize=20)  
        
    #DeepSHAP Count Ref
    axes[6,0]=plot_bases_on_ax(dnase_count_explanations_ref[400:600],axes[6,0],show_ticks=False)
    axes[6,0].set_title("DNASE Ref Count SHAP",fontsize=20)
    axes[6,1]=plot_bases_on_ax(tf_count_explanations_ref[400:600],axes[6,1],show_ticks=False)
    axes[6,1].set_title("TF Ref Count SHAP",fontsize=20)
    axes[6,2]=plot_bases_on_ax(histone_count_explanations_ref[400:600],axes[6,2],show_ticks=False)
    axes[6,2].set_title("H3K27ac Ref Count SHAP",fontsize=20)  
    axes[6,3]=plot_bases_on_ax(histone_count_explanations_ref[400:600],axes[6,3],show_ticks=False)
    axes[6,3].set_title("H3K27ac Ref Count SHAP",fontsize=20)  
    
    #DeepSHAP Count Alt 
    axes[7,0]=plot_bases_on_ax(dnase_count_explanations_alt[400:600],axes[7,0],show_ticks=False)
    axes[7,0].set_title("DNASE Alt Count SHAP",fontsize=20)
    axes[7,1]=plot_bases_on_ax(tf_count_explanations_alt[400:600],axes[7,1],show_ticks=False)
    axes[7,1].set_title("TF Alt Count SHAP",fontsize=20)
    axes[7,2]=plot_bases_on_ax(histone_count_explanations_alt[400:600],axes[7,2],show_ticks=False)
    axes[7,2].set_title("H3K27ac Alt Count SHAP",fontsize=20)  
    axes[7,3]=plot_bases_on_ax(histone_count_explanations_alt[400:600],axes[7,3],show_ticks=False)
    axes[7,3].set_title("H3K27ac Alt Count SHAP",fontsize=20)  
    

    #set ylim for deepSHAP 
    dnase_profile_shap_min=min([np.min(dnase_profile_explanations_ref),
           np.min(dnase_profile_explanations_alt)])
    dnase_count_shap_min=min([np.min(dnase_count_explanations_ref),
           np.min(dnase_count_explanations_alt)])

    dnase_profile_shap_max=max([np.max(dnase_profile_explanations_ref),
           np.max(dnase_profile_explanations_alt)])
    dnase_count_shap_max=max([np.max(dnase_count_explanations_ref),
           np.max(dnase_count_explanations_alt)])
    
    axes[4,0].set_ylim(dnase_profile_shap_min,dnase_profile_shap_max)
    axes[5,0].set_ylim(dnase_profile_shap_min,dnase_profile_shap_max)
    axes[6,0].set_ylim(dnase_count_shap_min,dnase_count_shap_max)
    axes[7,0].set_ylim(dnase_count_shap_min,dnase_count_shap_max)

    tf_profile_shap_min=min([np.min(tf_profile_explanations_ref),
           np.min(tf_profile_explanations_alt)])
    tf_count_shap_min=min([np.min(tf_count_explanations_ref),
           np.min(tf_count_explanations_alt)])
    
    tf_profile_shap_max=max([np.max(tf_profile_explanations_ref),
           np.max(tf_profile_explanations_alt)])
    tf_count_shap_max=max([np.max(tf_count_explanations_ref),
           np.max(tf_count_explanations_alt)])
    axes[4,1].set_ylim(tf_profile_shap_min,tf_profile_shap_max)
    axes[5,1].set_ylim(tf_profile_shap_min,tf_profile_shap_max)
    axes[6,1].set_ylim(tf_count_shap_min,tf_count_shap_max)
    axes[7,1].set_ylim(tf_count_shap_min,tf_count_shap_max)
    
    histone_profile_shap_min=min([np.min(histone_profile_explanations_ref),
           np.min(histone_profile_explanations_alt)])
    histone_count_shap_min=max([np.min(histone_count_explanations_ref),
           np.min(histone_count_explanations_alt)])
    
    histone_profile_shap_max=max([np.max(histone_profile_explanations_ref),
           np.max(histone_profile_explanations_alt)])
    histone_count_shap_max=max([np.max(histone_count_explanations_ref),
           np.max(histone_count_explanations_alt)])

    axes[4,2].set_ylim(histone_profile_shap_min,histone_profile_shap_max)
    axes[5,2].set_ylim(histone_profile_shap_min,histone_profile_shap_max)
    axes[6,2].set_ylim(histone_count_shap_min,histone_count_shap_max)
    axes[7,2].set_ylim(histone_count_shap_min,histone_count_shap_max)     
    axes[4,3].set_ylim(histone_profile_shap_min,histone_profile_shap_max)
    axes[5,3].set_ylim(histone_profile_shap_min,histone_profile_shap_max)
    axes[6,3].set_ylim(histone_count_shap_min,histone_count_shap_max)
    axes[7,3].set_ylim(histone_count_shap_min,histone_count_shap_max) 
    
    plt.suptitle(title,fontsize=20)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.savefig(title.replace('/',':')+'.pdf',format='pdf',dpi=300)

# %%
import pdb
for index,row in regions.iterrows(): 
    chrom=row['Chrom']
    summit=row['hg38pos0']
    ref_allele=row['Major']
    alt_allele=row['Minor']
    rsid=row['Rsid']
    print(index)
    
    #DNASE 
    dnase_labels_unstranded,dnase_count_track_ref,dnase_count_track_alt,dnase_blast_radius_track, dnase_blast_radius_counts_track,dnase_profile_explanations_ref, dnase_count_explanations_ref, dnase_profile_explanations_alt, dnase_count_explanations_alt=analyze_dnase(ref=ref,
            chrom=chrom,
            summit=summit,
            ref_allele=ref_allele,
            alt_allele=alt_allele,
            rsid=rsid,
            bigwig_unstranded=dnase_bw,
            model=dnase_model,
            count_explainer=dnase_count_explainer,
            prof_explainer=dnase_prof_explainer,
            flank=1057)
    
    #TF CHIP SEQ 
    tf_labels_plus,tf_labels_minus,tf_count_track_ref,tf_count_track_alt,tf_blast_radius_track_plus,tf_blast_radius_track_minus, tf_blast_radius_counts_track_plus, tf_blast_radius_counts_track_minus,tf_profile_explanations_ref,tf_count_explanations_ref, tf_profile_explanations_alt, tf_count_explanations_alt=analyze_tf(ref=ref,
            chrom=chrom,
            summit=summit,
            ref_allele=ref_allele,
            alt_allele=alt_allele,
            rsid=rsid,
            bigwig_plus=tf_pos,
            bigwig_minus=tf_neg,
            control_plus=tf_control_pos,
            control_minus=tf_control_neg,
            count_explainer=tf_counts_explainer,
            prof_explainer=tf_profile_explainer,
            flank=1057,
            model=tf_model)
    
    #HISTONE CHIP SEQ 
    histone_labels_plus,histone_labels_minus, histone_count_track_ref, histone_count_track_alt, histone_blast_radius_track_plus, histone_blast_radius_track_minus, histone_blast_radius_counts_track_plus, histone_blast_radius_counts_track_minus, histone_profile_explanations_ref,histone_count_explanations_ref, histone_profile_explanations_alt, histone_count_explanations_alt=analyze_histone(ref=ref,
            chrom=chrom,
            summit=summit,
            ref_allele=ref_allele,
            alt_allele=alt_allele,
            rsid=rsid,
            bigwig_plus=chip_pos,
            bigwig_minus=chip_neg,
            control_plus=chip_control_pos,
            control_minus=chip_control_neg,
            count_explainer=histone_count_explainer,
            prof_explainer=histone_prof_explainer,
            flank=11000,
            model=histone_model)
 
    #make plot 
    make_plot(dnase_labels_unstranded,
              dnase_count_track_ref,
              dnase_count_track_alt,
              dnase_blast_radius_track,
              dnase_blast_radius_counts_track,
              dnase_profile_explanations_ref, 
              dnase_count_explanations_ref, 
              dnase_profile_explanations_alt, 
              dnase_count_explanations_alt,
              tf_labels_plus,
              tf_labels_minus,
              tf_count_track_ref,
              tf_count_track_alt,
              tf_blast_radius_track_plus,
              tf_blast_radius_track_minus,
              tf_blast_radius_counts_track_plus,
              tf_blast_radius_counts_track_minus,
              tf_profile_explanations_ref,
              tf_count_explanations_ref, 
              tf_profile_explanations_alt, 
              tf_count_explanations_alt,
              histone_labels_plus,
              histone_labels_minus, 
              histone_count_track_ref, 
              histone_count_track_alt, 
              histone_blast_radius_track_plus, 
              histone_blast_radius_track_minus, 
              histone_blast_radius_counts_track_plus,
              histone_blast_radius_counts_track_minus,
              histone_profile_explanations_ref,
              histone_count_explanations_ref, 
              histone_profile_explanations_alt, 
              histone_count_explanations_alt,
              rsid+":"+chrom+":"+str(summit)+":ref="+ref_allele+":alt="+alt_allele)
# Out:
# 0
# WARNING:tensorflow:From /users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_v1.py:2070: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted: OOM when allocating tensor with shape[320,1372,300] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node 3_dilconv_2/conv1d/SpaceToBatchND}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[gradients_4/concat_with_bias_cnts/concat_grad/Slice_1/_1833]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted: OOM when allocating tensor with shape[320,1372,300] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node 3_dilconv_2/conv1d/SpaceToBatchND}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored.
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-23-501cdf2f5b95> in <module>
#      51             prof_explainer=histone_prof_explainer,
#      52             flank=11000,
# ---> 53             model=histone_model)
#      54
#      55     #make plot
#
# <ipython-input-20-3f1cfa7ac1b0> in analyze_histone(ref, chrom, summit, ref_allele, alt_allele, rsid, model, count_explainer, prof_explainer, bigwig_plus, bigwig_minus, control_plus, control_minus, flank, output_bp)
#      52
#      53     #get deepSHAP scores for ref & alt alleles
# ---> 54     count_explanations_ref=count_explainer.shap_values([ref_onehot,control_input_count])[0][0]*ref_onehot
#      55     profile_explanations_ref=prof_explainer(ref_onehot,control_input_profile)[0]*ref_onehot
#      56
#
# ~/avshap/shap/explainers/deep/__init__.py in shap_values(self, X, ranked_outputs, output_rank_order, progress_message)
#     138         return self.explainer.shap_values(X, ranked_outputs,
#     139                                           output_rank_order,
# --> 140                                           progress_message=progress_message)
#
# ~/avshap/shap/explainers/deep/deep_tf.py in shap_values(self, X, ranked_outputs, output_rank_order, progress_message)
#     292                 # run attribution computation graph
#     293                 feature_ind = model_output_ranks[j,i]
# --> 294                 sample_phis = self.run(self.phi_symbolic(feature_ind), self.model_inputs, joint_input)
#     295
#     296                 #combine the multipliers with the difference from reference
#
# ~/avshap/shap/explainers/deep/deep_tf.py in run(self, out, model_inputs, X)
#     329             tensorflow.compat.v1.disable_v2_behavior()
#     330             self.session=get_session()
# --> 331         return self.session.run(out, feed_dict)
#     332
#     333     def custom_grad(self, op, *grads):
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     956     try:
#     957       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 958                          run_metadata_ptr)
#     959       if run_metadata:
#     960         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1179     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1180       results = self._do_run(handle, final_targets, final_fetches,
# -> 1181                              feed_dict_tensor, options, run_metadata)
#    1182     else:
#    1183       results = []
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1382                     '\nsession_config.graph_options.rewrite_options.'
#    1383                     'disable_meta_optimizer = True')
# -> 1384       raise type(e)(node_def, op, message)
#    1385
#    1386   def _extend_graph(self):
#
# ResourceExhaustedError: 2 root error(s) found.
#   (0) Resource exhausted: OOM when allocating tensor with shape[320,1372,300] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node 3_dilconv_2/conv1d/SpaceToBatchND (defined at <ipython-input-6-eede811557eb>:29) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 	 [[gradients_4/concat_with_bias_cnts/concat_grad/Slice_1/_1833]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
#   (1) Resource exhausted: OOM when allocating tensor with shape[320,1372,300] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node 3_dilconv_2/conv1d/SpaceToBatchND (defined at <ipython-input-6-eede811557eb>:29) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.
#
# 0 successful operations.
# 0 derived errors ignored.
#
# Original stack trace for '3_dilconv_2/conv1d/SpaceToBatchND':
#   File "/users/annashch/miniconda3/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/users/annashch/miniconda3/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/traitlets/config/application.py", line 664, in launch_instance
#     app.start()
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 583, in start
#     self.io_loop.start()
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 149, in start
#     self.asyncio_loop.run_forever()
#   File "/users/annashch/miniconda3/lib/python3.7/asyncio/base_events.py", line 538, in run_forever
#     self._run_once()
#   File "/users/annashch/miniconda3/lib/python3.7/asyncio/base_events.py", line 1782, in _run_once
#     handle._run()
#   File "/users/annashch/miniconda3/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tornado/gen.py", line 787, in inner
#     self.run()
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tornado/gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 545, in execute_request
#     user_expressions, allow_stdin,
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tornado/gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/ipykernel/ipkernel.py", line 300, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/ipykernel/zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2858, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2886, in _run_cell
#     return runner(coro)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3063, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3254, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-6-eede811557eb>", line 29, in <module>
#     histone_model=load_model("patience_6_5K_out_12_gm12878.h3k27ac.seed.2345.cs.25.filters.300.naive.range.4.6.to.11.5.0.hdf5")
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py", line 182, in load_model
#     return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/saving/hdf5_format.py", line 178, in load_model_from_hdf5
#     custom_objects=custom_objects)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/saving/model_config.py", line 55, in model_from_config
#     return deserialize(config, custom_objects=custom_objects)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/layers/serialization.py", line 175, in deserialize
#     printable_module_name='layer')
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/utils/generic_utils.py", line 358, in deserialize_keras_object
#     list(custom_objects.items())))
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py", line 2239, in from_config
#     config, custom_objects=custom_objects)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/functional.py", line 617, in from_config
#     config, custom_objects)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/functional.py", line 1214, in reconstruct_from_config
#     process_node(layer, node_data)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/functional.py", line 1162, in process_node
#     output_tensors = layer(input_tensors, **kwargs)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer_v1.py", line 776, in __call__
#     outputs = call_fn(cast_inputs, *args, **kwargs)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/layers/convolutional.py", line 247, in call
#     outputs = self._convolution_op(inputs, self.kernel)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py", line 201, in wrapper
#     return target(*args, **kwargs)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py", line 1017, in convolution_v2
#     name=name)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py", line 1165, in convolution_internal
#     return op(input, filters)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py", line 1324, in __call__
#     return self.conv_op(inp, filter)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py", line 742, in __call__
#     return self.call(inp, filter)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/nn_ops.py", line 725, in _with_space_to_batch_call
#     input=inp, block_shape=dilation_rate, paddings=paddings)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py", line 9661, in space_to_batch_nd
#     paddings=paddings, name=name)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py", line 744, in _apply_op_helper
#     attrs=attr_protos, op_def=op_def)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/ops.py", line 3485, in _create_op_internal
#     op_def=op_def)
#   File "/users/annashch/miniconda3/lib/python3.7/site-packages/tensorflow/python/framework/ops.py", line 1949, in __init__
#     self._traceback = tf_stack.extract_stack()
