# %% [markdown]
# ### Get uncorrected bigwigs

# %%
import pyBigWig
import pandas as pd
import numpy as np

uncorrected_bigwig = "/srv/scratch/anusri/chrombpnet_paper/GM12878/data/shifted_4_4.sorted.bam.bpnet.unstranded.bw"

uncorretced_bw = pyBigWig.open(uncorrected_bigwig)

spi1_bed = "/srv/scratch/anusri/chrombpnet_paper/GM12878/tf_bed/SPI1_task0_peaks.bed"
spi1_peaks = pd.read_csv(spi1_bed, delimiter="\t").sample(frac=0.001)
print(spi1_peaks.shape)
print(spi1_peaks.head())
# Out:
# (44, 10)
#        chr12  102483806  102484090  .  1000 ..1   4.13574  -1.00000  0.54391  \
# 18289  chr10   83373722   83374006  .  1000   .  34.99925      -1.0  4.71746
# 18778   chr5   80240355   80240639  .  1000   .  35.79656      -1.0  4.71746
# 34281   chr1  119069818  119069982  .  1000   .  95.83233      -1.0  4.71746
# 18234   chr1  248688753  248689037  .  1000   .  34.90617      -1.0  4.71746
# 31189   chr1  200363206  200363490  .  1000   .  74.16524      -1.0  4.71746
#
#        142
# 18289  142
# 18778  142
# 34281   84
# 18234  142
# 31189  142

# %%
def fetch_footprint_from_bigwig(bed_file,bw):
    foot_prints = []
    for i in range(bed_file.shape[0]):
        start = int(bed_file.iloc[i,1])
        summit = int(bed_file.iloc[i,-1])
        flank=150
        foot_prints.append(bw.values(bed_file.iloc[i,0], start+summit-flank, start+summit+flank))
    
    foot_prints = np.array(foot_prints)
    return np.mean(foot_prints, axis=0)

# %%
uncorrected_footprints = fetch_footprint_from_bigwig(spi1_peaks,uncorretced_bw)

# %%
import matplotlib.pyplot as plt
plt.plot(uncorrected_footprints)

# %%
from load_model import *
import os
import pyfaidx

os.environ["CUDA_VISIBLE_DEVICES"]="3"
corrected_model=load_model_wrapper(model_hdf5="/srv/scratch/anusri/chrombpnet_paper/GM12878/ATAC_07.22.2021/final_model_step3/unplug/model.0.hdf5")
reference_genome_path="/mnt/data/GRCh38_no_alt_analysis_set_GCA_000001405.15.fasta"
reader = pyfaidx.Fasta(reference_genome_path)
# Out:
# WARNING:tensorflow:From /users/anusri/anaconda3/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Using TensorFlow backend.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# sequence (InputLayer)           [(None, 2114, 4)]    0
# __________________________________________________________________________________________________
# 1st_conv (Conv1D)               (None, 2094, 500)    42500       sequence[0][0]
# __________________________________________________________________________________________________
# 0_non_dil-crop_1th_dconv (Cropp (None, 2090, 500)    0           1st_conv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv (Conv1D)              (None, 2090, 500)    750500      1st_conv[0][0]
# __________________________________________________________________________________________________
# add2 (Add)                      (None, 2090, 500)    0           0_non_dil-crop_1th_dconv[0][0]
#                                                                  1_dilconv[0][0]
# __________________________________________________________________________________________________
# 0_non_dil-crop_2th_dconv (Cropp (None, 2082, 500)    0           0_non_dil-crop_1th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_2th_dconv (Cropp (None, 2082, 500)    0           1_dilconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv (Conv1D)              (None, 2082, 500)    750500      add2[0][0]
# __________________________________________________________________________________________________
# add3 (Add)                      (None, 2082, 500)    0           0_non_dil-crop_2th_dconv[0][0]
#                                                                  1_dilconv-crop_2th_dconv[0][0]
#                                                                  2_dilconv[0][0]
# __________________________________________________________________________________________________
# 0_non_dil-crop_3th_dconv (Cropp (None, 2066, 500)    0           0_non_dil-crop_2th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_3th_dconv (Cropp (None, 2066, 500)    0           1_dilconv-crop_2th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_3th_dconv (Cropp (None, 2066, 500)    0           2_dilconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv (Conv1D)              (None, 2066, 500)    750500      add3[0][0]
# __________________________________________________________________________________________________
# add4 (Add)                      (None, 2066, 500)    0           0_non_dil-crop_3th_dconv[0][0]
#                                                                  1_dilconv-crop_3th_dconv[0][0]
#                                                                  2_dilconv-crop_3th_dconv[0][0]
#                                                                  3_dilconv[0][0]
# __________________________________________________________________________________________________
# 0_non_dil-crop_4th_dconv (Cropp (None, 2034, 500)    0           0_non_dil-crop_3th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_4th_dconv (Cropp (None, 2034, 500)    0           1_dilconv-crop_3th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_4th_dconv (Cropp (None, 2034, 500)    0           2_dilconv-crop_3th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_4th_dconv (Cropp (None, 2034, 500)    0           3_dilconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv (Conv1D)              (None, 2034, 500)    750500      add4[0][0]
# __________________________________________________________________________________________________
# add5 (Add)                      (None, 2034, 500)    0           0_non_dil-crop_4th_dconv[0][0]
#                                                                  1_dilconv-crop_4th_dconv[0][0]
#                                                                  2_dilconv-crop_4th_dconv[0][0]
#                                                                  3_dilconv-crop_4th_dconv[0][0]
#                                                                  4_dilconv[0][0]
# __________________________________________________________________________________________________
# 0_non_dil-crop_5th_dconv (Cropp (None, 1970, 500)    0           0_non_dil-crop_4th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_5th_dconv (Cropp (None, 1970, 500)    0           1_dilconv-crop_4th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_5th_dconv (Cropp (None, 1970, 500)    0           2_dilconv-crop_4th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_5th_dconv (Cropp (None, 1970, 500)    0           3_dilconv-crop_4th_dconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv-crop_5th_dconv (Cropp (None, 1970, 500)    0           4_dilconv[0][0]
# __________________________________________________________________________________________________
# 5_dilconv (Conv1D)              (None, 1970, 500)    750500      add5[0][0]
# __________________________________________________________________________________________________
# add6 (Add)                      (None, 1970, 500)    0           0_non_dil-crop_5th_dconv[0][0]
#                                                                  1_dilconv-crop_5th_dconv[0][0]
#                                                                  2_dilconv-crop_5th_dconv[0][0]
#                                                                  3_dilconv-crop_5th_dconv[0][0]
#                                                                  4_dilconv-crop_5th_dconv[0][0]
#                                                                  5_dilconv[0][0]
# __________________________________________________________________________________________________
# 0_non_dil-crop_6th_dconv (Cropp (None, 1842, 500)    0           0_non_dil-crop_5th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_6th_dconv (Cropp (None, 1842, 500)    0           1_dilconv-crop_5th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_6th_dconv (Cropp (None, 1842, 500)    0           2_dilconv-crop_5th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_6th_dconv (Cropp (None, 1842, 500)    0           3_dilconv-crop_5th_dconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv-crop_6th_dconv (Cropp (None, 1842, 500)    0           4_dilconv-crop_5th_dconv[0][0]
# __________________________________________________________________________________________________
# 5_dilconv-crop_6th_dconv (Cropp (None, 1842, 500)    0           5_dilconv[0][0]
# __________________________________________________________________________________________________
# 6_dilconv (Conv1D)              (None, 1842, 500)    750500      add6[0][0]
# __________________________________________________________________________________________________
# add7 (Add)                      (None, 1842, 500)    0           0_non_dil-crop_6th_dconv[0][0]
#                                                                  1_dilconv-crop_6th_dconv[0][0]
#                                                                  2_dilconv-crop_6th_dconv[0][0]
#                                                                  3_dilconv-crop_6th_dconv[0][0]
#                                                                  4_dilconv-crop_6th_dconv[0][0]
#                                                                  5_dilconv-crop_6th_dconv[0][0]
#                                                                  6_dilconv[0][0]
# __________________________________________________________________________________________________
# 0_non_dil-crop_7th_dconv (Cropp (None, 1586, 500)    0           0_non_dil-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_7th_dconv (Cropp (None, 1586, 500)    0           1_dilconv-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_7th_dconv (Cropp (None, 1586, 500)    0           2_dilconv-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_7th_dconv (Cropp (None, 1586, 500)    0           3_dilconv-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv-crop_7th_dconv (Cropp (None, 1586, 500)    0           4_dilconv-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 5_dilconv-crop_7th_dconv (Cropp (None, 1586, 500)    0           5_dilconv-crop_6th_dconv[0][0]
# __________________________________________________________________________________________________
# 6_dilconv-crop_7th_dconv (Cropp (None, 1586, 500)    0           6_dilconv[0][0]
# __________________________________________________________________________________________________
# 7_dilconv (Conv1D)              (None, 1586, 500)    750500      add7[0][0]
# __________________________________________________________________________________________________
# add8 (Add)                      (None, 1586, 500)    0           0_non_dil-crop_7th_dconv[0][0]
#                                                                  1_dilconv-crop_7th_dconv[0][0]
#                                                                  2_dilconv-crop_7th_dconv[0][0]
#                                                                  3_dilconv-crop_7th_dconv[0][0]
#                                                                  4_dilconv-crop_7th_dconv[0][0]
#                                                                  5_dilconv-crop_7th_dconv[0][0]
#                                                                  6_dilconv-crop_7th_dconv[0][0]
#                                                                  7_dilconv[0][0]
# __________________________________________________________________________________________________
# 0_non_dil-crop_8th_dconv (Cropp (None, 1074, 500)    0           0_non_dil-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 1_dilconv-crop_8th_dconv (Cropp (None, 1074, 500)    0           1_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 2_dilconv-crop_8th_dconv (Cropp (None, 1074, 500)    0           2_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 3_dilconv-crop_8th_dconv (Cropp (None, 1074, 500)    0           3_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 4_dilconv-crop_8th_dconv (Cropp (None, 1074, 500)    0           4_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 5_dilconv-crop_8th_dconv (Cropp (None, 1074, 500)    0           5_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 6_dilconv-crop_8th_dconv (Cropp (None, 1074, 500)    0           6_dilconv-crop_7th_dconv[0][0]
# __________________________________________________________________________________________________
# 7_dilconv-crop_8th_dconv (Cropp (None, 1074, 500)    0           7_dilconv[0][0]
# __________________________________________________________________________________________________
# 8_dilconv (Conv1D)              (None, 1074, 500)    750500      add8[0][0]
# __________________________________________________________________________________________________
# combined_conv (Add)             (None, 1074, 500)    0           0_non_dil-crop_8th_dconv[0][0]
#                                                                  1_dilconv-crop_8th_dconv[0][0]
#                                                                  2_dilconv-crop_8th_dconv[0][0]
#                                                                  3_dilconv-crop_8th_dconv[0][0]
#                                                                  4_dilconv-crop_8th_dconv[0][0]
#                                                                  5_dilconv-crop_8th_dconv[0][0]
#                                                                  6_dilconv-crop_8th_dconv[0][0]
#                                                                  7_dilconv-crop_8th_dconv[0][0]
#                                                                  8_dilconv[0][0]
# __________________________________________________________________________________________________
# profile_out_prebias (Conv1D)    (None, 1000, 1)      37501       combined_conv[0][0]
# __________________________________________________________________________________________________
# gap (GlobalAveragePooling1D)    (None, 500)          0           combined_conv[0][0]
# __________________________________________________________________________________________________
# profile_predictions (Conv1D)    (None, 1000, 1)      2           profile_out_prebias[0][0]
# __________________________________________________________________________________________________
# logcount_predictions (Dense)    (None, 1)            501         gap[0][0]
# ==================================================================================================
# Total params: 6,084,504
# Trainable params: 6,084,504
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
def fetch_footprint_from_model(bed_file,model):
    foot_prints = []
    for i in range(bed_file.shape[0]):
        start = int(bed_file.iloc[i,1])
        summit = int(bed_file.iloc[i,-1])
        flank=1057
        flank_tf=150
        seq = reader[bed_file.iloc[i,0]][start+summit-flank:start+summit+flank].seq
        one_hot_seq = np.identity(4)[np.unique(list(seq), return_inverse=True)[1]]
        input_tensor = tf.convert_to_tensor(one_hot_seq[None])
        predictions = model(input_tensor)[0]
        predictions = predictions.eval(session=get_session())
        foot_prints.append(predictions[0][500-flank_tf:500+flank_tf,0])
        #plt.plot(predictions.reshape(-1))
        
    foot_prints = np.array(foot_prints)
    return np.mean(foot_prints, axis=0)

# %%
corrected_footprints = fetch_footprint_from_model(spi1_peaks,corrected_model)
import matplotlib.pyplot as plt
plt.plot(corrected_footprints)
# Out:
# [<matplotlib.lines.Line2D object at 0x7fa97b029910>]

# %%
def get_seq(genome, peaks_df, width=2000):
    vals = []
    for i, r in peaks_df.iterrows():
        vals.append(str(reader[r['chr']][(r['start']+r['summit'] - width//2):(r['start'] + r['summit'] + width//2)]))
        
    return one_hot.dna_to_one_hot(vals)
