# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import get_custom_objects
import context
import tensorflow as tf
import os
import viz_sequence
import deepdish

model1="/mnt/lab_data2/anusri/chrombpnet/results/chrombpnet/ATAC_PE/K562_stability/K562_02.08.2022_bias_128_4_1234/bias_model/interpret_locus/interesting.locus.profile_scores.h5"

# %%
scores1 = deepdish.io.load(model1)

# %%
per_example = scores1['projected_shap']['seq'][0].transpose()

# %%
viz_sequence.plot_weights(per_example[(2114 // 2) - 500:(2114 // 2) + 500], subticks_frequency=100)
