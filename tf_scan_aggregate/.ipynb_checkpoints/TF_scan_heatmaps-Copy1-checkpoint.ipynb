# %%
library(tidyr)
library(dplyr)
library(ggplot2)

# %%
## LOAD THE DATA 
gm12878_sig=read.table("GM12878.tf.sig.tsv",header=TRUE,sep='\t')
k562_sig=read.table("K562.tf.sig.tsv",header=TRUE,sep='\t')
imr90_sig=read.table("IMR90.tf.sig.tsv",header=TRUE,sep='\t')
h1esc_sig=read.table("H1ESC.tf.sig.tsv",header=TRUE,sep='\t')
hepg2_sig=read.table("HEPG2.tf.sig.tsv",header=TRUE,sep='\t')

# %%
gm12878_all=read.table("../gm12878_dnase/tf_scan/GM12878.idr.peaks.50bp.around.summit.overlap.tf.all.bed")
k562_all=read.table("../k562_dnase/bpnet/tf_scan/K562.idr.peaks.50bp.around.summit.overlap.tf.all.bed")
imr90_all=read.table("../imr90_dnase/tf_scan/IMR90.idr.peaks.50bp.around.summit.overlap.tf.all.bed")
h1esc_all=read.table("../h1esc_dnase/tf_scan/H1ESC.idr.peaks.50bp.around.summit.overlap.tf.all.bed")
hepg2_all=read.table("../hepg2_dnase/tf_scan/HEPG2.idr.peaks.50bp.around.summit.overlap.tf.all.bed")

# %%
gm12878_peaks=99749
k562_peaks=154628
imr90_peaks=164194
h1esc_peaks=70662
hepg2_peaks=135628
