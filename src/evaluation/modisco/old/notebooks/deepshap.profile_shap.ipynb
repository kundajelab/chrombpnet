# %% [markdown]
# ## Imports

# %%
import numpy as np
#import modisco
import random
import warnings
import h5py
import sys

#import modisco.visualization
#from modisco.visualization import viz_sequence
import viz_sequence

#sys.path.append('/home/groups/akundaje/soumyak/chromatin-atlas/modisco')
#sys.path.append('/users/soumyak/chromatin-atlas/modisco')
from plot_modisco import *

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Visualize Modisco

# %%
path = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper/modisco/BIAS/HEPG2/ATAC_07.22.2021/20K.fold0.deepSHAP.profile_shap.hdf5'
plot_modisco(path)
# Out:
# Metaclusters heatmap
# metacluster_0
# metacluster_1
# activity pattern: [1]
# metacluster_1 pattern_0
# total seqlets: 13341
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_1 pattern_1
# total seqlets: 7498
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_1 pattern_2
# total seqlets: 3134
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_1 pattern_3
# total seqlets: 3112
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_1 pattern_4
# total seqlets: 752
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_1 pattern_5
# total seqlets: 477
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_1 pattern_6
# total seqlets: 232
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_1 pattern_7
# total seqlets: 209
# ...
