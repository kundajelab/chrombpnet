# %% [markdown]
# ## Imports

# %%
import numpy as np
#import modisco
import random
import warnings
import h5py
import sys

#import modisco.visualization
#from modisco.visualization import viz_sequence
import viz_sequence

#sys.path.append('/home/groups/akundaje/soumyak/chromatin-atlas/modisco')
#sys.path.append('/users/soumyak/chromatin-atlas/modisco')
from plot_modisco import *

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Visualize Modisco

# %%
path = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper/modisco/BIAS/HEPG2/ATAC_07.22.2021/20K.fold0.deepSHAP.count_shap.hdf5'
plot_modisco(path)
# Out:
# Metaclusters heatmap
# metacluster_0
# activity pattern: [1]
# metacluster_0 pattern_0
# total seqlets: 11272
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_0 pattern_1
# total seqlets: 2500
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_0 pattern_2
# total seqlets: 2211
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_0 pattern_3
# total seqlets: 1937
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_0 pattern_4
# total seqlets: 385
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_0 pattern_5
# total seqlets: 316
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_0 pattern_6
# total seqlets: 258
# Hypothetical scores:
# Actual importance scores:
# onehot, fwd and rev:
# metacluster_0 pattern_7
# total seqlets: 258
# Hypothetical scores:
# ...
