# %%
import pandas as pd
import os

# %%
profile_dir="/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/DNASE_PE/HEPG2/HEPG2_06.08.2022_bias_128_4_1234_0.8_fold_0/06_22_2022_motif_scanning/moods/profile/"
counts_dir="/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/DNASE_PE/HEPG2/HEPG2_06.08.2022_bias_128_4_1234_0.8_fold_0/06_22_2022_motif_scanning/moods/counts"

# %%
counts_path = os.path.join(counts_dir,"moods_modisco_hits_with_pvalues_0.01_sig.bed.gz")
profile_path = os.path.join(profile_dir,"moods_modisco_hits_with_pvalues_0.01_sig.bed.gz")

# %%
counts_df = pd.read_csv(counts_path,names=["pattern_chr", "pattern_start", "pattern_end", "tf", "pattern_name",
                         "score", "strand", "sequence", "peak_chrom", "peak_start", "peak_end", "mean_imp_score", "pvalue"], sep='\t')

profile_df = pd.read_csv(profile_path,names=["pattern_chr", "pattern_start", "pattern_end", "tf", "pattern_name",
                         "score", "strand", "sequence", "peak_chrom", "peak_start", "peak_end", "mean_imp_score", "pvalue"], sep="\t")

# %%
counts_df.head()
# Out:
#   pattern_chr  pattern_start  pattern_end                     tf  \
# 0        chr1          10520        10531  KLF12_HUMAN.H11MO.0.C
# 1        chr1          10566        10577  KLF12_HUMAN.H11MO.0.C
# 2        chr1          10635        10646   NRF1_HUMAN.H11MO.0.A
# 3        chr1          10636        10647   NRF1_HUMAN.H11MO.0.A
# 4        chr1          10641        10652   NRF1_HUMAN.H11MO.0.A
#
#                pattern_name      score strand     sequence peak_chrom  \
# 0   metacluster_0.pattern_6   8.828358      +  GCTCCGCCTTC       chr1
# 1   metacluster_0.pattern_6  10.400568      +  GCTCCGCCCTC       chr1
# 2  metacluster_0.pattern_18   9.788153      +  CGCGCCGGCGC       chr1
# 3  metacluster_0.pattern_18   9.505883      -  GCGCCGGCGCA       chr1
# 4  metacluster_0.pattern_18   9.302516      +  GGCGCAGGCGC       chr1
#
#    peak_start  peak_end  mean_imp_score    pvalue
# 0       10003     11003        0.004446  0.993990
# 1       10003     11003        0.013400  0.998964
# ...
