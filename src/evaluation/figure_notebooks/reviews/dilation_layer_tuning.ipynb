# %%
import pandas as pd
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../supplementary/dil_files_temp_2.csv",sep=",")

# %%
val = data["chrombpnet model performance peaks (mse counts)"]
means = [float(y.split(" ")[0]) for y in val]
stds = [float(y.split(" ")[1][1:-1]) for y in val]

# %%
plt.plot(data["dilation layer"], means,c="r",alpha=0.5)
plt.errorbar(x=data["dilation layer"], y=means, yerr=stds, fmt = 'o',color = 'red', 
            ecolor = '#ffcccb', elinewidth = 5, capsize=10)
plt.ylabel("Mean squared error")
plt.xlabel("Dilation Layers")
# Out:
# Text(0.5, 0, 'Dilation Layers')

# %%
val = data["chrombpnet model performance peaks (pearsonr counts)"]
means = [float(y.split(" ")[0]) for y in val]
stds = [float(y.split(" ")[1][1:-1]) for y in val]

# %%
plt.plot(data["dilation layer"], means,c="r",alpha=0.5)
plt.errorbar(x=data["dilation layer"], y=means, yerr=stds, fmt = 'o',color = 'red', 
            ecolor = '#ffcccb', elinewidth = 5, capsize=10)
plt.ylabel("Pearsonr counts")
plt.xlabel("Dilation Layers")
plt.ylim((0,1))
plt.savefig("figures/pearsonr_dilation.pdf",format='pdf',dpi=300, transparent=True)

# %%
val = data["chrombpnet model performance peaks (spearmanr counts)"]
means = [float(y.split(" ")[0]) for y in val]
stds = [float(y.split(" ")[1][1:-1]) for y in val]

# %%
plt.plot(data["dilation layer"], means,c="r",alpha=0.5)
plt.errorbar(x=data["dilation layer"], y=means, yerr=stds, fmt = 'o',color = 'red', 
            ecolor = '#ffcccb', elinewidth = 5, capsize=10)
plt.ylabel("Spearmanr counts")
plt.xlabel("Dilation Layers")
plt.ylim((0,1))
plt.savefig("figures/spearmanr_dilation.pdf",format='pdf',dpi=300, transparent=True)

# %%
val = data["chrombpnet model performance peaks (jsd profile)"]
means = [float(y.split(" ")[0]) for y in val]
stds = [float(y.split(" ")[1][1:-1]) for y in val]

# %%
plt.plot(data["dilation layer"], means,c="r",alpha=0.5)
plt.errorbar(x=data["dilation layer"], y=means, yerr=stds, fmt = 'o',color = 'red', 
            ecolor = '#ffcccb', elinewidth = 5, capsize=10)
plt.ylabel("Normalized Jensen Shannon Distance")
plt.xlabel("Dilation Layers")
plt.ylim((0,1))
#plt.savefig("figure_2_supp/norm_jsd_dilation.pdf",format='pdf',dpi=300, transparent=True)
# Out:
# (0.0, 1.0)

# %%
data.head()
# Out:
#    dilation layer  input length receptive field (input length constant)  \
# 0               1          2114                                     ~30
# 1               2          2114                                     ~40
# 2               3          2114                                     ~50
# 3               4          2114                                     ~80
# 4               5          2114                                    ~150
#
#   chrombpnet model performance peaks (pearsonr counts)  \
# 0                                        0.64 (0.01)
# 1                                        0.64 (0.02)
# 2                                        0.64 (0.02)
# 3                                        0.65 (0.01)
# 4                                        0.66 (0.02)
#
#   chrombpnet model performance peaks (spearmanr counts)  \
# 0                                        0.61 (0.02)
# 1                                        0.62 (0.02)
# ...

# %%
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))

val = data["chrombpnet model performance peaks (jsd profile)"]
means = [float(y.split(" ")[0]) for y in val]
stds = [float(y.split(" ")[1][1:-1]) for y in val]

axes[0].plot(data["dilation layer"], means,c="r",alpha=0.5)
axes[0].errorbar(x=data["dilation layer"], y=means, yerr=stds, fmt = 'o',color = 'red', 
            ecolor = '#ffcccb', elinewidth = 5, capsize=10)
axes[0].set_ylabel("Normalized Jensen Shannon Distance")
axes[0].set_xlabel("Dilation Layers")
axes[0].set_ylim(0.4,0.6)

val = data["chrombpnet model performance peaks (pearsonr counts)"]
means = [float(y.split(" ")[0]) for y in val]
stds = [float(y.split(" ")[1][1:-1]) for y in val]

axes[1].plot(data["dilation layer"], means,c="r",alpha=0.5)
axes[1].errorbar(x=data["dilation layer"], y=means, yerr=stds, fmt = 'o',color = 'red', 
            ecolor = '#ffcccb', elinewidth = 5, capsize=10)
axes[1].set_ylabel("Pearsonr counts")
axes[1].set_xlabel("Dilation Layers")
axes[1].set_ylim(0.5,1.0)

plt.savefig("dilation_layer_tuning_hepg2_zoomed.pdf")

# %%
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,5))

val = data["chrombpnet model performance peaks (jsd profile)"]
means = [float(y.split(" ")[0]) for y in val]
stds = [float(y.split(" ")[1][1:-1]) for y in val]

axes[0].plot(data["dilation layer"], means,c="r",alpha=0.5)
axes[0].errorbar(x=data["dilation layer"], y=means, yerr=stds, fmt = 'o',color = 'red', 
            ecolor = '#ffcccb', elinewidth = 5, capsize=10)
axes[0].set_ylabel("Normalized Jensen Shannon Distance")
axes[0].set_xlabel("Dilation Layers")
axes[0].set_ylim(0,1.0)
val = data["chrombpnet model performance peaks (pearsonr counts)"]
means = [float(y.split(" ")[0]) for y in val]
stds = [float(y.split(" ")[1][1:-1]) for y in val]

axes[1].plot(data["dilation layer"], means,c="r",alpha=0.5)
axes[1].errorbar(x=data["dilation layer"], y=means, yerr=stds, fmt = 'o',color = 'red', 
            ecolor = '#ffcccb', elinewidth = 5, capsize=10)
axes[1].set_ylabel("Pearsonr counts")
axes[1].set_xlabel("Dilation Layers")
axes[1].set_ylim(0,1.0)

plt.savefig("dilation_layer_tuning_hepg2.pdf")
