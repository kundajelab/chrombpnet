# %%
cols <- c('character',  'character', rep('numeric', 2))
#cols <- c('numeric',  'character', rep('numeric', 2))

annotations = read.table("subsample_data_finemo_profile.csv",sep=",",header=TRUE, colClasses = cols)

# %%
#annotations = annotations[order(annotations$Motif,decreasing = FALSE),]

# %%
annotations
# Out:
#     Motif  Timepoint Recall    Total
# 1   IRF1   250       0.7026373 103742
# 2   IRF1   100       0.6799850 103742
# 3   IRF1   50        0.7156889 103742
# 4   IRF1   25        0.6571784 103742
# 5   IRF1   15        0.6302076 103742
# 6   IRF1   10        0.6081336 103742
# 7   IRF1   5         0.4993445 103742
# 8   IRF1   2         0.4574329 103742
# 9   BATF   250       0.6004071  27513
# 10  BATF   100       0.5422891  27513
# 11  BATF   50        0.4817359  27513
# 12  BATF   25        0.4401919  27513
# 13  BATF   15        0.4477156  27513
# 14  BATF   10        0.3042198  27513
# 15  BATF   5         0.2331262  27513
# 16  BATF   2         0.2097190  27513
# 17  NRF1   250       0.4465272  19739
# 18  NRF1   100       0.4091393  19739
# 19  NRF1   50        0.4661837  19739
# 20  NRF1   25        0.4675009  19739
# 21  NRF1   15        0.4048331  19739
# 22  NRF1   10        0.4225138  19739
# 23  NRF1   5         0.3618218  19739
# 24  NRF1   2         0.3697249  19739
# 25  POU5F1 250       0.5971620  21212
# 26  POU5F1 100       0.5793890  21212
# 27  POU5F1 50        0.5393645  21212
# 28  POU5F1 25        0.5626532  21212
# 29  POU5F1 15        0.3540920  21212
# 30  POU5F1 10        0.1422308  21212
# ⋮   ⋮      ⋮         ⋮         ⋮
# 115 ELK    50        0.3774565 74292
# 116 ELK    25        0.3747106 74292
# 117 ELK    15        0.3428902 74292
# 118 ELK    10        0.3410731 74292
# 119 ELK    5         0.3017014 74292
# 120 ELK    2         0.3185807 74292
# 121 KLF12  250       0.5530483 88985
# 122 KLF12  100       0.5787492 88985
# 123 KLF12  50        0.5662527 88985
# 124 KLF12  25        0.5882227 88985
# 125 KLF12  15        0.5995505 88985
# 126 KLF12  10        0.5491150 88985
# 127 KLF12  5         0.5464741 88985
# 128 KLF12  2         0.5380120 88985
# 129 NFYB   250       0.3532770 42219
# 130 NFYB   100       0.3551718 42219
# 131 NFYB   50        0.3580615 42219
# 132 NFYB   25        0.3615908 42219
# 133 NFYB   15        0.3429972 42219
# 134 NFYB   10        0.3540349 42219
# 135 NFYB   5         0.3546271 42219
# 136 NFYB   2         0.3269381 42219
# 137 CTCF   250       0.8434820 42206
# 138 CTCF   100       0.8487656 42206
# 139 CTCF   50        0.8376771 42206
# 140 CTCF   25        0.8273468 42206
# 141 CTCF   15        0.7824243 42206
# 142 CTCF   10        0.8056437 42206
# 143 CTCF   5         0.7491826 42206
# 144 CTCF   2         0.7393025 42206

# %%
library(ggplot2)
library(ggpubr)


options(repr.plot.width = 10, repr.plot.height = 6)
EffectNames= c("250","100","50","25","15", "10", "5", "2")
#MotifNames = annotations[annotations$Timepoint=="2",][order(annotations[annotations$Timepoint=="2",]$Recall, decreasing=FALSE),"Motif"]
#MotifNames = annotations[annotations$Timepoint=="5",][order(annotations[annotations$Timepoint=="5",]$Motif, decreasing=FALSE),"Motif"]
#MotifNames = annotations[annotations$Timepoint=="5",][order(annotations[annotations$Timepoint=="5",]$Motif, decreasing=FALSE),"Motif"]
MotifNames = c("PAX", "HNF1A", "POU5F1", "COE1", "BATF", "RUNX",  "FOSL1+JUND", "ELK",  "NFKB1",  "NFYB",  "NRF1" , "SPI1",  "IRF4" , "IRF1", "KLF12" , "ZNF76",  "JDP", "CTCF")   
print(MotifNames)
#MotifNames=annotations$Motif
ggballoonplot(annotations,  x = "Timepoint", y = "Motif", fill = "Recall", size="Recall")+
  scale_fill_viridis_c(option = "C") +   scale_x_discrete(limits = EffectNames)  +   scale_y_discrete(limits = MotifNames)

ggsave("figures/recall_with_read_depth_finemo.pdf", device = "pdf",  width = 5, height = 6, dpi = 300)
# Out:
#  [1] "PAX"        "HNF1A"      "POU5F1"     "COE1"       "BATF"
#  [6] "RUNX"       "FOSL1+JUND" "ELK"        "NFKB1"      "NFYB"
# [11] "NRF1"       "SPI1"       "IRF4"       "IRF1"       "KLF12"
# [16] "ZNF76"      "JDP"        "CTCF"
# Error in Cairo::Cairo(width, height, tf, "png", pointsize, bg, "transparent", : Graphics API version mismatch
# Traceback:
# plot without title

# %%
MotifNames
# Out:
# character(0)
