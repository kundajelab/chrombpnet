# %%
import pandas as pd
import scipy.stats

# %%
data = pd.read_csv("scatac.dsqtls.yoruba.lcls.benchmarking.all.tsv", sep="\t", header=0)

# %%
data.head(1)
# Out:
#   var.chrom  var.pos_hg19 var.allele1 var.allele2     var.rsid  obs.label  \
# 0      chr1        856583           A           G  rs141671872          1
#
#    var.isused  obs.estimate  pred.chrombpnet.ENCSR371ZNU.varscore.logfc  \
# 0        True        0.9301                                    0.880032
#
#    pred.chrombpnet.ENCSR371ZNU.varscore.jsd  ...  \
# 0                                  0.099852  ...
#
#    pred.chrombpnet.ENCSR371ZNU_15m.varscore.ips  \
# 0                                      0.005207
#
#    pred.chrombpnet.ENCSR371ZNU_10m.varscore.logfc  \
# 0                                        0.223266
#
#    pred.chrombpnet.ENCSR371ZNU_10m.varscore.jsd  \
# 0                                      0.067395
#
#    pred.chrombpnet.ENCSR371ZNU_10m.varscore.ips  \
# 0                                      0.001606
#
#    pred.chrombpnet.ENCSR371ZNU_5m.varscore.logfc  \
# 0                                       0.142058
#
#    pred.chrombpnet.ENCSR371ZNU_5m.varscore.jsd  \
# 0                                     0.078699
#
#    pred.chrombpnet.ENCSR371ZNU_5m.varscore.ips  \
# 0                                     0.002022
#
#    pred.chrombpnet.ENCSR371ZNU_2m.varscore.logfc  \
# 0                                       0.062305
#
#    pred.chrombpnet.ENCSR371ZNU_2m.varscore.jsd  \
# 0                                     0.042606
#
#    pred.chrombpnet.ENCSR371ZNU_2m.varscore.ips
# 0                                     0.000728
#
# [1 rows x 43 columns]

# %%
dataf = data[data["var.isused"]]

# %%
dataf.shape
# Out:
# (27373, 43)

# %%
print(sum(dataf["obs.label"]==1))
print(sum(dataf["obs.label"]==-1))
# Out:
# 560
# 26813

# %% [markdown]
# # AUPRC Benchmarking

# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import RocCurveDisplay
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt
import matplotlib


matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42 

import random
import os
import argparse
from sklearn.metrics import precision_recall_curve


# fig, ax = plt.subplots(figsize=(10,6))

# ######################################

# keyd="pred.chrombpnet.encsr637xsc.varscore.ips"
# label=dataf["obs.label"].astype(int)
# score=abs(dataf[keyd])

# title="ChromBPnet w/ ATAC (572M)"

# fpr_chrombpnet, tpr_chrombpnet, _ = precision_recall_curve(label,score)
# roc_auc = metrics.average_precision_score(label, score)
# ax.plot(tpr_chrombpnet,fpr_chrombpnet,  linewidth=2, c='blue', linestyle='dashed', label=title+", AP="+str(round(roc_auc,2)))

# ######################################

# keyd="pred.chrombpnet.encsr637xsc_50m.varscore.ips"
# label=dataf["obs.label"].astype(int)
# score=abs(dataf[keyd])

# title="ChromBPnet w/ ATAC (50M)"

# fpr_chrombpnet, tpr_chrombpnet, _ = precision_recall_curve(label,score)
# roc_auc = metrics.average_precision_score(label, score)
# ax.plot(tpr_chrombpnet,fpr_chrombpnet,  linewidth=2, c='blue', label=title+", AP="+str(round(roc_auc,2)))

# ######################################

# keyd="pred.chrombpnet.encsr000emt.varscore.ips"
# label=dataf["obs.label"].astype(int)
# score=abs(dataf[keyd])

# title="ChromBPnet w/ DNASE (68M)"

# fpr_chrombpnet, tpr_chrombpnet, _ = precision_recall_curve(label,score)
# roc_auc = metrics.average_precision_score(label, score)
# ax.plot(tpr_chrombpnet,fpr_chrombpnet,  linewidth=2, label=title+", AP="+str(round(roc_auc,2)))

# ######################################

# keyd="pred.enformer.encsr000emt.varscore.local_logfc"
# label=dataf["obs.label"].astype(int)
# score=abs(dataf[keyd])
# title="Enformer w/ DNASE (recomputed) (68M)"

# fpr_chrombpnet, tpr_chrombpnet, _ = precision_recall_curve(label,score)
# roc_auc = metrics.average_precision_score(label, score)
# enformer_auc_recomp = roc_auc

# ax.plot(tpr_chrombpnet,fpr_chrombpnet,  linewidth=2, label=title+", AP="+str(round(roc_auc,2)))

# ######################################

# # keyd="pred.enformer.encsr000emt.varscore.sad"
# # label=dataf["obs.label"].astype(int)
# # score=abs(dataf[keyd])
# # title="Enformer w/ DNASE SAD (50M)"

# # fpr_chrombpnet, tpr_chrombpnet, _ = precision_recall_curve(label,score)
# # roc_auc = metrics.average_precision_score(label, score)
# # ax.plot(tpr_chrombpnet,fpr_chrombpnet,  linewidth=2, label=title+", AP="+str(round(roc_auc,2)))

# ######################################

# keyd="pred.enformer.encsr000emt.varscore.global_sar"
# label=dataf["obs.label"].astype(int)
# score=abs(dataf[keyd])
# title="Enformer w/ DNASE (reported) (68M)"


# fpr_chrombpnet, tpr_chrombpnet, _ = precision_recall_curve(label,score)
# roc_auc = metrics.average_precision_score(label, score)
# ax.plot(tpr_chrombpnet,fpr_chrombpnet,  linewidth=2, label=title+", AP="+str(round(roc_auc,2)))
# enformer_auc = roc_auc

# ######################################

# keyd="pred.gkmsvm.encsr000emt.varscore.deltasvm"
# label=dataf["obs.label"].astype(int)
# score=abs(dataf[keyd])
# title="DeltaSVM w/ DNASE (68M)"

# fpr_chrombpnet, tpr_chrombpnet, _ = precision_recall_curve(label,score)
# roc_auc = metrics.average_precision_score(label, score)
# ax.plot(tpr_chrombpnet,fpr_chrombpnet,  linewidth=2, label=title+", AP="+str(round(roc_auc,2)))
# deltasvm_roc=roc_auc

# roc_auc=sum(dataf["obs.label"]==1)/len(dataf["obs.label"])
# ax.plot(fpr_chrombpnet, [sum(dataf["obs.label"]==1)/len(dataf["obs.label"])]*len(fpr_chrombpnet), linewidth=2, label="Random baseline, AP="+str(round(roc_auc,2)))


# ax.spines[["top", "right"]].set_visible(False)
# ax.legend(loc='upper right')
# ax.set_xlabel("Recall")
# ax.set_ylabel("Precision")

# #plt.savefig("subfigs/dsqtls_auprc.pdf", transparent=True, dpi=300)

# %% [markdown]
# # AUPRC (best metric)

# %%
# scores = []
# labels = []
# keys_df = []

# keys = ['pred.chrombpnet.encsr637xsc.varscore.ips',
#        'pred.chrombpnet.encsr637xsc.varscore.ies',
#        'pred.chrombpnet.encsr637xsc.varscore.jsd_x_aaq',
#        'pred.chrombpnet.encsr637xsc.varscore.logfc_x_aaq',
#        'pred.chrombpnet.encsr637xsc.varscore.jsd',     
#        'pred.chrombpnet.encsr637xsc.varscore.logfc',
#        'pred.chrombpnet.encsr637xsc.varscore.aaq']


# key_shorts = ["IPS", 
#               "IES",
#               "jsd_x_aaq",
#               "logfc_x_aaq",
#               "jsd",
#               "logfc",
#               "AAQ"]

# names = ["ATAC (572M)", "ATAC (50M)", "DNASE (50M)"]

# j=0
# for kd in keys:
#     i = 0
#     for title in ["encsr637xsc", "encsr637xsc_50m", "encsr000emt"]:
#         label=data["obs.label"].astype(int)
#         score=abs(data[kd.replace("encsr637xsc", title)])
#         roc_auc = metrics.average_precision_score(label, score)
#         scores.append(roc_auc)
#         labels.append(names[i])
#         keys_df.append(key_shorts[j])
#         i=i+1
#     j=j+1

# %%
# import seaborn as sns
# dictt={"scores":scores, "labels":labels, "method":keys_df}
# df = pd.DataFrame(dictt)
# matplotlib.rcParams['pdf.fonttype'] = 42
# matplotlib.rcParams['ps.fonttype'] = 42 

# fig, ax = plt.subplots(figsize=(15,8))

# sns.barplot(data=df, x="labels", y="scores", hue="method", ax=ax)
# ax.spines[["top", "right"]].set_visible(False)

# #plt.savefig("subfigs/dsqtls_auprc_score_compare.pdf", transparent=True, dpi=300)

# %%
dataf["obs.label"].astype(int)
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 28302   -1
# 28303   -1
# 28304   -1
# 28305   -1
# 28307   -1
# Name: obs.label, Length: 27373, dtype: int64

# %%
# keyd="pred.chrombpnet.encsr000emt.varscore.ips"
#score=dataf[keyd]

# %%
# plt.hist(score[dataf["obs.label"].astype(int)==-1])

# %%
#sum(score[dataf["obs.label"].astype(int)==-1]>0.025)

# %%
#sum(score[dataf["obs.label"].astype(int)==1]>0.025)

# %%
#plt.hist(score[dataf["obs.label"].astype(int)==1])

# %% [markdown]
# # AUPRC (subsampling)

# %%
def fetch_auprc_new(p):
    fpr_chrombpnet, tpr_chrombpnet, _ = precision_recall_curve(merged_atac[key_label], abs(merged_atac["abs_logfc_x_jsd_x_max_percentile.mean"]))
    roc_auc = metrics.average_precision_score(merged_atac[key_label], abs(merged_atac["abs_logfc_x_jsd_x_max_percentile.mean"]))
    #roc_auc = metrics.average_precision_score(merged_atac[key_label], abs(merged_atac["jsd.mean"]))
    print(roc_auc)
    return roc_auc

# %%
rocs = []
for title in ["ENCSR371ZNU", "ENCSR371ZNU_250m", "ENCSR371ZNU_100m",
              "ENCSR371ZNU_50m", "ENCSR371ZNU_25m", "ENCSR371ZNU_15m", "ENCSR371ZNU_10m", "ENCSR371ZNU_5m", "ENCSR371ZNU_2m"]:
    
    roc_auc = metrics.average_precision_score(dataf["obs.label"].astype(int), abs(dataf["pred.chrombpnet.encsr637xsc.varscore.ips".replace("encsr637xsc", title)]))
    print(roc_auc)
    rocs.append(roc_auc)
# Out:
# 0.5468518780096837
# 0.5500120334751555
# 0.5338427350450508
# 0.5104544270021492
# 0.4715942304147161
# 0.41939762076857734
# 0.37159482638621016
# 0.3279864258369851
# 0.28794173115908944

# %%
fix, ax = plt.subplots(figsize=(5,3))
ax.scatter(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M" ,"ATAC\n50M", "ATAC\n25M",  "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"],rocs)
ax.plot(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M","ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"],rocs, alpha=0.5)
#ax.scatter(["DNASE\n68M"], [rocs[-1]], marker="*")
#ax.scatter(["Enformer recomp"], [enformer_auc_recomp], marker="*")
#ax.scatter(["Enformer"], [enformer_auc], marker="*")
#ax.scatter(["DeltSVM"], [deltasvm_roc], marker="*")

xtix=["ChromBPNet scATAC 19K", " ChromBPNet scATAC 11K", "ChromBPNet scATAC 4K","ChromBPNet scATAC 2K", "ChromBPNet scATAC 1K", "ChromBPNet scATAC 663", "ChromBPNet ATAC 463", "ChromBPNet scATAC 212", "ChromBPNet scATAC 103"]

ax.set_ylim((0,0.6))
ax.spines[["top", "right"]].set_visible(False)
ax.set_xticklabels(labels=xtix, rotation=90)
ax.set_xlabel("Method")
ax.set_ylabel("Average Precision")

plt.savefig("figures/scatac_dsqtls_auprc_subsampling.pdf", transparent=True, dpi=300)
# Out:
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   del sys.path[0]

# %% [markdown]
# # Pearsonr (benchmarking)

# %%
# key_enf_1="pred.enformer.encsr000emt.varscore.local_logfc"
# key_enf_2="pred.enformer.encsr000emt.varscore.global_sar"
# key_label="obs.label"
# obs_estimate="obs.estimate"
# chrombpnet_logfc="pred.chrombpnet.encsr000emt.varscore.logfc"
# chrombpnet_atac_logfc="pred.chrombpnet.encsr637xsc.varscore.logfc"
# delta_svm_key="pred.gkmsvm.encsr000emt.varscore.deltasvm"
# chrombpnet_atac_50m_logfc="pred.chrombpnet.encsr637xsc_50m.varscore.logfc"


# # enformer_perf = np.max([scipy.stats.pearsonr(dataf[key_enf_1][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])[0],
# #                        scipy.stats.pearsonr(dataf[key_enf_2][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])[0]])
# enformer_perf = scipy.stats.pearsonr(dataf[key_enf_1][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])[0]
# enformer_perf_old = scipy.stats.pearsonr(dataf[key_enf_2][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])[0]

# print(np.round(enformer_perf,2))

# %%
#enformer_perf = scipy.stats.pearsonr(abs(dataf[key_enf_1][dataf[key_label]==1]),abs(dataf[obs_estimate][dataf[key_label]==1]))[0]

# %%
#print(np.round(enformer_perf,2))

# %%
# print(np.round(enformer_perf_old,2))

# %%
# scipy.stats.pearsonr(dataf[key_enf_1][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])

# %%
# scipy.stats.pearsonr(dataf[key_enf_2][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])

# %%
# scipy.stats.pearsonr(dataf[chrombpnet_logfc][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])

# %%
# scipy.stats.pearsonr(dataf[chrombpnet_atac_logfc][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])

# %%
# scipy.stats.pearsonr(dataf[delta_svm_key][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])

# %%
# # enformer_perf_abs = np.max([scipy.stats.pearsonr(abs(dataf[key_enf_1][dataf[key_label]==1]),abs(dataf[obs_estimate][dataf[key_label]==1]))[0],
# #                        scipy.stats.pearsonr(abs(dataf[key_enf_2][dataf[key_label]==1]),abs(dataf[obs_estimate][dataf[key_label]==1]))[0]])
# enformer_perf_abs = scipy.stats.pearsonr(abs(dataf[key_enf_1][dataf[key_label]==1]),abs(dataf[obs_estimate][dataf[key_label]==1]))[0]
# enformer_perf_abs_old = scipy.stats.pearsonr(abs(dataf[key_enf_2][dataf[key_label]==1]),abs(dataf[obs_estimate][dataf[key_label]==1]))[0]

# print(np.round(enformer_perf_abs,2))
# print(scipy.stats.pearsonr(abs(dataf[key_enf_2][dataf[key_label]==1]),abs(dataf[obs_estimate][dataf[key_label]==1])))

# %%
# print(np.round(enformer_perf_abs_old,2))

# %%
# deltasvm_perf = scipy.stats.pearsonr(dataf[delta_svm_key][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])[0]
# print(np.round(deltasvm_perf,2))

# %%
# deltasvm_perf_abs = scipy.stats.pearsonr(abs(dataf[delta_svm_key][dataf[key_label]==1]),abs(dataf[obs_estimate][dataf[key_label]==1]))
# print(np.round(deltasvm_perf_abs[0],2))
# print(deltasvm_perf_abs)

# %%
# chrombpnet_perf = scipy.stats.pearsonr(dataf[chrombpnet_logfc][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])[0]
# print(np.round(chrombpnet_perf,2))

# %%
# chrombpnet_perf_abs = scipy.stats.pearsonr(abs(dataf[chrombpnet_logfc][dataf[key_label]==1]),abs(dataf[obs_estimate][dataf[key_label]==1]))
# print(np.round(chrombpnet_perf_abs[0],2))
# print(chrombpnet_perf_abs)

# %%
# chrombpnet_perf = scipy.stats.pearsonr(dataf[chrombpnet_atac_50m_logfc][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])[0]
# print(np.round(chrombpnet_perf,2))

# %%
# chrombpnet_perf_abs = scipy.stats.pearsonr(abs(dataf[chrombpnet_atac_50m_logfc][dataf[key_label]==1]),abs(dataf[obs_estimate][dataf[key_label]==1]))
# print(np.round(chrombpnet_perf_abs[0],2))
# print(chrombpnet_perf_abs)

# %%
#scipy.stats.pearsonr(abs(dataf[chrombpnet_atac_logfc][dataf[key_label]==1]),abs(dataf[obs_estimate][dataf[key_label]==1]))

# %%
import seaborn as sns
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42 

key_label="obs.label"
obs_estimate="obs.estimate"
chrombpnet_atac_logfc="pred.chrombpnet.ENCSR371ZNU.varscore.logfc"
data = pd.DataFrame()
data["logfc.mean"] = dataf[dataf[key_label]==1][chrombpnet_atac_logfc]
data["Beta"] = dataf[dataf[key_label]==1][obs_estimate]

print(data.shape)
plt.figure(figsize=(6,5))

sns.kdeplot(
    data=data,
    x="Beta",
    y="logfc.mean",
    levels=5,
    fill=False,
    alpha=0.2,
    color="grey",
    cut=2,

)


ax = sns.scatterplot(x="Beta", y="logfc.mean", data=data, s=6, color="Red")
sns.regplot(x="Beta", y="logfc.mean", data=data, scatter=False, ci=None, color="#ffcccb")
ax.spines[["top", "right"]].set_visible(False)

atc_pear = scipy.stats.pearsonr(dataf[chrombpnet_atac_logfc][dataf[key_label]==1],dataf[obs_estimate][dataf[key_label]==1])
print(atc_pear)

ax.set_title("Pearsonr = "+str(np.round(atc_pear[0],2)))

atc_pear = scipy.stats.pearsonr(abs(dataf[chrombpnet_atac_logfc][dataf[key_label]==1]),abs(dataf[obs_estimate][dataf[key_label]==1]))
print(atc_pear)

#plt.savefig("subfigs/dsqtls_pearsonr_plot.pdf", transparent=True, dpi=300)
# Out:
# (560, 2)
# (0.7666515666260625, 1.8696235631450234e-109)
# (0.3068313944981208, 1.1315339407890857e-13)

# %% [markdown]
# # Pearsonr (subsampling)

# %%
pearsonrs_logfc_abs = []
for title in ["ENCSR371ZNU", "ENCSR371ZNU_250m", "ENCSR371ZNU_100m",
              "ENCSR371ZNU_50m", "ENCSR371ZNU_25m", "ENCSR371ZNU_15m", "ENCSR371ZNU_10m", "ENCSR371ZNU_5m", "ENCSR371ZNU_2m"]:
  
    pear = scipy.stats.pearsonr(abs(dataf[obs_estimate][dataf[key_label]==1]), abs(dataf["pred.chrombpnet.encsr637xsc.varscore.logfc".replace("encsr637xsc", title)][dataf[key_label]==1]))
    print(pear)
    pearsonrs_logfc_abs.append(pear[0])
# Out:
# (0.3068313944981208, 1.1315339407890857e-13)
# (0.30583494613467166, 1.3698184800604357e-13)
# (0.3008659391806578, 3.514246526225863e-13)
# (0.2895540111017345, 2.8080166998455564e-12)
# (0.2615060139383365, 3.2951905997897867e-10)
# (0.25178396337266007, 1.516516349682795e-09)
# (0.20942551445354812, 5.721349147705743e-07)
# (0.17588137436802787, 2.845596712867784e-05)
# (0.17315515159166617, 3.79528635673287e-05)

# %%
pearsonrs_logfc = []
for title in ["ENCSR371ZNU", "ENCSR371ZNU_250m", "ENCSR371ZNU_100m",
              "ENCSR371ZNU_50m", "ENCSR371ZNU_25m", "ENCSR371ZNU_15m", "ENCSR371ZNU_10m", "ENCSR371ZNU_5m", "ENCSR371ZNU_2m"]:
  
    print("pred.chrombpnet.encsr637xsc.varscore.logfc".replace("encsr637xsc", title))
    pear = scipy.stats.pearsonr(dataf[obs_estimate][dataf[key_label]==1], dataf["pred.chrombpnet.encsr637xsc.varscore.logfc".replace("encsr637xsc", title)][dataf[key_label]==1])
    print(pear)
    pearsonrs_logfc.append(pear[0])
# Out:
# pred.chrombpnet.ENCSR371ZNU.varscore.logfc
# (0.7666515666260625, 1.8696235631450234e-109)
# pred.chrombpnet.ENCSR371ZNU_250m.varscore.logfc
# (0.761922824674794, 2.4018958019642264e-107)
# pred.chrombpnet.ENCSR371ZNU_100m.varscore.logfc
# (0.755664801423428, 1.2497680262729973e-104)
# pred.chrombpnet.ENCSR371ZNU_50m.varscore.logfc
# (0.7535031967657231, 1.037614322132282e-103)
# pred.chrombpnet.ENCSR371ZNU_25m.varscore.logfc
# (0.7363653607204137, 9.555273510812857e-97)
# pred.chrombpnet.ENCSR371ZNU_15m.varscore.logfc
# (0.7258622766808576, 9.658021738718235e-93)
# pred.chrombpnet.ENCSR371ZNU_10m.varscore.logfc
# (0.7097682452135456, 5.913953560110564e-87)
# pred.chrombpnet.ENCSR371ZNU_5m.varscore.logfc
# (0.686347760563943, 3.298916959605149e-79)
# pred.chrombpnet.ENCSR371ZNU_2m.varscore.logfc
# (0.6790249436313208, 6.195456943426244e-77)

# %%
pearsonrs_jsd_abs = []
for title in ["ENCSR371ZNU", "ENCSR371ZNU_250m", "ENCSR371ZNU_100m",
              "ENCSR371ZNU_50m", "ENCSR371ZNU_25m", "ENCSR371ZNU_15m", "ENCSR371ZNU_10m", "ENCSR371ZNU_5m", "ENCSR371ZNU_2m"]:
      
    print("pred.chrombpnet.encsr637xsc.varscore.jsd".replace("encsr637xsc", title))
    pear = scipy.stats.pearsonr(abs(dataf[obs_estimate][dataf[key_label]==1]), abs(dataf["pred.chrombpnet.encsr637xsc.varscore.jsd".replace("encsr637xsc", title)][dataf[key_label]==1]))
    print(pear)
    pearsonrs_jsd_abs.append(pear[0])
# Out:
# pred.chrombpnet.ENCSR371ZNU.varscore.jsd
# (0.32168403566477577, 6.007205870733521e-15)
# pred.chrombpnet.ENCSR371ZNU_250m.varscore.jsd
# (0.32394562405540495, 3.786354187286671e-15)
# pred.chrombpnet.ENCSR371ZNU_100m.varscore.jsd
# (0.31306210251481204, 3.3689675889094236e-14)
# pred.chrombpnet.ENCSR371ZNU_50m.varscore.jsd
# (0.3042307252067213, 1.8604448931770718e-13)
# pred.chrombpnet.ENCSR371ZNU_25m.varscore.jsd
# (0.29036016877196613, 2.42880717739215e-12)
# pred.chrombpnet.ENCSR371ZNU_15m.varscore.jsd
# (0.27861536991357383, 1.92154120388547e-11)
# pred.chrombpnet.ENCSR371ZNU_10m.varscore.jsd
# (0.26986364192565093, 8.430481490865494e-11)
# pred.chrombpnet.ENCSR371ZNU_5m.varscore.jsd
# (0.2586363806646427, 5.205042926319895e-10)
# pred.chrombpnet.ENCSR371ZNU_2m.varscore.jsd
# (0.2486926288219501, 2.4318025096651656e-09)

# %%
pearsonrs_jsd = []
for title in ["ENCSR371ZNU", "ENCSR371ZNU_250m", "ENCSR371ZNU_100m",
              "ENCSR371ZNU_50m", "ENCSR371ZNU_25m", "ENCSR371ZNU_15m", "ENCSR371ZNU_10m", "ENCSR371ZNU_5m", "ENCSR371ZNU_2m"]:
    pear = scipy.stats.pearsonr(dataf[obs_estimate][dataf[key_label]==1], dataf["pred.chrombpnet.encsr637xsc.varscore.jsd".replace("encsr637xsc", title)][dataf[key_label]==1])
    print(pear)
    pearsonrs_jsd.append(pear[0])
# Out:
# (0.7531008578672179, 1.5348791899783684e-103)
# (0.7556428430876659, 1.2770718575679836e-104)
# (0.7522844015301003, 3.3893893774347017e-103)
# (0.7517270874973543, 5.810282823332585e-103)
# (0.7333272860770106, 1.439363817174596e-95)
# (0.7184334194133211, 5.087128895459434e-90)
# (0.7078284175773242, 2.7711981908702982e-86)
# (0.6799549939340634, 3.2135038837229914e-77)
# (0.6580374671814637, 9.036444009499104e-71)

# %%
fig, ax = plt.subplots(figsize=(4,3))
ax.scatter(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M" ,"ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"],pearsonrs_logfc, c="orange", marker="^")
ax.plot(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M","ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"],pearsonrs_logfc, alpha=0.1, c="orange")
ax.scatter(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M" ,"ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"],pearsonrs_jsd, c="blue", marker="^")
ax.plot(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M","ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"],pearsonrs_jsd, alpha=0.1, c="blue")

ax.scatter(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M" ,"ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"],pearsonrs_logfc_abs, c="orange", marker="v")
ax.plot(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M","ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"],pearsonrs_logfc_abs, alpha=0.1,c="orange")
ax.scatter(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M" ,"ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"],pearsonrs_jsd_abs, c="blue", marker="v")
ax.plot(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M","ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"],pearsonrs_jsd_abs, alpha=0.1, c="blue" )


xtix=["ChromBPNet scATAC 19K", " ChromBPNet scATAC 11K", "ChromBPNet scATAC 4K","ChromBPNet scATAC 2K", "ChromBPNet scATAC 1K", "ChromBPNet scATAC 663", "ChromBPNet ATAC 463", "ChromBPNet scATAC 212", "ChromBPNet scATAC 103"]
ax.set_ylim((0,0.8))
ax.spines[["top", "right"]].set_visible(False)
ax.set_xticklabels(labels=xtix, rotation=90)
ax.legend()
plt.savefig("figures/sctac_dsqtls_subsample_pearsonr_performance.pdf", transparent=True, dpi=300)
# Out:
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   app.launch_new_instance()
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#572M - 277907
#250M - 265030
#100M - 240287
#50M - 187344
#25M - 149430
#15M - 125597
#10M - 100349
#5M - 75601
#2M - 48963

# %%
depth = ["19K", "11K", "4K", "2K", "1K", "663", "463", "212", "103"]


peaks = [194930, 192420, 182282, 165617, 135950, 121518, 98217, 75976, 48863]

# %%
plt.scatter(depth,peaks)
plt.ylabel("#peaks")
plt.xlabel("scATAC #cells")
plt.savefig("figures/sctac_peaks.pdf", transparent=True, dpi=300)

# %%
fig, ax = plt.subplots(1, 3, figsize=(10, 3))

# First plot
ax[0].scatter(depth, peaks)
ax[0].set_xlabel("scATAC #cells")
ax[0].set_ylabel("#peaks")
ax[0].spines[["top", "right"]].set_visible(False)
ax[0].set_title("Peaks vs Cells")

# Second plot
xtix = ["19K", "11K", "4K", "2K", "1K", "663", "463", "212", "103"]
ax[1].scatter(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M", "ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"], rocs)
ax[1].plot(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M", "ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"], rocs, alpha=0.5)
ax[1].set_ylim((0, 0.6))
ax[1].spines[["top", "right"]].set_visible(False)
ax[1].set_xticklabels(xtix, rotation=0)
ax[1].set_xlabel("Method")
ax[1].set_ylabel("Average Precision")
ax[1].set_title("ROCS")

# Third plot
ax[2].scatter(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M", "ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"], pearsonrs_logfc, c="orange", marker="^")
ax[2].plot(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M", "ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"], pearsonrs_logfc, alpha=0.1, c="orange")
ax[2].scatter(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M", "ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"], pearsonrs_jsd, c="blue", marker="^")
ax[2].plot(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M", "ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"], pearsonrs_jsd, alpha=0.1, c="blue")
ax[2].scatter(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M", "ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"], pearsonrs_logfc_abs, c="orange", marker="v")
ax[2].plot(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M", "ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"], pearsonrs_logfc_abs, alpha=0.1, c="orange")
ax[2].scatter(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M", "ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"], pearsonrs_jsd_abs, c="blue", marker="v")
ax[2].plot(["ATAC\n572M", "ATAC\n250M", "ATAC\n100M", "ATAC\n50M", "ATAC\n25M", "ATAC\n15M", "ATAC\n10M", "ATAC\n5M", "ATAC\n2M"], pearsonrs_jsd_abs, alpha=0.1, c="blue")
ax[2].set_ylim((0, 0.8))
ax[2].spines[["top", "right"]].set_visible(False)
ax[2].set_xticklabels(xtix, rotation=0)
ax[2].set_xlabel("Method")
ax[2].set_ylabel("Performance")
ax[2].set_title("Pearson Performance")
ax[2].legend()

plt.tight_layout()
plt.savefig("figures/scatac_combined_plot.pdf", transparent=True, dpi=300)
plt.show()
# Out:
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   app.launch_new_instance()
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: UserWarning: FixedFormatter should only be used together with FixedLocator
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Calculate rate of change

rates_of_change = [(rocs[i] - rocs[0]) / (int(xtix[i].replace("K","000")) - int(xtix[0].replace("K","000"))) for i in range(1, len(rocs))]
labels =  ["11K", "4K", "2K", "1K", "663", "463", "212", "103"]

print(rates_of_change)
fig, ax = plt.subplots()
ax.scatter(labels, rates_of_change)
#ax.set_ylim((0, max(rates_of_change) * 1.1))
ax.spines[["top", "right"]].set_visible(False)
ax.set_xticklabels(labels, rotation=0)
ax.set_xlabel("Method")
ax.set_ylabel("Rate of Change")
ax.set_title("Rate of Drop in Average Precision")

# Show plot
plt.show()
# Out:
# [-3.950194331839713e-07, 8.672761976421972e-07, 2.1410265298549738e-06, 4.1809804219426455e-06, 6.950660262916855e-06, 9.454445251306768e-06, 1.1649215040062732e-05, 1.3701124350457441e-05]
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   # This is added back by InteractiveShellApp.init_path()

# %%
pearsonrs_logfc = []
for title in ["encsr637xsc", 
              "encsr637xsc_50m", "encsr000emt"]:
 
    print("pred.chrombpnet.encsr637xsc.varscore.logfc".replace("encsr637xsc", title))
    pear = scipy.stats.pearsonr(dataf[obs_estimate][dataf[key_label]==1], dataf["pred.chrombpnet.encsr637xsc.varscore.logfc".replace("encsr637xsc", title)][dataf[key_label]==1])
    print(np.round(pear,2))
    pearsonrs_logfc.append(pear[0])


import seaborn as sns

pearsonrs_logfc.extend([deltasvm_perf,enformer_perf_old])
labels = [" ATAC-seq (572M)",  " ATAC-seq (50M)", " DNase-seq (68M)", "deltaSVM", "Enformer" ]
dictt={"scores":pearsonrs_logfc, "labels":labels}
df = pd.DataFrame(dictt)
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42 

fig, ax = plt.subplots(figsize=(5,3))
ax.set_ylim((0.5,1.0))
sns.barplot(data=df, x="labels", y="scores", ax=ax)

ax.spines[["top", "right"]].set_visible(False)

print(np.round(deltasvm_perf,2))
print(np.round(enformer_perf_old,2))
# Out:
# pred.chrombpnet.encsr637xsc.varscore.logfc
# [0.76 0.  ]
# pred.chrombpnet.encsr637xsc_50m.varscore.logfc
# [0.73 0.  ]
# pred.chrombpnet.encsr000emt.varscore.logfc
# [0.74 0.  ]
# 0.73
# 0.56

# %%
pearsonrs_logfc = []
for title in ["encsr637xsc", 
              "encsr637xsc_50m", "encsr000emt"]:
 
    print("pred.chrombpnet.encsr637xsc.varscore.logfc".replace("encsr637xsc", title))
    pear = scipy.stats.pearsonr(dataf[obs_estimate][dataf[key_label]==1], dataf["pred.chrombpnet.encsr637xsc.varscore.logfc".replace("encsr637xsc", title)][dataf[key_label]==1])
    print(pear)
    pearsonrs_logfc.append(pear[0])


import seaborn as sns

hue=["cyan"]+["#7FFFD4"]+["b"]+["red"]+["green"]+["#ff7f0e"]

pearsonrs_logfc.extend([deltasvm_perf,enformer_perf_old, enformer_perf])
labels = [" ATAC-seq (572M)",  " ATAC-seq (50M)", " DNase-seq (68M)", "deltaSVM", "Enformer (reported)", "Enformer (revised)" ]
dictt={"scores":pearsonrs_logfc, "labels":labels, "hue": hue}
df = pd.DataFrame(dictt)
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42 

fig, ax = plt.subplots(figsize=(5,3))
ax.set_ylim((0.5,1.0))
sns.barplot(data=df, x="labels", y="scores", palette=hue, ax=ax)

ax.spines[["top", "right"]].set_visible(False)
# Out:
# pred.chrombpnet.encsr637xsc.varscore.logfc
# (0.7586179164294138, 6.689376032748603e-106)
# pred.chrombpnet.encsr637xsc_50m.varscore.logfc
# (0.7346524058027831, 4.429888240845516e-96)
# pred.chrombpnet.encsr000emt.varscore.logfc
# (0.7393262959574392, 6.552289684724055e-98)

# %%
pearsonrs_logfc = []
for title in ["encsr637xsc", 
              "encsr637xsc_50m", "encsr000emt"]:
 
    print("pred.chrombpnet.encsr637xsc.varscore.logfc".replace("encsr637xsc", title))
    pear = scipy.stats.pearsonr(dataf[obs_estimate][dataf[key_label]==1], dataf["pred.chrombpnet.encsr637xsc.varscore.logfc".replace("encsr637xsc", title)][dataf[key_label]==1])
    print(pear)
    pearsonrs_logfc.append(pear[0])


import seaborn as sns

hue=["cyan"]+["#7FFFD4"]+["b"]+["red"]+["green"]+["#ff7f0e"]

pearsonrs_logfc.extend([deltasvm_perf,enformer_perf_old, enformer_perf])
labels = [" ATAC-seq (572M)",  " ATAC-seq (50M)", " DNase-seq (68M)", "deltaSVM", "Enformer (reported)", "Enformer (revised)" ]
dictt={"scores":pearsonrs_logfc, "labels":labels, "hue": hue}
df = pd.DataFrame(dictt)
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42 

fig, ax = plt.subplots(figsize=(5,3))
ax.set_ylim((0.5,1.0))
sns.barplot(data=df, x="labels", y="scores", palette=hue, ax=ax)

ax.spines[["top", "right"]].set_visible(False)
# Out:
# pred.chrombpnet.encsr637xsc.varscore.logfc
# (0.7586179164294138, 6.689376032748603e-106)
# pred.chrombpnet.encsr637xsc_50m.varscore.logfc
# (0.7346524058027831, 4.429888240845516e-96)
# pred.chrombpnet.encsr000emt.varscore.logfc
# (0.7393262959574392, 6.552289684724055e-98)

# %%
enformer_perf
# Out:
# 0.727161386520316

# %%
dataf.head()
# Out:
#   var.chrom  var.pos_hg19 var.allele1 var.allele2     var.rsid  obs.label  \
# 0      chr1        856583           A           G  rs141671872          1
# 1      chr1        911595           G           A    rs7417106          1
# 2      chr1       1186502           T           A    rs6603785          1
# 3      chr1       1227412           A           G  rs112571439          1
# 4      chr1       1590575           A           G    rs9661285          1
#
#    var.isused  obs.estimate  pred.gkmsvm.encsr000emt.varscore.deltasvm  \
# 0        True        0.9301                                   2.653531
# 1        True       -0.6285                                   2.821422
# 2        True       -0.7363                                  -7.167236
# 3        True       -0.9236                                  -3.957382
# 4        True       -1.0890                                  -4.785596
#
#    pred.enformer.encsr000emt.varscore.global_sad  ...  \
# 0                                       0.000342  ...
# 1                                      -0.001241  ...
# 2                                      -0.006530  ...
# 3                                      -0.001878  ...
# 4                                      -0.008736  ...
#
#    pred.chrombpnet.encsr637xsc_50m.varscore.aaq  \
# 0                                      0.248566
# 1                                      0.726685
# 2                                      0.696101
# 3                                      0.521835
# 4                                      0.988211
#
#    pred.chrombpnet.encsr637xsc_50m.varscore.ies  \
# 0                                      0.044994
# 1                                      0.002535
# 2                                      0.021468
# 3                                      0.265543
# 4                                      0.006033
#
#    pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq  \
# 0                                           0.021877
# 1                                           0.027762
# 2                                           0.029658
# 3                                           0.137196
# 4                                           0.053680
#
#    pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq  \
# 0                                           0.127298
# 1                                           0.056287
# 2                                           0.349964
# 3                                           0.518532
# 4                                           0.103350
#
#    pred.chrombpnet.encsr637xsc_25m.varscore.logfc  \
# 0                                        0.291935
# 1                                        0.093192
# 2                                       -0.402188
# 3                                       -0.622704
# 4                                       -0.061906
#
#    pred.chrombpnet.encsr637xsc_25m.varscore.jsd  \
# 0                                      0.067401
# 1                                      0.036053
# 2                                     -0.038791
# 3                                     -0.222396
# 4                                     -0.050589
#
#    pred.chrombpnet.encsr637xsc_25m.varscore.ips  \
# 0                                      0.004840
# 1                                      0.002239
# 2                                      0.008839
# 3                                      0.086945
# 4                                      0.003275
#
#    pred.chrombpnet.encsr637xsc_5m.varscore.logfc  \
# 0                                       0.065098
# 1                                       0.045314
# 2                                      -0.163023
# 3                                      -0.259064
# 4                                      -0.032300
#
#    pred.chrombpnet.encsr637xsc_5m.varscore.jsd  \
# 0                                     0.049902
# 1                                     0.034489
# 2                                    -0.039080
# 3                                    -0.172960
# 4                                    -0.023135
#
#    pred.chrombpnet.encsr637xsc_5m.varscore.ips
# 0                                     0.001360
# 1                                     0.000898
# 2                                     0.002210
# 3                                     0.027583
# 4                                     0.000802
#
# [5 rows x 45 columns]

# %%
plt.scatter(newdf["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"], newdf["pred.gkmsvm.encsr000emt.varscore.deltasvm"], s=1)

# %%
plt.scatter(newdf["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"], newdf["pred.enformer.encsr000emt.varscore.local_logfc"], s=1)

# %%
scipy.stats.pearsonr(newdf["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"], newdf["pred.gkmsvm.encsr000emt.varscore.deltasvm"])
# Out:
# (0.8264218390944509, 2.610357160112255e-141)

# %%
scipy.stats.pearsonr(newdf["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"], newdf["pred.enformer.encsr000emt.varscore.local_logfc"])
# Out:
# (0.8071744723292618, 7.673152508558958e-130)

# %%
scipy.stats.pearsonr(newdf["pred.chrombpnet.encsr637xsc.varscore.logfc"], newdf["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"])
# Out:
# (0.973312376278302, 0.0)

# %%
plt.scatter(newdf["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"], newdf["pred.chrombpnet.encsr637xsc.varscore.logfc"], s=1)

# %%
newdf[(abs(newdf["pred.chrombpnet.encsr637xsc.varscore.logfc"]) > 1.0) & (abs(newdf["pred.chrombpnet.encsr637xsc_25m.varscore.logfc"]) < 0.3)]
# Out:
# Empty DataFrame
# Columns: [var.chrom, var.pos_hg19, var.allele1, var.allele2, var.rsid, obs.label, var.isused, obs.estimate, pred.gkmsvm.encsr000emt.varscore.deltasvm, pred.enformer.encsr000emt.varscore.global_sad, pred.enformer.encsr000emt.varscore.global_sar, pred.enformer.encsr000emt.varscore.local_logfc, pred.chrombpnet.encsr000emt.varscore.logfc, pred.chrombpnet.encsr000emt.varscore.jsd, pred.chrombpnet.encsr000emt.varscore.ips, pred.chrombpnet.encsr000emt.varscore.aaq, pred.chrombpnet.encsr000emt.varscore.ies, pred.chrombpnet.encsr000emt.varscore.jsd_x_aaq, pred.chrombpnet.encsr000emt.varscore.logfc_x_aaq, pred.chrombpnet.encsr637xsc.varscore.logfc, pred.chrombpnet.encsr637xsc.varscore.jsd, pred.chrombpnet.encsr637xsc.varscore.ips, pred.chrombpnet.encsr637xsc.varscore.aaq, pred.chrombpnet.encsr637xsc.varscore.ies, pred.chrombpnet.encsr637xsc.varscore.jsd_x_aaq, pred.chrombpnet.encsr637xsc.varscore.logfc_x_aaq, pred.chrombpnet.encsr637xsc_250m.varscore.logfc, pred.chrombpnet.encsr637xsc_250m.varscore.jsd, pred.chrombpnet.encsr637xsc_250m.varscore.ips, pred.chrombpnet.encsr637xsc_100m.varscore.logfc, pred.chrombpnet.encsr637xsc_100m.varscore.jsd, pred.chrombpnet.encsr637xsc_100m.varscore.ips, pred.chrombpnet.encsr637xsc_50m.varscore.logfc, pred.chrombpnet.encsr637xsc_50m.varscore.jsd, pred.chrombpnet.encsr637xsc_50m.varscore.ips, pred.chrombpnet.encsr637xsc_50m.varscore.aaq, pred.chrombpnet.encsr637xsc_50m.varscore.ies, pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq, pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq, pred.chrombpnet.encsr637xsc_25m.varscore.logfc, pred.chrombpnet.encsr637xsc_25m.varscore.jsd, pred.chrombpnet.encsr637xsc_25m.varscore.ips, pred.chrombpnet.encsr637xsc_5m.varscore.logfc, pred.chrombpnet.encsr637xsc_5m.varscore.jsd, pred.chrombpnet.encsr637xsc_5m.varscore.ips]
# Index: []
#
# [0 rows x 45 columns]

# %%
newdf[(abs(newdf["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"]) > 1.0) & (abs(newdf["pred.enformer.encsr000emt.varscore.local_logfc"]) < 0.25)]
# Out:
#     var.chrom  var.pos_hg19 var.allele1 var.allele2    var.rsid  obs.label  \
# 410      chr3     119999621           T           G    rs787202          1
# 306      chr2      20391281           C           G   rs7563253          1
# 303      chr2      17342057           T           C   rs1396073          1
# 268     chr19      14788486           A           G  rs76943706          1
#
#      var.isused  obs.estimate  pred.gkmsvm.encsr000emt.varscore.deltasvm  \
# 410        True         1.061                                  12.183722
# 306        True         1.395                                   0.766670
# 303        True         1.356                                   8.744398
# 268        True         1.500                                   7.997565
#
#      pred.enformer.encsr000emt.varscore.global_sad  ...  \
# 410                                       0.001058  ...
# 306                                      -0.000653  ...
# 303                                       0.000862  ...
# 268                                       0.001189  ...
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.aaq  \
# 410                                      0.490914
# 306                                      0.158290
# 303                                      0.484705
# 268                                      0.637403
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.ies  \
# 410                                      0.240430
# 306                                      0.229513
# 303                                      0.097740
# 268                                      0.126441
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq  \
# 410                                           0.068919
# 306                                           0.035464
# 303                                           0.044197
# 268                                           0.072883
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq  \
# 410                                           0.857548
# 306                                           0.161356
# 303                                           0.514474
# 268                                           0.700973
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.logfc  \
# 410                                        1.542522
# 306                                        0.620272
# 303                                        0.779526
# 268                                        0.820226
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.jsd  \
# 410                                      0.130211
# 306                                      0.191968
# 303                                      0.081831
# 268                                      0.093474
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.ips  \
# 410                                      0.099296
# 306                                      0.020358
# 303                                      0.026170
# 268                                      0.045054
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.logfc  \
# 410                                       0.507238
# 306                                       0.212775
# 303                                       0.329974
# 268                                       0.359859
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.jsd  \
# 410                                     0.103556
# 306                                     0.135474
# 303                                     0.069764
# 268                                     0.078785
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.ips
# 410                                     0.015007
# 306                                     0.006709
# 303                                     0.008237
# 268                                     0.016060
#
# [4 rows x 45 columns]

# %%
newdf[(abs(newdf["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"]) > 1.0) & (abs(newdf["pred.enformer.encsr000emt.varscore.local_logfc"]) > 1.0)]


#newdf[(abs(newdf["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"]) > 0.8)]
# Out:
#     var.chrom  var.pos_hg19 var.allele1 var.allele2     var.rsid  obs.label  \
# 570      chr9     135991219           G           A   rs74734156          1
# 523      chr7     108237224           G           T   rs76144775          1
# 467      chr5     150618993           T           C   rs72794132          1
# 466      chr5     137937318           G           A   rs11242436          1
# 417      chr3     194878063           G           A     rs750470          1
# 387     chr22      42925131           A           G    rs2413698          1
# 359     chr20      48585958           T           C   rs73131258          1
# 314      chr2      45517342           T           C    rs4953223          1
# 242     chr17      77083852           C           G   rs74001531          1
# 235     chr17      70236669           C           T   rs60805964          1
# 219     chr17      42486310           C           T  rs116606536          1
# 199     chr16      84541173           C           T   rs76547445          1
# 196     chr16      56905250           T           C    rs1123507          1
# 189     chr16       4700675           G           C   rs80265182          1
# 173     chr15      70174409           T           C     rs304951          1
# 171     chr15      64175305           G           T    rs8037081          1
# 142     chr14      39921156           G           A   rs73287557          1
# 127     chr13      42086794           T           C    rs9532865          1
# 90      chr11      69029210           C           A    rs7122786          1
# 79      chr11      44797140           G           C   rs76873282          1
# 65      chr10      87984457           T           C   rs10887562          1
# 51      chr10       5894500           A           G   rs10905307          1
# 14       chr1      32059773           G           C   rs12079905          1
#
#      var.isused  obs.estimate  pred.gkmsvm.encsr000emt.varscore.deltasvm  \
# 570        True       -1.6220                                 -10.955990
# 523        True        1.1690                                   8.052371
# 467        True       -1.2780                                  -3.093466
# 466        True        0.9855                                   6.997243
# 417        True        0.9927                                   8.053620
# 387        True        0.9991                                  12.244517
# 359        True        1.2060                                  18.674545
# 314        True       -1.1530                                 -13.131274
# 242        True       -0.9836                                 -20.754752
# 235        True        1.1210                                  11.174321
# 219        True        1.3680                                   7.027461
# 199        True       -1.0270                                  -8.216525
# 196        True       -1.0410                                  -8.042490
# 189        True       -1.4140                                  -9.528703
# 173        True        1.0220                                  11.228525
# 171        True        0.7629                                   8.644216
# 142        True       -0.8703                                  -7.658354
# 127        True        1.2890                                  13.789687
# 90         True        1.2520                                   5.661384
# 79         True       -1.7930                                 -18.558214
# 65         True        1.3880                                  13.422075
# 51         True        0.7446                                   6.876955
# 14         True       -1.2990                                 -14.727417
#
#      pred.enformer.encsr000emt.varscore.global_sad  ...  \
# 570                                      -0.022230  ...
# 523                                       0.002249  ...
# 467                                      -0.004475  ...
# 466                                       0.007010  ...
# 417                                       0.014915  ...
# 387                                       0.008030  ...
# 359                                       0.008480  ...
# 314                                      -0.002533  ...
# 242                                      -0.001341  ...
# 235                                       0.004940  ...
# 219                                       0.009800  ...
# 199                                      -0.009380  ...
# 196                                      -0.015564  ...
# 189                                      -0.002386  ...
# 173                                       0.011560  ...
# 171                                       0.008766  ...
# 142                                      -0.004177  ...
# 127                                       0.010390  ...
# 90                                        0.004720  ...
# 79                                       -0.001867  ...
# 65                                        0.012580  ...
# 51                                        0.025480  ...
# 14                                       -0.001211  ...
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.aaq  \
# 570                                      0.859768
# 523                                      0.204930
# 467                                      0.304990
# 466                                      0.493146
# 417                                      0.687899
# 387                                      0.571482
# 359                                      0.654419
# 314                                      0.430438
# 242                                      0.546433
# 235                                      0.679356
# 219                                      0.773826
# 199                                      0.679548
# 196                                      0.484321
# 189                                      0.360530
# 173                                      0.767054
# 171                                      0.454505
# 142                                      0.330717
# 127                                      0.697435
# 90                                       0.244973
# 79                                       0.233801
# 65                                       0.782449
# 51                                       0.811725
# 14                                       0.389753
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.ies  \
# 570                                      0.128659
# 523                                      0.299179
# 467                                      0.274788
# 466                                      0.093025
# 417                                      0.088292
# 387                                      0.184228
# 359                                      0.291587
# 314                                      0.417112
# 242                                      0.303466
# 235                                      0.112254
# 219                                      0.092333
# 199                                      0.182507
# 196                                      0.135007
# 189                                      0.245626
# 173                                      0.204941
# 171                                      0.133302
# 142                                      0.176004
# 127                                      0.167300
# 90                                       0.138614
# 79                                       0.418543
# 65                                       0.383649
# 51                                       0.170502
# 14                                       0.343921
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq  \
# 570                                           0.082782
# 523                                           0.059315
# 467                                           0.077893
# 466                                           0.040465
# 417                                           0.057154
# 387                                           0.080432
# 359                                           0.101279
# 314                                           0.081813
# 242                                           0.137125
# 235                                           0.067785
# 219                                           0.062293
# 199                                           0.081358
# 196                                           0.047758
# 189                                           0.082013
# 173                                           0.126060
# 171                                           0.056206
# 142                                           0.051266
# 127                                           0.070789
# 90                                            0.025621
# 79                                            0.072180
# 65                                            0.152143
# 51                                            0.094322
# 14                                            0.097795
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq  \
# 570                                           1.149839
# 523                                           0.217551
# 467                                           0.314057
# 466                                           0.538237
# 417                                           0.709692
# 387                                           0.745055
# 359                                           1.218286
# 314                                           0.938479
# 242                                           0.667938
# 235                                           0.752954
# 219                                           0.876604
# 199                                           1.037469
# 196                                           0.676614
# 189                                           0.419332
# 173                                           0.959148
# 171                                           0.501513
# 142                                           0.381074
# 127                                           1.161218
# 90                                            0.345281
# 79                                            0.322432
# 65                                            1.529167
# 51                                            1.157476
# 14                                            0.540682
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.logfc  \
# 570                                       -1.054812
# 523                                        0.861197
# 467                                       -0.872374
# 466                                        0.852853
# 417                                        0.967391
# 387                                        1.090731
# 359                                        1.738351
# 314                                       -1.769171
# 242                                       -0.784592
# 235                                        0.843166
# 219                                        1.149467
# 199                                       -1.183006
# 196                                       -0.853229
# 189                                       -0.864882
# 173                                        1.204373
# 171                                        1.056640
# 142                                       -1.003394
# 127                                        1.281790
# 90                                         1.133202
# 79                                        -0.993717
# 65                                         1.579020
# 51                                         1.292201
# 14                                        -1.052535
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.jsd  \
# 570                                     -0.097857
# 523                                      0.277101
# 467                                     -0.267241
# 466                                      0.074192
# 417                                      0.092217
# 387                                      0.111491
# 359                                      0.151742
# 314                                     -0.190801
# 242                                     -0.229239
# 235                                      0.092169
# 219                                      0.080500
# 199                                     -0.122161
# 196                                     -0.075872
# 189                                     -0.247891
# 173                                      0.160066
# 171                                      0.136811
# 142                                     -0.128082
# 127                                      0.088776
# 90                                       0.118371
# 79                                      -0.284154
# 65                                       0.165722
# 51                                       0.118313
# 14                                      -0.255262
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.ips  \
# 570                                      0.078159
# 523                                      0.045481
# 467                                      0.052306
# 466                                      0.030390
# 417                                      0.050607
# 387                                      0.065357
# 359                                      0.162467
# 314                                      0.133344
# 242                                      0.095662
# 235                                      0.052828
# 219                                      0.067980
# 199                                      0.078884
# 196                                      0.023301
# 189                                      0.062275
# 173                                      0.137997
# 171                                      0.042861
# 142                                      0.040189
# 127                                      0.078113
# 90                                       0.031234
# 79                                       0.063346
# 65                                       0.186010
# 51                                       0.110705
# 14                                       0.071336
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.logfc  \
# 570                                      -0.369366
# 523                                       0.272638
# 467                                      -0.267408
# 466                                       0.395728
# 417                                       0.281895
# 387                                       0.473912
# 359                                       0.748674
# 314                                      -0.698953
# 242                                      -0.262317
# 235                                       0.502446
# 219                                       0.546778
# 199                                      -0.388887
# 196                                      -0.490694
# 189                                      -0.237989
# 173                                       0.625088
# 171                                       0.548501
# 142                                      -0.370091
# 127                                       0.502119
# 90                                        0.414964
# 79                                       -0.340318
# 65                                        0.655255
# 51                                        0.528862
# 14                                       -0.248440
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.jsd  \
# 570                                    -0.069461
# 523                                     0.242283
# 467                                    -0.210576
# 466                                     0.053673
# 417                                     0.071430
# 387                                     0.083184
# 359                                     0.144198
# 314                                    -0.149296
# 242                                    -0.223948
# 235                                     0.081098
# 219                                     0.077039
# 199                                    -0.074243
# 196                                    -0.080231
# 189                                    -0.215834
# 173                                     0.128051
# 171                                     0.142378
# 142                                    -0.099089
# 127                                     0.068574
# 90                                      0.112682
# 79                                     -0.268510
# 65                                      0.131014
# 51                                      0.097272
# 14                                     -0.220418
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.ips
# 570                                     0.017225
# 523                                     0.010678
# 467                                     0.011222
# 466                                     0.007366
# 417                                     0.008648
# 387                                     0.015098
# 359                                     0.043202
# 314                                     0.033836
# 242                                     0.022052
# 235                                     0.025993
# 219                                     0.022479
# 199                                     0.010464
# 196                                     0.017526
# 189                                     0.016587
# 173                                     0.039569
# 171                                     0.016223
# 142                                     0.007813
# 127                                     0.017933
# 90                                      0.008777
# 79                                      0.022092
# 65                                      0.047033
# 51                                      0.030503
# 14                                      0.008146
#
# [23 rows x 45 columns]

# %%
newdf[(abs(newdf["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"]) > 1.0)].loc[:,["var.chrom", "var.pos_hg19", "var.allele1", "var.allele2", "var.rsid"]].to_csv("/mnt/lab_data2/anusri/chrombpnet/dsqtl_meta_data_small_new.tsv", sep="\t", header=False, index=False)

# %%
newdf[newdf["var.rsid"]=="rs11242436"]["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"]
# Out:
# 466    1.091536
# Name: pred.chrombpnet.encsr637xsc_50m.varscore.logfc, dtype: float64

# %%
newdf[newdf["var.rsid"]=="rs11242436"]["pred.gkmsvm.encsr000emt.varscore.deltasvm"]
# Out:
# 466    6.997243
# Name: pred.gkmsvm.encsr000emt.varscore.deltasvm, dtype: float64

# %%
newdf[newdf["var.rsid"]=="rs11242436"]["pred.enformer.encsr000emt.varscore.local_logfc"]
# Out:
# 466    1.188561
# Name: pred.enformer.encsr000emt.varscore.local_logfc, dtype: float64

# %%
newdf = dataf[dataf["obs.label"]==1].sort_values(['var.chrom','var.pos_hg19'],ascending=False)

# %%
newdf
# Out:
#     var.chrom  var.pos_hg19 var.allele1 var.allele2     var.rsid  obs.label  \
# 573      chr9     140499646           C           T    rs4494021          1
# 572      chr9     140376668           G           A   rs10116708          1
# 571      chr9     136811747           A           G    rs2519112          1
# 570      chr9     135991219           G           A   rs74734156          1
# 569      chr9     133769169           G           A    rs3847193          1
# ..        ...           ...         ...         ...          ...        ...
# 4        chr1       1590575           A           G    rs9661285          1
# 3        chr1       1227412           A           G  rs112571439          1
# 2        chr1       1186502           T           A    rs6603785          1
# 1        chr1        911595           G           A    rs7417106          1
# 0        chr1        856583           A           G  rs141671872          1
#
#      var.isused  obs.estimate  pred.gkmsvm.encsr000emt.varscore.deltasvm  \
# 573        True        0.8279                                   7.858264
# 572        True        1.0270                                   4.130903
# 571        True       -0.7492                                  -8.944194
# 570        True       -1.6220                                 -10.955990
# 569        True        0.7767                                   4.271205
# ..          ...           ...                                        ...
# 4          True       -1.0890                                  -4.785596
# 3          True       -0.9236                                  -3.957382
# 2          True       -0.7363                                  -7.167236
# 1          True       -0.6285                                   2.821422
# 0          True        0.9301                                   2.653531
#
#      pred.enformer.encsr000emt.varscore.global_sad  ...  \
# 573                                       0.001646  ...
# 572                                       0.000917  ...
# 571                                      -0.007446  ...
# 570                                      -0.022230  ...
# 569                                       0.000025  ...
# ..                                             ...  ...
# 4                                        -0.008736  ...
# 3                                        -0.001878  ...
# 2                                        -0.006530  ...
# 1                                        -0.001241  ...
# 0                                         0.000342  ...
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.aaq  \
# 573                                      0.916726
# 572                                      0.498460
# 571                                      0.464208
# 570                                      0.859768
# 569                                      0.740023
# ..                                            ...
# 4                                        0.988211
# 3                                        0.521835
# 2                                        0.696101
# 1                                        0.726685
# 0                                        0.248566
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.ies  \
# 573                                      0.001974
# 572                                      0.007134
# 571                                      0.132887
# 570                                      0.128659
# 569                                      0.030903
# ..                                            ...
# 4                                        0.006033
# 3                                        0.265543
# 2                                        0.021468
# 1                                        0.002535
# 0                                        0.044994
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq  \
# 573                                           0.032355
# 572                                           0.011000
# 571                                           0.055721
# 570                                           0.082782
# 569                                           0.075640
# ..                                                 ...
# 4                                             0.053680
# 3                                             0.137196
# 2                                             0.029658
# 1                                             0.027762
# 0                                             0.021877
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq  \
# 573                                           0.050632
# 572                                           0.163987
# 571                                           0.520439
# 570                                           1.149839
# 569                                           0.216968
# ..                                                 ...
# 4                                             0.103350
# 3                                             0.518532
# 2                                             0.349964
# 1                                             0.056287
# 0                                             0.127298
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.logfc  \
# 573                                        0.031360
# 572                                        0.257331
# 571                                       -0.924885
# 570                                       -1.054812
# 569                                        0.333520
# ..                                              ...
# 4                                         -0.061906
# 3                                         -0.622704
# 2                                         -0.402188
# 1                                          0.093192
# 0                                          0.291935
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.jsd  \
# 573                                      0.039969
# 572                                      0.026206
# 571                                     -0.123568
# 570                                     -0.097857
# 569                                      0.131947
# ..                                            ...
# 4                                       -0.050589
# 3                                       -0.222396
# 2                                       -0.038791
# 1                                        0.036053
# 0                                        0.067401
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.ips  \
# 573                                      0.001500
# 572                                      0.003634
# 571                                      0.046317
# 570                                      0.078159
# 569                                      0.031692
# ..                                            ...
# 4                                        0.003275
# 3                                        0.086945
# 2                                        0.008839
# 1                                        0.002239
# 0                                        0.004840
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.logfc  \
# 573                                       0.012683
# 572                                       0.174108
# 571                                      -0.355947
# 570                                      -0.369366
# 569                                       0.051163
# ..                                             ...
# 4                                        -0.032300
# 3                                        -0.259064
# 2                                        -0.163023
# 1                                         0.045314
# 0                                         0.065098
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.jsd  \
# 573                                     0.030208
# 572                                     0.030441
# 571                                    -0.111057
# 570                                    -0.069461
# 569                                     0.122563
# ..                                           ...
# 4                                      -0.023135
# 3                                      -0.172960
# 2                                      -0.039080
# 1                                       0.034489
# 0                                       0.049902
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.ips
# 573                                     0.000375
# 572                                     0.003031
# 571                                     0.012353
# 570                                     0.017225
# 569                                     0.003779
# ..                                           ...
# 4                                       0.000802
# 3                                       0.027583
# 2                                       0.002210
# 1                                       0.000898
# 0                                       0.001360
#
# [560 rows x 45 columns]

# %%
#newdf[newdf['var.chrom']=="chr3"]
# Out:
#     var.chrom  var.pos_hg19 var.allele1 var.allele2    var.rsid  obs.label  \
# 421      chr3     197479257           T           C   rs1606519          1
# 420      chr3     197185378           T           C  rs56104465          1
# 419      chr3     195916604           A           G  rs12163558          1
# 418      chr3     195622041           A           G   rs6762607          1
# 417      chr3     194878063           G           A    rs750470          1
# 416      chr3     185869440           T           C  rs11927308          1
# 415      chr3     141759948           C           T  rs75465423          1
# 414      chr3     137801779           A           G   rs1107422          1
# 413      chr3     124642835           C           T   rs9859266          1
# 412      chr3     124487849           A           G   rs2291082          1
# 411      chr3     122380722           A           C   rs6438753          1
# 410      chr3     119999621           T           G    rs787202          1
# 409      chr3     119078592           G           A  rs56665819          1
# 408      chr3      98053033           T           C   rs4061832          1
# 407      chr3      72148540           T           C  rs72950600          1
# 406      chr3      58071644           C           A   rs4681784          1
# 405      chr3      50388607           C           A   rs2233474          1
# 404      chr3      47017915           A           G    rs936180          1
# 403      chr3      46773510           T           G  rs59637204          1
# 402      chr3      39002669           G           C  rs79814974          1
# 401      chr3      38045036           A           T   rs6781889          1
# 400      chr3      16424645           C           T  rs77156492          1
# 399      chr3      14495455           A           G   rs1529942          1
# 398      chr3      13041138           A           G  rs13061279          1
# 397      chr3      12829036           T           C   rs9881832          1
# 396      chr3      10328782           G           A     rs35682          1
#
#      var.isused  obs.estimate  pred.gkmsvm.encsr000emt.varscore.deltasvm  \
# 421        True        0.7974                                   9.042312
# 420        True       -1.1810                                  -2.119043
# 419        True        1.5500                                   4.480584
# 418        True       -0.8027                                  -5.329387
# 417        True        0.9927                                   8.053620
# 416        True        0.7692                                  -0.038336
# 415        True        1.1880                                   3.870294
# 414        True       -0.7559                                  -2.722054
# 413        True       -0.8159                                   0.389019
# 412        True        1.2420                                   4.170800
# 411        True        0.7710                                   0.159781
# 410        True        1.0610                                  12.183722
# 409        True       -0.8019                                  -0.734075
# 408        True       -0.8977                                  -8.113492
# 407        True        0.6968                                  -1.116943
# 406        True        0.7363                                   0.131364
# 405        True        0.7213                                   2.266311
# 404        True        0.7619                                   6.617132
# 403        True        0.8644                                   0.203891
# 402        True       -1.4180                                  -7.668820
# 401        True       -1.1020                                  -7.283665
# 400        True        0.9827                                   3.692747
# 399        True       -0.6595                                 -12.615671
# 398        True       -0.9607                                  -6.261942
# 397        True        1.0180                                   8.105979
# 396        True        1.2790                                   8.447420
#
#      pred.enformer.encsr000emt.varscore.global_sad  ...  \
# 421                                       0.001077  ...
# 420                                       0.000205  ...
# 419                                       0.000831  ...
# 418                                      -0.000220  ...
# 417                                       0.014915  ...
# 416                                       0.002035  ...
# 415                                       0.005238  ...
# 414                                      -0.001182  ...
# 413                                      -0.000335  ...
# 412                                       0.000543  ...
# 411                                      -0.000078  ...
# 410                                       0.001058  ...
# 409                                      -0.003738  ...
# 408                                       0.001569  ...
# 407                                       0.004020  ...
# 406                                       0.000078  ...
# 405                                       0.002270  ...
# 404                                       0.006527  ...
# 403                                       0.003016  ...
# 402                                      -0.000621  ...
# 401                                      -0.001680  ...
# 400                                       0.003143  ...
# 399                                       0.000854  ...
# 398                                      -0.001716  ...
# 397                                       0.001337  ...
# 396                                       0.000252  ...
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.aaq  \
# 421                                      0.284606
# 420                                      0.087627
# 419                                      0.181246
# 418                                      0.846271
# 417                                      0.687899
# 416                                      0.245315
# 415                                      0.448149
# 414                                      0.727870
# 413                                      0.064995
# 412                                      0.032195
# 411                                      0.582559
# 410                                      0.490914
# 409                                      0.218759
# 408                                      0.368604
# 407                                      0.381792
# 406                                      0.486858
# 405                                      0.972450
# 404                                      0.980797
# 403                                      0.404019
# 402                                      0.275796
# 401                                      0.219349
# 400                                      0.430947
# 399                                      0.766667
# 398                                      0.763080
# 397                                      0.127253
# 396                                      0.160992
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.ies  \
# 421                                      0.141450
# 420                                      0.032295
# 419                                      0.010922
# 418                                      0.008913
# 417                                      0.088292
# 416                                      0.020220
# 415                                      0.052323
# 414                                      0.009767
# 413                                      0.016157
# 412                                      0.012478
# 411                                      0.001181
# 410                                      0.240430
# 409                                      0.009560
# 408                                      0.060138
# 407                                      0.012719
# 406                                      0.000249
# 405                                      0.002238
# 404                                      0.010438
# 403                                      0.008706
# 402                                      0.044013
# 401                                      0.065744
# 400                                      0.014580
# 399                                      0.087894
# 398                                      0.011997
# 397                                      0.029271
# 396                                      0.401271
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq  \
# 421                                           0.036814
# 420                                           0.008060
# 419                                           0.005976
# 418                                           0.050729
# 417                                           0.057154
# 416                                           0.014965
# 415                                           0.035855
# 414                                           0.032854
# 413                                           0.005645
# 412                                           0.001626
# 411                                           0.009894
# 410                                           0.068919
# 409                                           0.008211
# 408                                           0.049582
# 407                                           0.018872
# 406                                           0.004350
# 405                                           0.024934
# 404                                           0.056847
# 403                                           0.013931
# 402                                           0.030910
# 401                                           0.026370
# 400                                           0.015801
# 399                                           0.069371
# 398                                           0.020706
# 397                                           0.011197
# 396                                           0.049679
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq  \
# 421                                           0.320128
# 420                                           0.032856
# 419                                           0.056064
# 418                                           0.113948
# 417                                           0.709692
# 416                                           0.084408
# 415                                           0.286575
# 414                                           0.155043
# 413                                           0.014409
# 412                                           0.006196
# 411                                           0.037161
# 410                                           0.857548
# 409                                           0.062654
# 408                                           0.163097
# 407                                           0.093639
# 406                                           0.013337
# 405                                           0.078434
# 404                                           0.174093
# 403                                           0.093596
# 402                                           0.098231
# 401                                           0.117083
# 400                                           0.173207
# 399                                           0.745942
# 398                                           0.332915
# 397                                           0.043072
# 396                                           0.223272
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.logfc  \
# 421                                        0.820970
# 420                                       -0.141641
# 419                                        0.166742
# 418                                       -0.096817
# 417                                        0.967391
# 416                                        0.188885
# 415                                        0.601119
# 414                                       -0.148414
# 413                                       -0.151305
# 412                                        0.052687
# 411                                       -0.015139
# 410                                        1.542522
# 409                                       -0.193442
# 408                                       -0.486367
# 407                                        0.117881
# 406                                        0.020653
# 405                                        0.081553
# 404                                        0.164026
# 403                                        0.221556
# 402                                       -0.304927
# 401                                       -0.382870
# 400                                        0.317506
# 399                                       -0.653556
# 398                                       -0.303295
# 397                                        0.273099
# 396                                        0.915001
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.jsd  \
# 421                                      0.111699
# 420                                     -0.051438
# 419                                      0.021537
# 418                                     -0.046875
# 417                                      0.092217
# 416                                      0.045165
# 415                                      0.087399
# 414                                     -0.034991
# 413                                     -0.074726
# 412                                      0.032542
# 411                                     -0.017163
# 410                                      0.130211
# 409                                     -0.034220
# 408                                     -0.155775
# 407                                      0.036495
# 406                                      0.010726
# 405                                      0.022571
# 404                                      0.055893
# 403                                      0.032712
# 402                                     -0.105591
# 401                                     -0.111471
# 400                                      0.033587
# 399                                     -0.077809
# 398                                     -0.026455
# 397                                      0.084513
# 396                                      0.283127
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.ips  \
# 421                                      0.020781
# 420                                      0.000970
# 419                                      0.000854
# 418                                      0.004209
# 417                                      0.050607
# 416                                      0.002038
# 415                                      0.022796
# 414                                      0.003411
# 413                                      0.000603
# 412                                      0.000129
# 411                                      0.000381
# 410                                      0.099296
# 409                                      0.001026
# 408                                      0.032302
# 407                                      0.001118
# 406                                      0.000157
# 405                                      0.001829
# 404                                      0.009270
# 403                                      0.002490
# 402                                      0.012102
# 401                                      0.008290
# 400                                      0.004539
# 399                                      0.035827
# 398                                      0.005932
# 397                                      0.003310
# 396                                      0.032416
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.logfc  \
# 421                                       0.326687
# 420                                      -0.036679
# 419                                       0.058925
# 418                                      -0.055512
# 417                                       0.281895
# 416                                       0.136458
# 415                                       0.166630
# 414                                      -0.164774
# 413                                      -0.003055
# 412                                      -0.043158
# 411                                       0.039560
# 410                                       0.507238
# 409                                      -0.049269
# 408                                      -0.227332
# 407                                       0.065199
# 406                                       0.012085
# 405                                       0.043051
# 404                                       0.053284
# 403                                       0.064261
# 402                                      -0.065666
# 401                                      -0.104725
# 400                                       0.189694
# 399                                      -0.210268
# 398                                      -0.154891
# 397                                       0.047210
# 396                                       0.328260
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.jsd  \
# 421                                     0.096042
# 420                                    -0.019422
# 419                                     0.015999
# 418                                    -0.029448
# 417                                     0.071430
# 416                                     0.045281
# 415                                     0.048224
# 414                                    -0.026710
# 413                                    -0.006213
# 412                                    -0.014077
# 411                                     0.014313
# 410                                     0.103556
# 409                                    -0.020308
# 408                                    -0.136237
# 407                                     0.026914
# 406                                     0.012344
# 405                                     0.020906
# 404                                     0.045827
# 403                                     0.022320
# 402                                    -0.034129
# 401                                    -0.089676
# 400                                     0.036582
# 399                                    -0.056945
# 398                                    -0.027267
# 397                                     0.090057
# 396                                     0.251000
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.ips
# 421                                     0.006301
# 420                                     0.000163
# 419                                     0.000345
# 418                                     0.001214
# 417                                     0.008648
# 416                                     0.001688
# 415                                     0.002971
# 414                                     0.003191
# 413                                     0.000004
# 412                                     0.000053
# 411                                     0.000312
# 410                                     0.015007
# 409                                     0.000158
# 408                                     0.008980
# 407                                     0.000572
# 406                                     0.000057
# 405                                     0.000787
# 404                                     0.002281
# 403                                     0.000422
# 402                                     0.000756
# 401                                     0.001996
# 400                                     0.002890
# 399                                     0.006429
# 398                                     0.001810
# 397                                     0.000691
# 396                                     0.011531
#
# [26 rows x 45 columns]

# %%
plt.plot(newdf[newdf['var.chrom']=="chr3"]["var.pos_hg19"].values)

# %%
diff = newdf["var.pos_hg19"].diff()

# %%
mask = diff.abs() < 1000

# %%
#np.sort(diff.abs())

# %%
sum(mask)
# Out:
# 4

# %%
diff[mask]
# Out:
# 463    -27.0
# 452    -72.0
# 298   -170.0
# 61     -73.0
# Name: var.pos_hg19, dtype: float64

# %%
newdf.loc[463:469,:]
# Out:
#     var.chrom  var.pos_hg19 var.allele1 var.allele2    var.rsid  obs.label  \
# 463      chr5     132866975           C           G    rs823991          1
# 464      chr5     132867002           G           A    rs823992          1
# 465      chr5     133882639           C           A   rs4958189          1
# 466      chr5     137937318           G           A  rs11242436          1
# 467      chr5     150618993           T           C  rs72794132          1
# 468      chr5     153577099           G           A  rs55946756          1
# 469      chr5     153618712           G           C  rs74396372          1
#
#      var.isused  obs.estimate  pred.gkmsvm.encsr000emt.varscore.deltasvm  \
# 463        True       -0.9007                                  -5.587800
# 464        True       -0.7486                                 -12.801433
# 465        True        1.0950                                   5.268227
# 466        True        0.9855                                   6.997243
# 467        True       -1.2780                                  -3.093466
# 468        True        0.8093                                   4.002773
# 469        True       -1.1710                                  -3.859885
#
#      pred.enformer.encsr000emt.varscore.global_sad  ...  \
# 463                                       0.000064  ...
# 464                                      -0.001295  ...
# 465                                       0.001057  ...
# 466                                       0.007010  ...
# 467                                      -0.004475  ...
# 468                                      -0.004448  ...
# 469                                      -0.003950  ...
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.aaq  \
# 463                                      0.636967
# 464                                      0.651068
# 465                                      0.117665
# 466                                      0.493146
# 467                                      0.304990
# 468                                      0.440272
# 469                                      0.367339
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.ies  \
# 463                                      0.013091
# 464                                      0.054868
# 465                                      0.040962
# 466                                      0.093025
# 467                                      0.274788
# 468                                      0.060155
# 469                                      0.042817
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq  \
# 463                                           0.035124
# 464                                           0.039140
# 465                                           0.008801
# 466                                           0.040465
# 467                                           0.077893
# 468                                           0.068781
# 469                                           0.023402
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq  \
# 463                                           0.147120
# 464                                           0.570535
# 465                                           0.067814
# 466                                           0.538237
# 467                                           0.314057
# 468                                           0.167274
# 469                                           0.237060
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.logfc  \
# 463                                       -0.222111
# 464                                       -0.767703
# 465                                        0.433198
# 466                                        0.852853
# 467                                       -0.872374
# 468                                        0.254969
# 469                                       -0.459853
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.jsd  \
# 463                                     -0.060891
# 464                                     -0.068672
# 465                                      0.067040
# 466                                      0.074192
# 467                                     -0.267241
# 468                                      0.145468
# 469                                     -0.051568
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.ips  \
# 463                                      0.007337
# 464                                      0.028155
# 465                                      0.003490
# 466                                      0.030390
# 467                                      0.052306
# 468                                      0.015291
# 469                                      0.008282
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.logfc  \
# 463                                      -0.070184
# 464                                      -0.232271
# 465                                       0.167892
# 466                                       0.395728
# 467                                      -0.267408
# 468                                       0.205392
# 469                                      -0.038226
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.jsd  \
# 463                                    -0.030603
# 464                                    -0.053321
# 465                                     0.055930
# 466                                     0.053673
# 467                                    -0.210576
# 468                                     0.163947
# 469                                    -0.011883
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.ips
# 463                                     0.000965
# 464                                     0.005319
# 465                                     0.001061
# 466                                     0.007366
# 467                                     0.011222
# 468                                     0.012600
# 469                                     0.000215
#
# [7 rows x 45 columns]

# %%
newdf.loc[61:63,:]
# Out:
#    var.chrom  var.pos_hg19 var.allele1 var.allele2    var.rsid  obs.label  \
# 61     chr10      75911342           G           C  rs10824083          1
# 62     chr10      75911415           C           T  rs10824084          1
# 63     chr10      80197361           T           G  rs77570953          1
#
#     var.isused  obs.estimate  pred.gkmsvm.encsr000emt.varscore.deltasvm  \
# 61        True        0.7581                                   3.211179
# 62        True        0.6487                                   1.465231
# 63        True        1.5330                                   1.840004
#
#     pred.enformer.encsr000emt.varscore.global_sad  ...  \
# 61                                       0.000211  ...
# 62                                       0.000297  ...
# 63                                       0.001089  ...
#
#     pred.chrombpnet.encsr637xsc_50m.varscore.aaq  \
# 61                                      0.871857
# 62                                      0.789447
# 63                                      0.436784
#
#     pred.chrombpnet.encsr637xsc_50m.varscore.ies  \
# 61                                      0.019301
# 62                                      0.000581
# 63                                      0.009559
#
#     pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq  \
# 61                                           0.064960
# 62                                           0.011063
# 63                                           0.012995
#
#     pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq  \
# 61                                           0.224810
# 62                                           0.032909
# 63                                           0.118076
#
#     pred.chrombpnet.encsr637xsc_25m.varscore.logfc  \
# 61                                        0.187870
# 62                                        0.048786
# 63                                        0.093123
#
#     pred.chrombpnet.encsr637xsc_25m.varscore.jsd  \
# 61                                      0.078877
# 62                                      0.014944
# 63                                      0.017480
#
#     pred.chrombpnet.encsr637xsc_25m.varscore.ips  \
# 61                                      0.013863
# 62                                      0.000629
# 63                                      0.000633
#
#     pred.chrombpnet.encsr637xsc_5m.varscore.logfc  \
# 61                                       0.075078
# 62                                       0.021391
# 63                                       0.003827
#
#     pred.chrombpnet.encsr637xsc_5m.varscore.jsd  \
# 61                                     0.046417
# 62                                     0.013766
# 63                                     0.009344
#
#     pred.chrombpnet.encsr637xsc_5m.varscore.ips
# 61                                     0.002973
# 62                                     0.000238
# 63                                     0.000069
#
# [3 rows x 45 columns]

# %%
newdf.loc[298:300,:]
# Out:
#     var.chrom  var.pos_hg19 var.allele1 var.allele2     var.rsid  obs.label  \
# 298      chr2       9983686           T           G    rs2303914          1
# 299      chr2       9983856           G           A  rs115657324          1
# 300      chr2      10169300           C           G    rs6741776          1
#
#      var.isused  obs.estimate  pred.gkmsvm.encsr000emt.varscore.deltasvm  \
# 298        True       -0.5864                                  -4.072223
# 299        True       -1.2130                                  -1.512685
# 300        True       -0.7245                                  -4.875526
#
#      pred.enformer.encsr000emt.varscore.global_sad  ...  \
# 298                                      -0.001447  ...
# 299                                      -0.000372  ...
# 300                                      -0.005955  ...
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.aaq  \
# 298                                      0.984103
# 299                                      0.967353
# 300                                      0.749257
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.ies  \
# 298                                      0.000259
# 299                                      0.000561
# 300                                      0.022688
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq  \
# 298                                           0.023705
# 299                                           0.020542
# 300                                           0.054489
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq  \
# 298                                           0.010022
# 299                                           0.025420
# 300                                           0.232308
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.logfc  \
# 298                                       -0.005048
# 299                                       -0.049169
# 300                                       -0.226588
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.jsd  \
# 298                                     -0.031338
# 299                                     -0.017865
# 300                                     -0.065657
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.ips  \
# 298                                      0.000382
# 299                                      0.000857
# 300                                      0.011126
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.logfc  \
# 298                                      -0.004709
# 299                                      -0.026088
# 300                                      -0.113183
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.jsd  \
# 298                                    -0.019532
# 299                                    -0.013528
# 300                                    -0.051654
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.ips
# 298                                     0.000191
# 299                                     0.000340
# 300                                     0.004025
#
# [3 rows x 45 columns]

# %%
newdf.loc[452:457,:]
# Out:
#     var.chrom  var.pos_hg19 var.allele1 var.allele2    var.rsid  obs.label  \
# 452      chr5      34452510           C           T   rs6451097          1
# 453      chr5      34452582           G           A   rs6451098          1
# 454      chr5      40437845           A           G   rs9292776          1
# 455      chr5      56205357           A           G    rs185220          1
# 456      chr5      59020526           T           G  rs56763295          1
#
#      var.isused  obs.estimate  pred.gkmsvm.encsr000emt.varscore.deltasvm  \
# 452        True        1.0060                                   8.665144
# 453        True        1.0690                                  -3.237986
# 454        True       -0.7408                                  -6.748464
# 455        True       -0.7502                                  -6.541892
# 456        True       -0.5926                                  -9.648554
#
#      pred.enformer.encsr000emt.varscore.global_sad  ...  \
# 452                                       0.000159  ...
# 453                                       0.000015  ...
# 454                                       0.000189  ...
# 455                                      -0.004433  ...
# 456                                      -0.000408  ...
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.aaq  \
# 452                                      0.215498
# 453                                      0.236626
# 454                                      0.714247
# 455                                      0.984001
# 456                                      0.012719
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.ies  \
# 452                                      0.050969
# 453                                      0.001829
# 454                                      0.010964
# 455                                      0.020791
# 456                                      0.135030
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq  \
# 452                                           0.035547
# 453                                           0.003394
# 454                                           0.024564
# 455                                           0.074527
# 456                                           0.002963
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq  \
# 452                                           0.070687
# 453                                           0.024061
# 454                                           0.224446
# 455                                           0.264613
# 456                                           0.007731
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.logfc  \
# 452                                        0.158468
# 453                                       -0.035114
# 454                                       -0.307851
# 455                                       -0.210279
# 456                                       -0.527439
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.jsd  \
# 452                                      0.130611
# 453                                     -0.013992
# 454                                     -0.030032
# 455                                     -0.069660
# 456                                     -0.225615
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.ips  \
# 452                                      0.004071
# 453                                      0.000111
# 454                                      0.006440
# 455                                      0.014472
# 456                                      0.002815
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.logfc  \
# 452                                       0.103375
# 453                                      -0.005684
# 454                                      -0.127723
# 455                                      -0.135177
# 456                                      -0.328706
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.jsd  \
# 452                                     0.143592
# 453                                    -0.010481
# 454                                    -0.022915
# 455                                    -0.062595
# 456                                    -0.278949
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.ips
# 452                                     0.003862
# 453                                     0.000086
# 454                                     0.002014
# 455                                     0.008270
# 456                                     0.005039
#
# [5 rows x 45 columns]

# %%
newdf.iloc[60:63]["pred.chrombpnet.encsr637xsc.varscore.logfc"]
# Out:
# 61    0.145453
# 62    0.048056
# 63    0.463644
# Name: pred.chrombpnet.encsr637xsc.varscore.logfc, dtype: float64

# %%
# Shift the mask by one row to identify the previous row in the pair
mask_shifted = mask.shift(-1)

# Combine the masks to find consecutive rows
consecutive_mask = mask & mask_shifted

# Return the rows that meet the criteria
newdf[mask]
# Out:
#     var.chrom  var.pos_hg19 var.allele1 var.allele2     var.rsid  obs.label  \
# 62      chr10      75911415           C           T   rs10824084          1
# 299      chr2       9983856           G           A  rs115657324          1
# 453      chr5      34452582           G           A    rs6451098          1
# 464      chr5     132867002           G           A     rs823992          1
#
#      var.isused  obs.estimate  pred.gkmsvm.encsr000emt.varscore.deltasvm  \
# 62         True        0.6487                                   1.465231
# 299        True       -1.2130                                  -1.512685
# 453        True        1.0690                                  -3.237986
# 464        True       -0.7486                                 -12.801433
#
#      pred.enformer.encsr000emt.varscore.global_sad  ...  \
# 62                                        0.000297  ...
# 299                                      -0.000372  ...
# 453                                       0.000015  ...
# 464                                      -0.001295  ...
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.aaq  \
# 62                                       0.789447
# 299                                      0.967353
# 453                                      0.236626
# 464                                      0.651068
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.ies  \
# 62                                       0.000581
# 299                                      0.000561
# 453                                      0.001829
# 464                                      0.054868
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.jsd_x_aaq  \
# 62                                            0.011063
# 299                                           0.020542
# 453                                           0.003394
# 464                                           0.039140
#
#      pred.chrombpnet.encsr637xsc_50m.varscore.logfc_x_aaq  \
# 62                                            0.032909
# 299                                           0.025420
# 453                                           0.024061
# 464                                           0.570535
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.logfc  \
# 62                                         0.048786
# 299                                       -0.049169
# 453                                       -0.035114
# 464                                       -0.767703
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.jsd  \
# 62                                       0.014944
# 299                                     -0.017865
# 453                                     -0.013992
# 464                                     -0.068672
#
#      pred.chrombpnet.encsr637xsc_25m.varscore.ips  \
# 62                                       0.000629
# 299                                      0.000857
# 453                                      0.000111
# 464                                      0.028155
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.logfc  \
# 62                                        0.021391
# 299                                      -0.026088
# 453                                      -0.005684
# 464                                      -0.232271
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.jsd  \
# 62                                      0.013766
# 299                                    -0.013528
# 453                                    -0.010481
# 464                                    -0.053321
#
#      pred.chrombpnet.encsr637xsc_5m.varscore.ips
# 62                                      0.000238
# 299                                     0.000340
# 453                                     0.000086
# 464                                     0.005319
#
# [4 rows x 45 columns]

# %%
# Out:
# nan

# %%
dataf[dataf["var.rsid"]=="rs76943706"]["pred.enformer.encsr000emt.varscore.local_logfc"]
# Out:
# 268    0.246145
# Name: pred.enformer.encsr000emt.varscore.local_logfc, dtype: float64

# %%
dataf[dataf["var.rsid"]=="rs76943706"]["pred.chrombpnet.encsr637xsc_50m.varscore.logfc"]
# Out:
# 268    1.1031
# Name: pred.chrombpnet.encsr637xsc_50m.varscore.logfc, dtype: float64

# %%
dataf[dataf["var.rsid"]=="rs7094325"]["obs.estimate"]
# Out:
# 69   -1.154
# Name: obs.estimate, dtype: float64

# %%
plt.scatter(dataf["obs.estimate"], dataf["pred.enformer.encsr000emt.varscore.local_logfc"], s=1)

# %%
import pickle as pkl
import os
enformer_recompute = pkl.load(open(os.path.join("/mnt/lab_data2/anusri/variant-scorer/src/output/dsqtls_lcl/enformer_preds_small_window/predictions_at_snp.pkl"),'rb'))
mean_change=[]
for i in range(data.shape[0]):
    mean_change.append(np.log2( (enformer_recompute["ref_logcount_preds"][i,440+4:456-4].sum()+1) / (enformer_recompute["alt_logcount_preds"][i,440+4:456-4].sum()+1)))

# %%
plt.plot(enformer_recompute["ref_logcount_preds"][410,440+4:456-4])

# %%
mean_change[410]
# Out:
# 0.22869224994648316

# %%
print
