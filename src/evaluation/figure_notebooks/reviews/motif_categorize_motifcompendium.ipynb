# %%
#conda activate motifcompendium
#get stats
#/mnt/lab_data2/anusri/MotifCompendium/final-composite-from-selex-1.ipynb
#para to replace https://docs.google.com/document/d/18sNI6W7ucmfASomK0SP0b52W7yq91Wmsnbt2pn_eSgQ/edit?tab=t.0
#motif_categorize.ipynb to carectorize the filtered motifs
