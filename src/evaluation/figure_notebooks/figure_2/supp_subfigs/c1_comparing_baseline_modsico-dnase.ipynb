# %%
import pandas as pd

uncorrected = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper_new/DNASE_SE/GM12878/uncorrected_model_05.10.2022/SIGNAL/modisco_crop_500/profile.tomtom.tsv'
uncorrected_annotations_path = "/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/uncorrected_model_05.10.2022/profile_annotations_chip.tsv"
hint = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper_new/DNASE_SE/GM12878/DNASE_SE_11.28.2022_hint_atac/SIGNAL/modisco_crop_500/profile.tomtom.tsv'
hint_annotations_path = "/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/DNASE_SE_11.28.2022_hint_atac/profile_annotations_chip.tsv"
simple_bias = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper_new/DNASE_SE/GM12878/DNASE_SE_03.06.2022_simplebias/SIGNAL/modisco_crop_500/profile.tomtom.tsv'
simple_bias_annotations_path = "/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/DNASE_SE_03.06.2022_simplebias/profile_annotations_chip.tsv"

corrected = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper_new/DNASE_SE/GM12878/GM12878_03.06.2022_bias_128_4_1234_0.8_fold_0/SIGNAL/modisco_crop_500/profile.tomtom.tsv'
corrected_annotations_path = "/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/GM12878_03.06.2022_bias_128_4_1234_0.8_fold_0/profile_annotations_chip.tsv"
corrected_counts = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper_new/DNASE_SE/GM12878/GM12878_03.06.2022_bias_128_4_1234_0.8_fold_0/SIGNAL/modisco_crop_500/counts.tomtom.tsv'
corrected_annotations_path_counts = "/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/GM12878_03.06.2022_bias_128_4_1234_0.8_fold_0/counts_annotations_chip.tsv"

# %%
def read_data(tomtom_path_atac,annotations_path,model_name):
    atac_data = pd.read_csv(tomtom_path_atac,sep="\t")
    atac_data["Num_Seqlets"] = atac_data["Num_Seqlets"]/sum(atac_data["Num_Seqlets"])
    atac_data["Pattern"] = atac_data["Pattern"].str.replace("metacluster_","").str.replace(".pattern_","_")
    annotations = pd.read_csv(annotations_path,sep=",", names=["Pattern", "Label"])
    merged = pd.merge(annotations,atac_data,on="Pattern",how="inner")
    merged = merged[merged["Num_Seqlets"]>0.01]
    merged["model"] = model_name
    return merged

# %%
df1 = read_data(uncorrected,uncorrected_annotations_path, "Uncorrected")
df2 = read_data(hint,hint_annotations_path, "HINT-ATAC")
df4 = read_data(simple_bias,simple_bias_annotations_path, "Simple-bias")
df5 = read_data(corrected,corrected_annotations_path, "ChromBpnet-Profile")
df6 = read_data(corrected_counts,corrected_annotations_path_counts, "ChromBpnet-Counts")

df1 = df1.append(df2, ignore_index=True)
df1 = df1.append(df4, ignore_index=True)
df1 = df1.append(df5, ignore_index=True)
df1 = df1.append(df6, ignore_index=True)
# Out:
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.

# %%
df1[["Label", "model", "Num_Seqlets"]].to_csv("modisco_compare/combine_pd_benchmark.csv",sep=",",header=False,index=False)

# %%
df1
# Out:
#    Pattern      Label  Num_Seqlets                Match_1       q-value  \
# 0      0_0       CTCF     0.196057          CTCF_MA0139.1  3.019530e-12
# 1      0_1       SPI1     0.123087   ELF5_HUMAN.H11MO.0.A  4.477090e-05
# 2      0_2      RUNX3     0.120942  RUNX1_HUMAN.H11MO.0.A  9.497370e-02
# 3      0_3  BATF/JUNB     0.118962   ATF3_MOUSE.H11MO.0.A  4.427060e-03
# 4      0_4       IRF4     0.081632   IRF8_HUMAN.H11MO.0.B  1.021730e-05
# ..     ...        ...          ...                    ...           ...
# 77    0_11       NFYA     0.016613   NFYB_HUMAN.H11MO.0.A  1.526200e-03
# 78    0_12       EBF1     0.016577   COE1_MOUSE.H11MO.0.A  1.030080e-06
# 79    0_13       RELB     0.014973   RELB_HUMAN.H11MO.0.C  7.313800e-01
# 80    0_14     ZNF143     0.012085  ZN143_MOUSE.H11MO.0.A  6.645740e-15
# 81    0_15      dimer     0.011194   ETS1_HUMAN.H11MO.0.A  2.894490e-02
#
#                   Match_2     q-value.1                Match_3     q-value.2  \
# ...
