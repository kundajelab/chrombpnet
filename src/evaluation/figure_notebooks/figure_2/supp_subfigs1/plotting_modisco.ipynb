# %%
data = read.table("naked_dna/combine_pd_benchmark.csv", sep=",")

# %%
data
# Out:
#    V1        V2                   V3
# 1  CTCF      naked-dna            0.22026456
# 2  GC        naked-dna            0.10840332
# 3  GC        naked-dna            0.10752511
# 4  BATF/JUNB naked-dna            0.08787530
# 5  SPI1      naked-dna            0.06449311
# 6  IRF4      naked-dna            0.06043142
# 7  SP1       naked-dna            0.04736813
# 8  RELB      naked-dna            0.04319666
# 9  GC        naked-dna            0.03633569
# 10 IRF4      naked-dna            0.03424996
# 11 IRF4      naked-dna            0.03414018
# 12 RUNX3     naked-dna            0.02920029
# 13 GC        naked-dna            0.02832208
# 14 GC        naked-dna            0.02069268
# 15 NFYA      naked-dna            0.01882650
# 16 SPI1      hepg2-bias           0.16192621
# 17 CTCF      hepg2-bias           0.15526283
# 18 RUNX3     hepg2-bias           0.12752962
# 19 IRF4      hepg2-bias           0.09294793
# 20 BATF/JUNB hepg2-bias           0.08406343
# 21 RELB      hepg2-bias           0.05090079
# 22 SP1       hepg2-bias           0.04781589
# 23 IRF4      hepg2-bias           0.03927073
# 24 IRF4      hepg2-bias           0.03300839
# 25 NFYA      hepg2-bias           0.02921397
# 26 NRF1      hepg2-bias           0.02119324
# 27 GC        hepg2-bias           0.01699778
# 28 POU2F2    hepg2-bias           0.01415967
# 29 ATF3      hepg2-bias           0.01351185
# 30 dimer     hepg2-bias           0.01252468
# 31 CTCF      gm12878-bias-profile 0.15175777
# 32 IRF4      gm12878-bias-profile 0.10694870
# 33 BATF/JUNB gm12878-bias-profile 0.08978287
# 34 SPI1      gm12878-bias-profile 0.07983262
# 35 RUNX3     gm12878-bias-profile 0.07426444
# 36 RELB      gm12878-bias-profile 0.06754308
# 37 IRF4      gm12878-bias-profile 0.06523673
# 38 SP1       gm12878-bias-profile 0.05377088
# 39 NFYA      gm12878-bias-profile 0.02915884
# 40 ELK1      gm12878-bias-profile 0.02553458
# 41 NRF1      gm12878-bias-profile 0.01943923
# 42 POU2F2    gm12878-bias-profile 0.01492537
# 43 BATF/IRF4 gm12878-bias-profile 0.01347567
# 44 ATF3      gm12878-bias-profile 0.01107048
# 45 CTCF      gm12878-bias-counts  0.15170770
# 46 IRF4      gm12878-bias-counts  0.13540158
# 47 SPI1      gm12878-bias-counts  0.12853338
# 48 BATF/JUNB gm12878-bias-counts  0.09573424
# 49 IRF4      gm12878-bias-counts  0.08895949
# 50 RUNX3     gm12878-bias-counts  0.08508153
# 51 RELB      gm12878-bias-counts  0.07531654
# 52 SP1       gm12878-bias-counts  0.03770499
# 53 ELK1      gm12878-bias-counts  0.03733122
# 54 RELB      gm12878-bias-counts  0.01752091
# 55 NFYA      gm12878-bias-counts  0.01565201
# 56 RELB      gm12878-bias-counts  0.01504462
# 57 POU2F2    gm12878-bias-counts  0.01443723
# 58 BATF/IRF4 gm12878-bias-counts  0.01317572
# 59 NRF1      gm12878-bias-counts  0.01294211
# 60 ATF3      gm12878-bias-counts  0.01013877

# %%
library(RColorBrewer)
n <- 15
qual_col_pals = brewer.pal.info[brewer.pal.info$category == 'qual',]
col_vector = unlist(mapply(brewer.pal, qual_col_pals$maxcolors, rownames(qual_col_pals)))
pie(rep(1,n), col=sample(col_vector, n))
# Out:
# plot without title

# %%
data
# Out:
#    V1        V2                   V3
# 1  CTCF      naked-dna            0.22026456
# 2  GC        naked-dna            0.10840332
# 3  GC        naked-dna            0.10752511
# 4  BATF/JUNB naked-dna            0.08787530
# 5  SPI1      naked-dna            0.06449311
# 6  IRF4      naked-dna            0.06043142
# 7  SP1       naked-dna            0.04736813
# 8  RELB      naked-dna            0.04319666
# 9  GC        naked-dna            0.03633569
# 10 IRF4      naked-dna            0.03424996
# 11 IRF4      naked-dna            0.03414018
# 12 RUNX3     naked-dna            0.02920029
# 13 GC        naked-dna            0.02832208
# 14 GC        naked-dna            0.02069268
# 15 NFYA      naked-dna            0.01882650
# 16 SPI1      hepg2-bias           0.16192621
# 17 CTCF      hepg2-bias           0.15526283
# 18 RUNX3     hepg2-bias           0.12752962
# 19 IRF4      hepg2-bias           0.09294793
# 20 BATF/JUNB hepg2-bias           0.08406343
# 21 RELB      hepg2-bias           0.05090079
# 22 SP1       hepg2-bias           0.04781589
# 23 IRF4      hepg2-bias           0.03927073
# 24 IRF4      hepg2-bias           0.03300839
# 25 NFYA      hepg2-bias           0.02921397
# 26 NRF1      hepg2-bias           0.02119324
# 27 GC        hepg2-bias           0.01699778
# 28 POU2F2    hepg2-bias           0.01415967
# 29 ATF3      hepg2-bias           0.01351185
# 30 dimer     hepg2-bias           0.01252468
# 31 CTCF      gm12878-bias-profile 0.15175777
# 32 IRF4      gm12878-bias-profile 0.10694870
# 33 BATF/JUNB gm12878-bias-profile 0.08978287
# 34 SPI1      gm12878-bias-profile 0.07983262
# 35 RUNX3     gm12878-bias-profile 0.07426444
# 36 RELB      gm12878-bias-profile 0.06754308
# 37 IRF4      gm12878-bias-profile 0.06523673
# 38 SP1       gm12878-bias-profile 0.05377088
# 39 NFYA      gm12878-bias-profile 0.02915884
# 40 ELK1      gm12878-bias-profile 0.02553458
# 41 NRF1      gm12878-bias-profile 0.01943923
# 42 POU2F2    gm12878-bias-profile 0.01492537
# 43 BATF/IRF4 gm12878-bias-profile 0.01347567
# 44 ATF3      gm12878-bias-profile 0.01107048
# 45 CTCF      gm12878-bias-counts  0.15170770
# 46 IRF4      gm12878-bias-counts  0.13540158
# 47 SPI1      gm12878-bias-counts  0.12853338
# 48 BATF/JUNB gm12878-bias-counts  0.09573424
# 49 IRF4      gm12878-bias-counts  0.08895949
# 50 RUNX3     gm12878-bias-counts  0.08508153
# 51 RELB      gm12878-bias-counts  0.07531654
# 52 SP1       gm12878-bias-counts  0.03770499
# 53 ELK1      gm12878-bias-counts  0.03733122
# 54 RELB      gm12878-bias-counts  0.01752091
# 55 NFYA      gm12878-bias-counts  0.01565201
# 56 RELB      gm12878-bias-counts  0.01504462
# 57 POU2F2    gm12878-bias-counts  0.01443723
# 58 BATF/IRF4 gm12878-bias-counts  0.01317572
# 59 NRF1      gm12878-bias-counts  0.01294211
# 60 ATF3      gm12878-bias-counts  0.01013877

# %%
merged_new2 = data[data$V2=="hepg2-bias",]
MotifNames = merged_new2[order(merged_new2$V3, decreasing=TRUE),]$V1
MotifNames
data$V1 <- factor(data$V1, levels = MotifNames[!duplicated(MotifNames)])
# Out:
#  [1] "SPI1"      "CTCF"      "RUNX3"     "IRF4"      "BATF/JUNB" "RELB"
#  [7] "SP1"       "IRF4"      "IRF4"      "NFYA"      "NRF1"      "GC"
# [13] "POU2F2"    "ATF3"      "dimer"

# %%
MotifNames
# Out:
#  [1] "SPI1"      "CTCF"      "RUNX3"     "IRF4"      "BATF/JUNB" "RELB"
#  [7] "SP1"       "IRF4"      "IRF4"      "NFYA"      "NRF1"      "GC"
# [13] "POU2F2"    "ATF3"      "dimer"

# %%
library(ggplot2)
#data
options(repr.plot.width = 9, repr.plot.height = 8)


ggplot(data, aes(x=V2, y=V3, fill=V1)) +
geom_bar(position='fill', stat='identity') +
theme_classic() +
theme(plot.title = element_text(hjust = 0.5),
    text = element_text(size=16),
    axis.line=element_blank(),
    axis.ticks.y=element_blank(),
    axis.title.x=element_blank(),
    axis.text.x = element_text(angle=0, vjust=0.5, hjust=0.5, size=14),
    axis.text.y = element_text(size=14),
    panel.border = element_rect(colour = "black", fill=NA, size=0.5)) +  scale_x_discrete(limits =c("naked-dna","hepg2-bias", "gm12878-bias-profile", "gm12878-bias-counts")) +
scale_fill_manual("legend", values = col_vector) +
ylab("Distribution of seqlets")
# Out:
# plot without title
