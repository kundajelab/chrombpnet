# %%
import pandas as pd

uncorrected = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper_new/ATAC_PE/GM12878/uncorrected_model_05.10.2022//SIGNAL/modisco_crop_500/profile.tomtom.tsv'
uncorrected_annotations_path = "/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/ATAC_PE/GM12878/uncorrected_model_05.10.2022/profile_annotations_chip_annotated.csv"
hint = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper_new/ATAC_PE/GM12878/ATAC_PE_09.22.2022_hint_atac/SIGNAL/modisco_crop_500/profile.tomtom.tsv'
hint_annotations_path = "/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/ATAC_PE/GM12878/ATAC_PE_09.22.2022_hint_atac/profile_annotations_chip_annotated.csv"
tobias = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper_new/ATAC_PE/GM12878/ATAC_PE_09.22.2022_tobias_with_bias_bigwig/SIGNAL/modisco_crop_500/profile.tomtom.tsv'
tobias_annotations_path = "/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/ATAC_PE/GM12878/ATAC_PE_09.22.2022_tobias_with_bias_bigwig/profile_annotations_chip_annotated.csv"
simple_bias = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper_new/ATAC_PE/GM12878/ATAC_PE_03.06.2022_simplebias/SIGNAL/modisco_crop_500/profile.tomtom.tsv'
simple_bias_annotations_path = "/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/ATAC_PE/GM12878/ATAC_PE_03.06.2022_simplebias/profile_annotations_chip_annotated.csv"

corrected = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper_new/ATAC_PE/GM12878/GM12878_03.01.2022_bias_128_4_1234_0.4_fold_0/SIGNAL/modisco_crop_500/profile.tomtom.tsv'
corrected_annotations_path = "/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/ATAC_PE/GM12878/GM12878_03.01.2022_bias_128_4_1234_0.4_fold_0/motif_annotations/profile_annotations_chip_annotated.csv"
corrected_counts = '/oak/stanford/groups/akundaje/projects/chrombpnet_paper_new/ATAC_PE/GM12878/GM12878_03.01.2022_bias_128_4_1234_0.4_fold_0/SIGNAL/modisco_crop_500/counts.tomtom.tsv'
corrected_annotations_path_counts = "/mnt/lab_data3/anusri/chrombpnet/results/chrombpnet/ATAC_PE/GM12878/GM12878_03.01.2022_bias_128_4_1234_0.4_fold_0/motif_annotations/counts_annotations_chip_annotated.csv"

# %%
def read_data(tomtom_path_atac,annotations_path,model_name):
    atac_data = pd.read_csv(tomtom_path_atac,sep="\t")
    atac_data["Num_Seqlets"] = atac_data["Num_Seqlets"]/sum(atac_data["Num_Seqlets"])
    atac_data["Pattern"] = atac_data["Pattern"].str.replace("metacluster_","").str.replace(".pattern_","_")
    annotations = pd.read_csv(annotations_path,sep=",", names=["Pattern", "Label"])
    merged = pd.merge(annotations,atac_data,on="Pattern",how="inner")
    merged = merged[merged["Num_Seqlets"]>0.01]
    merged["model"] = model_name
    return merged

# %%
df1 = read_data(uncorrected,uncorrected_annotations_path, "Uncorrected")
df2 = read_data(hint,hint_annotations_path, "HINT-ATAC")
df3 = read_data(tobias,tobias_annotations_path, "Tobias")
df4 = read_data(simple_bias,simple_bias_annotations_path, "Simple-bias")
df5 = read_data(corrected,corrected_annotations_path, "ChromBpnet-Profile")
df6 = read_data(corrected_counts,corrected_annotations_path_counts, "ChromBpnet-Counts")

df1 = df1.append(df2, ignore_index=True)
df1 = df1.append(df3, ignore_index=True)
df1 = df1.append(df4, ignore_index=True)
df1 = df1.append(df5, ignore_index=True)
df1 = df1.append(df6, ignore_index=True)
# Out:
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.

# %%
df1[["Label", "model", "Num_Seqlets"]].to_csv("subfigs/modisco_compare_baselines/combine_pd_benchmark.csv",sep=",",header=False,index=False)

# %%
df1
# Out:
#    Pattern      Label  Num_Seqlets                Match_1       q-value  \
# 0      0_0        Tn5     0.302442  TEAD1_MOUSE.H11MO.0.A  6.327780e-01
# 1      0_1        Tn5     0.210834                    NaN           NaN
# 2      0_2       CTCF     0.154871          CTCF_MA0139.1  3.891570e-14
# 3      0_3        Tn5     0.069752            TBX21_TBX_3  5.449500e-01
# 4      0_4        Tn5     0.038291          KLF4_MA0039.3  1.000000e+00
# ..     ...        ...          ...                    ...           ...
# 83    0_11       RELB     0.015045  NFKB1_HUMAN.H11MO.1.B  6.500480e-03
# 84    0_12     POU2F2     0.014437     Pou2f2.mouse_POU_2  6.807610e-03
# 85    0_13  BATF/IRF4     0.013176   BATF_HUMAN.H11MO.0.A  1.177080e-06
# 86    0_14       NRF1     0.012942   NRF1_MOUSE.H11MO.0.A  1.278260e-07
# 87    0_15       ATF3     0.010139      Mafb.mouse_bZIP_3  3.243920e-04
#
#                   Match_2     q-value.1                Match_3     q-value.2  \
# ...
