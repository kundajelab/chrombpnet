# %%
library(ggseqlogo)
library(ggplot2)
library(patchwork)

# %%
read_nptxt_matrix <- function(fname) {
    d=read.table(fname)
    colnames(d) = c("A", "C", "G", "T")
    t(d)
}

# %%
revcomp <- function(x) {
    x = x[rev(seq(nrow(x))), rev(seq(ncol(x)))]
    rownames(x) = c("A", "C", "G", "T")
    x
}

# %%
trim_and_plot <- function(m, rc=F, trim_left=0, trim_right=0, method='bits', ymin=0, ymax=2, title=NULL) {
    if (rc) {
        m = revcomp(m)                
    }

    #m = m[, trim_left:(ncol(m)-trim_right)]
    #m

    rownames(m) = c("A","C","G","T")
    
    
    f="helvetica_bold"
    
    p <- ggseqlogo(m, method=method, font=f, ncol=1, size=12) + 
                                    ylim(c(ymin,ymax)) +
                                    theme_void() 

    
    if (!is.null(title)) {
        p = p 
        p = p + ggtitle(title)
        p = p + theme(plot.title = element_text(hjust = 0.5, size=20))
        #p = p + theme(plot.title = element_text(hjust = 0.5, size=20))
    }
    
    p
}

# %%
get_plots <- function(subcluster_base_path, input_ls, annotations, ymax, rc=F, trim_left=0, trim_right=0, first_yaxis=F) {
    transient_plots = list()
    num_instances_per_motif = 5
    i = 1
    print("new")
    for (x in input_ls) {

        submotif = read_nptxt_matrix(sprintf(subcluster_base_path, x))

        #print(submotif)
        print(max(submotif))
 
        textn = annotations[annotations["key"]==sprintf("0_%d",x)][2]
        transient_plots[[i]] = trim_and_plot(submotif, rc, trim_left, trim_right, method='custom',
                                         ymin=-0.01, ymax=ymax, title=textn)

        #transient_plots[[i]] = trim_and_plot(submotif, rc, trim_left, trim_right)

        transient_plots[[i]] = transient_plots[[i]]  
                                    #annotate('text', 
                                    #         x=ncol(submotif), 
                                    #         y=max(submotif), 
                                    #         size=5,
                                    #         label=sprintf("%.2f",as.numeric(textn))
                                    #         )
        theme(plot.margin = unit(c(20,0,0,0), "pt"))
        transient_plots[[i]]


        i = i +1
        }
        
        
    transient_plots

}

# %%
get_plots1 <- function(subcluster_base_path, input_ls, annotations, ymax, ymaxn, rc=F, trim_left=0, trim_right=0, first_yaxis=F) {
    transient_plots = list()
    num_instances_per_motif = 5
    i = 1
    print("new")
    for (x in input_ls) {

        submotif = read_nptxt_matrix(sprintf(subcluster_base_path, x))

        #print(submotif)
        print(max(submotif))
        
        if (max(submotif)>(ymaxn)){
            ymax1=ymax}
        else{
            ymax1=ymaxn}
 
        textn = annotations[annotations["key"]==sprintf("0_%d",x)][2]
        transient_plots[[i]] = trim_and_plot(submotif, rc, trim_left, trim_right, method='custom',
                                         ymin=-0.01, ymax=ymax1, title=textn)

        #transient_plots[[i]] = trim_and_plot(submotif, rc, trim_left, trim_right)

        transient_plots[[i]] = transient_plots[[i]]  
                                    #annotate('text', 
                                    #         x=ncol(submotif), 
                                    #         y=max(submotif), 
                                    #         size=5,
                                    #         label=sprintf("%.2f",as.numeric(textn))
                                    #         )
        theme(plot.margin = unit(c(20,0,0,0), "pt"))
        transient_plots[[i]]


        i = i +1
        }
        
        
    transient_plots

}

# %%
options(repr.plot.width = 18, repr.plot.height = 15)

atac_annotations = read.table("../jan_3_2024/mean_modisco_plots/ATAC/HEPG2/counts_annotations.tsv",sep=",", header=FALSE)

colnames(atac_annotations) = c("key","label")

all_plots = get_plots("../jan_3_2024/mean_modisco_plots/ATAC/HEPG2/counts_0_%d.pfm", seq(0,9), atac_annotations,
                       rc=F, trim_left=0, trim_right=0, first_yaxis = F, ymax=0.068323)

atac_annotations = read.table("../jan_3_2024/mean_modisco_plots/ATAC/GM12878/counts_annotations.tsv",sep=",", header=FALSE)

colnames(atac_annotations) = c("key","label")

all_plots1 = get_plots("../jan_3_2024/mean_modisco_plots/ATAC/GM12878/counts_0_%d.pfm", seq(0,9), atac_annotations,
                       rc=F, trim_left=0, trim_right=0, first_yaxis = F, ymax=0.085323)

atac_annotations = read.table("../jan_3_2024/mean_modisco_plots/ATAC/K562/counts_annotations.tsv",sep=",", header=FALSE)

colnames(atac_annotations) = c("key","label")

all_plots2 = get_plots("../jan_3_2024/mean_modisco_plots/ATAC/K562/counts_0_%d.pfm", seq(0,9), atac_annotations,
                       rc=F, trim_left=0, trim_right=0, first_yaxis = F,ymax=0.075)

atac_annotations = read.table("../jan_3_2024/mean_modisco_plots/ATAC/H1ESC/counts_annotations.tsv",sep=",", header=FALSE)

colnames(atac_annotations) = c("key","label")

all_plots3 = get_plots("../jan_3_2024/mean_modisco_plots/ATAC/H1ESC/counts_0_%d.pfm", seq(0,9), atac_annotations,
                       rc=F, trim_left=0, trim_right=0, first_yaxis = F, ymax=0.084564)


atac_annotations = read.table("../jan_3_2024/mean_modisco_plots/ATAC/IMR90/counts_annotations.tsv",sep=",", header=FALSE)

colnames(atac_annotations) = c("key","label")

all_plots4 = get_plots("../jan_3_2024/mean_modisco_plots/ATAC/IMR90/counts_0_%d.pfm", seq(0,9), atac_annotations,
                       rc=F, trim_left=0, trim_right=0, first_yaxis = F,ymax=0.111)

#do.call(gridExtra::grid.arrange, c(all_plots, ncol=1))

wrap_plots(append(append(append(append(all_plots, all_plots1), all_plots2), all_plots3), all_plots4), nrow=10, byrow=FALSE)

ggsave("subfigs/compare_top_10_modisco_counts_jan_26.pdf", device = "pdf",  width = 18, height = 15, dpi = 300)
# Out:
# [1] "new"
# [1] 0.05842
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.056638
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.04011
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.029255
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.043397
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.065572
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.039104
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.043152
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.045231
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.039256
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] "new"
# [1] 0.076104
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.080554
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.065065
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.059854
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.056512
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.073508
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.091924
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.060287
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.039794
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.053802
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] "new"
# [1] 0.057836
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.049566
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.028837
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.042206
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.03512
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.033053
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.051769
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.030329
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.035002
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.036701
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] "new"
# [1] 0.0801
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.05945
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.048507
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.037939
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.051162
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.038201
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.036564
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.040199
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.047486
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.049345
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] "new"
# [1] 0.105229
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.106323
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.070857
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.066954
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.067887
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.048419
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.065861
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.056354
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.059152
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.057333
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# plot without title

# %%
options(repr.plot.width = 18, repr.plot.height = 15)

atac_annotations = read.table("../jan_3_2024/mean_modisco_plots/ATAC/HEPG2/profile_annotations.tsv",sep=",", header=FALSE)

colnames(atac_annotations) = c("key","label")

all_plots = get_plots1("../jan_3_2024/mean_modisco_plots/ATAC/HEPG2/profile_0_%d.pfm", seq(0,9), atac_annotations,
                       rc=F, trim_left=0, trim_right=0, first_yaxis = F, ymax=0.020798, ymaxn=0.006975)

atac_annotations = read.table("../jan_3_2024/mean_modisco_plots/ATAC/GM12878/profile_annotations.tsv",sep=",", header=FALSE)

colnames(atac_annotations) = c("key","label")

all_plots1 = get_plots1("../jan_3_2024/mean_modisco_plots/ATAC/GM12878/profile_0_%d.pfm", seq(0,9), atac_annotations,
                       rc=F, trim_left=0, trim_right=0, first_yaxis = F, ymax=0.035458, ymaxn=0.010525)

atac_annotations = read.table("../jan_3_2024/mean_modisco_plots/ATAC/K562/profile_annotations.tsv",sep=",", header=FALSE)

colnames(atac_annotations) = c("key","label")

all_plots2 = get_plots1("../jan_3_2024/mean_modisco_plots/ATAC/K562/profile_0_%d.pfm", seq(0,9), atac_annotations,
                       rc=F, trim_left=0, trim_right=0, first_yaxis = F,ymax=0.027318, ymaxn=0.007177)

atac_annotations = read.table("../jan_3_2024/mean_modisco_plots/ATAC/H1ESC/profile_annotations.tsv",sep=",", header=FALSE)

colnames(atac_annotations) = c("key","label")

all_plots3 = get_plots1("../jan_3_2024/mean_modisco_plots/ATAC/H1ESC/profile_0_%d.pfm", seq(0,9), atac_annotations,
                       rc=F, trim_left=0, trim_right=0, first_yaxis = F, ymax=0.019743, ymaxn=0.007579)


atac_annotations = read.table("../jan_3_2024/mean_modisco_plots/ATAC/IMR90/profile_annotations.tsv",sep=",", header=FALSE)

colnames(atac_annotations) = c("key","label")

all_plots4 = get_plots1("../jan_3_2024/mean_modisco_plots/ATAC/IMR90/profile_0_%d.pfm", seq(0,9), atac_annotations,
                       rc=F, trim_left=0, trim_right=0, first_yaxis = F,ymax=0.030718, ymaxn=0.01191)

#do.call(gridExtra::grid.arrange, c(all_plots, ncol=1))

wrap_plots(append(append(append(append(all_plots, all_plots1), all_plots2), all_plots3), all_plots4), nrow=10, byrow=FALSE)

ggsave("subfigs/compare_top_10_modisco_profile_jan_26.pdf", device = "pdf",  width = 18, height = 15, dpi = 300)
# Out:
# [1] "new"
# [1] 0.020798
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.005185
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.003216
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.00399
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.004424
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006103
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.004184
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006975
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.00358
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.004717
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] "new"
# [1] 0.035458
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.009131
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006504
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006287
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.005524
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.007101
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.008502
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.010525
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.007934
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006681
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] "new"
# [1] 0.027318
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.005036
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.005759
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006753
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.007177
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.00474
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.00104
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006287
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.003666
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.00464
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] "new"
# [1] 0.019743
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.007579
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.004985
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.005187
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.004783
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.004992
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.007434
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006563
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006489
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006791
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] "new"
# [1] 0.01191
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.030718
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.007057
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.0072
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.005897
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.008252
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.008337
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006342
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.006183
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# [1] 0.007378
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# plot without title
