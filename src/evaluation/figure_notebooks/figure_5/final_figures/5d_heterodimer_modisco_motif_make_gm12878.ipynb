# %%
library(ggseqlogo)
library(ggplot2)
library(patchwork)

# %%
read_nptxt_matrix <- function(fname) {
    d=read.table(fname)
    colnames(d) = c("A", "C", "G", "T")
    t(d)
}

# %%
subcluster_base_path="../jan_3_2024/mean_modisco_plots/ATAC/GM12878/profile_0_7.pfm"
submotif = read_nptxt_matrix(subcluster_base_path)

# %%
m=submotif

revcomp <- function(x) {
    x = x[rev(seq(nrow(x))), rev(seq(ncol(x)))]
    rownames(x) = c("A", "C", "G", "T")
    x
}

m = revcomp(m)                

options(repr.plot.width = 8, repr.plot.height = 1)

rownames(m) = c("A","C","G","T")
    
f="helvetica_regular"
    
p <- ggseqlogo(m, method="custom", font=f, ncol=1, size=12) + 
                                    theme_void() 
    
p

ggsave("subfigs/irf1_spi1_gm_motif.pdf", device = "pdf",  width = 8, height = 1, dpi = 300)
# Out:
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# plot without title

# %%
subcluster_base_path="../jan_3_2024/mean_modisco_plots/ATAC/GM12878/profile_0_12.pfm"
submotif = read_nptxt_matrix(subcluster_base_path)


m=submotif

revcomp <- function(x) {
    x = x[rev(seq(nrow(x))), rev(seq(ncol(x)))]
    rownames(x) = c("A", "C", "G", "T")
    x
}

#m = revcomp(m)                

options(repr.plot.width = 8, repr.plot.height = 1)

rownames(m) = c("A","C","G","T")
    
f="helvetica_regular"
    
p <- ggseqlogo(m, method="custom", font=f, ncol=1, size=12) + 
                                    theme_void() 
    
p

ggsave("subfigs/irf1_ap1_gm_motif.pdf", device = "pdf",  width = 8, height = 1, dpi = 300)
# Out:
# Warning message:
# “`guides(<scale> = FALSE)` is deprecated. Please use `guides(<scale> = "none")` instead.”
# plot without title
