# %%
import numpy as np
import pandas as pd
import h5py
import pysam
import os
from modisco.visualization import viz_sequence
from modisco import util
from matplotlib import pyplot as plt
import pybedtools
from bs4 import BeautifulSoup

pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
dttype = 'ATAC'
mode = "counts"
celltype="K562"
modisco_path = '/oak/stanford/groups/akundaje/projects/chromatin-atlas-2022/chrombpnet/folds/ATAC/'+celltype+'/merge_folds_new/'+mode+'/modisco_old_format.h5'
ppm_dir = ''

htmld="/oak/stanford/groups/akundaje/projects/chromatin-atlas-2022/chrombpnet/folds/"+dttype+'/'+celltype+"/merge_folds_new/"+mode+"/motifs.html"
tomtom = pd.read_html(htmld)


background=[0.25, 0.25, 0.25, 0.25]

# %%
def trim_motif_new(cwm, motif, trim_threshold=0.20):
    """
    Given the PFM and motif (both L x 4 arrays) (the motif could be the
    PFM itself), trims `motif` by cutting off flanks of low information
    content in `pfm`. `min_ic` is the minimum required information
    content. If specified this trimmed motif will be extended on either
    side by `pad` bases.
    If no base passes the `min_ic` threshold, then no trimming is done.
    """
    
    score = np.sum(np.abs(cwm), axis=1)
    trim_thresh = np.max(score) * trim_threshold  # Cut off anything less than 30% of max score
    pass_inds = np.where(score >= trim_thresh)[0]
    trimmed = motif[np.min(pass_inds): np.max(pass_inds) + 1]
 
    if not trimmed.size:
        return motif
    
    return trimmed

def import_tfmodisco_motifs(tfm_results_path, trim=True, only_pos=True):
    """
    Imports the PFMs to into a dictionary, mapping `(x, y)` to the PFM,
    where `x` is the metacluster index and `y` is the pattern index.
    Arguments:
        `tfm_results_path`: path to HDF5 containing TF-MoDISco results
        `out_dir`: where to save motifs
        `trim`: if True, trim the motif flanks based on information content
        `only_pos`: if True, only return motifs with positive contributions
    Returns the dictionary of PFMs.
    """ 
    pfms = {}
    with h5py.File(tfm_results_path, "r") as f:
        metaclusters = f["metacluster_idx_to_submetacluster_results"]
        num_metaclusters = len(metaclusters.keys())
        for metacluster_i, metacluster_key in enumerate(metaclusters.keys()):
            metacluster = metaclusters[metacluster_key]
            if "patterns" not in metacluster["seqlets_to_patterns_result"]:
                continue
            patterns = metacluster["seqlets_to_patterns_result"]["patterns"]
            num_patterns = len(patterns["all_pattern_names"][:])
            for pattern_i, pattern_name in enumerate(patterns["all_pattern_names"][:]):
#                pattern_name = pattern_name.decode()
                pattern_name = pattern_name

                pattern = patterns[pattern_name]
                pfm = pattern["sequence"]["fwd"][:]
                cwm = pattern["task0_contrib_scores"]["fwd"][:]
                
                # Check that the contribution scores are overall positive
                if only_pos and np.sum(cwm) < 0:
                    continue
                    
                if trim:
                    pfm = trim_motif_new(cwm, cwm)
                else:
                    pfm = cwm
                    
                pfms["%d_%d" % (metacluster_i,pattern_i)] = pfm
    return pfms

# %%
pfms = import_tfmodisco_motifs(modisco_path, trim=False)

# %%
for key in pfms:
    f = open(os.path.join(ppm_dir,mode+"_"+key+".pfm"),"w")
    #print(pfms[key])
    np.savetxt(f, pfms[key], fmt='%f')
    f.close()

# %%
tomtom[0]
# Out:
#                     pattern  num_seqlets  modisco_cwm_fwd  modisco_cwm_rev  \
# 0    pos_patterns.pattern_0        36366              NaN              NaN
# 1    pos_patterns.pattern_1        33817              NaN              NaN
# 2    pos_patterns.pattern_2        26683              NaN              NaN
# 3    pos_patterns.pattern_3        13473              NaN              NaN
# 4    pos_patterns.pattern_4         9415              NaN              NaN
# 5    pos_patterns.pattern_5         5999              NaN              NaN
# 6    pos_patterns.pattern_6         4151              NaN              NaN
# 7    pos_patterns.pattern_7         3616              NaN              NaN
# 8    pos_patterns.pattern_8         3234              NaN              NaN
# 9    pos_patterns.pattern_9         2722              NaN              NaN
# 10  pos_patterns.pattern_10         2699              NaN              NaN
# 11  pos_patterns.pattern_11         2553              NaN              NaN
# 12  pos_patterns.pattern_12         2279              NaN              NaN
# 13  pos_patterns.pattern_13         1719              NaN              NaN
# 14  pos_patterns.pattern_14         1293              NaN              NaN
# 15  pos_patterns.pattern_15         1002              NaN              NaN
# 16  pos_patterns.pattern_16          960              NaN              NaN
# 17  pos_patterns.pattern_17          933              NaN              NaN
# 18  pos_patterns.pattern_18          771              NaN              NaN
# 19  pos_patterns.pattern_19          525              NaN              NaN
# 20  pos_patterns.pattern_20          518              NaN              NaN
# 21  pos_patterns.pattern_21          304              NaN              NaN
# 22  pos_patterns.pattern_22          290              NaN              NaN
# 23  pos_patterns.pattern_23          247              NaN              NaN
# 24  pos_patterns.pattern_24          233              NaN              NaN
# 25  pos_patterns.pattern_25          224              NaN              NaN
# 26  pos_patterns.pattern_26          173              NaN              NaN
# 27  pos_patterns.pattern_27          133              NaN              NaN
# 28  pos_patterns.pattern_28          116              NaN              NaN
# 29  pos_patterns.pattern_29           96              NaN              NaN
# 30  pos_patterns.pattern_30           81              NaN              NaN
# 31  pos_patterns.pattern_31           76              NaN              NaN
# 32  pos_patterns.pattern_32           67              NaN              NaN
# 33  pos_patterns.pattern_33           64              NaN              NaN
# 34  pos_patterns.pattern_34           63              NaN              NaN
# 35  pos_patterns.pattern_35           61              NaN              NaN
# 36  pos_patterns.pattern_36           49              NaN              NaN
# 37  pos_patterns.pattern_37           47              NaN              NaN
# 38  pos_patterns.pattern_38           46              NaN              NaN
# 39  pos_patterns.pattern_39           42              NaN              NaN
# 40  pos_patterns.pattern_40           40              NaN              NaN
# 41  pos_patterns.pattern_41           38              NaN              NaN
# 42  pos_patterns.pattern_42           21              NaN              NaN
# 43   neg_patterns.pattern_0          497              NaN              NaN
# 44   neg_patterns.pattern_1          228              NaN              NaN
# 45   neg_patterns.pattern_2          205              NaN              NaN
# 46   neg_patterns.pattern_3          145              NaN              NaN
# 47   neg_patterns.pattern_4          120              NaN              NaN
# 48   neg_patterns.pattern_5          111              NaN              NaN
# 49   neg_patterns.pattern_6          104              NaN              NaN
# 50   neg_patterns.pattern_7           91              NaN              NaN
# 51   neg_patterns.pattern_8           89              NaN              NaN
# 52   neg_patterns.pattern_9           86              NaN              NaN
# 53  neg_patterns.pattern_10           80              NaN              NaN
# 54  neg_patterns.pattern_11           75              NaN              NaN
# 55  neg_patterns.pattern_12           47              NaN              NaN
# 56  neg_patterns.pattern_13           44              NaN              NaN
# 57  neg_patterns.pattern_14           40              NaN              NaN
# 58  neg_patterns.pattern_15           39              NaN              NaN
# 59  neg_patterns.pattern_16           39              NaN              NaN
# 60  neg_patterns.pattern_17           34              NaN              NaN
# 61  neg_patterns.pattern_18           34              NaN              NaN
# 62  neg_patterns.pattern_19           26              NaN              NaN
#
#                    match0         qval0  match0_logo                 match1  \
# 0            GATA3_GATA_1  2.261690e-01          NaN           GATA3_GATA_2
# 1           CTCF_MA0139.1  1.215460e-15          NaN   CTCF_HUMAN.H11MO.0.A
# 2   KLF12_HUMAN.H11MO.0.C  8.183800e-06          NaN   KLF3_HUMAN.H11MO.0.B
# 3   BACH2_MOUSE.H11MO.0.A  5.835680e-06          NaN  BACH2_HUMAN.H11MO.0.A
# 4          Gabpa_MA0062.2  9.275380e-05          NaN              EHF_ETS_1
# 5    NFYB_HUMAN.H11MO.0.A  1.351140e-03          NaN   NFYB_MOUSE.H11MO.0.A
# 6   CEBPG_HUMAN.H11MO.0.B  3.531970e-04          NaN   ATF4_HUMAN.H11MO.0.A
# 7    ETV4_MOUSE.H11MO.0.B  2.549890e-03          NaN   ELF5_HUMAN.H11MO.0.A
# 8           NRF1_MA0506.1  3.172790e-05          NaN   NRF1_MOUSE.H11MO.0.A
# 9   BACH2_HUMAN.H11MO.0.A  1.757660e-04          NaN  BACH2_MOUSE.H11MO.0.A
# 10    FOSL1+JUND_MA1143.1  1.868430e-04          NaN  CREB1_HUMAN.H11MO.0.A
# 11   NFIC_HUMAN.H11MO.0.A  6.551130e-06          NaN   NFIA_HUMAN.H11MO.0.C
# 12  ZNF76_HUMAN.H11MO.0.C  5.813130e-17          NaN  ZN143_MOUSE.H11MO.0.A
# 13    SP2_HUMAN.H11MO.0.A  2.852150e-04          NaN    SP2_MOUSE.H11MO.0.B
# 14   TYY1_HUMAN.H11MO.0.A  2.268760e-06          NaN   TYY1_MOUSE.H11MO.0.A
# 15         Stat4_MA0518.1  9.567500e-03          NaN  STA5A_MOUSE.H11MO.0.A
# 16        ZBTB33_MA0527.1  4.452670e-05          NaN  KAISO_HUMAN.H11MO.0.A
# 17    SP1_HUMAN.H11MO.0.A  2.091270e-06          NaN  PATZ1_HUMAN.H11MO.0.C
# 18           ARNTL_bHLH_1  3.371770e-05          NaN   USF1_HUMAN.H11MO.0.A
# 19          JUND_MA0492.1  2.149230e-04          NaN   ATF2_HUMAN.H11MO.0.B
# 20  ZNF76_HUMAN.H11MO.0.C  2.047250e-04          NaN          ZNF143_C2H2_1
# 21  CTCFL_MOUSE.H11MO.0.A  2.999620e-01          NaN  CTCFL_HUMAN.H11MO.0.A
# 22    SP2_HUMAN.H11MO.0.A  8.246200e-02          NaN    SP2_MOUSE.H11MO.0.B
# 23    GCR_MOUSE.H11MO.0.A  4.704300e-01          NaN   PRGR_MOUSE.H11MO.0.A
# 24           SP1_MA0079.3  1.410080e-05          NaN    SP1_HUMAN.H11MO.0.A
# 25          ZNF524_C2H2_2  1.000000e+00          NaN                    NaN
# 26           YY1_MA0095.2  7.055190e-03          NaN  ZFP42_HUMAN.H11MO.0.A
# 27          TFE3_MA0831.2  1.721260e-01          NaN   MITF_MOUSE.H11MO.0.A
# 28  KLF12_HUMAN.H11MO.0.C  1.047390e-02          NaN          KLF5_MA0599.1
# 29       Bhlha15_MA0607.1  1.000000e+00          NaN                    NaN
# 30   IRF1_MOUSE.H11MO.0.A  3.846650e-09          NaN   IRF2_HUMAN.H11MO.0.A
# 31   KLF6_HUMAN.H11MO.0.A  1.215540e-02          NaN   KLF6_MOUSE.H11MO.0.B
# 32             ETS1_ETS_2  6.379220e-01          NaN   ELF2_HUMAN.H11MO.0.C
# 33             SOX8_HMG_7  5.195060e-01          NaN            SOX10_HMG_4
# 34  PO3F1_MOUSE.H11MO.0.C  1.394820e-01          NaN           POU1F1_POU_1
# 35           GATA3_GATA_1  1.236000e-01          NaN         GATA3_MA0037.3
# 36            CTCF_C2H2_1  1.224710e-01          NaN   TYY1_HUMAN.H11MO.0.A
# 37    GATA1+TAL1_MA0140.2  2.362160e-05          NaN  GATA4_HUMAN.H11MO.0.A
# 38   SPI1_MOUSE.H11MO.0.A  2.302440e-02          NaN   ETV4_HUMAN.H11MO.0.B
# 39  STAT1_HUMAN.H11MO.0.A  1.457820e-05          NaN         STAT1_MA0137.3
# 40   ETV4_MOUSE.H11MO.0.B  9.180250e-02          NaN          Rfx1_MA0509.1
# 41  THA11_MOUSE.H11MO.0.B  3.672120e-01          NaN  THA11_HUMAN.H11MO.0.B
# 42   OTX2_MOUSE.H11MO.0.A  5.696990e-01          NaN           Crx_MA0467.1
# 43          NFYB_MA0502.1  2.069290e-01          NaN   PDX1_HUMAN.H11MO.0.A
# 44   REST_HUMAN.H11MO.0.A  2.271180e-14          NaN          REST_MA0138.2
# 45   HXA1_HUMAN.H11MO.0.C  2.009330e-03          NaN   HXA1_MOUSE.H11MO.0.C
# 46   ITF2_MOUSE.H11MO.0.B  7.240670e-01          NaN          TCF4_MA0830.1
# 47    MEOX2_homeodomain_3  1.000000e+00          NaN                    NaN
# 48            HIC2_C2H2_1  1.000000e+00          NaN          HIC2_MA0738.1
# 49       FOXO3_forkhead_3  7.382480e-01          NaN          Klf1_MA0493.1
# 50            HIC2_C2H2_1  4.454880e-02          NaN          HIC2_MA0738.1
# 51  ZN680_HUMAN.H11MO.0.C  9.999980e-01          NaN          REST_MA0138.2
# 52   Ddit3+Cebpa_MA0019.1  4.576730e-01          NaN      Atf4.mouse_bZIP_1
# 53  GFI1B_HUMAN.H11MO.0.A  1.000000e+00          NaN   EGR2_HUMAN.H11MO.0.A
# 54   ELF1_MOUSE.H11MO.0.A  1.000000e+00          NaN          ZNF713_C2H2_1
# 55          NFYA_MA0060.3  2.281990e-02          NaN  FOXI1_HUMAN.H11MO.0.B
# 56            CTCF_C2H2_1  5.042710e-04          NaN          CTCF_MA0139.1
# 57             YY2_C2H2_3  1.000000e+00          NaN  ZN329_HUMAN.H11MO.0.C
# 58   MYF6_HUMAN.H11MO.0.C  1.190630e-01          NaN   MYF6_MOUSE.H11MO.0.C
# 59        PKNOX2_MA0783.1  3.550630e-02          NaN          PKNOX2_MEIS_1
# 60             YY2_C2H2_3  5.186480e-01          NaN      FOSB+JUN_MA1127.1
# 61  TFAP4_HUMAN.H11MO.0.A  3.024530e-01          NaN  TGIF1_MOUSE.H11MO.0.A
# 62          NFYB_MA0502.1  1.509090e-01          NaN          NFYA_MA0060.3
#
#            qval1  match1_logo                   match2         qval2  \
# 0   2.261690e-01          NaN           GATA3_MA0037.3  2.261690e-01
# 1   5.730620e-12          NaN     CTCF_MOUSE.H11MO.0.A  3.063360e-11
# 2   4.967560e-05          NaN     KLF3_MOUSE.H11MO.0.A  4.967560e-05
# 3   5.835680e-06          NaN     NFE2_HUMAN.H11MO.0.A  7.780910e-06
# 4   9.275380e-05          NaN             EHF_MA0598.2  9.275380e-05
# 5   1.351140e-03          NaN     NFYC_HUMAN.H11MO.0.A  1.351140e-03
# 6   4.210770e-04          NaN     ATF4_MOUSE.H11MO.0.A  4.210770e-04
# 7   3.759180e-03          NaN      EHF_HUMAN.H11MO.0.B  3.759180e-03
# 8   3.172790e-05          NaN     NRF1_HUMAN.H11MO.0.A  3.172790e-05
# 9   1.757660e-04          NaN    NF2L2_MOUSE.H11MO.0.A  1.757660e-04
# 10  2.817550e-04          NaN    CREB1_MOUSE.H11MO.0.A  2.817550e-04
# 11  3.481470e-04          NaN     NFIA_MOUSE.H11MO.0.C  3.481470e-04
# 12  1.445460e-10          NaN    ZN143_HUMAN.H11MO.0.A  2.714390e-10
# 13  2.852150e-04          NaN      SP1_MOUSE.H11MO.0.A  6.622240e-04
# 14  6.294420e-05          NaN             YY1_MA0095.2  6.388930e-05
# 15  9.567500e-03          NaN    STAT3_MOUSE.H11MO.0.A  1.614960e-02
# 16  4.452670e-05          NaN    KAISO_MOUSE.H11MO.0.B  4.452670e-05
# 17  2.546480e-05          NaN      SP1_MOUSE.H11MO.0.A  8.983170e-05
# 18  3.371770e-05          NaN     USF1_MOUSE.H11MO.0.A  4.615160e-05
# 19  2.149230e-04          NaN     ATF2_MOUSE.H11MO.0.A  2.149230e-04
# 20  4.543960e-03          NaN          ZNF143_MA0088.2  4.543960e-03
# 21  2.999620e-01          NaN     CTCF_MOUSE.H11MO.0.A  2.999620e-01
# 22  8.246200e-02          NaN            KLF5_MA0599.1  8.246200e-02
# 23  4.704300e-01          NaN      GCR_HUMAN.H11MO.0.A  4.704300e-01
# 24  2.666940e-04          NaN     KLF1_HUMAN.H11MO.0.A  2.666940e-04
# 25           NaN          NaN                      NaN           NaN
# 26  7.055190e-03          NaN    ZFP42_MOUSE.H11MO.0.A  7.055190e-03
# 27  1.721260e-01          NaN     TFEB_HUMAN.H11MO.0.C  1.721260e-01
# 28  1.047390e-02          NaN             SP1_MA0079.3  1.047390e-02
# 29           NaN          NaN                      NaN           NaN
# 30  3.846650e-09          NaN     IRF2_MOUSE.H11MO.0.B  3.846650e-09
# 31  1.215540e-02          NaN     KLF3_HUMAN.H11MO.0.B  1.215540e-02
# 32  6.379220e-01          NaN  ESRRA_nuclearreceptor_6  6.379220e-01
# 33  5.195060e-01          NaN               SOX8_HMG_2  6.060650e-01
# 34  1.394820e-01          NaN          POU4F3_MA0791.1  1.394820e-01
# 35  1.236000e-01          NaN             GATA5_GATA_1  1.236000e-01
# 36  1.224710e-01          NaN               E2F2_E2F_1  1.224710e-01
# 37  4.079950e-01          NaN    GATA4_MOUSE.H11MO.0.A  4.079950e-01
# 38  2.700830e-02          NaN      ERG_HUMAN.H11MO.0.A  2.700830e-02
# 39  7.506710e-03          NaN           Stat4_MA0518.1  9.470530e-03
# 40  9.180250e-02          NaN      SRF_MOUSE.H11MO.0.A  9.180250e-02
# 41  3.672120e-01          NaN    ZN143_HUMAN.H11MO.0.A  7.764350e-01
# 42  5.696990e-01          NaN           Gata4_MA0482.1  5.696990e-01
# 43  3.211250e-01          NaN             Dux_MA0611.1  5.969840e-01
# 44  3.005100e-12          NaN     REST_MOUSE.H11MO.0.A  1.423440e-11
# 45  2.009330e-03          NaN     PDX1_HUMAN.H11MO.0.A  5.157460e-02
# 46  7.848750e-01          NaN              TCF4_bHLH_1  7.848750e-01
# 47           NaN          NaN                      NaN           NaN
# 48  1.000000e+00          NaN        Hic1.mouse_C2H2_2  1.000000e+00
# 49  7.382480e-01          NaN            MZF1_MA0056.1  7.382480e-01
# 50  4.454880e-02          NaN        Hic1.mouse_C2H2_2  2.316650e-01
# 51  9.999980e-01          NaN     REST_MOUSE.H11MO.0.A  9.999980e-01
# 52  4.576730e-01          NaN        Hic1.mouse_C2H2_2  4.576730e-01
# 53  1.000000e+00          NaN    GFI1B_MOUSE.H11MO.0.A  1.000000e+00
# 54  1.000000e+00          NaN     ELF1_HUMAN.H11MO.0.A  1.000000e+00
# 55  2.281990e-02          NaN    FOXI1_MOUSE.H11MO.0.B  2.281990e-02
# 56  5.042710e-04          NaN     CTCF_HUMAN.H11MO.0.A  1.668990e-03
# 57  1.000000e+00          NaN    SNAI2_MOUSE.H11MO.0.A  1.000000e+00
# 58  1.190630e-01          NaN    SNAI1_HUMAN.H11MO.0.C  1.217790e-01
# 59  3.550630e-02          NaN       Meis2.mouse_MEIS_2  3.550630e-02
# 60  5.186480e-01          NaN       FOSL1+JUN_MA1129.1  5.186480e-01
# 61  3.024530e-01          NaN           ASCL1_MA1100.1  3.975420e-01
# 62  1.513110e-01          NaN            KLF4_MA0039.3  2.646600e-01
#
#     match2_logo
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN
# 54          NaN
# 55          NaN
# 56          NaN
# 57          NaN
# 58          NaN
# 59          NaN
# 60          NaN
# 61          NaN
# 62          NaN

# %%
tomtom[0]["pattern"] = tomtom[0]["pattern"].str.replace("pos_patterns.pattern","0").str.replace("neg_patterns.pattern","1")
# Out:
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
tomtom[0]
# Out:
#    pattern  num_seqlets  modisco_cwm_fwd  modisco_cwm_rev  \
# 0      0_0        36366              NaN              NaN
# 1      0_1        33817              NaN              NaN
# 2      0_2        26683              NaN              NaN
# 3      0_3        13473              NaN              NaN
# 4      0_4         9415              NaN              NaN
# 5      0_5         5999              NaN              NaN
# 6      0_6         4151              NaN              NaN
# 7      0_7         3616              NaN              NaN
# 8      0_8         3234              NaN              NaN
# 9      0_9         2722              NaN              NaN
# 10    0_10         2699              NaN              NaN
# 11    0_11         2553              NaN              NaN
# 12    0_12         2279              NaN              NaN
# 13    0_13         1719              NaN              NaN
# 14    0_14         1293              NaN              NaN
# 15    0_15         1002              NaN              NaN
# 16    0_16          960              NaN              NaN
# 17    0_17          933              NaN              NaN
# 18    0_18          771              NaN              NaN
# 19    0_19          525              NaN              NaN
# 20    0_20          518              NaN              NaN
# 21    0_21          304              NaN              NaN
# 22    0_22          290              NaN              NaN
# 23    0_23          247              NaN              NaN
# 24    0_24          233              NaN              NaN
# 25    0_25          224              NaN              NaN
# 26    0_26          173              NaN              NaN
# 27    0_27          133              NaN              NaN
# 28    0_28          116              NaN              NaN
# 29    0_29           96              NaN              NaN
# 30    0_30           81              NaN              NaN
# 31    0_31           76              NaN              NaN
# 32    0_32           67              NaN              NaN
# 33    0_33           64              NaN              NaN
# 34    0_34           63              NaN              NaN
# 35    0_35           61              NaN              NaN
# 36    0_36           49              NaN              NaN
# 37    0_37           47              NaN              NaN
# 38    0_38           46              NaN              NaN
# 39    0_39           42              NaN              NaN
# 40    0_40           40              NaN              NaN
# 41    0_41           38              NaN              NaN
# 42    0_42           21              NaN              NaN
# 43     1_0          497              NaN              NaN
# 44     1_1          228              NaN              NaN
# 45     1_2          205              NaN              NaN
# 46     1_3          145              NaN              NaN
# 47     1_4          120              NaN              NaN
# 48     1_5          111              NaN              NaN
# 49     1_6          104              NaN              NaN
# 50     1_7           91              NaN              NaN
# 51     1_8           89              NaN              NaN
# 52     1_9           86              NaN              NaN
# 53    1_10           80              NaN              NaN
# 54    1_11           75              NaN              NaN
# 55    1_12           47              NaN              NaN
# 56    1_13           44              NaN              NaN
# 57    1_14           40              NaN              NaN
# 58    1_15           39              NaN              NaN
# 59    1_16           39              NaN              NaN
# 60    1_17           34              NaN              NaN
# 61    1_18           34              NaN              NaN
# 62    1_19           26              NaN              NaN
#
#                    match0         qval0  match0_logo                 match1  \
# 0            GATA3_GATA_1  2.261690e-01          NaN           GATA3_GATA_2
# 1           CTCF_MA0139.1  1.215460e-15          NaN   CTCF_HUMAN.H11MO.0.A
# 2   KLF12_HUMAN.H11MO.0.C  8.183800e-06          NaN   KLF3_HUMAN.H11MO.0.B
# 3   BACH2_MOUSE.H11MO.0.A  5.835680e-06          NaN  BACH2_HUMAN.H11MO.0.A
# 4          Gabpa_MA0062.2  9.275380e-05          NaN              EHF_ETS_1
# 5    NFYB_HUMAN.H11MO.0.A  1.351140e-03          NaN   NFYB_MOUSE.H11MO.0.A
# 6   CEBPG_HUMAN.H11MO.0.B  3.531970e-04          NaN   ATF4_HUMAN.H11MO.0.A
# 7    ETV4_MOUSE.H11MO.0.B  2.549890e-03          NaN   ELF5_HUMAN.H11MO.0.A
# 8           NRF1_MA0506.1  3.172790e-05          NaN   NRF1_MOUSE.H11MO.0.A
# 9   BACH2_HUMAN.H11MO.0.A  1.757660e-04          NaN  BACH2_MOUSE.H11MO.0.A
# 10    FOSL1+JUND_MA1143.1  1.868430e-04          NaN  CREB1_HUMAN.H11MO.0.A
# 11   NFIC_HUMAN.H11MO.0.A  6.551130e-06          NaN   NFIA_HUMAN.H11MO.0.C
# 12  ZNF76_HUMAN.H11MO.0.C  5.813130e-17          NaN  ZN143_MOUSE.H11MO.0.A
# 13    SP2_HUMAN.H11MO.0.A  2.852150e-04          NaN    SP2_MOUSE.H11MO.0.B
# 14   TYY1_HUMAN.H11MO.0.A  2.268760e-06          NaN   TYY1_MOUSE.H11MO.0.A
# 15         Stat4_MA0518.1  9.567500e-03          NaN  STA5A_MOUSE.H11MO.0.A
# 16        ZBTB33_MA0527.1  4.452670e-05          NaN  KAISO_HUMAN.H11MO.0.A
# 17    SP1_HUMAN.H11MO.0.A  2.091270e-06          NaN  PATZ1_HUMAN.H11MO.0.C
# 18           ARNTL_bHLH_1  3.371770e-05          NaN   USF1_HUMAN.H11MO.0.A
# 19          JUND_MA0492.1  2.149230e-04          NaN   ATF2_HUMAN.H11MO.0.B
# 20  ZNF76_HUMAN.H11MO.0.C  2.047250e-04          NaN          ZNF143_C2H2_1
# 21  CTCFL_MOUSE.H11MO.0.A  2.999620e-01          NaN  CTCFL_HUMAN.H11MO.0.A
# 22    SP2_HUMAN.H11MO.0.A  8.246200e-02          NaN    SP2_MOUSE.H11MO.0.B
# 23    GCR_MOUSE.H11MO.0.A  4.704300e-01          NaN   PRGR_MOUSE.H11MO.0.A
# 24           SP1_MA0079.3  1.410080e-05          NaN    SP1_HUMAN.H11MO.0.A
# 25          ZNF524_C2H2_2  1.000000e+00          NaN                    NaN
# 26           YY1_MA0095.2  7.055190e-03          NaN  ZFP42_HUMAN.H11MO.0.A
# 27          TFE3_MA0831.2  1.721260e-01          NaN   MITF_MOUSE.H11MO.0.A
# 28  KLF12_HUMAN.H11MO.0.C  1.047390e-02          NaN          KLF5_MA0599.1
# 29       Bhlha15_MA0607.1  1.000000e+00          NaN                    NaN
# 30   IRF1_MOUSE.H11MO.0.A  3.846650e-09          NaN   IRF2_HUMAN.H11MO.0.A
# 31   KLF6_HUMAN.H11MO.0.A  1.215540e-02          NaN   KLF6_MOUSE.H11MO.0.B
# 32             ETS1_ETS_2  6.379220e-01          NaN   ELF2_HUMAN.H11MO.0.C
# 33             SOX8_HMG_7  5.195060e-01          NaN            SOX10_HMG_4
# 34  PO3F1_MOUSE.H11MO.0.C  1.394820e-01          NaN           POU1F1_POU_1
# 35           GATA3_GATA_1  1.236000e-01          NaN         GATA3_MA0037.3
# 36            CTCF_C2H2_1  1.224710e-01          NaN   TYY1_HUMAN.H11MO.0.A
# 37    GATA1+TAL1_MA0140.2  2.362160e-05          NaN  GATA4_HUMAN.H11MO.0.A
# 38   SPI1_MOUSE.H11MO.0.A  2.302440e-02          NaN   ETV4_HUMAN.H11MO.0.B
# 39  STAT1_HUMAN.H11MO.0.A  1.457820e-05          NaN         STAT1_MA0137.3
# 40   ETV4_MOUSE.H11MO.0.B  9.180250e-02          NaN          Rfx1_MA0509.1
# 41  THA11_MOUSE.H11MO.0.B  3.672120e-01          NaN  THA11_HUMAN.H11MO.0.B
# 42   OTX2_MOUSE.H11MO.0.A  5.696990e-01          NaN           Crx_MA0467.1
# 43          NFYB_MA0502.1  2.069290e-01          NaN   PDX1_HUMAN.H11MO.0.A
# 44   REST_HUMAN.H11MO.0.A  2.271180e-14          NaN          REST_MA0138.2
# 45   HXA1_HUMAN.H11MO.0.C  2.009330e-03          NaN   HXA1_MOUSE.H11MO.0.C
# 46   ITF2_MOUSE.H11MO.0.B  7.240670e-01          NaN          TCF4_MA0830.1
# 47    MEOX2_homeodomain_3  1.000000e+00          NaN                    NaN
# 48            HIC2_C2H2_1  1.000000e+00          NaN          HIC2_MA0738.1
# 49       FOXO3_forkhead_3  7.382480e-01          NaN          Klf1_MA0493.1
# 50            HIC2_C2H2_1  4.454880e-02          NaN          HIC2_MA0738.1
# 51  ZN680_HUMAN.H11MO.0.C  9.999980e-01          NaN          REST_MA0138.2
# 52   Ddit3+Cebpa_MA0019.1  4.576730e-01          NaN      Atf4.mouse_bZIP_1
# 53  GFI1B_HUMAN.H11MO.0.A  1.000000e+00          NaN   EGR2_HUMAN.H11MO.0.A
# 54   ELF1_MOUSE.H11MO.0.A  1.000000e+00          NaN          ZNF713_C2H2_1
# 55          NFYA_MA0060.3  2.281990e-02          NaN  FOXI1_HUMAN.H11MO.0.B
# 56            CTCF_C2H2_1  5.042710e-04          NaN          CTCF_MA0139.1
# 57             YY2_C2H2_3  1.000000e+00          NaN  ZN329_HUMAN.H11MO.0.C
# 58   MYF6_HUMAN.H11MO.0.C  1.190630e-01          NaN   MYF6_MOUSE.H11MO.0.C
# 59        PKNOX2_MA0783.1  3.550630e-02          NaN          PKNOX2_MEIS_1
# 60             YY2_C2H2_3  5.186480e-01          NaN      FOSB+JUN_MA1127.1
# 61  TFAP4_HUMAN.H11MO.0.A  3.024530e-01          NaN  TGIF1_MOUSE.H11MO.0.A
# 62          NFYB_MA0502.1  1.509090e-01          NaN          NFYA_MA0060.3
#
#            qval1  match1_logo                   match2         qval2  \
# 0   2.261690e-01          NaN           GATA3_MA0037.3  2.261690e-01
# 1   5.730620e-12          NaN     CTCF_MOUSE.H11MO.0.A  3.063360e-11
# 2   4.967560e-05          NaN     KLF3_MOUSE.H11MO.0.A  4.967560e-05
# 3   5.835680e-06          NaN     NFE2_HUMAN.H11MO.0.A  7.780910e-06
# 4   9.275380e-05          NaN             EHF_MA0598.2  9.275380e-05
# 5   1.351140e-03          NaN     NFYC_HUMAN.H11MO.0.A  1.351140e-03
# 6   4.210770e-04          NaN     ATF4_MOUSE.H11MO.0.A  4.210770e-04
# 7   3.759180e-03          NaN      EHF_HUMAN.H11MO.0.B  3.759180e-03
# 8   3.172790e-05          NaN     NRF1_HUMAN.H11MO.0.A  3.172790e-05
# 9   1.757660e-04          NaN    NF2L2_MOUSE.H11MO.0.A  1.757660e-04
# 10  2.817550e-04          NaN    CREB1_MOUSE.H11MO.0.A  2.817550e-04
# 11  3.481470e-04          NaN     NFIA_MOUSE.H11MO.0.C  3.481470e-04
# 12  1.445460e-10          NaN    ZN143_HUMAN.H11MO.0.A  2.714390e-10
# 13  2.852150e-04          NaN      SP1_MOUSE.H11MO.0.A  6.622240e-04
# 14  6.294420e-05          NaN             YY1_MA0095.2  6.388930e-05
# 15  9.567500e-03          NaN    STAT3_MOUSE.H11MO.0.A  1.614960e-02
# 16  4.452670e-05          NaN    KAISO_MOUSE.H11MO.0.B  4.452670e-05
# 17  2.546480e-05          NaN      SP1_MOUSE.H11MO.0.A  8.983170e-05
# 18  3.371770e-05          NaN     USF1_MOUSE.H11MO.0.A  4.615160e-05
# 19  2.149230e-04          NaN     ATF2_MOUSE.H11MO.0.A  2.149230e-04
# 20  4.543960e-03          NaN          ZNF143_MA0088.2  4.543960e-03
# 21  2.999620e-01          NaN     CTCF_MOUSE.H11MO.0.A  2.999620e-01
# 22  8.246200e-02          NaN            KLF5_MA0599.1  8.246200e-02
# 23  4.704300e-01          NaN      GCR_HUMAN.H11MO.0.A  4.704300e-01
# 24  2.666940e-04          NaN     KLF1_HUMAN.H11MO.0.A  2.666940e-04
# 25           NaN          NaN                      NaN           NaN
# 26  7.055190e-03          NaN    ZFP42_MOUSE.H11MO.0.A  7.055190e-03
# 27  1.721260e-01          NaN     TFEB_HUMAN.H11MO.0.C  1.721260e-01
# 28  1.047390e-02          NaN             SP1_MA0079.3  1.047390e-02
# 29           NaN          NaN                      NaN           NaN
# 30  3.846650e-09          NaN     IRF2_MOUSE.H11MO.0.B  3.846650e-09
# 31  1.215540e-02          NaN     KLF3_HUMAN.H11MO.0.B  1.215540e-02
# 32  6.379220e-01          NaN  ESRRA_nuclearreceptor_6  6.379220e-01
# 33  5.195060e-01          NaN               SOX8_HMG_2  6.060650e-01
# 34  1.394820e-01          NaN          POU4F3_MA0791.1  1.394820e-01
# 35  1.236000e-01          NaN             GATA5_GATA_1  1.236000e-01
# 36  1.224710e-01          NaN               E2F2_E2F_1  1.224710e-01
# 37  4.079950e-01          NaN    GATA4_MOUSE.H11MO.0.A  4.079950e-01
# 38  2.700830e-02          NaN      ERG_HUMAN.H11MO.0.A  2.700830e-02
# 39  7.506710e-03          NaN           Stat4_MA0518.1  9.470530e-03
# 40  9.180250e-02          NaN      SRF_MOUSE.H11MO.0.A  9.180250e-02
# 41  3.672120e-01          NaN    ZN143_HUMAN.H11MO.0.A  7.764350e-01
# 42  5.696990e-01          NaN           Gata4_MA0482.1  5.696990e-01
# 43  3.211250e-01          NaN             Dux_MA0611.1  5.969840e-01
# 44  3.005100e-12          NaN     REST_MOUSE.H11MO.0.A  1.423440e-11
# 45  2.009330e-03          NaN     PDX1_HUMAN.H11MO.0.A  5.157460e-02
# 46  7.848750e-01          NaN              TCF4_bHLH_1  7.848750e-01
# 47           NaN          NaN                      NaN           NaN
# 48  1.000000e+00          NaN        Hic1.mouse_C2H2_2  1.000000e+00
# 49  7.382480e-01          NaN            MZF1_MA0056.1  7.382480e-01
# 50  4.454880e-02          NaN        Hic1.mouse_C2H2_2  2.316650e-01
# 51  9.999980e-01          NaN     REST_MOUSE.H11MO.0.A  9.999980e-01
# 52  4.576730e-01          NaN        Hic1.mouse_C2H2_2  4.576730e-01
# 53  1.000000e+00          NaN    GFI1B_MOUSE.H11MO.0.A  1.000000e+00
# 54  1.000000e+00          NaN     ELF1_HUMAN.H11MO.0.A  1.000000e+00
# 55  2.281990e-02          NaN    FOXI1_MOUSE.H11MO.0.B  2.281990e-02
# 56  5.042710e-04          NaN     CTCF_HUMAN.H11MO.0.A  1.668990e-03
# 57  1.000000e+00          NaN    SNAI2_MOUSE.H11MO.0.A  1.000000e+00
# 58  1.190630e-01          NaN    SNAI1_HUMAN.H11MO.0.C  1.217790e-01
# 59  3.550630e-02          NaN       Meis2.mouse_MEIS_2  3.550630e-02
# 60  5.186480e-01          NaN       FOSL1+JUN_MA1129.1  5.186480e-01
# 61  3.024530e-01          NaN           ASCL1_MA1100.1  3.975420e-01
# 62  1.513110e-01          NaN            KLF4_MA0039.3  2.646600e-01
#
#     match2_logo
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN
# 54          NaN
# 55          NaN
# 56          NaN
# 57          NaN
# 58          NaN
# 59          NaN
# 60          NaN
# 61          NaN
# 62          NaN

# %%
tomtom[0][["pattern","num_seqlets"]].to_csv(os.path.join(ppm_dir,mode+"_counts.csv"),sep=",",index=False, header=False)
