# %%
import numpy as np
import pandas as pd
import h5py
import pysam
import os
from modisco.visualization import viz_sequence
from modisco import util
from matplotlib import pyplot as plt
import pybedtools
from bs4 import BeautifulSoup

pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
dttype = 'ATAC'
mode = "counts"
celltype="IMR90"
modisco_path = '/oak/stanford/groups/akundaje/projects/chromatin-atlas-2022/chrombpnet/folds/ATAC/'+celltype+'/merge_folds_new/'+mode+'/modisco_old_format.h5'
ppm_dir = ''

htmld="/oak/stanford/groups/akundaje/projects/chromatin-atlas-2022/chrombpnet/folds/"+dttype+'/'+celltype+"/merge_folds_new/"+mode+"/motifs.html"
tomtom = pd.read_html(htmld)


background=[0.25, 0.25, 0.25, 0.25]

# %%
def trim_motif_new(cwm, motif, trim_threshold=0.20):
    """
    Given the PFM and motif (both L x 4 arrays) (the motif could be the
    PFM itself), trims `motif` by cutting off flanks of low information
    content in `pfm`. `min_ic` is the minimum required information
    content. If specified this trimmed motif will be extended on either
    side by `pad` bases.
    If no base passes the `min_ic` threshold, then no trimming is done.
    """
    
    score = np.sum(np.abs(cwm), axis=1)
    trim_thresh = np.max(score) * trim_threshold  # Cut off anything less than 30% of max score
    pass_inds = np.where(score >= trim_thresh)[0]
    trimmed = motif[np.min(pass_inds): np.max(pass_inds) + 1]
 
    if not trimmed.size:
        return motif
    
    return trimmed

def import_tfmodisco_motifs(tfm_results_path, trim=True, only_pos=True):
    """
    Imports the PFMs to into a dictionary, mapping `(x, y)` to the PFM,
    where `x` is the metacluster index and `y` is the pattern index.
    Arguments:
        `tfm_results_path`: path to HDF5 containing TF-MoDISco results
        `out_dir`: where to save motifs
        `trim`: if True, trim the motif flanks based on information content
        `only_pos`: if True, only return motifs with positive contributions
    Returns the dictionary of PFMs.
    """ 
    pfms = {}
    with h5py.File(tfm_results_path, "r") as f:
        metaclusters = f["metacluster_idx_to_submetacluster_results"]
        num_metaclusters = len(metaclusters.keys())
        for metacluster_i, metacluster_key in enumerate(metaclusters.keys()):
            metacluster = metaclusters[metacluster_key]
            if "patterns" not in metacluster["seqlets_to_patterns_result"]:
                continue
            patterns = metacluster["seqlets_to_patterns_result"]["patterns"]
            num_patterns = len(patterns["all_pattern_names"][:])
            for pattern_i, pattern_name in enumerate(patterns["all_pattern_names"][:]):
#                pattern_name = pattern_name.decode()
                pattern_name = pattern_name

                pattern = patterns[pattern_name]
                pfm = pattern["sequence"]["fwd"][:]
                cwm = pattern["task0_contrib_scores"]["fwd"][:]
                
                # Check that the contribution scores are overall positive
                if only_pos and np.sum(cwm) < 0:
                    continue
                    
                if trim:
                    pfm = trim_motif_new(cwm, cwm)
                else:
                    pfm = cwm
                    
                pfms["%d_%d" % (metacluster_i,pattern_i)] = pfm
    return pfms

# %%
pfms = import_tfmodisco_motifs(modisco_path, trim=False)

# %%
for key in pfms:
    f = open(os.path.join(ppm_dir,mode+"_"+key+".pfm"),"w")
    #print(pfms[key])
    np.savetxt(f, pfms[key], fmt='%f')
    f.close()

# %%
tomtom[0]
# Out:
#                     pattern  num_seqlets  modisco_cwm_fwd  modisco_cwm_rev  \
# 0    pos_patterns.pattern_0        52566              NaN              NaN
# 1    pos_patterns.pattern_1        24506              NaN              NaN
# 2    pos_patterns.pattern_2        17515              NaN              NaN
# 3    pos_patterns.pattern_3        15469              NaN              NaN
# 4    pos_patterns.pattern_4         6306              NaN              NaN
# 5    pos_patterns.pattern_5         6263              NaN              NaN
# 6    pos_patterns.pattern_6         4262              NaN              NaN
# 7    pos_patterns.pattern_7         4011              NaN              NaN
# 8    pos_patterns.pattern_8         3364              NaN              NaN
# 9    pos_patterns.pattern_9         3210              NaN              NaN
# 10  pos_patterns.pattern_10         2987              NaN              NaN
# 11  pos_patterns.pattern_11         2812              NaN              NaN
# 12  pos_patterns.pattern_12         2579              NaN              NaN
# 13  pos_patterns.pattern_13         2459              NaN              NaN
# 14  pos_patterns.pattern_14         2239              NaN              NaN
# 15  pos_patterns.pattern_15         2205              NaN              NaN
# 16  pos_patterns.pattern_16         2042              NaN              NaN
# 17  pos_patterns.pattern_17         2027              NaN              NaN
# 18  pos_patterns.pattern_18         1927              NaN              NaN
# 19  pos_patterns.pattern_19         1874              NaN              NaN
# 20  pos_patterns.pattern_20         1737              NaN              NaN
# 21  pos_patterns.pattern_21         1718              NaN              NaN
# 22  pos_patterns.pattern_22         1591              NaN              NaN
# 23  pos_patterns.pattern_23         1438              NaN              NaN
# 24  pos_patterns.pattern_24         1395              NaN              NaN
# 25  pos_patterns.pattern_25         1382              NaN              NaN
# 26  pos_patterns.pattern_26         1260              NaN              NaN
# 27  pos_patterns.pattern_27         1206              NaN              NaN
# 28  pos_patterns.pattern_28         1165              NaN              NaN
# 29  pos_patterns.pattern_29         1046              NaN              NaN
# 30  pos_patterns.pattern_30          813              NaN              NaN
# 31  pos_patterns.pattern_31          794              NaN              NaN
# 32  pos_patterns.pattern_32          693              NaN              NaN
# 33  pos_patterns.pattern_33          594              NaN              NaN
# 34  pos_patterns.pattern_34          571              NaN              NaN
# 35  pos_patterns.pattern_35          551              NaN              NaN
# 36  pos_patterns.pattern_36          549              NaN              NaN
# 37  pos_patterns.pattern_37          529              NaN              NaN
# 38  pos_patterns.pattern_38          487              NaN              NaN
# 39  pos_patterns.pattern_39          399              NaN              NaN
# 40  pos_patterns.pattern_40          398              NaN              NaN
# 41  pos_patterns.pattern_41          380              NaN              NaN
# 42  pos_patterns.pattern_42          328              NaN              NaN
# 43  pos_patterns.pattern_43          300              NaN              NaN
# 44  pos_patterns.pattern_44          243              NaN              NaN
# 45  pos_patterns.pattern_45          240              NaN              NaN
# 46  pos_patterns.pattern_46          203              NaN              NaN
# 47  pos_patterns.pattern_47          195              NaN              NaN
# 48  pos_patterns.pattern_48          183              NaN              NaN
# 49  pos_patterns.pattern_49          165              NaN              NaN
# 50  pos_patterns.pattern_50          146              NaN              NaN
# 51  pos_patterns.pattern_51          144              NaN              NaN
# 52  pos_patterns.pattern_52          130              NaN              NaN
# 53  pos_patterns.pattern_53          129              NaN              NaN
# 54  pos_patterns.pattern_54          128              NaN              NaN
# 55  pos_patterns.pattern_55          102              NaN              NaN
# 56  pos_patterns.pattern_56           96              NaN              NaN
# 57  pos_patterns.pattern_57           87              NaN              NaN
# 58  pos_patterns.pattern_58           81              NaN              NaN
# 59  pos_patterns.pattern_59           76              NaN              NaN
# 60  pos_patterns.pattern_60           75              NaN              NaN
# 61  pos_patterns.pattern_61           71              NaN              NaN
# 62  pos_patterns.pattern_62           57              NaN              NaN
# 63  pos_patterns.pattern_63           54              NaN              NaN
# 64  pos_patterns.pattern_64           30              NaN              NaN
# 65  pos_patterns.pattern_65           28              NaN              NaN
# 66  pos_patterns.pattern_66           26              NaN              NaN
# 67   neg_patterns.pattern_0         1015              NaN              NaN
# 68   neg_patterns.pattern_1          230              NaN              NaN
# 69   neg_patterns.pattern_2           26              NaN              NaN
#
#                    match0         qval0  match0_logo  \
# 0      FOSL2+JUN_MA1130.1  1.229150e-03          NaN
# 1           CTCF_MA0139.1  1.142870e-15          NaN
# 2          FOXO6_MA0849.1  2.615150e-02          NaN
# 3   TEAD1_MOUSE.H11MO.0.A  1.424960e-04          NaN
# 4    NFIC_HUMAN.H11MO.0.A  1.999210e-05          NaN
# 5   KLF12_HUMAN.H11MO.0.C  2.132090e-04          NaN
# 6            POU1F1_POU_1  1.000000e+00          NaN
# 7          CEBPA_MA0102.3  9.738800e-07          NaN
# 8    NFYC_HUMAN.H11MO.0.A  1.835470e-03          NaN
# 9   RUNX3_HUMAN.H11MO.0.A  5.133580e-02          NaN
# 10           JUN_MA0488.1  5.270230e-03          NaN
# 11  TEAD4_MOUSE.H11MO.0.A  5.035540e-10          NaN
# 12  TWST1_HUMAN.H11MO.0.A  4.642840e-04          NaN
# 13            TEAD1_TEA_2  1.013440e-05          NaN
# 14         TEAD3_MA0808.1  1.736940e-04          NaN
# 15   ATF4_MOUSE.H11MO.0.A  3.744280e-04          NaN
# 16  FOXL2_MOUSE.H11MO.0.C  7.650390e-03          NaN
# 17         TEAD3_MA0808.1  3.955460e-04          NaN
# 18          NRF1_MA0506.1  1.408080e-05          NaN
# 19   SIX1_HUMAN.H11MO.0.A  3.220690e-12          NaN
# 20             ELK1_ETS_1  1.847110e-03          NaN
# 21   ETS1_HUMAN.H11MO.0.A  1.446470e-03          NaN
# 22            TEAD3_TEA_1  1.764410e-01          NaN
# 23  ZN143_HUMAN.H11MO.0.A  8.025690e-19          NaN
# 24      FOSB+JUN_MA1127.1  1.039890e-04          NaN
# 25  SMCA1_HUMAN.H11MO.0.C  6.705860e-01          NaN
# 26    FOSL1+JUND_MA1142.1  5.372940e-03          NaN
# 27  TEAD4_MOUSE.H11MO.0.A  3.070140e-04          NaN
# 28   BATF_HUMAN.H11MO.0.A  8.587750e-02          NaN
# 29           JUN_MA0488.1  3.125650e-01          NaN
# 30   IRF2_HUMAN.H11MO.0.A  8.500460e-10          NaN
# 31       FOXC1_forkhead_2  3.431250e-02          NaN
# 32    SRF_HUMAN.H11MO.0.A  7.028240e-05          NaN
# 33   TYY1_HUMAN.H11MO.0.A  4.605660e-05          NaN
# 34       FOXC2_forkhead_2  2.329960e-01          NaN
# 35  FOSL2_HUMAN.H11MO.0.A  1.609790e-01          NaN
# 36         Foxd3_MA0041.1  2.562930e-02          NaN
# 37   IRF2_HUMAN.H11MO.0.A  1.519750e-11          NaN
# 38   ETV4_MOUSE.H11MO.0.B  2.548120e-01          NaN
# 39          ATF4_MA0833.1  4.191700e-02          NaN
# 40         Gabpa_MA0062.2  3.135830e-03          NaN
# 41           REL_MA0101.1  1.386250e-01          NaN
# 42          ZNF524_C2H2_2  1.000000e+00          NaN
# 43        ZBTB33_MA0527.1  5.276310e-03          NaN
# 44           ARNTL_bHLH_1  8.553670e-05          NaN
# 45   RFX2_MOUSE.H11MO.0.A  3.313510e-09          NaN
# 46          REST_MA0138.2  4.977420e-16          NaN
# 47             ETV6_ETS_1  4.753330e-06          NaN
# 48         CEBPB_MA0466.2  6.853750e-02          NaN
# 49  FOXP1_HUMAN.H11MO.0.A  2.651300e-01          NaN
# 50         Foxj2_MA0614.1  1.904010e-02          NaN
# 51  ZNF76_HUMAN.H11MO.0.C  3.069690e-04          NaN
# 52  FOXA1_MOUSE.H11MO.0.A  3.598180e-01          NaN
# 53             SOX9_HMG_4  3.161720e-01          NaN
# 54      BATF+JUN_MA0462.1  2.553090e-01          NaN
# 55         TEAD4_MA0809.1  5.651030e-01          NaN
# 56         ZBED1_MA0749.1  1.181890e-01          NaN
# 57  ZN350_HUMAN.H11MO.0.C  1.000000e+00          NaN
# 58         CEBPA_MA0102.3  5.972390e-05          NaN
# 59         Gabpa_MA0062.2  1.629010e-01          NaN
# 60   NFIC_HUMAN.H11MO.0.A  7.695510e-01          NaN
# 61         STAT3_MA0144.2  1.000000e+00          NaN
# 62   ELK4_MOUSE.H11MO.0.B  1.972880e-02          NaN
# 63   ETV6_MOUSE.H11MO.0.C  1.936960e-01          NaN
# 64  DDIT3_MOUSE.H11MO.0.C  1.493660e-01          NaN
# 65   KLF6_HUMAN.H11MO.0.A  2.151820e-03          NaN
# 66             FLI1_ETS_3  1.563130e-02          NaN
# 67   ZEB1_HUMAN.H11MO.0.A  2.999510e-02          NaN
# 68          JUNB_MA0490.1  7.880630e-03          NaN
# 69        Arid3b_MA0601.1  1.012620e-02          NaN
#
#                       match1         qval1  match1_logo  \
# 0          FOS+JUND_MA1141.1  1.229150e-03          NaN
# 1       CTCF_HUMAN.H11MO.0.A  2.071220e-11          NaN
# 2           FOXO6_forkhead_2  2.615150e-02          NaN
# 3      TEAD2_MOUSE.H11MO.0.C  1.424960e-04          NaN
# 4         NFIC+TLX1_MA0119.1  4.141310e-03          NaN
# 5        SP3_HUMAN.H11MO.0.B  2.487440e-04          NaN
# 6                TBX21_TBX_6  1.000000e+00          NaN
# 7      CEBPB_MOUSE.H11MO.0.A  9.738800e-07          NaN
# 8       NFYB_HUMAN.H11MO.0.A  1.835470e-03          NaN
# 9             RUNX1_MA0002.2  5.190490e-02          NaN
# 10             JUND_MA0492.1  5.270230e-03          NaN
# 11               TEAD1_TEA_2  1.703600e-07          NaN
# 12     TWST1_MOUSE.H11MO.0.B  4.642840e-04          NaN
# 13               TEAD3_TEA_1  2.834690e-05          NaN
# 14               TEAD3_TEA_2  1.736940e-04          NaN
# 15      ATF4_HUMAN.H11MO.0.A  4.629410e-04          NaN
# 16     FOXA1_MOUSE.H11MO.0.A  1.115490e-02          NaN
# 17               TEAD3_TEA_2  3.955460e-04          NaN
# 18      NRF1_MOUSE.H11MO.0.A  3.793460e-05          NaN
# 19      SIX2_MOUSE.H11MO.0.A  1.676650e-10          NaN
# 20                ELK1_ETS_2  1.847110e-03          NaN
# 21      ETS1_MOUSE.H11MO.0.A  1.446470e-03          NaN
# 22               TEAD1_TEA_2  1.771060e-01          NaN
# 23     ZN143_MOUSE.H11MO.0.A  2.934300e-18          NaN
# 24        FOSL2+JUN_MA1131.1  1.039890e-04          NaN
# 25     TEAD4_MOUSE.H11MO.0.A  6.705860e-01          NaN
# 26            FOSL2_MA0478.1  5.372940e-03          NaN
# 27               TEAD1_TEA_2  3.070140e-04          NaN
# 28     BATF3_HUMAN.H11MO.0.B  1.199350e-01          NaN
# 29         FOSB+JUN_MA1127.1  3.125650e-01          NaN
# 30      IRF2_MOUSE.H11MO.0.B  8.500460e-10          NaN
# 31          FOXC2_forkhead_1  3.431250e-02          NaN
# 32       SRF_MOUSE.H11MO.0.A  2.056850e-04          NaN
# 33      TYY1_MOUSE.H11MO.0.A  1.071170e-04          NaN
# 34          FOXC1_forkhead_1  2.329960e-01          NaN
# 35         Jdp2.mouse_bZIP_1  1.609790e-01          NaN
# 36     FOXJ2_HUMAN.H11MO.0.C  2.562930e-02          NaN
# 37      IRF2_MOUSE.H11MO.0.B  1.519750e-11          NaN
# 38      ETV6_MOUSE.H11MO.0.C  2.548120e-01          NaN
# 39               ATF4_bZIP_1  4.191700e-02          NaN
# 40      ELK1_HUMAN.H11MO.0.B  1.330040e-02          NaN
# 41              BCL6B_C2H2_1  1.386250e-01          NaN
# 42                       NaN           NaN          NaN
# 43     KAISO_HUMAN.H11MO.0.A  5.276310e-03          NaN
# 44      TFE3_HUMAN.H11MO.0.B  8.553670e-05          NaN
# 45      RFX3_MOUSE.H11MO.0.C  3.313510e-09          NaN
# 46      REST_HUMAN.H11MO.0.A  7.349760e-14          NaN
# 47     GABPA_MOUSE.H11MO.0.A  3.586650e-02          NaN
# 48              CEBPB_bZIP_1  6.853750e-02          NaN
# 49          FOXJ2_forkhead_2  2.651300e-01          NaN
# 50    Foxj3.mouse_forkhead_3  2.364780e-02          NaN
# 51             ZNF143_C2H2_1  2.682900e-03          NaN
# 52     FOXA2_HUMAN.H11MO.0.A  3.598180e-01          NaN
# 53         Sox10.mouse_HMG_3  7.475710e-01          NaN
# 54      JUND_MOUSE.H11MO.0.A  2.553090e-01          NaN
# 55               TEAD4_TEA_1  5.651030e-01          NaN
# 56           ZBED1_znf_BED_1  1.181890e-01          NaN
# 57     ZN264_HUMAN.H11MO.0.C  1.000000e+00          NaN
# 58     CEBPD_MOUSE.H11MO.0.B  5.899940e-04          NaN
# 59                FLI1_ETS_2  1.629010e-01          NaN
# 60        NFIC+TLX1_MA0119.1  7.695510e-01          NaN
# 61     STAT3_HUMAN.H11MO.0.A  1.000000e+00          NaN
# 62      FLI1_MOUSE.H11MO.0.A  1.972880e-02          NaN
# 63      ETV4_MOUSE.H11MO.0.B  1.936960e-01          NaN
# 64     CEBPD_MOUSE.H11MO.0.B  1.493660e-01          NaN
# 65      KLF6_MOUSE.H11MO.0.B  2.151820e-03          NaN
# 66             FLI1_MA0475.2  1.563130e-02          NaN
# 67      ZEB1_MOUSE.H11MO.0.B  2.999510e-02          NaN
# 68      JUND_MOUSE.H11MO.0.A  7.880630e-03          NaN
# 69  Alx4.mouse_homeodomain_1  1.012620e-02          NaN
#
#                     match2         qval2  match2_logo
# 0      FOSL1+JUNB_MA1137.1  1.229150e-03          NaN
# 1     CTCF_MOUSE.H11MO.0.A  1.742790e-09          NaN
# 2           FOXD1_MA0031.1  2.615150e-02          NaN
# 3           TEAD3_MA0808.1  2.489020e-04          NaN
# 4     NFIA_HUMAN.H11MO.0.C  4.141310e-03          NaN
# 5      SP3_MOUSE.H11MO.0.B  2.487440e-04          NaN
# 6           TEAD3_MA0808.1  1.000000e+00          NaN
# 7    CEBPB_HUMAN.H11MO.0.A  9.738800e-07          NaN
# 8     NFYB_MOUSE.H11MO.0.A  1.835470e-03          NaN
# 9    RUNX2_HUMAN.H11MO.0.A  5.190490e-02          NaN
# 10    ATF2_HUMAN.H11MO.0.B  5.270230e-03          NaN
# 11   TEAD4_HUMAN.H11MO.0.A  1.712210e-07          NaN
# 12   OLIG2_HUMAN.H11MO.0.B  8.448040e-02          NaN
# 13   TEAD4_MOUSE.H11MO.0.A  1.617040e-03          NaN
# 14       BATF+JUN_MA0462.1  3.249640e-03          NaN
# 15   DDIT3_MOUSE.H11MO.0.C  7.241570e-04          NaN
# 16   FOXK1_HUMAN.H11MO.0.A  1.115490e-02          NaN
# 17   TEAD1_MOUSE.H11MO.0.A  1.261710e-01          NaN
# 18    NRF1_HUMAN.H11MO.0.A  3.838290e-05          NaN
# 19    SIX2_HUMAN.H11MO.0.A  1.302890e-08          NaN
# 20              ELK1_ETS_4  1.847110e-03          NaN
# 21    ETV4_HUMAN.H11MO.0.B  1.446470e-03          NaN
# 22           ZNF713_C2H2_1  4.620640e-01          NaN
# 23   ZNF76_HUMAN.H11MO.0.C  1.014350e-17          NaN
# 24        FOS+JUN_MA1126.1  1.039890e-04          NaN
# 25             TEAD3_TEA_1  6.705860e-01          NaN
# 26     FOSL2+JUNB_MA1138.1  5.372940e-03          NaN
# 27             TEAD3_TEA_1  2.201160e-03          NaN
# 28   BATF3_MOUSE.H11MO.0.A  1.199350e-01          NaN
# 29      FOSL2+JUN_MA1131.1  3.125650e-01          NaN
# 30           IRF1_MA0050.2  8.500460e-10          NaN
# 31        FOXD2_forkhead_1  3.431250e-02          NaN
# 32              SRF_MADS_1  2.045960e-03          NaN
# 33            YY1_MA0095.2  1.135620e-04          NaN
# 34        FOXD3_forkhead_2  2.329960e-01          NaN
# 35     FOSL1+JUNB_MA1137.1  1.609790e-01          NaN
# 36   FOXJ2_MOUSE.H11MO.0.C  2.562930e-02          NaN
# 37    IRF1_MOUSE.H11MO.0.A  1.933450e-11          NaN
# 38     EHF_HUMAN.H11MO.0.B  2.548120e-01          NaN
# 39     FOSL1+JUND_MA1143.1  5.472350e-02          NaN
# 40    ELK1_MOUSE.H11MO.0.B  1.330040e-02          NaN
# 41          BCL6B_MA0731.1  1.386250e-01          NaN
# 42                     NaN           NaN          NaN
# 43   KAISO_MOUSE.H11MO.0.B  5.276310e-03          NaN
# 44    TFE3_MOUSE.H11MO.0.A  8.553670e-05          NaN
# 45    RFX2_HUMAN.H11MO.0.A  4.514190e-09          NaN
# 46    REST_MOUSE.H11MO.0.A  7.349760e-14          NaN
# 47   GABPA_HUMAN.H11MO.0.A  5.463270e-02          NaN
# 48          CEBPD_MA0836.1  6.853750e-02          NaN
# 49          Foxj2_MA0614.1  2.651300e-01          NaN
# 50  Foxc1.mouse_forkhead_2  2.402020e-02          NaN
# 51         ZNF143_MA0088.2  2.682900e-03          NaN
# 52  Foxg1.mouse_forkhead_1  3.598180e-01          NaN
# 53              PAX6_PAX_1  7.475710e-01          NaN
# 54   FOSL2_HUMAN.H11MO.0.A  2.553090e-01          NaN
# 55          TEAD1_MA0090.2  5.651030e-01          NaN
# 56          CEBPE_MA0837.1  1.181890e-01          NaN
# 57                     NaN           NaN          NaN
# 58   CEBPB_MOUSE.H11MO.0.A  5.899940e-04          NaN
# 59              FLI1_ETS_4  1.629010e-01          NaN
# 60   MEIS2_HUMAN.H11MO.0.B  7.695510e-01          NaN
# 61    Ddit3+Cebpa_MA0019.1  1.000000e+00          NaN
# 62              IRF3_IRF_1  1.972880e-02          NaN
# 63    ETV4_HUMAN.H11MO.0.B  1.936960e-01          NaN
# 64    ATF4_HUMAN.H11MO.0.A  1.493660e-01          NaN
# 65    KLF1_HUMAN.H11MO.0.A  2.151820e-03          NaN
# 66               ERG_ETS_3  1.563130e-02          NaN
# 67           ZEB1_MA0103.3  3.328070e-02          NaN
# 68          FOSL2_MA0478.1  8.879650e-03          NaN
# 69          PROP1_MA0715.1  1.012620e-02          NaN

# %%
tomtom[0]["pattern"] = tomtom[0]["pattern"].str.replace("pos_patterns.pattern","0").str.replace("neg_patterns.pattern","1")
# Out:
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
tomtom[0]
# Out:
#    pattern  num_seqlets  modisco_cwm_fwd  modisco_cwm_rev  \
# 0      0_0        52566              NaN              NaN
# 1      0_1        24506              NaN              NaN
# 2      0_2        17515              NaN              NaN
# 3      0_3        15469              NaN              NaN
# 4      0_4         6306              NaN              NaN
# 5      0_5         6263              NaN              NaN
# 6      0_6         4262              NaN              NaN
# 7      0_7         4011              NaN              NaN
# 8      0_8         3364              NaN              NaN
# 9      0_9         3210              NaN              NaN
# 10    0_10         2987              NaN              NaN
# 11    0_11         2812              NaN              NaN
# 12    0_12         2579              NaN              NaN
# 13    0_13         2459              NaN              NaN
# 14    0_14         2239              NaN              NaN
# 15    0_15         2205              NaN              NaN
# 16    0_16         2042              NaN              NaN
# 17    0_17         2027              NaN              NaN
# 18    0_18         1927              NaN              NaN
# 19    0_19         1874              NaN              NaN
# 20    0_20         1737              NaN              NaN
# 21    0_21         1718              NaN              NaN
# 22    0_22         1591              NaN              NaN
# 23    0_23         1438              NaN              NaN
# 24    0_24         1395              NaN              NaN
# 25    0_25         1382              NaN              NaN
# 26    0_26         1260              NaN              NaN
# 27    0_27         1206              NaN              NaN
# 28    0_28         1165              NaN              NaN
# 29    0_29         1046              NaN              NaN
# 30    0_30          813              NaN              NaN
# 31    0_31          794              NaN              NaN
# 32    0_32          693              NaN              NaN
# 33    0_33          594              NaN              NaN
# 34    0_34          571              NaN              NaN
# 35    0_35          551              NaN              NaN
# 36    0_36          549              NaN              NaN
# 37    0_37          529              NaN              NaN
# 38    0_38          487              NaN              NaN
# 39    0_39          399              NaN              NaN
# 40    0_40          398              NaN              NaN
# 41    0_41          380              NaN              NaN
# 42    0_42          328              NaN              NaN
# 43    0_43          300              NaN              NaN
# 44    0_44          243              NaN              NaN
# 45    0_45          240              NaN              NaN
# 46    0_46          203              NaN              NaN
# 47    0_47          195              NaN              NaN
# 48    0_48          183              NaN              NaN
# 49    0_49          165              NaN              NaN
# 50    0_50          146              NaN              NaN
# 51    0_51          144              NaN              NaN
# 52    0_52          130              NaN              NaN
# 53    0_53          129              NaN              NaN
# 54    0_54          128              NaN              NaN
# 55    0_55          102              NaN              NaN
# 56    0_56           96              NaN              NaN
# 57    0_57           87              NaN              NaN
# 58    0_58           81              NaN              NaN
# 59    0_59           76              NaN              NaN
# 60    0_60           75              NaN              NaN
# 61    0_61           71              NaN              NaN
# 62    0_62           57              NaN              NaN
# 63    0_63           54              NaN              NaN
# 64    0_64           30              NaN              NaN
# 65    0_65           28              NaN              NaN
# 66    0_66           26              NaN              NaN
# 67     1_0         1015              NaN              NaN
# 68     1_1          230              NaN              NaN
# 69     1_2           26              NaN              NaN
#
#                    match0         qval0  match0_logo  \
# 0      FOSL2+JUN_MA1130.1  1.229150e-03          NaN
# 1           CTCF_MA0139.1  1.142870e-15          NaN
# 2          FOXO6_MA0849.1  2.615150e-02          NaN
# 3   TEAD1_MOUSE.H11MO.0.A  1.424960e-04          NaN
# 4    NFIC_HUMAN.H11MO.0.A  1.999210e-05          NaN
# 5   KLF12_HUMAN.H11MO.0.C  2.132090e-04          NaN
# 6            POU1F1_POU_1  1.000000e+00          NaN
# 7          CEBPA_MA0102.3  9.738800e-07          NaN
# 8    NFYC_HUMAN.H11MO.0.A  1.835470e-03          NaN
# 9   RUNX3_HUMAN.H11MO.0.A  5.133580e-02          NaN
# 10           JUN_MA0488.1  5.270230e-03          NaN
# 11  TEAD4_MOUSE.H11MO.0.A  5.035540e-10          NaN
# 12  TWST1_HUMAN.H11MO.0.A  4.642840e-04          NaN
# 13            TEAD1_TEA_2  1.013440e-05          NaN
# 14         TEAD3_MA0808.1  1.736940e-04          NaN
# 15   ATF4_MOUSE.H11MO.0.A  3.744280e-04          NaN
# 16  FOXL2_MOUSE.H11MO.0.C  7.650390e-03          NaN
# 17         TEAD3_MA0808.1  3.955460e-04          NaN
# 18          NRF1_MA0506.1  1.408080e-05          NaN
# 19   SIX1_HUMAN.H11MO.0.A  3.220690e-12          NaN
# 20             ELK1_ETS_1  1.847110e-03          NaN
# 21   ETS1_HUMAN.H11MO.0.A  1.446470e-03          NaN
# 22            TEAD3_TEA_1  1.764410e-01          NaN
# 23  ZN143_HUMAN.H11MO.0.A  8.025690e-19          NaN
# 24      FOSB+JUN_MA1127.1  1.039890e-04          NaN
# 25  SMCA1_HUMAN.H11MO.0.C  6.705860e-01          NaN
# 26    FOSL1+JUND_MA1142.1  5.372940e-03          NaN
# 27  TEAD4_MOUSE.H11MO.0.A  3.070140e-04          NaN
# 28   BATF_HUMAN.H11MO.0.A  8.587750e-02          NaN
# 29           JUN_MA0488.1  3.125650e-01          NaN
# 30   IRF2_HUMAN.H11MO.0.A  8.500460e-10          NaN
# 31       FOXC1_forkhead_2  3.431250e-02          NaN
# 32    SRF_HUMAN.H11MO.0.A  7.028240e-05          NaN
# 33   TYY1_HUMAN.H11MO.0.A  4.605660e-05          NaN
# 34       FOXC2_forkhead_2  2.329960e-01          NaN
# 35  FOSL2_HUMAN.H11MO.0.A  1.609790e-01          NaN
# 36         Foxd3_MA0041.1  2.562930e-02          NaN
# 37   IRF2_HUMAN.H11MO.0.A  1.519750e-11          NaN
# 38   ETV4_MOUSE.H11MO.0.B  2.548120e-01          NaN
# 39          ATF4_MA0833.1  4.191700e-02          NaN
# 40         Gabpa_MA0062.2  3.135830e-03          NaN
# 41           REL_MA0101.1  1.386250e-01          NaN
# 42          ZNF524_C2H2_2  1.000000e+00          NaN
# 43        ZBTB33_MA0527.1  5.276310e-03          NaN
# 44           ARNTL_bHLH_1  8.553670e-05          NaN
# 45   RFX2_MOUSE.H11MO.0.A  3.313510e-09          NaN
# 46          REST_MA0138.2  4.977420e-16          NaN
# 47             ETV6_ETS_1  4.753330e-06          NaN
# 48         CEBPB_MA0466.2  6.853750e-02          NaN
# 49  FOXP1_HUMAN.H11MO.0.A  2.651300e-01          NaN
# 50         Foxj2_MA0614.1  1.904010e-02          NaN
# 51  ZNF76_HUMAN.H11MO.0.C  3.069690e-04          NaN
# 52  FOXA1_MOUSE.H11MO.0.A  3.598180e-01          NaN
# 53             SOX9_HMG_4  3.161720e-01          NaN
# 54      BATF+JUN_MA0462.1  2.553090e-01          NaN
# 55         TEAD4_MA0809.1  5.651030e-01          NaN
# 56         ZBED1_MA0749.1  1.181890e-01          NaN
# 57  ZN350_HUMAN.H11MO.0.C  1.000000e+00          NaN
# 58         CEBPA_MA0102.3  5.972390e-05          NaN
# 59         Gabpa_MA0062.2  1.629010e-01          NaN
# 60   NFIC_HUMAN.H11MO.0.A  7.695510e-01          NaN
# 61         STAT3_MA0144.2  1.000000e+00          NaN
# 62   ELK4_MOUSE.H11MO.0.B  1.972880e-02          NaN
# 63   ETV6_MOUSE.H11MO.0.C  1.936960e-01          NaN
# 64  DDIT3_MOUSE.H11MO.0.C  1.493660e-01          NaN
# 65   KLF6_HUMAN.H11MO.0.A  2.151820e-03          NaN
# 66             FLI1_ETS_3  1.563130e-02          NaN
# 67   ZEB1_HUMAN.H11MO.0.A  2.999510e-02          NaN
# 68          JUNB_MA0490.1  7.880630e-03          NaN
# 69        Arid3b_MA0601.1  1.012620e-02          NaN
#
#                       match1         qval1  match1_logo  \
# 0          FOS+JUND_MA1141.1  1.229150e-03          NaN
# 1       CTCF_HUMAN.H11MO.0.A  2.071220e-11          NaN
# 2           FOXO6_forkhead_2  2.615150e-02          NaN
# 3      TEAD2_MOUSE.H11MO.0.C  1.424960e-04          NaN
# 4         NFIC+TLX1_MA0119.1  4.141310e-03          NaN
# 5        SP3_HUMAN.H11MO.0.B  2.487440e-04          NaN
# 6                TBX21_TBX_6  1.000000e+00          NaN
# 7      CEBPB_MOUSE.H11MO.0.A  9.738800e-07          NaN
# 8       NFYB_HUMAN.H11MO.0.A  1.835470e-03          NaN
# 9             RUNX1_MA0002.2  5.190490e-02          NaN
# 10             JUND_MA0492.1  5.270230e-03          NaN
# 11               TEAD1_TEA_2  1.703600e-07          NaN
# 12     TWST1_MOUSE.H11MO.0.B  4.642840e-04          NaN
# 13               TEAD3_TEA_1  2.834690e-05          NaN
# 14               TEAD3_TEA_2  1.736940e-04          NaN
# 15      ATF4_HUMAN.H11MO.0.A  4.629410e-04          NaN
# 16     FOXA1_MOUSE.H11MO.0.A  1.115490e-02          NaN
# 17               TEAD3_TEA_2  3.955460e-04          NaN
# 18      NRF1_MOUSE.H11MO.0.A  3.793460e-05          NaN
# 19      SIX2_MOUSE.H11MO.0.A  1.676650e-10          NaN
# 20                ELK1_ETS_2  1.847110e-03          NaN
# 21      ETS1_MOUSE.H11MO.0.A  1.446470e-03          NaN
# 22               TEAD1_TEA_2  1.771060e-01          NaN
# 23     ZN143_MOUSE.H11MO.0.A  2.934300e-18          NaN
# 24        FOSL2+JUN_MA1131.1  1.039890e-04          NaN
# 25     TEAD4_MOUSE.H11MO.0.A  6.705860e-01          NaN
# 26            FOSL2_MA0478.1  5.372940e-03          NaN
# 27               TEAD1_TEA_2  3.070140e-04          NaN
# 28     BATF3_HUMAN.H11MO.0.B  1.199350e-01          NaN
# 29         FOSB+JUN_MA1127.1  3.125650e-01          NaN
# 30      IRF2_MOUSE.H11MO.0.B  8.500460e-10          NaN
# 31          FOXC2_forkhead_1  3.431250e-02          NaN
# 32       SRF_MOUSE.H11MO.0.A  2.056850e-04          NaN
# 33      TYY1_MOUSE.H11MO.0.A  1.071170e-04          NaN
# 34          FOXC1_forkhead_1  2.329960e-01          NaN
# 35         Jdp2.mouse_bZIP_1  1.609790e-01          NaN
# 36     FOXJ2_HUMAN.H11MO.0.C  2.562930e-02          NaN
# 37      IRF2_MOUSE.H11MO.0.B  1.519750e-11          NaN
# 38      ETV6_MOUSE.H11MO.0.C  2.548120e-01          NaN
# 39               ATF4_bZIP_1  4.191700e-02          NaN
# 40      ELK1_HUMAN.H11MO.0.B  1.330040e-02          NaN
# 41              BCL6B_C2H2_1  1.386250e-01          NaN
# 42                       NaN           NaN          NaN
# 43     KAISO_HUMAN.H11MO.0.A  5.276310e-03          NaN
# 44      TFE3_HUMAN.H11MO.0.B  8.553670e-05          NaN
# 45      RFX3_MOUSE.H11MO.0.C  3.313510e-09          NaN
# 46      REST_HUMAN.H11MO.0.A  7.349760e-14          NaN
# 47     GABPA_MOUSE.H11MO.0.A  3.586650e-02          NaN
# 48              CEBPB_bZIP_1  6.853750e-02          NaN
# 49          FOXJ2_forkhead_2  2.651300e-01          NaN
# 50    Foxj3.mouse_forkhead_3  2.364780e-02          NaN
# 51             ZNF143_C2H2_1  2.682900e-03          NaN
# 52     FOXA2_HUMAN.H11MO.0.A  3.598180e-01          NaN
# 53         Sox10.mouse_HMG_3  7.475710e-01          NaN
# 54      JUND_MOUSE.H11MO.0.A  2.553090e-01          NaN
# 55               TEAD4_TEA_1  5.651030e-01          NaN
# 56           ZBED1_znf_BED_1  1.181890e-01          NaN
# 57     ZN264_HUMAN.H11MO.0.C  1.000000e+00          NaN
# 58     CEBPD_MOUSE.H11MO.0.B  5.899940e-04          NaN
# 59                FLI1_ETS_2  1.629010e-01          NaN
# 60        NFIC+TLX1_MA0119.1  7.695510e-01          NaN
# 61     STAT3_HUMAN.H11MO.0.A  1.000000e+00          NaN
# 62      FLI1_MOUSE.H11MO.0.A  1.972880e-02          NaN
# 63      ETV4_MOUSE.H11MO.0.B  1.936960e-01          NaN
# 64     CEBPD_MOUSE.H11MO.0.B  1.493660e-01          NaN
# 65      KLF6_MOUSE.H11MO.0.B  2.151820e-03          NaN
# 66             FLI1_MA0475.2  1.563130e-02          NaN
# 67      ZEB1_MOUSE.H11MO.0.B  2.999510e-02          NaN
# 68      JUND_MOUSE.H11MO.0.A  7.880630e-03          NaN
# 69  Alx4.mouse_homeodomain_1  1.012620e-02          NaN
#
#                     match2         qval2  match2_logo
# 0      FOSL1+JUNB_MA1137.1  1.229150e-03          NaN
# 1     CTCF_MOUSE.H11MO.0.A  1.742790e-09          NaN
# 2           FOXD1_MA0031.1  2.615150e-02          NaN
# 3           TEAD3_MA0808.1  2.489020e-04          NaN
# 4     NFIA_HUMAN.H11MO.0.C  4.141310e-03          NaN
# 5      SP3_MOUSE.H11MO.0.B  2.487440e-04          NaN
# 6           TEAD3_MA0808.1  1.000000e+00          NaN
# 7    CEBPB_HUMAN.H11MO.0.A  9.738800e-07          NaN
# 8     NFYB_MOUSE.H11MO.0.A  1.835470e-03          NaN
# 9    RUNX2_HUMAN.H11MO.0.A  5.190490e-02          NaN
# 10    ATF2_HUMAN.H11MO.0.B  5.270230e-03          NaN
# 11   TEAD4_HUMAN.H11MO.0.A  1.712210e-07          NaN
# 12   OLIG2_HUMAN.H11MO.0.B  8.448040e-02          NaN
# 13   TEAD4_MOUSE.H11MO.0.A  1.617040e-03          NaN
# 14       BATF+JUN_MA0462.1  3.249640e-03          NaN
# 15   DDIT3_MOUSE.H11MO.0.C  7.241570e-04          NaN
# 16   FOXK1_HUMAN.H11MO.0.A  1.115490e-02          NaN
# 17   TEAD1_MOUSE.H11MO.0.A  1.261710e-01          NaN
# 18    NRF1_HUMAN.H11MO.0.A  3.838290e-05          NaN
# 19    SIX2_HUMAN.H11MO.0.A  1.302890e-08          NaN
# 20              ELK1_ETS_4  1.847110e-03          NaN
# 21    ETV4_HUMAN.H11MO.0.B  1.446470e-03          NaN
# 22           ZNF713_C2H2_1  4.620640e-01          NaN
# 23   ZNF76_HUMAN.H11MO.0.C  1.014350e-17          NaN
# 24        FOS+JUN_MA1126.1  1.039890e-04          NaN
# 25             TEAD3_TEA_1  6.705860e-01          NaN
# 26     FOSL2+JUNB_MA1138.1  5.372940e-03          NaN
# 27             TEAD3_TEA_1  2.201160e-03          NaN
# 28   BATF3_MOUSE.H11MO.0.A  1.199350e-01          NaN
# 29      FOSL2+JUN_MA1131.1  3.125650e-01          NaN
# 30           IRF1_MA0050.2  8.500460e-10          NaN
# 31        FOXD2_forkhead_1  3.431250e-02          NaN
# 32              SRF_MADS_1  2.045960e-03          NaN
# 33            YY1_MA0095.2  1.135620e-04          NaN
# 34        FOXD3_forkhead_2  2.329960e-01          NaN
# 35     FOSL1+JUNB_MA1137.1  1.609790e-01          NaN
# 36   FOXJ2_MOUSE.H11MO.0.C  2.562930e-02          NaN
# 37    IRF1_MOUSE.H11MO.0.A  1.933450e-11          NaN
# 38     EHF_HUMAN.H11MO.0.B  2.548120e-01          NaN
# 39     FOSL1+JUND_MA1143.1  5.472350e-02          NaN
# 40    ELK1_MOUSE.H11MO.0.B  1.330040e-02          NaN
# 41          BCL6B_MA0731.1  1.386250e-01          NaN
# 42                     NaN           NaN          NaN
# 43   KAISO_MOUSE.H11MO.0.B  5.276310e-03          NaN
# 44    TFE3_MOUSE.H11MO.0.A  8.553670e-05          NaN
# 45    RFX2_HUMAN.H11MO.0.A  4.514190e-09          NaN
# 46    REST_MOUSE.H11MO.0.A  7.349760e-14          NaN
# 47   GABPA_HUMAN.H11MO.0.A  5.463270e-02          NaN
# 48          CEBPD_MA0836.1  6.853750e-02          NaN
# 49          Foxj2_MA0614.1  2.651300e-01          NaN
# 50  Foxc1.mouse_forkhead_2  2.402020e-02          NaN
# 51         ZNF143_MA0088.2  2.682900e-03          NaN
# 52  Foxg1.mouse_forkhead_1  3.598180e-01          NaN
# 53              PAX6_PAX_1  7.475710e-01          NaN
# 54   FOSL2_HUMAN.H11MO.0.A  2.553090e-01          NaN
# 55          TEAD1_MA0090.2  5.651030e-01          NaN
# 56          CEBPE_MA0837.1  1.181890e-01          NaN
# 57                     NaN           NaN          NaN
# 58   CEBPB_MOUSE.H11MO.0.A  5.899940e-04          NaN
# 59              FLI1_ETS_4  1.629010e-01          NaN
# 60   MEIS2_HUMAN.H11MO.0.B  7.695510e-01          NaN
# 61    Ddit3+Cebpa_MA0019.1  1.000000e+00          NaN
# 62              IRF3_IRF_1  1.972880e-02          NaN
# 63    ETV4_HUMAN.H11MO.0.B  1.936960e-01          NaN
# 64    ATF4_HUMAN.H11MO.0.A  1.493660e-01          NaN
# 65    KLF1_HUMAN.H11MO.0.A  2.151820e-03          NaN
# 66               ERG_ETS_3  1.563130e-02          NaN
# 67           ZEB1_MA0103.3  3.328070e-02          NaN
# 68          FOSL2_MA0478.1  8.879650e-03          NaN
# 69          PROP1_MA0715.1  1.012620e-02          NaN

# %%
tomtom[0][["pattern","num_seqlets"]].to_csv(os.path.join(ppm_dir,mode+"_counts.csv"),sep=",",index=False, header=False)
