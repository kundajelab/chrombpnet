# %%
import numpy as np
import pandas as pd
import h5py
import pysam
import os
from modisco.visualization import viz_sequence
from modisco import util
from matplotlib import pyplot as plt
import pybedtools
from bs4 import BeautifulSoup

pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
dttype = 'DNASE'
mode = "counts"
celltype="IMR90"
modisco_path = '/oak/stanford/groups/akundaje/projects/chromatin-atlas-2022/chrombpnet/folds/'+dttype+'/'+celltype+'/merge_folds_new/'+mode+'/modisco_old_format.h5'
ppm_dir = ''

htmld="/oak/stanford/groups/akundaje/projects/chromatin-atlas-2022/chrombpnet/folds/"+dttype+'/'+celltype+"/merge_folds_new/"+mode+"/motifs.html"
tomtom = pd.read_html(htmld)


background=[0.25, 0.25, 0.25, 0.25]

# %%
def trim_motif_new(cwm, motif, trim_threshold=0.20):
    """
    Given the PFM and motif (both L x 4 arrays) (the motif could be the
    PFM itself), trims `motif` by cutting off flanks of low information
    content in `pfm`. `min_ic` is the minimum required information
    content. If specified this trimmed motif will be extended on either
    side by `pad` bases.
    If no base passes the `min_ic` threshold, then no trimming is done.
    """
    
    score = np.sum(np.abs(cwm), axis=1)
    trim_thresh = np.max(score) * trim_threshold  # Cut off anything less than 30% of max score
    pass_inds = np.where(score >= trim_thresh)[0]
    trimmed = motif[np.min(pass_inds): np.max(pass_inds) + 1]
 
    if not trimmed.size:
        return motif
    
    return trimmed

def import_tfmodisco_motifs(tfm_results_path, trim=True, only_pos=True):
    """
    Imports the PFMs to into a dictionary, mapping `(x, y)` to the PFM,
    where `x` is the metacluster index and `y` is the pattern index.
    Arguments:
        `tfm_results_path`: path to HDF5 containing TF-MoDISco results
        `out_dir`: where to save motifs
        `trim`: if True, trim the motif flanks based on information content
        `only_pos`: if True, only return motifs with positive contributions
    Returns the dictionary of PFMs.
    """ 
    pfms = {}
    with h5py.File(tfm_results_path, "r") as f:
        metaclusters = f["metacluster_idx_to_submetacluster_results"]
        num_metaclusters = len(metaclusters.keys())
        for metacluster_i, metacluster_key in enumerate(metaclusters.keys()):
            metacluster = metaclusters[metacluster_key]
            if "patterns" not in metacluster["seqlets_to_patterns_result"]:
                continue
            patterns = metacluster["seqlets_to_patterns_result"]["patterns"]
            num_patterns = len(patterns["all_pattern_names"][:])
            for pattern_i, pattern_name in enumerate(patterns["all_pattern_names"][:]):
#                pattern_name = pattern_name.decode()
                pattern_name = pattern_name

                pattern = patterns[pattern_name]
                pfm = pattern["sequence"]["fwd"][:]
                cwm = pattern["task0_contrib_scores"]["fwd"][:]
                
                # Check that the contribution scores are overall positive
                if only_pos and np.sum(cwm) < 0:
                    continue
                    
                if trim:
                    pfm = trim_motif_new(cwm, cwm)
                else:
                    pfm = cwm
                    
                pfms["%d_%d" % (metacluster_i,pattern_i)] = pfm
    return pfms

# %%
pfms = import_tfmodisco_motifs(modisco_path, trim=False)

# %%
for key in pfms:
    f = open(os.path.join(ppm_dir,mode+"_"+key+".pfm"),"w")
    #print(pfms[key])
    np.savetxt(f, pfms[key], fmt='%f')
    f.close()

# %%
tomtom[0]
# Out:
#                     pattern  num_seqlets  modisco_cwm_fwd  modisco_cwm_rev  \
# 0    pos_patterns.pattern_0        81493              NaN              NaN
# 1    pos_patterns.pattern_1        21717              NaN              NaN
# 2    pos_patterns.pattern_2        12484              NaN              NaN
# 3    pos_patterns.pattern_3         9546              NaN              NaN
# 4    pos_patterns.pattern_4         7776              NaN              NaN
# 5    pos_patterns.pattern_5         7181              NaN              NaN
# 6    pos_patterns.pattern_6         6867              NaN              NaN
# 7    pos_patterns.pattern_7         6667              NaN              NaN
# 8    pos_patterns.pattern_8         5459              NaN              NaN
# 9    pos_patterns.pattern_9         4696              NaN              NaN
# 10  pos_patterns.pattern_10         4372              NaN              NaN
# 11  pos_patterns.pattern_11         4339              NaN              NaN
# 12  pos_patterns.pattern_12         3139              NaN              NaN
# 13  pos_patterns.pattern_13         3082              NaN              NaN
# 14  pos_patterns.pattern_14         2536              NaN              NaN
# 15  pos_patterns.pattern_15         2249              NaN              NaN
# 16  pos_patterns.pattern_16         2133              NaN              NaN
# 17  pos_patterns.pattern_17         1822              NaN              NaN
# 18  pos_patterns.pattern_18         1782              NaN              NaN
# 19  pos_patterns.pattern_19         1554              NaN              NaN
# 20  pos_patterns.pattern_20         1427              NaN              NaN
# 21  pos_patterns.pattern_21         1119              NaN              NaN
# 22  pos_patterns.pattern_22         1088              NaN              NaN
# 23  pos_patterns.pattern_23         1062              NaN              NaN
# 24  pos_patterns.pattern_24         1053              NaN              NaN
# 25  pos_patterns.pattern_25          964              NaN              NaN
# 26  pos_patterns.pattern_26          774              NaN              NaN
# 27  pos_patterns.pattern_27          707              NaN              NaN
# 28  pos_patterns.pattern_28          615              NaN              NaN
# 29  pos_patterns.pattern_29          529              NaN              NaN
# 30  pos_patterns.pattern_30          496              NaN              NaN
# 31  pos_patterns.pattern_31          462              NaN              NaN
# 32  pos_patterns.pattern_32          446              NaN              NaN
# 33  pos_patterns.pattern_33          429              NaN              NaN
# 34  pos_patterns.pattern_34          374              NaN              NaN
# 35  pos_patterns.pattern_35          312              NaN              NaN
# 36  pos_patterns.pattern_36          283              NaN              NaN
# 37  pos_patterns.pattern_37          277              NaN              NaN
# 38  pos_patterns.pattern_38          273              NaN              NaN
# 39  pos_patterns.pattern_39          190              NaN              NaN
# 40  pos_patterns.pattern_40          175              NaN              NaN
# 41  pos_patterns.pattern_41          143              NaN              NaN
# 42  pos_patterns.pattern_42          114              NaN              NaN
# 43  pos_patterns.pattern_43          109              NaN              NaN
# 44  pos_patterns.pattern_44          101              NaN              NaN
# 45  pos_patterns.pattern_45           98              NaN              NaN
# 46  pos_patterns.pattern_46           90              NaN              NaN
# 47  pos_patterns.pattern_47           88              NaN              NaN
# 48  pos_patterns.pattern_48           78              NaN              NaN
# 49  pos_patterns.pattern_49           71              NaN              NaN
# 50  pos_patterns.pattern_50           71              NaN              NaN
# 51  pos_patterns.pattern_51           65              NaN              NaN
# 52  pos_patterns.pattern_52           62              NaN              NaN
# 53  pos_patterns.pattern_53           57              NaN              NaN
# 54  pos_patterns.pattern_54           50              NaN              NaN
# 55  pos_patterns.pattern_55           47              NaN              NaN
# 56  pos_patterns.pattern_56           47              NaN              NaN
# 57  pos_patterns.pattern_57           46              NaN              NaN
# 58  pos_patterns.pattern_58           46              NaN              NaN
# 59  pos_patterns.pattern_59           45              NaN              NaN
# 60  pos_patterns.pattern_60           41              NaN              NaN
# 61  pos_patterns.pattern_61           35              NaN              NaN
# 62  pos_patterns.pattern_62           28              NaN              NaN
# 63  pos_patterns.pattern_63           27              NaN              NaN
# 64  pos_patterns.pattern_64           25              NaN              NaN
# 65  pos_patterns.pattern_65           23              NaN              NaN
# 66  pos_patterns.pattern_66           20              NaN              NaN
# 67   neg_patterns.pattern_0          362              NaN              NaN
# 68   neg_patterns.pattern_1          263              NaN              NaN
# 69   neg_patterns.pattern_2           39              NaN              NaN
# 70   neg_patterns.pattern_3           38              NaN              NaN
# 71   neg_patterns.pattern_4           21              NaN              NaN
#
#                     match0         qval0  match0_logo                  match1  \
# 0       FOSL1+JUN_MA1128.1  5.955930e-04          NaN       FOS+JUND_MA1141.1
# 1            CTCF_MA0139.1  9.842360e-12          NaN    CTCF_HUMAN.H11MO.0.A
# 2     NFIC_HUMAN.H11MO.0.A  1.617250e-03          NaN    NFIA_HUMAN.H11MO.0.C
# 3           TEAD3_MA0808.1  1.646020e-04          NaN             TEAD3_TEA_2
# 4    RUNX1_HUMAN.H11MO.0.A  1.512400e-02          NaN   RUNX1_MOUSE.H11MO.0.A
# 5   Foxc1.mouse_forkhead_2  2.195140e-02          NaN        FOXJ3_forkhead_2
# 6             JUN_MA0488.1  1.376090e-03          NaN           JUND_MA0492.1
# 7      FOSL1+JUND_MA1143.1  1.502480e-03          NaN           Atf1_MA0604.1
# 8           FOSL2_MA0478.1  1.576570e-02          NaN           JUNB_MA0490.1
# 9     ATF4_MOUSE.H11MO.0.A  5.491060e-04          NaN    ATF4_HUMAN.H11MO.0.A
# 10   CEBPA_HUMAN.H11MO.0.A  6.554210e-04          NaN          CEBPA_MA0102.3
# 11    ETS1_MOUSE.H11MO.0.A  2.269700e-04          NaN     ERG_MOUSE.H11MO.0.A
# 12            MSC_MA0665.1  9.169330e-03          NaN              MSC_bHLH_1
# 13    NFYB_HUMAN.H11MO.0.A  9.241660e-03          NaN    NFYB_MOUSE.H11MO.0.A
# 14   KLF12_HUMAN.H11MO.0.C  7.274090e-05          NaN     SP1_HUMAN.H11MO.0.A
# 15           NRF1_MA0506.1  3.502930e-06          NaN    NRF1_MOUSE.H11MO.0.A
# 16          TEAD3_MA0808.1  4.415040e-04          NaN             TEAD3_TEA_2
# 17    SIX1_HUMAN.H11MO.0.A  8.158140e-13          NaN    SIX2_MOUSE.H11MO.0.A
# 18          TEAD3_MA0808.1  1.742420e-04          NaN             TEAD3_TEA_2
# 19          CEBPB_MA0466.2  1.776260e-02          NaN            CEBPB_bZIP_1
# 20   ZN143_HUMAN.H11MO.0.A  4.847610e-20          NaN   ZN143_MOUSE.H11MO.0.A
# 21    TF65_HUMAN.H11MO.0.A  8.409280e-06          NaN   NFKB1_HUMAN.H11MO.1.B
# 22            JUN_MA0489.1  4.937790e-03          NaN       BATF+JUN_MA0462.1
# 23   TEAD4_MOUSE.H11MO.0.A  1.727230e-09          NaN             TEAD1_TEA_2
# 24   ZN250_HUMAN.H11MO.0.C  1.000000e+00          NaN   SMCA1_HUMAN.H11MO.0.C
# 25    RFX2_MOUSE.H11MO.0.A  5.272470e-07          NaN           Rfx1_MA0509.1
# 26    BATF_HUMAN.H11MO.0.A  3.686020e-01          NaN          FOSL2_MA0478.1
# 27          TEAD4_MA0809.1  1.000000e+00          NaN             TEAD4_TEA_1
# 28   MEF2D_MOUSE.H11MO.0.A  2.284930e-07          NaN   MEF2D_HUMAN.H11MO.0.A
# 29   FOXL2_MOUSE.H11MO.0.C  1.205070e-02          NaN   FOXK1_HUMAN.H11MO.0.A
# 30         ZBTB33_MA0527.1  7.011930e-05          NaN   KAISO_HUMAN.H11MO.0.A
# 31           RELA_MA0107.1  1.674600e-01          NaN   NFKB1_HUMAN.H11MO.1.B
# 32        FOXC1_forkhead_1  1.236940e-03          NaN          Foxj3_MA0851.1
# 33          Gabpa_MA0062.2  5.711230e-03          NaN    ELK1_HUMAN.H11MO.0.B
# 34    EGR2_HUMAN.H11MO.0.A  7.334500e-05          NaN    EGR2_MOUSE.H11MO.0.A
# 35    NFIC_HUMAN.H11MO.0.A  3.989160e-02          NaN    NFIC_MOUSE.H11MO.0.A
# 36   FOXA1_HUMAN.H11MO.0.A  1.554580e-02          NaN   FOXD3_MOUSE.H11MO.0.C
# 37             TEAD3_TEA_1  4.281920e-02          NaN             TEAD1_TEA_2
# 38    TFE3_HUMAN.H11MO.0.B  1.154430e-04          NaN    TFE3_MOUSE.H11MO.0.A
# 39              ETV6_ETS_1  4.896580e-05          NaN              IRF7_IRF_1
# 40   CREB1_HUMAN.H11MO.0.A  5.321400e-02          NaN   CREB1_MOUSE.H11MO.0.A
# 41           KLF5_MA0599.1  1.916530e-01          NaN     SP2_HUMAN.H11MO.0.A
# 42        Rfx2.mouse_RFX_2  1.721140e-08          NaN              RFX3_RFX_2
# 43              SRF_MADS_1  5.195190e-05          NaN            SRF_MA0083.3
# 44    LYL1_HUMAN.H11MO.0.A  1.678190e-03          NaN    LYL1_MOUSE.H11MO.0.A
# 45       BATF+JUN_MA0462.1  1.305030e-02          NaN       Jdp2.mouse_bZIP_1
# 46  Foxk1.mouse_forkhead_2  7.914370e-03          NaN          FOXD2_MA0847.1
# 47    ETV2_HUMAN.H11MO.0.B  6.305720e-02          NaN    ETV2_MOUSE.H11MO.0.A
# 48   PRD14_MOUSE.H11MO.0.A  1.000000e+00          NaN   PRD14_HUMAN.H11MO.0.A
# 49        FOXD2_forkhead_1  6.701290e-02          NaN        FOXC1_forkhead_2
# 50   OLIG2_HUMAN.H11MO.0.B  5.706270e-03          NaN   OLIG2_MOUSE.H11MO.0.A
# 51      NFIC+TLX1_MA0119.1  4.801280e-04          NaN    NFIC_HUMAN.H11MO.0.A
# 52          TEAD3_MA0808.1  1.563510e-01          NaN             TEAD3_TEA_2
# 53   STAT3_HUMAN.H11MO.0.A  1.000000e+00          NaN           RBPJ_MA1116.1
# 54   FOXP1_HUMAN.H11MO.0.A  3.239650e-01          NaN  Foxc1.mouse_forkhead_2
# 55     FOS_HUMAN.H11MO.0.A  2.497480e-01          NaN   ZN708_HUMAN.H11MO.0.C
# 56       JUN+JUNB_MA1132.1  1.364770e-01          NaN        FOS+JUN_MA0099.3
# 57          RUNX1_MA0002.2  6.416390e-02          NaN   RUNX1_MOUSE.H11MO.0.A
# 58          FOXH1_MA0479.1  7.365210e-02          NaN   RUNX3_MOUSE.H11MO.0.A
# 59          Foxo1_MA0480.1  2.972750e-02          NaN   FOXO1_MOUSE.H11MO.0.A
# 60    ETV4_MOUSE.H11MO.0.B  1.921290e-02          NaN            JUN_MA0489.1
# 61          Gabpa_MA0062.2  9.382860e-03          NaN    ELK1_MOUSE.H11MO.0.B
# 62              NFIX_NFI_1  9.322720e-03          NaN              NFIB_NFI_1
# 63   DDIT3_MOUSE.H11MO.0.C  1.712370e-01          NaN          BATF3_MA0835.1
# 64   FOSL2_MOUSE.H11MO.0.A  5.666590e-01          NaN        FOS+JUN_MA0099.3
# 65      Ascl2.mouse_bHLH_1  4.160900e-03          NaN          Ascl2_MA0816.1
# 66   CEBPA_MOUSE.H11MO.0.A  1.331590e-02          NaN   CEBPB_MOUSE.H11MO.0.A
# 67    ZEB1_HUMAN.H11MO.0.A  3.501740e-02          NaN    ZEB1_MOUSE.H11MO.0.B
# 68             JDP2_bZIP_1  1.275300e-04          NaN       BATF+JUN_MA0462.1
# 69    ZEB1_HUMAN.H11MO.0.A  3.448220e-01          NaN    ZEB1_MOUSE.H11MO.0.B
# 70   ZN708_HUMAN.H11MO.0.C  3.997100e-01          NaN   PKNX1_HUMAN.H11MO.0.B
# 71   SNAI1_HUMAN.H11MO.0.C  3.189390e-01          NaN   SNAI1_MOUSE.H11MO.0.C
#
#            qval1  match1_logo                 match2         qval2  \
# 0   5.955930e-04          NaN   ATF3_MOUSE.H11MO.0.A  1.746280e-03
# 1   3.699040e-09          NaN   CTCF_MOUSE.H11MO.0.A  4.835700e-08
# 2   7.790550e-02          NaN   NFIA_MOUSE.H11MO.0.C  7.790550e-02
# 3   1.646020e-04          NaN  TEAD1_MOUSE.H11MO.0.A  2.200090e-02
# 4   1.512400e-02          NaN  RUNX3_MOUSE.H11MO.0.A  1.512400e-02
# 5   2.195140e-02          NaN       FOXG1_forkhead_1  2.195140e-02
# 6   3.974990e-03          NaN   ATF2_HUMAN.H11MO.0.B  3.974990e-03
# 7   2.745420e-03          NaN          Crem_MA0609.1  5.097960e-02
# 8   1.576570e-02          NaN      BATF+JUN_MA0462.1  1.996820e-02
# 9   7.297840e-04          NaN  DDIT3_MOUSE.H11MO.0.C  7.297840e-04
# 10  6.554210e-04          NaN  CEBPA_MOUSE.H11MO.0.A  7.914960e-04
# 11  2.703730e-04          NaN   ETS1_HUMAN.H11MO.0.A  2.989870e-04
# 12  9.169330e-03          NaN   HTF4_HUMAN.H11MO.0.A  9.169330e-03
# 13  9.241660e-03          NaN   NFYA_HUMAN.H11MO.0.A  9.241660e-03
# 14  1.697290e-04          NaN   KLF3_HUMAN.H11MO.0.B  5.820350e-04
# 15  5.224150e-05          NaN   NRF1_HUMAN.H11MO.0.A  5.224150e-05
# 16  4.415040e-04          NaN      BATF+JUN_MA0462.1  5.548580e-03
# 17  1.257720e-09          NaN   SIX2_HUMAN.H11MO.0.A  2.965680e-08
# 18  1.742420e-04          NaN      FOSB+JUN_MA1127.1  8.884020e-02
# 19  1.776260e-02          NaN           CEBPB_bZIP_2  1.776260e-02
# 20  1.833010e-19          NaN  ZNF76_HUMAN.H11MO.0.C  1.833010e-19
# 21  1.299850e-05          NaN  NFKB1_MOUSE.H11MO.0.A  1.299850e-05
# 22  8.369430e-03          NaN   ELF2_MOUSE.H11MO.0.C  3.538990e-02
# 23  4.729360e-08          NaN  TEAD4_HUMAN.H11MO.0.A  4.131210e-07
# 24  1.000000e+00          NaN         TEAD4_MA0809.1  1.000000e+00
# 25  5.272470e-07          NaN   RFX3_MOUSE.H11MO.0.C  9.372190e-07
# 26  3.686020e-01          NaN          JUNB_MA0490.1  3.686020e-01
# 27  1.000000e+00          NaN           JUN_MA0488.1  1.000000e+00
# 28  2.284930e-07          NaN         MEF2D_MA0773.1  2.487050e-07
# 29  1.205070e-02          NaN  FOXA1_MOUSE.H11MO.0.A  1.205070e-02
# 30  1.394180e-04          NaN  KAISO_MOUSE.H11MO.0.B  1.394180e-04
# 31  1.674600e-01          NaN  NFKB1_MOUSE.H11MO.0.A  1.674600e-01
# 32  9.984410e-03          NaN       FOXC2_forkhead_2  9.984410e-03
# 33  1.884890e-02          NaN   ELK1_MOUSE.H11MO.0.B  1.884890e-02
# 34  1.735530e-04          NaN   EGR1_HUMAN.H11MO.0.A  7.807050e-03
# 35  8.629550e-02          NaN        HOXA13_MA0650.1  1.930020e-01
# 36  1.554580e-02          NaN         Foxa2_MA0047.2  1.720340e-02
# 37  6.805160e-02          NaN          ZNF713_C2H2_1  4.266360e-01
# 38  1.154430e-04          NaN   MITF_HUMAN.H11MO.0.A  1.154430e-04
# 39  2.495510e-03          NaN          IRF7_MA0772.1  2.495510e-03
# 40  5.321400e-02          NaN          JUND_MA0492.1  5.321400e-02
# 41  1.916530e-01          NaN    SP2_MOUSE.H11MO.0.B  1.916530e-01
# 42  2.209810e-08          NaN             RFX2_RFX_2  3.300560e-08
# 43  1.017540e-04          NaN             SRF_MADS_2  1.017540e-04
# 44  1.678190e-03          NaN  OLIG2_HUMAN.H11MO.0.B  2.650370e-03
# 45  6.555780e-02          NaN          JDP2_MA0655.1  6.555780e-02
# 46  7.914370e-03          NaN       FOXD2_forkhead_2  7.914370e-03
# 47  6.305720e-02          NaN   ETV6_MOUSE.H11MO.0.C  6.305720e-02
# 48  1.000000e+00          NaN                    NaN           NaN
# 49  6.701290e-02          NaN       FOXC2_forkhead_1  1.087790e-01
# 50  5.706270e-03          NaN       Bhlha15_MA0607.1  1.622150e-01
# 51  3.702190e-03          NaN   NFIA_HUMAN.H11MO.0.C  1.272260e-02
# 52  1.563510e-01          NaN         TEAD1_MA0090.2  4.029550e-01
# 53  1.000000e+00          NaN   Ddit3+Cebpa_MA0019.1  1.000000e+00
# 54  3.239650e-01          NaN         FOXL1_MA0033.2  3.239650e-01
# 55  2.497480e-01          NaN   JUNB_MOUSE.H11MO.0.A  2.497480e-01
# 56  1.364770e-01          NaN    FOSL1+JUNB_MA1137.1  1.364770e-01
# 57  6.416390e-02          NaN  RUNX3_HUMAN.H11MO.0.A  6.416390e-02
# 58  7.365210e-02          NaN  RUNX3_HUMAN.H11MO.0.A  7.365210e-02
# 59  4.933060e-02          NaN  FOXO1_HUMAN.H11MO.0.A  1.281020e-01
# 60  4.349930e-02          NaN   ELK1_HUMAN.H11MO.0.B  4.349930e-02
# 61  9.382860e-03          NaN          ELK4_MA0076.2  9.382860e-03
# 62  9.322720e-03          NaN   NFIA_HUMAN.H11MO.0.C  9.322720e-03
# 63  1.712370e-01          NaN           BATF3_bZIP_1  1.712370e-01
# 64  5.666590e-01          NaN     FOSB+JUNB_MA1135.1  5.666590e-01
# 65  4.160900e-03          NaN           MSC_MA0665.1  4.160900e-03
# 66  1.331590e-02          NaN         CEBPA_MA0102.3  1.331590e-02
# 67  3.501740e-02          NaN           SNAI2_C2H2_1  7.731070e-02
# 68  1.275300e-04          NaN          JUNB_MA0490.1  1.275300e-04
# 69  3.448220e-01          NaN  SNAI1_HUMAN.H11MO.0.C  3.448220e-01
# 70  3.997100e-01          NaN  PKNX1_MOUSE.H11MO.0.A  3.997100e-01
# 71  3.189390e-01          NaN          ZEB1_MA0103.3  5.040230e-01
#
#     match2_logo
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN
# 54          NaN
# 55          NaN
# 56          NaN
# 57          NaN
# 58          NaN
# 59          NaN
# 60          NaN
# 61          NaN
# 62          NaN
# 63          NaN
# 64          NaN
# 65          NaN
# 66          NaN
# 67          NaN
# 68          NaN
# 69          NaN
# 70          NaN
# 71          NaN

# %%
tomtom[0]["pattern"] = tomtom[0]["pattern"].str.replace("pos_patterns.pattern","0").str.replace("neg_patterns.pattern","1")
# Out:
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
tomtom[0]
# Out:
#    pattern  num_seqlets  modisco_cwm_fwd  modisco_cwm_rev  \
# 0      0_0        81493              NaN              NaN
# 1      0_1        21717              NaN              NaN
# 2      0_2        12484              NaN              NaN
# 3      0_3         9546              NaN              NaN
# 4      0_4         7776              NaN              NaN
# 5      0_5         7181              NaN              NaN
# 6      0_6         6867              NaN              NaN
# 7      0_7         6667              NaN              NaN
# 8      0_8         5459              NaN              NaN
# 9      0_9         4696              NaN              NaN
# 10    0_10         4372              NaN              NaN
# 11    0_11         4339              NaN              NaN
# 12    0_12         3139              NaN              NaN
# 13    0_13         3082              NaN              NaN
# 14    0_14         2536              NaN              NaN
# 15    0_15         2249              NaN              NaN
# 16    0_16         2133              NaN              NaN
# 17    0_17         1822              NaN              NaN
# 18    0_18         1782              NaN              NaN
# 19    0_19         1554              NaN              NaN
# 20    0_20         1427              NaN              NaN
# 21    0_21         1119              NaN              NaN
# 22    0_22         1088              NaN              NaN
# 23    0_23         1062              NaN              NaN
# 24    0_24         1053              NaN              NaN
# 25    0_25          964              NaN              NaN
# 26    0_26          774              NaN              NaN
# 27    0_27          707              NaN              NaN
# 28    0_28          615              NaN              NaN
# 29    0_29          529              NaN              NaN
# 30    0_30          496              NaN              NaN
# 31    0_31          462              NaN              NaN
# 32    0_32          446              NaN              NaN
# 33    0_33          429              NaN              NaN
# 34    0_34          374              NaN              NaN
# 35    0_35          312              NaN              NaN
# 36    0_36          283              NaN              NaN
# 37    0_37          277              NaN              NaN
# 38    0_38          273              NaN              NaN
# 39    0_39          190              NaN              NaN
# 40    0_40          175              NaN              NaN
# 41    0_41          143              NaN              NaN
# 42    0_42          114              NaN              NaN
# 43    0_43          109              NaN              NaN
# 44    0_44          101              NaN              NaN
# 45    0_45           98              NaN              NaN
# 46    0_46           90              NaN              NaN
# 47    0_47           88              NaN              NaN
# 48    0_48           78              NaN              NaN
# 49    0_49           71              NaN              NaN
# 50    0_50           71              NaN              NaN
# 51    0_51           65              NaN              NaN
# 52    0_52           62              NaN              NaN
# 53    0_53           57              NaN              NaN
# 54    0_54           50              NaN              NaN
# 55    0_55           47              NaN              NaN
# 56    0_56           47              NaN              NaN
# 57    0_57           46              NaN              NaN
# 58    0_58           46              NaN              NaN
# 59    0_59           45              NaN              NaN
# 60    0_60           41              NaN              NaN
# 61    0_61           35              NaN              NaN
# 62    0_62           28              NaN              NaN
# 63    0_63           27              NaN              NaN
# 64    0_64           25              NaN              NaN
# 65    0_65           23              NaN              NaN
# 66    0_66           20              NaN              NaN
# 67     1_0          362              NaN              NaN
# 68     1_1          263              NaN              NaN
# 69     1_2           39              NaN              NaN
# 70     1_3           38              NaN              NaN
# 71     1_4           21              NaN              NaN
#
#                     match0         qval0  match0_logo                  match1  \
# 0       FOSL1+JUN_MA1128.1  5.955930e-04          NaN       FOS+JUND_MA1141.1
# 1            CTCF_MA0139.1  9.842360e-12          NaN    CTCF_HUMAN.H11MO.0.A
# 2     NFIC_HUMAN.H11MO.0.A  1.617250e-03          NaN    NFIA_HUMAN.H11MO.0.C
# 3           TEAD3_MA0808.1  1.646020e-04          NaN             TEAD3_TEA_2
# 4    RUNX1_HUMAN.H11MO.0.A  1.512400e-02          NaN   RUNX1_MOUSE.H11MO.0.A
# 5   Foxc1.mouse_forkhead_2  2.195140e-02          NaN        FOXJ3_forkhead_2
# 6             JUN_MA0488.1  1.376090e-03          NaN           JUND_MA0492.1
# 7      FOSL1+JUND_MA1143.1  1.502480e-03          NaN           Atf1_MA0604.1
# 8           FOSL2_MA0478.1  1.576570e-02          NaN           JUNB_MA0490.1
# 9     ATF4_MOUSE.H11MO.0.A  5.491060e-04          NaN    ATF4_HUMAN.H11MO.0.A
# 10   CEBPA_HUMAN.H11MO.0.A  6.554210e-04          NaN          CEBPA_MA0102.3
# 11    ETS1_MOUSE.H11MO.0.A  2.269700e-04          NaN     ERG_MOUSE.H11MO.0.A
# 12            MSC_MA0665.1  9.169330e-03          NaN              MSC_bHLH_1
# 13    NFYB_HUMAN.H11MO.0.A  9.241660e-03          NaN    NFYB_MOUSE.H11MO.0.A
# 14   KLF12_HUMAN.H11MO.0.C  7.274090e-05          NaN     SP1_HUMAN.H11MO.0.A
# 15           NRF1_MA0506.1  3.502930e-06          NaN    NRF1_MOUSE.H11MO.0.A
# 16          TEAD3_MA0808.1  4.415040e-04          NaN             TEAD3_TEA_2
# 17    SIX1_HUMAN.H11MO.0.A  8.158140e-13          NaN    SIX2_MOUSE.H11MO.0.A
# 18          TEAD3_MA0808.1  1.742420e-04          NaN             TEAD3_TEA_2
# 19          CEBPB_MA0466.2  1.776260e-02          NaN            CEBPB_bZIP_1
# 20   ZN143_HUMAN.H11MO.0.A  4.847610e-20          NaN   ZN143_MOUSE.H11MO.0.A
# 21    TF65_HUMAN.H11MO.0.A  8.409280e-06          NaN   NFKB1_HUMAN.H11MO.1.B
# 22            JUN_MA0489.1  4.937790e-03          NaN       BATF+JUN_MA0462.1
# 23   TEAD4_MOUSE.H11MO.0.A  1.727230e-09          NaN             TEAD1_TEA_2
# 24   ZN250_HUMAN.H11MO.0.C  1.000000e+00          NaN   SMCA1_HUMAN.H11MO.0.C
# 25    RFX2_MOUSE.H11MO.0.A  5.272470e-07          NaN           Rfx1_MA0509.1
# 26    BATF_HUMAN.H11MO.0.A  3.686020e-01          NaN          FOSL2_MA0478.1
# 27          TEAD4_MA0809.1  1.000000e+00          NaN             TEAD4_TEA_1
# 28   MEF2D_MOUSE.H11MO.0.A  2.284930e-07          NaN   MEF2D_HUMAN.H11MO.0.A
# 29   FOXL2_MOUSE.H11MO.0.C  1.205070e-02          NaN   FOXK1_HUMAN.H11MO.0.A
# 30         ZBTB33_MA0527.1  7.011930e-05          NaN   KAISO_HUMAN.H11MO.0.A
# 31           RELA_MA0107.1  1.674600e-01          NaN   NFKB1_HUMAN.H11MO.1.B
# 32        FOXC1_forkhead_1  1.236940e-03          NaN          Foxj3_MA0851.1
# 33          Gabpa_MA0062.2  5.711230e-03          NaN    ELK1_HUMAN.H11MO.0.B
# 34    EGR2_HUMAN.H11MO.0.A  7.334500e-05          NaN    EGR2_MOUSE.H11MO.0.A
# 35    NFIC_HUMAN.H11MO.0.A  3.989160e-02          NaN    NFIC_MOUSE.H11MO.0.A
# 36   FOXA1_HUMAN.H11MO.0.A  1.554580e-02          NaN   FOXD3_MOUSE.H11MO.0.C
# 37             TEAD3_TEA_1  4.281920e-02          NaN             TEAD1_TEA_2
# 38    TFE3_HUMAN.H11MO.0.B  1.154430e-04          NaN    TFE3_MOUSE.H11MO.0.A
# 39              ETV6_ETS_1  4.896580e-05          NaN              IRF7_IRF_1
# 40   CREB1_HUMAN.H11MO.0.A  5.321400e-02          NaN   CREB1_MOUSE.H11MO.0.A
# 41           KLF5_MA0599.1  1.916530e-01          NaN     SP2_HUMAN.H11MO.0.A
# 42        Rfx2.mouse_RFX_2  1.721140e-08          NaN              RFX3_RFX_2
# 43              SRF_MADS_1  5.195190e-05          NaN            SRF_MA0083.3
# 44    LYL1_HUMAN.H11MO.0.A  1.678190e-03          NaN    LYL1_MOUSE.H11MO.0.A
# 45       BATF+JUN_MA0462.1  1.305030e-02          NaN       Jdp2.mouse_bZIP_1
# 46  Foxk1.mouse_forkhead_2  7.914370e-03          NaN          FOXD2_MA0847.1
# 47    ETV2_HUMAN.H11MO.0.B  6.305720e-02          NaN    ETV2_MOUSE.H11MO.0.A
# 48   PRD14_MOUSE.H11MO.0.A  1.000000e+00          NaN   PRD14_HUMAN.H11MO.0.A
# 49        FOXD2_forkhead_1  6.701290e-02          NaN        FOXC1_forkhead_2
# 50   OLIG2_HUMAN.H11MO.0.B  5.706270e-03          NaN   OLIG2_MOUSE.H11MO.0.A
# 51      NFIC+TLX1_MA0119.1  4.801280e-04          NaN    NFIC_HUMAN.H11MO.0.A
# 52          TEAD3_MA0808.1  1.563510e-01          NaN             TEAD3_TEA_2
# 53   STAT3_HUMAN.H11MO.0.A  1.000000e+00          NaN           RBPJ_MA1116.1
# 54   FOXP1_HUMAN.H11MO.0.A  3.239650e-01          NaN  Foxc1.mouse_forkhead_2
# 55     FOS_HUMAN.H11MO.0.A  2.497480e-01          NaN   ZN708_HUMAN.H11MO.0.C
# 56       JUN+JUNB_MA1132.1  1.364770e-01          NaN        FOS+JUN_MA0099.3
# 57          RUNX1_MA0002.2  6.416390e-02          NaN   RUNX1_MOUSE.H11MO.0.A
# 58          FOXH1_MA0479.1  7.365210e-02          NaN   RUNX3_MOUSE.H11MO.0.A
# 59          Foxo1_MA0480.1  2.972750e-02          NaN   FOXO1_MOUSE.H11MO.0.A
# 60    ETV4_MOUSE.H11MO.0.B  1.921290e-02          NaN            JUN_MA0489.1
# 61          Gabpa_MA0062.2  9.382860e-03          NaN    ELK1_MOUSE.H11MO.0.B
# 62              NFIX_NFI_1  9.322720e-03          NaN              NFIB_NFI_1
# 63   DDIT3_MOUSE.H11MO.0.C  1.712370e-01          NaN          BATF3_MA0835.1
# 64   FOSL2_MOUSE.H11MO.0.A  5.666590e-01          NaN        FOS+JUN_MA0099.3
# 65      Ascl2.mouse_bHLH_1  4.160900e-03          NaN          Ascl2_MA0816.1
# 66   CEBPA_MOUSE.H11MO.0.A  1.331590e-02          NaN   CEBPB_MOUSE.H11MO.0.A
# 67    ZEB1_HUMAN.H11MO.0.A  3.501740e-02          NaN    ZEB1_MOUSE.H11MO.0.B
# 68             JDP2_bZIP_1  1.275300e-04          NaN       BATF+JUN_MA0462.1
# 69    ZEB1_HUMAN.H11MO.0.A  3.448220e-01          NaN    ZEB1_MOUSE.H11MO.0.B
# 70   ZN708_HUMAN.H11MO.0.C  3.997100e-01          NaN   PKNX1_HUMAN.H11MO.0.B
# 71   SNAI1_HUMAN.H11MO.0.C  3.189390e-01          NaN   SNAI1_MOUSE.H11MO.0.C
#
#            qval1  match1_logo                 match2         qval2  \
# 0   5.955930e-04          NaN   ATF3_MOUSE.H11MO.0.A  1.746280e-03
# 1   3.699040e-09          NaN   CTCF_MOUSE.H11MO.0.A  4.835700e-08
# 2   7.790550e-02          NaN   NFIA_MOUSE.H11MO.0.C  7.790550e-02
# 3   1.646020e-04          NaN  TEAD1_MOUSE.H11MO.0.A  2.200090e-02
# 4   1.512400e-02          NaN  RUNX3_MOUSE.H11MO.0.A  1.512400e-02
# 5   2.195140e-02          NaN       FOXG1_forkhead_1  2.195140e-02
# 6   3.974990e-03          NaN   ATF2_HUMAN.H11MO.0.B  3.974990e-03
# 7   2.745420e-03          NaN          Crem_MA0609.1  5.097960e-02
# 8   1.576570e-02          NaN      BATF+JUN_MA0462.1  1.996820e-02
# 9   7.297840e-04          NaN  DDIT3_MOUSE.H11MO.0.C  7.297840e-04
# 10  6.554210e-04          NaN  CEBPA_MOUSE.H11MO.0.A  7.914960e-04
# 11  2.703730e-04          NaN   ETS1_HUMAN.H11MO.0.A  2.989870e-04
# 12  9.169330e-03          NaN   HTF4_HUMAN.H11MO.0.A  9.169330e-03
# 13  9.241660e-03          NaN   NFYA_HUMAN.H11MO.0.A  9.241660e-03
# 14  1.697290e-04          NaN   KLF3_HUMAN.H11MO.0.B  5.820350e-04
# 15  5.224150e-05          NaN   NRF1_HUMAN.H11MO.0.A  5.224150e-05
# 16  4.415040e-04          NaN      BATF+JUN_MA0462.1  5.548580e-03
# 17  1.257720e-09          NaN   SIX2_HUMAN.H11MO.0.A  2.965680e-08
# 18  1.742420e-04          NaN      FOSB+JUN_MA1127.1  8.884020e-02
# 19  1.776260e-02          NaN           CEBPB_bZIP_2  1.776260e-02
# 20  1.833010e-19          NaN  ZNF76_HUMAN.H11MO.0.C  1.833010e-19
# 21  1.299850e-05          NaN  NFKB1_MOUSE.H11MO.0.A  1.299850e-05
# 22  8.369430e-03          NaN   ELF2_MOUSE.H11MO.0.C  3.538990e-02
# 23  4.729360e-08          NaN  TEAD4_HUMAN.H11MO.0.A  4.131210e-07
# 24  1.000000e+00          NaN         TEAD4_MA0809.1  1.000000e+00
# 25  5.272470e-07          NaN   RFX3_MOUSE.H11MO.0.C  9.372190e-07
# 26  3.686020e-01          NaN          JUNB_MA0490.1  3.686020e-01
# 27  1.000000e+00          NaN           JUN_MA0488.1  1.000000e+00
# 28  2.284930e-07          NaN         MEF2D_MA0773.1  2.487050e-07
# 29  1.205070e-02          NaN  FOXA1_MOUSE.H11MO.0.A  1.205070e-02
# 30  1.394180e-04          NaN  KAISO_MOUSE.H11MO.0.B  1.394180e-04
# 31  1.674600e-01          NaN  NFKB1_MOUSE.H11MO.0.A  1.674600e-01
# 32  9.984410e-03          NaN       FOXC2_forkhead_2  9.984410e-03
# 33  1.884890e-02          NaN   ELK1_MOUSE.H11MO.0.B  1.884890e-02
# 34  1.735530e-04          NaN   EGR1_HUMAN.H11MO.0.A  7.807050e-03
# 35  8.629550e-02          NaN        HOXA13_MA0650.1  1.930020e-01
# 36  1.554580e-02          NaN         Foxa2_MA0047.2  1.720340e-02
# 37  6.805160e-02          NaN          ZNF713_C2H2_1  4.266360e-01
# 38  1.154430e-04          NaN   MITF_HUMAN.H11MO.0.A  1.154430e-04
# 39  2.495510e-03          NaN          IRF7_MA0772.1  2.495510e-03
# 40  5.321400e-02          NaN          JUND_MA0492.1  5.321400e-02
# 41  1.916530e-01          NaN    SP2_MOUSE.H11MO.0.B  1.916530e-01
# 42  2.209810e-08          NaN             RFX2_RFX_2  3.300560e-08
# 43  1.017540e-04          NaN             SRF_MADS_2  1.017540e-04
# 44  1.678190e-03          NaN  OLIG2_HUMAN.H11MO.0.B  2.650370e-03
# 45  6.555780e-02          NaN          JDP2_MA0655.1  6.555780e-02
# 46  7.914370e-03          NaN       FOXD2_forkhead_2  7.914370e-03
# 47  6.305720e-02          NaN   ETV6_MOUSE.H11MO.0.C  6.305720e-02
# 48  1.000000e+00          NaN                    NaN           NaN
# 49  6.701290e-02          NaN       FOXC2_forkhead_1  1.087790e-01
# 50  5.706270e-03          NaN       Bhlha15_MA0607.1  1.622150e-01
# 51  3.702190e-03          NaN   NFIA_HUMAN.H11MO.0.C  1.272260e-02
# 52  1.563510e-01          NaN         TEAD1_MA0090.2  4.029550e-01
# 53  1.000000e+00          NaN   Ddit3+Cebpa_MA0019.1  1.000000e+00
# 54  3.239650e-01          NaN         FOXL1_MA0033.2  3.239650e-01
# 55  2.497480e-01          NaN   JUNB_MOUSE.H11MO.0.A  2.497480e-01
# 56  1.364770e-01          NaN    FOSL1+JUNB_MA1137.1  1.364770e-01
# 57  6.416390e-02          NaN  RUNX3_HUMAN.H11MO.0.A  6.416390e-02
# 58  7.365210e-02          NaN  RUNX3_HUMAN.H11MO.0.A  7.365210e-02
# 59  4.933060e-02          NaN  FOXO1_HUMAN.H11MO.0.A  1.281020e-01
# 60  4.349930e-02          NaN   ELK1_HUMAN.H11MO.0.B  4.349930e-02
# 61  9.382860e-03          NaN          ELK4_MA0076.2  9.382860e-03
# 62  9.322720e-03          NaN   NFIA_HUMAN.H11MO.0.C  9.322720e-03
# 63  1.712370e-01          NaN           BATF3_bZIP_1  1.712370e-01
# 64  5.666590e-01          NaN     FOSB+JUNB_MA1135.1  5.666590e-01
# 65  4.160900e-03          NaN           MSC_MA0665.1  4.160900e-03
# 66  1.331590e-02          NaN         CEBPA_MA0102.3  1.331590e-02
# 67  3.501740e-02          NaN           SNAI2_C2H2_1  7.731070e-02
# 68  1.275300e-04          NaN          JUNB_MA0490.1  1.275300e-04
# 69  3.448220e-01          NaN  SNAI1_HUMAN.H11MO.0.C  3.448220e-01
# 70  3.997100e-01          NaN  PKNX1_MOUSE.H11MO.0.A  3.997100e-01
# 71  3.189390e-01          NaN          ZEB1_MA0103.3  5.040230e-01
#
#     match2_logo
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 53          NaN
# 54          NaN
# 55          NaN
# 56          NaN
# 57          NaN
# 58          NaN
# 59          NaN
# 60          NaN
# 61          NaN
# 62          NaN
# 63          NaN
# 64          NaN
# 65          NaN
# 66          NaN
# 67          NaN
# 68          NaN
# 69          NaN
# 70          NaN
# 71          NaN

# %%
tomtom[0][["pattern","num_seqlets"]].to_csv(os.path.join(ppm_dir,mode+"_counts.csv"),sep=",",index=False, header=False)
