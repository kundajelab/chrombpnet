# %%
import pandas as pd

# %%
data = pd.read_csv("/mnt/lab_data2/anusri/chrombpnet/src/evaluation/figure_notebooks/figure_5/chip_seq_compare/output_jan_18/K562/pattern_0_GATA1.TAL1/ENCSR000EHB.bed", sep="\t", header=None)

# %%
data
# Out:
#          0          1          2   \
# 0      chr1     842971     842987
# 1      chr1    1005111    1005127
# 2      chr1    1185674    1185690
# 3      chr1    1883561    1883577
# 4      chr1    1883628    1883644
# ...     ...        ...        ...
# 11373  chrX  154124115  154124131
# 11374  chrX  154124202  154124218
# 11375  chrX  155087597  155087613
# 11376  chrX  155435090  155435106
# 11377  chrX  155666917  155666933
#
#                                                       3        4  5     6   \
# 0      pos_patterns.pattern_0.GATA3_GATA_1_pos_patter...  8.32795  +  chr1
# 1      pos_patterns.pattern_0.GATA3_GATA_1_pos_patter...  7.74173  -  chr1
# 2      pos_patterns.pattern_0.GATA3_GATA_1_pos_patter...  8.01999  -  chr1
# 3      pos_patterns.pattern_0.GATA3_GATA_1_pos_patter...  8.26569  -  chr1
# 4      pos_patterns.pattern_0.GATA3_GATA_1_pos_patter...  8.39462  +  chr1
# ...                                                  ...      ... ..   ...
# ...

# %%
import matplotlib.pyplot as plt
import scipy.stats
import numpy as np

# %%
plt.scatter(np.log(data[15]), data[14])
print(scipy.stats.pearsonr(np.log(data[15]), data[14]))
# Out:
# (0.09422620996999852, 7.331590507966095e-24)

# %%
plt.scatter(data[12], data[14])
print(scipy.stats.pearsonr(data[12], data[14]))
# Out:
# (0.8147228451812667, 0.0)
