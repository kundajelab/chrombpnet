# %%
import numpy as np
import pandas as pd
import h5py
import pysam
import os
from modisco.visualization import viz_sequence
from modisco import util
from matplotlib import pyplot as plt
import pybedtools
from bs4 import BeautifulSoup

pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
dttype = 'DNASE'
mode = "counts"
celltype="H1ESC_new"
modisco_path = '/oak/stanford/groups/akundaje/projects/chromatin-atlas-2022/chrombpnet/folds/'+dttype+'/'+celltype+'/merge_folds_new_may_05_24/'+mode+'/modisco_old_format.h5'
ppm_dir = ''

htmld="/oak/stanford/groups/akundaje/projects/chromatin-atlas-2022/chrombpnet/folds/"+dttype+'/'+celltype+"/merge_folds_new_may_05_24/"+mode+"/motifs.html"
tomtom = pd.read_html(htmld)


background=[0.25, 0.25, 0.25, 0.25]

# %%
def trim_motif_new(cwm, motif, trim_threshold=0.20):
    """
    Given the PFM and motif (both L x 4 arrays) (the motif could be the
    PFM itself), trims `motif` by cutting off flanks of low information
    content in `pfm`. `min_ic` is the minimum required information
    content. If specified this trimmed motif will be extended on either
    side by `pad` bases.
    If no base passes the `min_ic` threshold, then no trimming is done.
    """
    
    score = np.sum(np.abs(cwm), axis=1)
    trim_thresh = np.max(score) * trim_threshold  # Cut off anything less than 30% of max score
    pass_inds = np.where(score >= trim_thresh)[0]
    trimmed = motif[np.min(pass_inds): np.max(pass_inds) + 1]
 
    if not trimmed.size:
        return motif
    
    return trimmed

def import_tfmodisco_motifs(tfm_results_path, trim=True, only_pos=True):
    """
    Imports the PFMs to into a dictionary, mapping `(x, y)` to the PFM,
    where `x` is the metacluster index and `y` is the pattern index.
    Arguments:
        `tfm_results_path`: path to HDF5 containing TF-MoDISco results
        `out_dir`: where to save motifs
        `trim`: if True, trim the motif flanks based on information content
        `only_pos`: if True, only return motifs with positive contributions
    Returns the dictionary of PFMs.
    """ 
    pfms = {}
    with h5py.File(tfm_results_path, "r") as f:
        metaclusters = f["metacluster_idx_to_submetacluster_results"]
        num_metaclusters = len(metaclusters.keys())
        for metacluster_i, metacluster_key in enumerate(metaclusters.keys()):
            metacluster = metaclusters[metacluster_key]
            if "patterns" not in metacluster["seqlets_to_patterns_result"]:
                continue
            patterns = metacluster["seqlets_to_patterns_result"]["patterns"]
            num_patterns = len(patterns["all_pattern_names"][:])
            for pattern_i, pattern_name in enumerate(patterns["all_pattern_names"][:]):
#                pattern_name = pattern_name.decode()
                pattern_name = pattern_name

                pattern = patterns[pattern_name]
                pfm = pattern["sequence"]["fwd"][:]
                cwm = pattern["task0_contrib_scores"]["fwd"][:]
                
                # Check that the contribution scores are overall positive
                if only_pos and np.sum(cwm) < 0:
                    continue
                    
                if trim:
                    pfm = trim_motif_new(cwm, cwm)
                else:
                    pfm = cwm
                    
                pfms["%d_%d" % (metacluster_i,pattern_i)] = pfm
    return pfms

# %%
pfms = import_tfmodisco_motifs(modisco_path, trim=False)
print(modisco_path)
# Out:
# /oak/stanford/groups/akundaje/projects/chromatin-atlas-2022/chrombpnet/folds/DNASE/GM12878_new/merge_folds_new_may_05_24/counts/modisco_old_format.h5

# %%
for key in pfms:
    f = open(os.path.join(ppm_dir,mode+"_"+key+".pfm"),"w")
    #print(pfms[key])
    np.savetxt(f, pfms[key], fmt='%f')
    f.close()

# %%
tomtom[0]
# Out:
#                     pattern  num_seqlets  modisco_cwm_fwd  modisco_cwm_rev  \
# 0    pos_patterns.pattern_0        21130              NaN              NaN
# 1    pos_patterns.pattern_1        19291              NaN              NaN
# 2    pos_patterns.pattern_2        18747              NaN              NaN
# 3    pos_patterns.pattern_3        13648              NaN              NaN
# 4    pos_patterns.pattern_4        10198              NaN              NaN
# 5    pos_patterns.pattern_5         9063              NaN              NaN
# 6    pos_patterns.pattern_6         7770              NaN              NaN
# 7    pos_patterns.pattern_7         5623              NaN              NaN
# 8    pos_patterns.pattern_8         3197              NaN              NaN
# 9    pos_patterns.pattern_9         2759              NaN              NaN
# 10  pos_patterns.pattern_10         2559              NaN              NaN
# 11  pos_patterns.pattern_11         2044              NaN              NaN
# 12  pos_patterns.pattern_12         1691              NaN              NaN
# 13  pos_patterns.pattern_13         1626              NaN              NaN
# 14  pos_patterns.pattern_14         1567              NaN              NaN
# 15  pos_patterns.pattern_15         1000              NaN              NaN
# 16  pos_patterns.pattern_16          953              NaN              NaN
# 17  pos_patterns.pattern_17          643              NaN              NaN
# 18  pos_patterns.pattern_18          607              NaN              NaN
# 19  pos_patterns.pattern_19          582              NaN              NaN
# 20  pos_patterns.pattern_20          486              NaN              NaN
# 21  pos_patterns.pattern_21          484              NaN              NaN
# 22  pos_patterns.pattern_22          435              NaN              NaN
# 23  pos_patterns.pattern_23          251              NaN              NaN
# 24  pos_patterns.pattern_24          249              NaN              NaN
# 25  pos_patterns.pattern_25          238              NaN              NaN
# 26  pos_patterns.pattern_26          236              NaN              NaN
# 27  pos_patterns.pattern_27          213              NaN              NaN
# 28  pos_patterns.pattern_28          130              NaN              NaN
# 29  pos_patterns.pattern_29          102              NaN              NaN
# 30  pos_patterns.pattern_30           78              NaN              NaN
# 31  pos_patterns.pattern_31           66              NaN              NaN
# 32  pos_patterns.pattern_32           56              NaN              NaN
# 33  pos_patterns.pattern_33           55              NaN              NaN
# 34  pos_patterns.pattern_34           53              NaN              NaN
# 35  pos_patterns.pattern_35           52              NaN              NaN
# 36  pos_patterns.pattern_36           48              NaN              NaN
# 37  pos_patterns.pattern_37           48              NaN              NaN
# 38  pos_patterns.pattern_38           44              NaN              NaN
# 39  pos_patterns.pattern_39           35              NaN              NaN
# 40  pos_patterns.pattern_40           32              NaN              NaN
# 41  pos_patterns.pattern_41           30              NaN              NaN
# 42  pos_patterns.pattern_42           30              NaN              NaN
# 43  pos_patterns.pattern_43           28              NaN              NaN
# 44  pos_patterns.pattern_44           28              NaN              NaN
# 45  pos_patterns.pattern_45           24              NaN              NaN
# 46  pos_patterns.pattern_46           23              NaN              NaN
# 47   neg_patterns.pattern_0           51              NaN              NaN
# 48   neg_patterns.pattern_1           34              NaN              NaN
#
#                    match0         qval0  match0_logo                 match1  \
# 0    ELF5_HUMAN.H11MO.0.A  3.964650e-05          NaN   ETV4_MOUSE.H11MO.0.B
# 1    IRF1_MOUSE.H11MO.0.A  3.608090e-03          NaN  STAT2_HUMAN.H11MO.0.A
# 2           CTCF_MA0139.1  5.609340e-12          NaN   CTCF_HUMAN.H11MO.0.A
# 3   RUNX3_HUMAN.H11MO.0.A  3.801220e-03          NaN  RUNX1_HUMAN.H11MO.0.A
# 4           JDP2_MA0655.1  3.030890e-03          NaN            JDP2_bZIP_3
# 5   NFKB1_HUMAN.H11MO.1.B  2.732910e-06          NaN  NFKB1_MOUSE.H11MO.0.A
# 6    IRF4_HUMAN.H11MO.0.A  8.576750e-07          NaN   IRF8_HUMAN.H11MO.0.B
# 7   KLF12_HUMAN.H11MO.0.C  8.245610e-05          NaN    SP1_HUMAN.H11MO.0.A
# 8    NFYB_HUMAN.H11MO.0.A  2.653320e-03          NaN   NFYB_MOUSE.H11MO.0.A
# 9    ATF1_MOUSE.H11MO.0.B  3.164450e-03          NaN   ATF3_HUMAN.H11MO.0.A
# 10          NRF1_MA0506.1  7.090870e-07          NaN   NRF1_MOUSE.H11MO.0.A
# 11     Pou2f2.mouse_POU_2  5.815650e-03          NaN        POU5F1_MA1115.1
# 12   COE1_MOUSE.H11MO.0.A  1.727720e-07          NaN   COE1_HUMAN.H11MO.0.A
# 13   BATF_HUMAN.H11MO.0.A  2.238270e-06          NaN  BATF3_HUMAN.H11MO.0.B
# 14  ZNF76_HUMAN.H11MO.0.C  6.612300e-20          NaN  ZN143_MOUSE.H11MO.0.A
# 15  RUNX3_MOUSE.H11MO.0.A  7.148760e-01          NaN          Klf1_MA0493.1
# 16             PAX2_PAX_1  3.026240e-08          NaN          PAX1_MA0779.1
# 17   RELB_HUMAN.H11MO.0.C  2.405720e-01          NaN   RELB_MOUSE.H11MO.0.C
# 18             IRF4_IRF_1  9.281530e-03          NaN          IRF4_MA1419.1
# 19             SPI1_ETS_1  1.978750e-02          NaN          SPI1_MA0080.4
# 20   RFX3_MOUSE.H11MO.0.C  1.364620e-08          NaN   RFX2_HUMAN.H11MO.0.A
# 21  MEF2D_HUMAN.H11MO.0.A  5.954720e-06          NaN  MEF2D_MOUSE.H11MO.0.A
# 22        ZBTB33_MA0527.1  2.143780e-04          NaN  KAISO_HUMAN.H11MO.0.A
# 23   TYY1_HUMAN.H11MO.0.A  6.124300e-05          NaN   TYY1_MOUSE.H11MO.0.A
# 24          ZNF524_C2H2_2  1.000000e+00          NaN                    NaN
# 25   NFIC_HUMAN.H11MO.0.A  6.881820e-04          NaN   NFIA_HUMAN.H11MO.0.C
# 26  RUNX3_HUMAN.H11MO.0.A  1.000000e+00          NaN         RUNX2_MA0511.2
# 27           SP2_MA0516.1  2.841290e-04          NaN  KLF12_HUMAN.H11MO.0.C
# 28           JUN_MA0489.1  9.587480e-04          NaN      BATF+JUN_MA0462.1
# 29             ETS1_ETS_4  3.976970e-01          NaN             FLI1_ETS_2
# 30  RUNX3_HUMAN.H11MO.0.A  6.639920e-01          NaN   ZNF8_HUMAN.H11MO.0.C
# 31      BATF+JUN_MA0462.1  4.886880e-07          NaN   BATF_MOUSE.H11MO.0.A
# 32   KLF6_HUMAN.H11MO.0.A  8.438860e-04          NaN   KLF6_MOUSE.H11MO.0.B
# 33   PEBB_HUMAN.H11MO.0.C  1.592170e-02          NaN   PEBB_MOUSE.H11MO.0.C
# 34        ZNF384_MA1125.1  3.486600e-02          NaN  PRDM6_HUMAN.H11MO.0.C
# 35  NFKB2_HUMAN.H11MO.0.B  4.599740e-03          NaN  NFKB2_MOUSE.H11MO.0.C
# 36  RUNX3_HUMAN.H11MO.0.A  6.549270e-01          NaN         RUNX2_MA0511.2
# 37  NFKB2_HUMAN.H11MO.0.B  8.517000e-01          NaN  NFKB2_MOUSE.H11MO.0.C
# 38             PAX2_PAX_1  7.681990e-06          NaN             PAX5_PAX_1
# 39             IRF5_IRF_2  3.385150e-01          NaN   STAT1+STAT2_MA0517.1
# 40   IRF1_MOUSE.H11MO.0.A  6.634400e-06          NaN   IRF2_HUMAN.H11MO.0.A
# 41   ETV4_MOUSE.H11MO.0.B  3.505640e-03          NaN             SPIC_ETS_1
# 42   COE1_HUMAN.H11MO.0.A  1.996000e-03          NaN  NFKB2_HUMAN.H11MO.0.B
# 43   STAT1+STAT2_MA0517.1  1.000840e-01          NaN  PRDM1_HUMAN.H11MO.0.A
# 44        Nfe2l2_MA0150.2  2.605240e-01          NaN            JDP2_bZIP_1
# 45          JUNB_MA0490.1  3.683790e-02          NaN         FOSL2_MA0478.1
# 46   ETV4_MOUSE.H11MO.0.B  6.805000e-03          NaN   ETV6_MOUSE.H11MO.0.C
# 47  ZN502_HUMAN.H11MO.0.C  5.925820e-01          NaN         TEAD3_MA0808.1
# 48          NFATC1_NFAT_1  1.192720e-01          NaN             SOX2_HMG_6
#
#            qval1  match1_logo                 match2         qval2  \
# 0   1.092990e-04          NaN    EHF_HUMAN.H11MO.0.B  1.125400e-04
# 1   3.608090e-03          NaN  STAT2_MOUSE.H11MO.0.A  3.608090e-03
# 2   1.837070e-09          NaN   CTCF_MOUSE.H11MO.0.A  2.990510e-08
# 3   3.801220e-03          NaN  RUNX1_MOUSE.H11MO.0.A  3.801220e-03
# 4   3.030890e-03          NaN      Jdp2.mouse_bZIP_1  3.030890e-03
# 5   2.732910e-06          NaN   TF65_MOUSE.H11MO.0.A  3.795230e-06
# 6   4.104880e-06          NaN   IRF8_MOUSE.H11MO.0.A  4.104880e-06
# 7   8.245610e-05          NaN   KLF3_HUMAN.H11MO.0.B  6.726880e-04
# 8   2.653320e-03          NaN   NFYC_HUMAN.H11MO.0.A  2.653320e-03
# 9   3.164450e-03          NaN   CREM_HUMAN.H11MO.0.C  3.164450e-03
# 10  1.583230e-04          NaN   NRF1_HUMAN.H11MO.0.A  1.583230e-04
# 11  5.815650e-03          NaN        POU2F2_MA0507.1  5.815650e-03
# 12  7.442380e-05          NaN  PRD16_MOUSE.H11MO.0.B  2.265420e-03
# 13  1.458680e-05          NaN  BATF3_MOUSE.H11MO.0.A  1.458680e-05
# 14  7.910640e-11          NaN  ZN143_HUMAN.H11MO.0.A  7.910640e-11
# 15  7.148760e-01          NaN   TCF7_HUMAN.H11MO.0.A  7.148760e-01
# 16  1.982790e-07          NaN             PAX1_PAX_1  1.982790e-07
# 17  2.405720e-01          NaN           REL_MA0101.1  2.405720e-01
# 18  9.281530e-03          NaN             IRF5_IRF_2  1.828850e-02
# 19  1.978750e-02          NaN             SPIB_ETS_1  2.260740e-02
# 20  1.364620e-08          NaN          Rfx1_MA0509.1  1.485450e-08
# 21  5.954720e-06          NaN         MEF2B_MA0660.1  1.471290e-04
# 22  2.270210e-04          NaN  KAISO_MOUSE.H11MO.0.B  2.270210e-04
# 23  1.220800e-04          NaN           YY1_MA0095.2  1.429950e-04
# 24           NaN          NaN                    NaN           NaN
# 25  6.881820e-04          NaN   NFIA_MOUSE.H11MO.0.C  6.881820e-04
# 26  1.000000e+00          NaN           RUNX2_RUNX_3  1.000000e+00
# 27  6.165900e-04          NaN   KLF9_HUMAN.H11MO.0.C  9.667580e-04
# 28  1.288230e-02          NaN  NR1D2_MOUSE.H11MO.0.A  6.528030e-02
# 29  3.976970e-01          NaN             FLI1_ETS_4  3.976970e-01
# 30  6.639920e-01          NaN         RUNX2_MA0511.2  6.639920e-01
# 31  2.851600e-05          NaN   BATF_HUMAN.H11MO.0.A  9.962990e-05
# 32  8.438860e-04          NaN    SP1_HUMAN.H11MO.0.A  8.438860e-04
# 33  1.592170e-02          NaN  RUNX3_MOUSE.H11MO.0.A  1.592170e-02
# 34  6.700680e-02          NaN  FOXJ3_HUMAN.H11MO.0.A  2.635240e-01
# 35  4.599740e-03          NaN           REL_MA0101.1  1.309740e-02
# 36  6.549270e-01          NaN           RUNX2_RUNX_3  6.549270e-01
# 37  8.517000e-01          NaN          ZNF75A_C2H2_1  1.000000e+00
# 38  9.630440e-06          NaN             PAX6_PAX_1  3.594280e-03
# 39  3.385150e-01          NaN   IRF1_MOUSE.H11MO.0.A  4.521990e-01
# 40  1.769080e-05          NaN   IRF2_MOUSE.H11MO.0.B  1.769080e-05
# 41  2.517470e-02          NaN          SPIC_MA0687.1  2.517470e-02
# 42  3.639440e-03          NaN  NFKB2_MOUSE.H11MO.0.C  3.639440e-03
# 43  1.000840e-01          NaN  PRDM1_MOUSE.H11MO.0.A  1.000840e-01
# 44  2.605240e-01          NaN      Jdp2.mouse_bZIP_1  2.605240e-01
# 45  3.683790e-02          NaN   JUND_MOUSE.H11MO.0.A  8.184960e-02
# 46  9.207930e-02          NaN   ELK1_MOUSE.H11MO.0.B  9.207930e-02
# 47  5.925820e-01          NaN            TEAD3_TEA_2  5.925820e-01
# 48  1.192720e-01          NaN      Sox17.mouse_HMG_2  1.192720e-01
#
#     match2_logo
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN

# %%
tomtom[0]["pattern"] = tomtom[0]["pattern"].str.replace("pos_patterns.pattern","0").str.replace("neg_patterns.pattern","1")
# Out:
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
tomtom[0]
# Out:
#    pattern  num_seqlets  modisco_cwm_fwd  modisco_cwm_rev  \
# 0      0_0        21130              NaN              NaN
# 1      0_1        19291              NaN              NaN
# 2      0_2        18747              NaN              NaN
# 3      0_3        13648              NaN              NaN
# 4      0_4        10198              NaN              NaN
# 5      0_5         9063              NaN              NaN
# 6      0_6         7770              NaN              NaN
# 7      0_7         5623              NaN              NaN
# 8      0_8         3197              NaN              NaN
# 9      0_9         2759              NaN              NaN
# 10    0_10         2559              NaN              NaN
# 11    0_11         2044              NaN              NaN
# 12    0_12         1691              NaN              NaN
# 13    0_13         1626              NaN              NaN
# 14    0_14         1567              NaN              NaN
# 15    0_15         1000              NaN              NaN
# 16    0_16          953              NaN              NaN
# 17    0_17          643              NaN              NaN
# 18    0_18          607              NaN              NaN
# 19    0_19          582              NaN              NaN
# 20    0_20          486              NaN              NaN
# 21    0_21          484              NaN              NaN
# 22    0_22          435              NaN              NaN
# 23    0_23          251              NaN              NaN
# 24    0_24          249              NaN              NaN
# 25    0_25          238              NaN              NaN
# 26    0_26          236              NaN              NaN
# 27    0_27          213              NaN              NaN
# 28    0_28          130              NaN              NaN
# 29    0_29          102              NaN              NaN
# 30    0_30           78              NaN              NaN
# 31    0_31           66              NaN              NaN
# 32    0_32           56              NaN              NaN
# 33    0_33           55              NaN              NaN
# 34    0_34           53              NaN              NaN
# 35    0_35           52              NaN              NaN
# 36    0_36           48              NaN              NaN
# 37    0_37           48              NaN              NaN
# 38    0_38           44              NaN              NaN
# 39    0_39           35              NaN              NaN
# 40    0_40           32              NaN              NaN
# 41    0_41           30              NaN              NaN
# 42    0_42           30              NaN              NaN
# 43    0_43           28              NaN              NaN
# 44    0_44           28              NaN              NaN
# 45    0_45           24              NaN              NaN
# 46    0_46           23              NaN              NaN
# 47     1_0           51              NaN              NaN
# 48     1_1           34              NaN              NaN
#
#                    match0         qval0  match0_logo                 match1  \
# 0    ELF5_HUMAN.H11MO.0.A  3.964650e-05          NaN   ETV4_MOUSE.H11MO.0.B
# 1    IRF1_MOUSE.H11MO.0.A  3.608090e-03          NaN  STAT2_HUMAN.H11MO.0.A
# 2           CTCF_MA0139.1  5.609340e-12          NaN   CTCF_HUMAN.H11MO.0.A
# 3   RUNX3_HUMAN.H11MO.0.A  3.801220e-03          NaN  RUNX1_HUMAN.H11MO.0.A
# 4           JDP2_MA0655.1  3.030890e-03          NaN            JDP2_bZIP_3
# 5   NFKB1_HUMAN.H11MO.1.B  2.732910e-06          NaN  NFKB1_MOUSE.H11MO.0.A
# 6    IRF4_HUMAN.H11MO.0.A  8.576750e-07          NaN   IRF8_HUMAN.H11MO.0.B
# 7   KLF12_HUMAN.H11MO.0.C  8.245610e-05          NaN    SP1_HUMAN.H11MO.0.A
# 8    NFYB_HUMAN.H11MO.0.A  2.653320e-03          NaN   NFYB_MOUSE.H11MO.0.A
# 9    ATF1_MOUSE.H11MO.0.B  3.164450e-03          NaN   ATF3_HUMAN.H11MO.0.A
# 10          NRF1_MA0506.1  7.090870e-07          NaN   NRF1_MOUSE.H11MO.0.A
# 11     Pou2f2.mouse_POU_2  5.815650e-03          NaN        POU5F1_MA1115.1
# 12   COE1_MOUSE.H11MO.0.A  1.727720e-07          NaN   COE1_HUMAN.H11MO.0.A
# 13   BATF_HUMAN.H11MO.0.A  2.238270e-06          NaN  BATF3_HUMAN.H11MO.0.B
# 14  ZNF76_HUMAN.H11MO.0.C  6.612300e-20          NaN  ZN143_MOUSE.H11MO.0.A
# 15  RUNX3_MOUSE.H11MO.0.A  7.148760e-01          NaN          Klf1_MA0493.1
# 16             PAX2_PAX_1  3.026240e-08          NaN          PAX1_MA0779.1
# 17   RELB_HUMAN.H11MO.0.C  2.405720e-01          NaN   RELB_MOUSE.H11MO.0.C
# 18             IRF4_IRF_1  9.281530e-03          NaN          IRF4_MA1419.1
# 19             SPI1_ETS_1  1.978750e-02          NaN          SPI1_MA0080.4
# 20   RFX3_MOUSE.H11MO.0.C  1.364620e-08          NaN   RFX2_HUMAN.H11MO.0.A
# 21  MEF2D_HUMAN.H11MO.0.A  5.954720e-06          NaN  MEF2D_MOUSE.H11MO.0.A
# 22        ZBTB33_MA0527.1  2.143780e-04          NaN  KAISO_HUMAN.H11MO.0.A
# 23   TYY1_HUMAN.H11MO.0.A  6.124300e-05          NaN   TYY1_MOUSE.H11MO.0.A
# 24          ZNF524_C2H2_2  1.000000e+00          NaN                    NaN
# 25   NFIC_HUMAN.H11MO.0.A  6.881820e-04          NaN   NFIA_HUMAN.H11MO.0.C
# 26  RUNX3_HUMAN.H11MO.0.A  1.000000e+00          NaN         RUNX2_MA0511.2
# 27           SP2_MA0516.1  2.841290e-04          NaN  KLF12_HUMAN.H11MO.0.C
# 28           JUN_MA0489.1  9.587480e-04          NaN      BATF+JUN_MA0462.1
# 29             ETS1_ETS_4  3.976970e-01          NaN             FLI1_ETS_2
# 30  RUNX3_HUMAN.H11MO.0.A  6.639920e-01          NaN   ZNF8_HUMAN.H11MO.0.C
# 31      BATF+JUN_MA0462.1  4.886880e-07          NaN   BATF_MOUSE.H11MO.0.A
# 32   KLF6_HUMAN.H11MO.0.A  8.438860e-04          NaN   KLF6_MOUSE.H11MO.0.B
# 33   PEBB_HUMAN.H11MO.0.C  1.592170e-02          NaN   PEBB_MOUSE.H11MO.0.C
# 34        ZNF384_MA1125.1  3.486600e-02          NaN  PRDM6_HUMAN.H11MO.0.C
# 35  NFKB2_HUMAN.H11MO.0.B  4.599740e-03          NaN  NFKB2_MOUSE.H11MO.0.C
# 36  RUNX3_HUMAN.H11MO.0.A  6.549270e-01          NaN         RUNX2_MA0511.2
# 37  NFKB2_HUMAN.H11MO.0.B  8.517000e-01          NaN  NFKB2_MOUSE.H11MO.0.C
# 38             PAX2_PAX_1  7.681990e-06          NaN             PAX5_PAX_1
# 39             IRF5_IRF_2  3.385150e-01          NaN   STAT1+STAT2_MA0517.1
# 40   IRF1_MOUSE.H11MO.0.A  6.634400e-06          NaN   IRF2_HUMAN.H11MO.0.A
# 41   ETV4_MOUSE.H11MO.0.B  3.505640e-03          NaN             SPIC_ETS_1
# 42   COE1_HUMAN.H11MO.0.A  1.996000e-03          NaN  NFKB2_HUMAN.H11MO.0.B
# 43   STAT1+STAT2_MA0517.1  1.000840e-01          NaN  PRDM1_HUMAN.H11MO.0.A
# 44        Nfe2l2_MA0150.2  2.605240e-01          NaN            JDP2_bZIP_1
# 45          JUNB_MA0490.1  3.683790e-02          NaN         FOSL2_MA0478.1
# 46   ETV4_MOUSE.H11MO.0.B  6.805000e-03          NaN   ETV6_MOUSE.H11MO.0.C
# 47  ZN502_HUMAN.H11MO.0.C  5.925820e-01          NaN         TEAD3_MA0808.1
# 48          NFATC1_NFAT_1  1.192720e-01          NaN             SOX2_HMG_6
#
#            qval1  match1_logo                 match2         qval2  \
# 0   1.092990e-04          NaN    EHF_HUMAN.H11MO.0.B  1.125400e-04
# 1   3.608090e-03          NaN  STAT2_MOUSE.H11MO.0.A  3.608090e-03
# 2   1.837070e-09          NaN   CTCF_MOUSE.H11MO.0.A  2.990510e-08
# 3   3.801220e-03          NaN  RUNX1_MOUSE.H11MO.0.A  3.801220e-03
# 4   3.030890e-03          NaN      Jdp2.mouse_bZIP_1  3.030890e-03
# 5   2.732910e-06          NaN   TF65_MOUSE.H11MO.0.A  3.795230e-06
# 6   4.104880e-06          NaN   IRF8_MOUSE.H11MO.0.A  4.104880e-06
# 7   8.245610e-05          NaN   KLF3_HUMAN.H11MO.0.B  6.726880e-04
# 8   2.653320e-03          NaN   NFYC_HUMAN.H11MO.0.A  2.653320e-03
# 9   3.164450e-03          NaN   CREM_HUMAN.H11MO.0.C  3.164450e-03
# 10  1.583230e-04          NaN   NRF1_HUMAN.H11MO.0.A  1.583230e-04
# 11  5.815650e-03          NaN        POU2F2_MA0507.1  5.815650e-03
# 12  7.442380e-05          NaN  PRD16_MOUSE.H11MO.0.B  2.265420e-03
# 13  1.458680e-05          NaN  BATF3_MOUSE.H11MO.0.A  1.458680e-05
# 14  7.910640e-11          NaN  ZN143_HUMAN.H11MO.0.A  7.910640e-11
# 15  7.148760e-01          NaN   TCF7_HUMAN.H11MO.0.A  7.148760e-01
# 16  1.982790e-07          NaN             PAX1_PAX_1  1.982790e-07
# 17  2.405720e-01          NaN           REL_MA0101.1  2.405720e-01
# 18  9.281530e-03          NaN             IRF5_IRF_2  1.828850e-02
# 19  1.978750e-02          NaN             SPIB_ETS_1  2.260740e-02
# 20  1.364620e-08          NaN          Rfx1_MA0509.1  1.485450e-08
# 21  5.954720e-06          NaN         MEF2B_MA0660.1  1.471290e-04
# 22  2.270210e-04          NaN  KAISO_MOUSE.H11MO.0.B  2.270210e-04
# 23  1.220800e-04          NaN           YY1_MA0095.2  1.429950e-04
# 24           NaN          NaN                    NaN           NaN
# 25  6.881820e-04          NaN   NFIA_MOUSE.H11MO.0.C  6.881820e-04
# 26  1.000000e+00          NaN           RUNX2_RUNX_3  1.000000e+00
# 27  6.165900e-04          NaN   KLF9_HUMAN.H11MO.0.C  9.667580e-04
# 28  1.288230e-02          NaN  NR1D2_MOUSE.H11MO.0.A  6.528030e-02
# 29  3.976970e-01          NaN             FLI1_ETS_4  3.976970e-01
# 30  6.639920e-01          NaN         RUNX2_MA0511.2  6.639920e-01
# 31  2.851600e-05          NaN   BATF_HUMAN.H11MO.0.A  9.962990e-05
# 32  8.438860e-04          NaN    SP1_HUMAN.H11MO.0.A  8.438860e-04
# 33  1.592170e-02          NaN  RUNX3_MOUSE.H11MO.0.A  1.592170e-02
# 34  6.700680e-02          NaN  FOXJ3_HUMAN.H11MO.0.A  2.635240e-01
# 35  4.599740e-03          NaN           REL_MA0101.1  1.309740e-02
# 36  6.549270e-01          NaN           RUNX2_RUNX_3  6.549270e-01
# 37  8.517000e-01          NaN          ZNF75A_C2H2_1  1.000000e+00
# 38  9.630440e-06          NaN             PAX6_PAX_1  3.594280e-03
# 39  3.385150e-01          NaN   IRF1_MOUSE.H11MO.0.A  4.521990e-01
# 40  1.769080e-05          NaN   IRF2_MOUSE.H11MO.0.B  1.769080e-05
# 41  2.517470e-02          NaN          SPIC_MA0687.1  2.517470e-02
# 42  3.639440e-03          NaN  NFKB2_MOUSE.H11MO.0.C  3.639440e-03
# 43  1.000840e-01          NaN  PRDM1_MOUSE.H11MO.0.A  1.000840e-01
# 44  2.605240e-01          NaN      Jdp2.mouse_bZIP_1  2.605240e-01
# 45  3.683790e-02          NaN   JUND_MOUSE.H11MO.0.A  8.184960e-02
# 46  9.207930e-02          NaN   ELK1_MOUSE.H11MO.0.B  9.207930e-02
# 47  5.925820e-01          NaN            TEAD3_TEA_2  5.925820e-01
# 48  1.192720e-01          NaN      Sox17.mouse_HMG_2  1.192720e-01
#
#     match2_logo
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18          NaN
# 19          NaN
# 20          NaN
# 21          NaN
# 22          NaN
# 23          NaN
# 24          NaN
# 25          NaN
# 26          NaN
# 27          NaN
# 28          NaN
# 29          NaN
# 30          NaN
# 31          NaN
# 32          NaN
# 33          NaN
# 34          NaN
# 35          NaN
# 36          NaN
# 37          NaN
# 38          NaN
# 39          NaN
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN

# %%
tomtom[0][["pattern","num_seqlets"]].to_csv(os.path.join(ppm_dir,mode+"_counts.csv"),sep=",",index=False, header=False)
