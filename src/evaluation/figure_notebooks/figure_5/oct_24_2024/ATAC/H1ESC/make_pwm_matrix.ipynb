# %%
import numpy as np
import pandas as pd
import h5py
import pysam
import os
from modisco.visualization import viz_sequence
from modisco import util
from matplotlib import pyplot as plt
import pybedtools
from bs4 import BeautifulSoup

pd.options.display.max_rows = 500
pd.options.display.max_columns = 500

# %%
dttype = 'ATAC'
mode = "counts"
celltype="H1ESC"
modisco_path = '/oak/stanford/groups/akundaje/projects/chromatin-atlas-2022/chrombpnet/folds/ATAC/'+celltype+'/merge_folds_new_may_05_24/'+mode+'/modisco_old_format.h5'
ppm_dir = ''

htmld="/oak/stanford/groups/akundaje/projects/chromatin-atlas-2022/chrombpnet/folds/"+dttype+'/'+celltype+"/merge_folds_new_may_05_24/"+mode+"/motifs.html"
tomtom = pd.read_html(htmld)


background=[0.25, 0.25, 0.25, 0.25]

# %%
def trim_motif_new(cwm, motif, trim_threshold=0.20):
    """
    Given the PFM and motif (both L x 4 arrays) (the motif could be the
    PFM itself), trims `motif` by cutting off flanks of low information
    content in `pfm`. `min_ic` is the minimum required information
    content. If specified this trimmed motif will be extended on either
    side by `pad` bases.
    If no base passes the `min_ic` threshold, then no trimming is done.
    """
    
    score = np.sum(np.abs(cwm), axis=1)
    trim_thresh = np.max(score) * trim_threshold  # Cut off anything less than 30% of max score
    pass_inds = np.where(score >= trim_thresh)[0]
    trimmed = motif[np.min(pass_inds): np.max(pass_inds) + 1]
 
    if not trimmed.size:
        return motif
    
    return trimmed

def import_tfmodisco_motifs(tfm_results_path, trim=True, only_pos=True):
    """
    Imports the PFMs to into a dictionary, mapping `(x, y)` to the PFM,
    where `x` is the metacluster index and `y` is the pattern index.
    Arguments:
        `tfm_results_path`: path to HDF5 containing TF-MoDISco results
        `out_dir`: where to save motifs
        `trim`: if True, trim the motif flanks based on information content
        `only_pos`: if True, only return motifs with positive contributions
    Returns the dictionary of PFMs.
    """ 
    pfms = {}
    with h5py.File(tfm_results_path, "r") as f:
        metaclusters = f["metacluster_idx_to_submetacluster_results"]
        num_metaclusters = len(metaclusters.keys())
        for metacluster_i, metacluster_key in enumerate(metaclusters.keys()):
            metacluster = metaclusters[metacluster_key]
            if "patterns" not in metacluster["seqlets_to_patterns_result"]:
                continue
            patterns = metacluster["seqlets_to_patterns_result"]["patterns"]
            num_patterns = len(patterns["all_pattern_names"][:])
            for pattern_i, pattern_name in enumerate(patterns["all_pattern_names"][:]):
#                pattern_name = pattern_name.decode()
                pattern_name = pattern_name

                pattern = patterns[pattern_name]
                pfm = pattern["sequence"]["fwd"][:]
                cwm = pattern["task0_contrib_scores"]["fwd"][:]
                
                # Check that the contribution scores are overall positive
                if only_pos and np.sum(cwm) < 0:
                    continue
                    
                if trim:
                    pfm = trim_motif_new(cwm, cwm)
                else:
                    pfm = cwm
                    
                pfms["%d_%d" % (metacluster_i,pattern_i)] = pfm
    return pfms

# %%
pfms = import_tfmodisco_motifs(modisco_path, trim=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-4-b93f233f50c0> in <module>
# ----> 1 pfms = import_tfmodisco_motifs(modisco_path, trim=False)
#
# <ipython-input-3-9a7a6b627409> in import_tfmodisco_motifs(tfm_results_path, trim, only_pos)
#      31     """
#      32     pfms = {}
# ---> 33     with h5py.File(tfm_results_path, "r") as f:
#      34         metaclusters = f["metacluster_idx_to_submetacluster_results"]
#      35         num_metaclusters = len(metaclusters.keys())
#
# ~/anaconda3/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# ~/anaconda3/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     171         if swmr and swmr_support:
#     172             flags |= h5f.ACC_SWMR_READ
# --> 173         fid = h5f.open(name, flags, fapl=fapl)
#     174     elif mode == 'r+':
#     175         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (bad object header version number)

# %%
for key in pfms:
    f = open(os.path.join(ppm_dir,mode+"_"+key+".pfm"),"w")
    #print(pfms[key])
    np.savetxt(f, pfms[key], fmt='%f')
    f.close()

# %%
tomtom[0]
# Out:
#                     pattern  num_seqlets  modisco_cwm_fwd  modisco_cwm_rev  \
# 0    pos_patterns.pattern_0        39695              NaN              NaN
# 1    pos_patterns.pattern_1        34273              NaN              NaN
# 2    pos_patterns.pattern_2        10841              NaN              NaN
# 3    pos_patterns.pattern_3        10650              NaN              NaN
# 4    pos_patterns.pattern_4        10045              NaN              NaN
# 5    pos_patterns.pattern_5         8953              NaN              NaN
# 6    pos_patterns.pattern_6         6915              NaN              NaN
# 7    pos_patterns.pattern_7         5571              NaN              NaN
# 8    pos_patterns.pattern_8         5513              NaN              NaN
# 9    pos_patterns.pattern_9         5038              NaN              NaN
# 10  pos_patterns.pattern_10         3942              NaN              NaN
# 11  pos_patterns.pattern_11         2995              NaN              NaN
# 12  pos_patterns.pattern_12         2979              NaN              NaN
# 13  pos_patterns.pattern_13         2492              NaN              NaN
# 14  pos_patterns.pattern_14         2316              NaN              NaN
# 15  pos_patterns.pattern_15         2272              NaN              NaN
# 16  pos_patterns.pattern_16         2126              NaN              NaN
# 17  pos_patterns.pattern_17         2042              NaN              NaN
# 18  pos_patterns.pattern_18         1898              NaN              NaN
# 19  pos_patterns.pattern_19         1578              NaN              NaN
# 20  pos_patterns.pattern_20         1537              NaN              NaN
# 21  pos_patterns.pattern_21         1245              NaN              NaN
# 22  pos_patterns.pattern_22         1094              NaN              NaN
# 23  pos_patterns.pattern_23          966              NaN              NaN
# 24  pos_patterns.pattern_24          814              NaN              NaN
# 25  pos_patterns.pattern_25          759              NaN              NaN
# 26  pos_patterns.pattern_26          698              NaN              NaN
# 27  pos_patterns.pattern_27          677              NaN              NaN
# 28  pos_patterns.pattern_28          651              NaN              NaN
# 29  pos_patterns.pattern_29          568              NaN              NaN
# 30  pos_patterns.pattern_30          548              NaN              NaN
# 31  pos_patterns.pattern_31          457              NaN              NaN
# 32  pos_patterns.pattern_32          398              NaN              NaN
# 33  pos_patterns.pattern_33          377              NaN              NaN
# 34  pos_patterns.pattern_34          332              NaN              NaN
# 35  pos_patterns.pattern_35          318              NaN              NaN
# 36  pos_patterns.pattern_36          305              NaN              NaN
# 37  pos_patterns.pattern_37          242              NaN              NaN
# 38  pos_patterns.pattern_38          175              NaN              NaN
# 39  pos_patterns.pattern_39          163              NaN              NaN
# 40  pos_patterns.pattern_40          157              NaN              NaN
# 41  pos_patterns.pattern_41          110              NaN              NaN
# 42  pos_patterns.pattern_42          105              NaN              NaN
# 43  pos_patterns.pattern_43           79              NaN              NaN
# 44  pos_patterns.pattern_44           74              NaN              NaN
# 45  pos_patterns.pattern_45           56              NaN              NaN
# 46  pos_patterns.pattern_46           49              NaN              NaN
# 47  pos_patterns.pattern_47           49              NaN              NaN
# 48  pos_patterns.pattern_48           41              NaN              NaN
# 49  pos_patterns.pattern_49           40              NaN              NaN
# 50  pos_patterns.pattern_50           39              NaN              NaN
# 51  pos_patterns.pattern_51           34              NaN              NaN
# 52  pos_patterns.pattern_52           31              NaN              NaN
# 53  pos_patterns.pattern_53           24              NaN              NaN
# 54   neg_patterns.pattern_0           65              NaN              NaN
# 55   neg_patterns.pattern_1           46              NaN              NaN
# 56   neg_patterns.pattern_2           41              NaN              NaN
# 57   neg_patterns.pattern_3           40              NaN              NaN
# 58   neg_patterns.pattern_4           32              NaN              NaN
# 59   neg_patterns.pattern_5           25              NaN              NaN
# 60   neg_patterns.pattern_6           24              NaN              NaN
#
#                      match0         qval0  match0_logo  \
# 0             CTCF_MA0139.1  4.598650e-16          NaN
# 1            HNF4G_MA0484.1  2.891220e-09          NaN
# 2     FOXM1_HUMAN.H11MO.0.A  1.511910e-03          NaN
# 3     KLF12_HUMAN.H11MO.0.C  1.920700e-04          NaN
# 4            FOXO6_MA0849.1  7.031260e-04          NaN
# 5            HNF1B_MA0153.2  2.251600e-08          NaN
# 6      ATF3_MOUSE.H11MO.0.A  3.913190e-03          NaN
# 7      NFYB_HUMAN.H11MO.0.A  3.432360e-03          NaN
# 8             ELK4_MA0076.2  1.711800e-04          NaN
# 9     CEBPA_HUMAN.H11MO.0.A  8.891860e-06          NaN
# 10           Nr5a2_MA0505.1  3.977880e-04          NaN
# 11     ERR2_HUMAN.H11MO.0.A  9.272600e-04          NaN
# 12         FOXD2_forkhead_1  4.162410e-02          NaN
# 13    FOXM1_HUMAN.H11MO.0.A  2.008940e-01          NaN
# 14     SOX9_HUMAN.H11MO.0.B  2.508290e-05          NaN
# 15         FOXB1_forkhead_2  6.478860e-04          NaN
# 16            NRF1_MA0506.1  2.446090e-06          NaN
# 17           TEAD3_MA0808.1  5.624250e-03          NaN
# 18    ZNF76_HUMAN.H11MO.0.C  1.924590e-20          NaN
# 19           CEBPE_MA0837.1  3.667750e-02          NaN
# 20     ATF4_MOUSE.H11MO.0.A  1.845820e-03          NaN
# 21    CEBPD_HUMAN.H11MO.0.C  4.576480e-01          NaN
# 22     ATF3_HUMAN.H11MO.0.A  4.013160e-04          NaN
# 23  NR2E1_nuclearreceptor_2  6.102820e-02          NaN
# 24    HNF4A_HUMAN.H11MO.0.A  1.546700e-02          NaN
# 25            NRF1_MA0506.1  2.218720e-03          NaN
# 26     SOX9_HUMAN.H11MO.0.B  1.992310e-02          NaN
# 27     IRF2_HUMAN.H11MO.0.A  1.490430e-13          NaN
# 28          ZBTB33_MA0527.1  2.255440e-04          NaN
# 29               NRF1_NRF_1  1.405250e-02          NaN
# 30    FOXA2_HUMAN.H11MO.0.A  2.602350e-02          NaN
# 31     ETV6_MOUSE.H11MO.0.C  1.202300e-02          NaN
# 32  HNF4A_nuclearreceptor_3  2.646890e-03          NaN
# 33     NFIC_HUMAN.H11MO.0.A  2.586400e-06          NaN
# 34     SOX9_HUMAN.H11MO.0.B  9.962850e-04          NaN
# 35    CTCFL_MOUSE.H11MO.0.A  4.812650e-01          NaN
# 36     TAF1_MOUSE.H11MO.0.A  1.886400e-04          NaN
# 37    FOXM1_HUMAN.H11MO.0.A  2.052330e-04          NaN
# 38    FOXA2_HUMAN.H11MO.0.A  5.547880e-03          NaN
# 39      MYB_MOUSE.H11MO.0.A  1.000000e+00          NaN
# 40    FOXA2_HUMAN.H11MO.0.A  1.576070e-02          NaN
# 41    HNF1A_HUMAN.H11MO.0.C  1.571760e-02          NaN
# 42           Foxo1_MA0480.1  2.635030e-01          NaN
# 43         FOXD3_forkhead_1  1.219620e-01          NaN
# 44   Foxc1.mouse_forkhead_1  4.409010e-04          NaN
# 45    CEBPA_MOUSE.H11MO.0.A  1.524150e-03          NaN
# 46     RFX2_MOUSE.H11MO.0.A  1.543970e-07          NaN
# 47      FOS_HUMAN.H11MO.0.A  1.000000e+00          NaN
# 48     ERR2_HUMAN.H11MO.0.A  1.246090e-03          NaN
# 49     COT1_MOUSE.H11MO.0.B  1.008150e-01          NaN
# 50     SOX9_HUMAN.H11MO.0.B  3.493820e-03          NaN
# 51     KLF6_HUMAN.H11MO.0.A  9.226760e-04          NaN
# 52         FOXD2_forkhead_1  6.902240e-03          NaN
# 53           FOXI1_MA0042.2  4.151600e-03          NaN
# 54              CPEB1_RRM_1  1.000000e+00          NaN
# 55         FOXB1_forkhead_2  3.987910e-01          NaN
# 56     AIRE_HUMAN.H11MO.0.C  1.640580e-01          NaN
# 57            NFYB_MA0502.1  6.628390e-02          NaN
# 58     TYY1_HUMAN.H11MO.0.A  9.779280e-01          NaN
# 59            ONECUT3_CUT_1  9.010340e-01          NaN
# 60    THAP1_HUMAN.H11MO.0.C  9.338570e-01          NaN
#
#                            match1         qval1  match1_logo  \
# 0            CTCF_HUMAN.H11MO.0.A  2.050480e-12          NaN
# 1           HNF4G_HUMAN.H11MO.0.B  3.266830e-07          NaN
# 2           FOXM1_MOUSE.H11MO.0.B  1.511910e-03          NaN
# 3             SP1_HUMAN.H11MO.0.A  1.920700e-04          NaN
# 4                FOXO6_forkhead_2  7.031260e-04          NaN
# 5             HNF1B_homeodomain_1  2.251600e-08          NaN
# 6           FOSL2_MOUSE.H11MO.0.A  3.913190e-03          NaN
# 7            NFYB_MOUSE.H11MO.0.A  3.432360e-03          NaN
# 8            ELK1_MOUSE.H11MO.0.B  1.711800e-04          NaN
# 9                  CEBPA_MA0102.3  8.891860e-06          NaN
# 10           RXRA_MOUSE.H11MO.0.A  3.977880e-04          NaN
# 11                 ESRRB_MA0141.3  9.272600e-04          NaN
# 12               FOXC1_forkhead_2  4.162410e-02          NaN
# 13          FOXM1_MOUSE.H11MO.0.B  2.008940e-01          NaN
# 14           SOX9_MOUSE.H11MO.0.A  2.508290e-05          NaN
# 15                 FOXB1_MA0845.1  6.478860e-04          NaN
# 16                     NRF1_NRF_1  6.888810e-04          NaN
# 17                    TEAD3_TEA_2  5.624250e-03          NaN
# 18          ZN143_MOUSE.H11MO.0.A  1.252410e-10          NaN
# 19                   CEBPE_bZIP_1  3.667750e-02          NaN
# 20          CEBPG_MOUSE.H11MO.0.B  1.845820e-03          NaN
# 21          CEBPD_MOUSE.H11MO.0.B  4.576480e-01          NaN
# 22                SREBF2_MA0828.1  2.955720e-03          NaN
# 23  Nr2e1.mouse_nuclearreceptor_2  6.102820e-02          NaN
# 24          HNF4A_MOUSE.H11MO.0.A  1.546700e-02          NaN
# 25           NRF1_MOUSE.H11MO.0.A  8.348640e-03          NaN
# 26           SOX9_MOUSE.H11MO.0.A  1.992310e-02          NaN
# 27           IRF2_MOUSE.H11MO.0.B  1.490430e-13          NaN
# 28          KAISO_HUMAN.H11MO.0.A  2.348970e-04          NaN
# 29           NRF1_HUMAN.H11MO.0.A  1.405250e-02          NaN
# 30                 Foxa2_MA0047.2  3.135590e-02          NaN
# 31           ETV4_MOUSE.H11MO.0.B  1.202300e-02          NaN
# 32        HNF4A_nuclearreceptor_1  2.646890e-03          NaN
# 33           NFIA_HUMAN.H11MO.0.C  5.243900e-05          NaN
# 34           SOX9_MOUSE.H11MO.0.A  9.962850e-04          NaN
# 35          CTCFL_HUMAN.H11MO.0.A  4.812650e-01          NaN
# 36          THAP1_HUMAN.H11MO.0.C  2.582600e-04          NaN
# 37          FOXM1_MOUSE.H11MO.0.B  2.052330e-04          NaN
# 38                  JUND_MA0491.1  5.547880e-03          NaN
# 39           MYBA_MOUSE.H11MO.0.C  1.000000e+00          NaN
# 40          FOXA1_HUMAN.H11MO.0.A  2.428900e-02          NaN
# 41          HNF1B_HUMAN.H11MO.0.A  1.571760e-02          NaN
# 42          FOXO1_MOUSE.H11MO.0.A  3.081440e-01          NaN
# 43               FOXD2_forkhead_1  1.219620e-01          NaN
# 44               FOXC2_forkhead_2  4.409010e-04          NaN
# 45                 CEBPA_MA0102.3  1.524150e-03          NaN
# 46           RFX2_HUMAN.H11MO.0.A  1.543970e-07          NaN
# 47            JUN_MOUSE.H11MO.0.A  1.000000e+00          NaN
# 48           STF1_HUMAN.H11MO.0.B  1.246090e-03          NaN
# 49          NR4A2_HUMAN.H11MO.0.C  1.008150e-01          NaN
# 50           SOX9_MOUSE.H11MO.0.A  3.493820e-03          NaN
# 51           KLF6_MOUSE.H11MO.0.B  9.226760e-04          NaN
# 52               FOXD3_forkhead_1  8.736230e-03          NaN
# 53               FOXI1_forkhead_1  4.151600e-03          NaN
# 54                     SOX2_HMG_5  1.000000e+00          NaN
# 55                 FOXB1_MA0845.1  4.200960e-01          NaN
# 56           AIRE_MOUSE.H11MO.0.C  1.640580e-01          NaN
# 57           PDX1_HUMAN.H11MO.0.A  5.703960e-01          NaN
# 58           TYY1_MOUSE.H11MO.0.A  9.779280e-01          NaN
# 59               ONECUT3_MA0757.1  9.010340e-01          NaN
# 60           TYY1_HUMAN.H11MO.0.A  9.939270e-01          NaN
#
#                      match2         qval2  match2_logo
# 0      CTCF_MOUSE.H11MO.0.A  1.138010e-10          NaN
# 1     HNF4G_MOUSE.H11MO.0.C  3.266830e-07          NaN
# 2            Foxd3_MA0041.1  5.530710e-02          NaN
# 3      KLF3_HUMAN.H11MO.0.B  5.177870e-04          NaN
# 4     FOXO3_HUMAN.H11MO.0.B  9.599100e-04          NaN
# 5       HNF1B_homeodomain_2  9.803890e-07          NaN
# 6      JUNB_HUMAN.H11MO.0.A  3.913190e-03          NaN
# 7      NFYA_HUMAN.H11MO.0.A  4.144860e-03          NaN
# 8            Gabpa_MA0062.2  1.711800e-04          NaN
# 9     CEBPA_MOUSE.H11MO.0.A  8.891860e-06          NaN
# 10     RXRG_MOUSE.H11MO.0.B  4.194900e-04          NaN
# 11  ESRRB_nuclearreceptor_1  9.272600e-04          NaN
# 12         FOXC2_forkhead_1  4.162410e-02          NaN
# 13         FOXC1_forkhead_1  3.810130e-01          NaN
# 14    SOX10_HUMAN.H11MO.0.B  5.585510e-04          NaN
# 15         FOXB1_forkhead_3  6.478860e-04          NaN
# 16     NRF1_HUMAN.H11MO.0.A  6.888810e-04          NaN
# 17    TEAD1_HUMAN.H11MO.0.A  5.624250e-03          NaN
# 18    ZN143_HUMAN.H11MO.0.A  1.381430e-10          NaN
# 19           CEBPB_MA0466.2  3.667750e-02          NaN
# 20     ATF4_HUMAN.H11MO.0.A  1.845820e-03          NaN
# 21     ATF1_HUMAN.H11MO.0.B  4.576480e-01          NaN
# 22            SREBF2_bHLH_1  2.955720e-03          NaN
# 23     HNF6_HUMAN.H11MO.0.B  6.102820e-02          NaN
# 24           HNF4G_MA0484.1  1.546700e-02          NaN
# 25               NRF1_NRF_1  1.353570e-02          NaN
# 26    SOX10_HUMAN.H11MO.0.B  6.330880e-02          NaN
# 27            IRF1_MA0050.2  6.999470e-10          NaN
# 28    KAISO_MOUSE.H11MO.0.B  2.348970e-04          NaN
# 29     NRF1_MOUSE.H11MO.0.A  1.405250e-02          NaN
# 30           FOXA1_MA0148.3  3.622280e-02          NaN
# 31     ETS1_HUMAN.H11MO.0.A  1.202300e-02          NaN
# 32   RARA_nuclearreceptor_4  2.646890e-03          NaN
# 33     NFIA_MOUSE.H11MO.0.C  5.243900e-05          NaN
# 34    SOX10_HUMAN.H11MO.0.B  9.365150e-03          NaN
# 35           CTCFL_MA1102.1  4.812650e-01          NaN
# 36     TYY1_HUMAN.H11MO.0.A  2.582600e-04          NaN
# 37    FOXA2_HUMAN.H11MO.0.A  2.541190e-03          NaN
# 38    FOXA1_HUMAN.H11MO.0.A  5.547880e-03          NaN
# 39      MYB_HUMAN.H11MO.0.A  1.000000e+00          NaN
# 40    FOXM1_HUMAN.H11MO.0.A  2.428900e-02          NaN
# 41    HNF1B_MOUSE.H11MO.0.A  1.571760e-02          NaN
# 42     ETV2_HUMAN.H11MO.0.B  3.330540e-01          NaN
# 43         FOXJ3_forkhead_3  1.219620e-01          NaN
# 44         FOXL1_forkhead_2  8.767470e-04          NaN
# 45    CEBPB_MOUSE.H11MO.0.A  3.031330e-03          NaN
# 46            Rfx1_MA0509.1  1.543970e-07          NaN
# 47     FOSB_HUMAN.H11MO.0.A  1.000000e+00          NaN
# 48     STF1_MOUSE.H11MO.0.B  1.246090e-03          NaN
# 49    NR4A2_MOUSE.H11MO.0.C  1.008150e-01          NaN
# 50    SOX10_HUMAN.H11MO.0.B  8.770910e-02          NaN
# 51      SP1_HUMAN.H11MO.0.A  1.518830e-03          NaN
# 52         FOXC1_forkhead_2  1.524490e-02          NaN
# 53           FOXD1_MA0031.1  4.151600e-03          NaN
# 54                      NaN           NaN          NaN
# 55         FOXB1_forkhead_3  4.200960e-01          NaN
# 56          Arid3b_MA0601.1  2.656650e-01          NaN
# 57             Dux_MA0611.1  8.140810e-01          NaN
# 58             YY1_MA0095.2  1.000000e+00          NaN
# 59          Arid3b_MA0601.1  9.010340e-01          NaN
# 60             YY1_MA0095.2  9.939270e-01          NaN

# %%
tomtom[0]["pattern"] = tomtom[0]["pattern"].str.replace("pos_patterns.pattern","0").str.replace("neg_patterns.pattern","1")
# Out:
# /users/anusri/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
tomtom[0]
# Out:
#    pattern  num_seqlets  modisco_cwm_fwd  modisco_cwm_rev  \
# 0      0_0        39695              NaN              NaN
# 1      0_1        34273              NaN              NaN
# 2      0_2        10841              NaN              NaN
# 3      0_3        10650              NaN              NaN
# 4      0_4        10045              NaN              NaN
# 5      0_5         8953              NaN              NaN
# 6      0_6         6915              NaN              NaN
# 7      0_7         5571              NaN              NaN
# 8      0_8         5513              NaN              NaN
# 9      0_9         5038              NaN              NaN
# 10    0_10         3942              NaN              NaN
# 11    0_11         2995              NaN              NaN
# 12    0_12         2979              NaN              NaN
# 13    0_13         2492              NaN              NaN
# 14    0_14         2316              NaN              NaN
# 15    0_15         2272              NaN              NaN
# 16    0_16         2126              NaN              NaN
# 17    0_17         2042              NaN              NaN
# 18    0_18         1898              NaN              NaN
# 19    0_19         1578              NaN              NaN
# 20    0_20         1537              NaN              NaN
# 21    0_21         1245              NaN              NaN
# 22    0_22         1094              NaN              NaN
# 23    0_23          966              NaN              NaN
# 24    0_24          814              NaN              NaN
# 25    0_25          759              NaN              NaN
# 26    0_26          698              NaN              NaN
# 27    0_27          677              NaN              NaN
# 28    0_28          651              NaN              NaN
# 29    0_29          568              NaN              NaN
# 30    0_30          548              NaN              NaN
# 31    0_31          457              NaN              NaN
# 32    0_32          398              NaN              NaN
# 33    0_33          377              NaN              NaN
# 34    0_34          332              NaN              NaN
# 35    0_35          318              NaN              NaN
# 36    0_36          305              NaN              NaN
# 37    0_37          242              NaN              NaN
# 38    0_38          175              NaN              NaN
# 39    0_39          163              NaN              NaN
# 40    0_40          157              NaN              NaN
# 41    0_41          110              NaN              NaN
# 42    0_42          105              NaN              NaN
# 43    0_43           79              NaN              NaN
# 44    0_44           74              NaN              NaN
# 45    0_45           56              NaN              NaN
# 46    0_46           49              NaN              NaN
# 47    0_47           49              NaN              NaN
# 48    0_48           41              NaN              NaN
# 49    0_49           40              NaN              NaN
# 50    0_50           39              NaN              NaN
# 51    0_51           34              NaN              NaN
# 52    0_52           31              NaN              NaN
# 53    0_53           24              NaN              NaN
# 54     1_0           65              NaN              NaN
# 55     1_1           46              NaN              NaN
# 56     1_2           41              NaN              NaN
# 57     1_3           40              NaN              NaN
# 58     1_4           32              NaN              NaN
# 59     1_5           25              NaN              NaN
# 60     1_6           24              NaN              NaN
#
#                      match0         qval0  match0_logo  \
# 0             CTCF_MA0139.1  4.598650e-16          NaN
# 1            HNF4G_MA0484.1  2.891220e-09          NaN
# 2     FOXM1_HUMAN.H11MO.0.A  1.511910e-03          NaN
# 3     KLF12_HUMAN.H11MO.0.C  1.920700e-04          NaN
# 4            FOXO6_MA0849.1  7.031260e-04          NaN
# 5            HNF1B_MA0153.2  2.251600e-08          NaN
# 6      ATF3_MOUSE.H11MO.0.A  3.913190e-03          NaN
# 7      NFYB_HUMAN.H11MO.0.A  3.432360e-03          NaN
# 8             ELK4_MA0076.2  1.711800e-04          NaN
# 9     CEBPA_HUMAN.H11MO.0.A  8.891860e-06          NaN
# 10           Nr5a2_MA0505.1  3.977880e-04          NaN
# 11     ERR2_HUMAN.H11MO.0.A  9.272600e-04          NaN
# 12         FOXD2_forkhead_1  4.162410e-02          NaN
# 13    FOXM1_HUMAN.H11MO.0.A  2.008940e-01          NaN
# 14     SOX9_HUMAN.H11MO.0.B  2.508290e-05          NaN
# 15         FOXB1_forkhead_2  6.478860e-04          NaN
# 16            NRF1_MA0506.1  2.446090e-06          NaN
# 17           TEAD3_MA0808.1  5.624250e-03          NaN
# 18    ZNF76_HUMAN.H11MO.0.C  1.924590e-20          NaN
# 19           CEBPE_MA0837.1  3.667750e-02          NaN
# 20     ATF4_MOUSE.H11MO.0.A  1.845820e-03          NaN
# 21    CEBPD_HUMAN.H11MO.0.C  4.576480e-01          NaN
# 22     ATF3_HUMAN.H11MO.0.A  4.013160e-04          NaN
# 23  NR2E1_nuclearreceptor_2  6.102820e-02          NaN
# 24    HNF4A_HUMAN.H11MO.0.A  1.546700e-02          NaN
# 25            NRF1_MA0506.1  2.218720e-03          NaN
# 26     SOX9_HUMAN.H11MO.0.B  1.992310e-02          NaN
# 27     IRF2_HUMAN.H11MO.0.A  1.490430e-13          NaN
# 28          ZBTB33_MA0527.1  2.255440e-04          NaN
# 29               NRF1_NRF_1  1.405250e-02          NaN
# 30    FOXA2_HUMAN.H11MO.0.A  2.602350e-02          NaN
# 31     ETV6_MOUSE.H11MO.0.C  1.202300e-02          NaN
# 32  HNF4A_nuclearreceptor_3  2.646890e-03          NaN
# 33     NFIC_HUMAN.H11MO.0.A  2.586400e-06          NaN
# 34     SOX9_HUMAN.H11MO.0.B  9.962850e-04          NaN
# 35    CTCFL_MOUSE.H11MO.0.A  4.812650e-01          NaN
# 36     TAF1_MOUSE.H11MO.0.A  1.886400e-04          NaN
# 37    FOXM1_HUMAN.H11MO.0.A  2.052330e-04          NaN
# 38    FOXA2_HUMAN.H11MO.0.A  5.547880e-03          NaN
# 39      MYB_MOUSE.H11MO.0.A  1.000000e+00          NaN
# 40    FOXA2_HUMAN.H11MO.0.A  1.576070e-02          NaN
# 41    HNF1A_HUMAN.H11MO.0.C  1.571760e-02          NaN
# 42           Foxo1_MA0480.1  2.635030e-01          NaN
# 43         FOXD3_forkhead_1  1.219620e-01          NaN
# 44   Foxc1.mouse_forkhead_1  4.409010e-04          NaN
# 45    CEBPA_MOUSE.H11MO.0.A  1.524150e-03          NaN
# 46     RFX2_MOUSE.H11MO.0.A  1.543970e-07          NaN
# 47      FOS_HUMAN.H11MO.0.A  1.000000e+00          NaN
# 48     ERR2_HUMAN.H11MO.0.A  1.246090e-03          NaN
# 49     COT1_MOUSE.H11MO.0.B  1.008150e-01          NaN
# 50     SOX9_HUMAN.H11MO.0.B  3.493820e-03          NaN
# 51     KLF6_HUMAN.H11MO.0.A  9.226760e-04          NaN
# 52         FOXD2_forkhead_1  6.902240e-03          NaN
# 53           FOXI1_MA0042.2  4.151600e-03          NaN
# 54              CPEB1_RRM_1  1.000000e+00          NaN
# 55         FOXB1_forkhead_2  3.987910e-01          NaN
# 56     AIRE_HUMAN.H11MO.0.C  1.640580e-01          NaN
# 57            NFYB_MA0502.1  6.628390e-02          NaN
# 58     TYY1_HUMAN.H11MO.0.A  9.779280e-01          NaN
# 59            ONECUT3_CUT_1  9.010340e-01          NaN
# 60    THAP1_HUMAN.H11MO.0.C  9.338570e-01          NaN
#
#                            match1         qval1  match1_logo  \
# 0            CTCF_HUMAN.H11MO.0.A  2.050480e-12          NaN
# 1           HNF4G_HUMAN.H11MO.0.B  3.266830e-07          NaN
# 2           FOXM1_MOUSE.H11MO.0.B  1.511910e-03          NaN
# 3             SP1_HUMAN.H11MO.0.A  1.920700e-04          NaN
# 4                FOXO6_forkhead_2  7.031260e-04          NaN
# 5             HNF1B_homeodomain_1  2.251600e-08          NaN
# 6           FOSL2_MOUSE.H11MO.0.A  3.913190e-03          NaN
# 7            NFYB_MOUSE.H11MO.0.A  3.432360e-03          NaN
# 8            ELK1_MOUSE.H11MO.0.B  1.711800e-04          NaN
# 9                  CEBPA_MA0102.3  8.891860e-06          NaN
# 10           RXRA_MOUSE.H11MO.0.A  3.977880e-04          NaN
# 11                 ESRRB_MA0141.3  9.272600e-04          NaN
# 12               FOXC1_forkhead_2  4.162410e-02          NaN
# 13          FOXM1_MOUSE.H11MO.0.B  2.008940e-01          NaN
# 14           SOX9_MOUSE.H11MO.0.A  2.508290e-05          NaN
# 15                 FOXB1_MA0845.1  6.478860e-04          NaN
# 16                     NRF1_NRF_1  6.888810e-04          NaN
# 17                    TEAD3_TEA_2  5.624250e-03          NaN
# 18          ZN143_MOUSE.H11MO.0.A  1.252410e-10          NaN
# 19                   CEBPE_bZIP_1  3.667750e-02          NaN
# 20          CEBPG_MOUSE.H11MO.0.B  1.845820e-03          NaN
# 21          CEBPD_MOUSE.H11MO.0.B  4.576480e-01          NaN
# 22                SREBF2_MA0828.1  2.955720e-03          NaN
# 23  Nr2e1.mouse_nuclearreceptor_2  6.102820e-02          NaN
# 24          HNF4A_MOUSE.H11MO.0.A  1.546700e-02          NaN
# 25           NRF1_MOUSE.H11MO.0.A  8.348640e-03          NaN
# 26           SOX9_MOUSE.H11MO.0.A  1.992310e-02          NaN
# 27           IRF2_MOUSE.H11MO.0.B  1.490430e-13          NaN
# 28          KAISO_HUMAN.H11MO.0.A  2.348970e-04          NaN
# 29           NRF1_HUMAN.H11MO.0.A  1.405250e-02          NaN
# 30                 Foxa2_MA0047.2  3.135590e-02          NaN
# 31           ETV4_MOUSE.H11MO.0.B  1.202300e-02          NaN
# 32        HNF4A_nuclearreceptor_1  2.646890e-03          NaN
# 33           NFIA_HUMAN.H11MO.0.C  5.243900e-05          NaN
# 34           SOX9_MOUSE.H11MO.0.A  9.962850e-04          NaN
# 35          CTCFL_HUMAN.H11MO.0.A  4.812650e-01          NaN
# 36          THAP1_HUMAN.H11MO.0.C  2.582600e-04          NaN
# 37          FOXM1_MOUSE.H11MO.0.B  2.052330e-04          NaN
# 38                  JUND_MA0491.1  5.547880e-03          NaN
# 39           MYBA_MOUSE.H11MO.0.C  1.000000e+00          NaN
# 40          FOXA1_HUMAN.H11MO.0.A  2.428900e-02          NaN
# 41          HNF1B_HUMAN.H11MO.0.A  1.571760e-02          NaN
# 42          FOXO1_MOUSE.H11MO.0.A  3.081440e-01          NaN
# 43               FOXD2_forkhead_1  1.219620e-01          NaN
# 44               FOXC2_forkhead_2  4.409010e-04          NaN
# 45                 CEBPA_MA0102.3  1.524150e-03          NaN
# 46           RFX2_HUMAN.H11MO.0.A  1.543970e-07          NaN
# 47            JUN_MOUSE.H11MO.0.A  1.000000e+00          NaN
# 48           STF1_HUMAN.H11MO.0.B  1.246090e-03          NaN
# 49          NR4A2_HUMAN.H11MO.0.C  1.008150e-01          NaN
# 50           SOX9_MOUSE.H11MO.0.A  3.493820e-03          NaN
# 51           KLF6_MOUSE.H11MO.0.B  9.226760e-04          NaN
# 52               FOXD3_forkhead_1  8.736230e-03          NaN
# 53               FOXI1_forkhead_1  4.151600e-03          NaN
# 54                     SOX2_HMG_5  1.000000e+00          NaN
# 55                 FOXB1_MA0845.1  4.200960e-01          NaN
# 56           AIRE_MOUSE.H11MO.0.C  1.640580e-01          NaN
# 57           PDX1_HUMAN.H11MO.0.A  5.703960e-01          NaN
# 58           TYY1_MOUSE.H11MO.0.A  9.779280e-01          NaN
# 59               ONECUT3_MA0757.1  9.010340e-01          NaN
# 60           TYY1_HUMAN.H11MO.0.A  9.939270e-01          NaN
#
#                      match2         qval2  match2_logo
# 0      CTCF_MOUSE.H11MO.0.A  1.138010e-10          NaN
# 1     HNF4G_MOUSE.H11MO.0.C  3.266830e-07          NaN
# 2            Foxd3_MA0041.1  5.530710e-02          NaN
# 3      KLF3_HUMAN.H11MO.0.B  5.177870e-04          NaN
# 4     FOXO3_HUMAN.H11MO.0.B  9.599100e-04          NaN
# 5       HNF1B_homeodomain_2  9.803890e-07          NaN
# 6      JUNB_HUMAN.H11MO.0.A  3.913190e-03          NaN
# 7      NFYA_HUMAN.H11MO.0.A  4.144860e-03          NaN
# 8            Gabpa_MA0062.2  1.711800e-04          NaN
# 9     CEBPA_MOUSE.H11MO.0.A  8.891860e-06          NaN
# 10     RXRG_MOUSE.H11MO.0.B  4.194900e-04          NaN
# 11  ESRRB_nuclearreceptor_1  9.272600e-04          NaN
# 12         FOXC2_forkhead_1  4.162410e-02          NaN
# 13         FOXC1_forkhead_1  3.810130e-01          NaN
# 14    SOX10_HUMAN.H11MO.0.B  5.585510e-04          NaN
# 15         FOXB1_forkhead_3  6.478860e-04          NaN
# 16     NRF1_HUMAN.H11MO.0.A  6.888810e-04          NaN
# 17    TEAD1_HUMAN.H11MO.0.A  5.624250e-03          NaN
# 18    ZN143_HUMAN.H11MO.0.A  1.381430e-10          NaN
# 19           CEBPB_MA0466.2  3.667750e-02          NaN
# 20     ATF4_HUMAN.H11MO.0.A  1.845820e-03          NaN
# 21     ATF1_HUMAN.H11MO.0.B  4.576480e-01          NaN
# 22            SREBF2_bHLH_1  2.955720e-03          NaN
# 23     HNF6_HUMAN.H11MO.0.B  6.102820e-02          NaN
# 24           HNF4G_MA0484.1  1.546700e-02          NaN
# 25               NRF1_NRF_1  1.353570e-02          NaN
# 26    SOX10_HUMAN.H11MO.0.B  6.330880e-02          NaN
# 27            IRF1_MA0050.2  6.999470e-10          NaN
# 28    KAISO_MOUSE.H11MO.0.B  2.348970e-04          NaN
# 29     NRF1_MOUSE.H11MO.0.A  1.405250e-02          NaN
# 30           FOXA1_MA0148.3  3.622280e-02          NaN
# 31     ETS1_HUMAN.H11MO.0.A  1.202300e-02          NaN
# 32   RARA_nuclearreceptor_4  2.646890e-03          NaN
# 33     NFIA_MOUSE.H11MO.0.C  5.243900e-05          NaN
# 34    SOX10_HUMAN.H11MO.0.B  9.365150e-03          NaN
# 35           CTCFL_MA1102.1  4.812650e-01          NaN
# 36     TYY1_HUMAN.H11MO.0.A  2.582600e-04          NaN
# 37    FOXA2_HUMAN.H11MO.0.A  2.541190e-03          NaN
# 38    FOXA1_HUMAN.H11MO.0.A  5.547880e-03          NaN
# 39      MYB_HUMAN.H11MO.0.A  1.000000e+00          NaN
# 40    FOXM1_HUMAN.H11MO.0.A  2.428900e-02          NaN
# 41    HNF1B_MOUSE.H11MO.0.A  1.571760e-02          NaN
# 42     ETV2_HUMAN.H11MO.0.B  3.330540e-01          NaN
# 43         FOXJ3_forkhead_3  1.219620e-01          NaN
# 44         FOXL1_forkhead_2  8.767470e-04          NaN
# 45    CEBPB_MOUSE.H11MO.0.A  3.031330e-03          NaN
# 46            Rfx1_MA0509.1  1.543970e-07          NaN
# 47     FOSB_HUMAN.H11MO.0.A  1.000000e+00          NaN
# 48     STF1_MOUSE.H11MO.0.B  1.246090e-03          NaN
# 49    NR4A2_MOUSE.H11MO.0.C  1.008150e-01          NaN
# 50    SOX10_HUMAN.H11MO.0.B  8.770910e-02          NaN
# 51      SP1_HUMAN.H11MO.0.A  1.518830e-03          NaN
# 52         FOXC1_forkhead_2  1.524490e-02          NaN
# 53           FOXD1_MA0031.1  4.151600e-03          NaN
# 54                      NaN           NaN          NaN
# 55         FOXB1_forkhead_3  4.200960e-01          NaN
# 56          Arid3b_MA0601.1  2.656650e-01          NaN
# 57             Dux_MA0611.1  8.140810e-01          NaN
# 58             YY1_MA0095.2  1.000000e+00          NaN
# 59          Arid3b_MA0601.1  9.010340e-01          NaN
# 60             YY1_MA0095.2  9.939270e-01          NaN

# %%
tomtom[0][["pattern","num_seqlets"]].to_csv(os.path.join(ppm_dir,mode+"_counts.csv"),sep=",",index=False, header=False)
