# %%
import pandas as pd

# %%
data = pd.read_csv("/mnt/lab_data2/anusri/chrombpnet/dsqtl_meta_data_small_new.tsv", sep='\t', header=None)

# %%
data.head()
# Out:
#       0          1  2  3           4
# 0  chr9  136811747  A  G   rs2519112
# 1  chr9  135991219  G  A  rs74734156
# 2  chr7  108237224  G  T  rs76144775
# 3  chr7  102107697  C  G  rs11761361
# 4  chr6   10965119  T  G   rs7753995

# %%
import pyBigWig as pw
bw_ref = pw.open("/mnt/lab_data2/anusri/chrombpnet/results/chrombpnet/ATAC_PE/GM12878/nautilus_runs/GM12878_03.01.2022_bias_128_4_1234_0.4_fold_0/chrombpnet_model/dsqtls_interpret_small_new_1/bigwigs/count_shap_ref.bw")
bw_alt = pw.open("/mnt/lab_data2/anusri/chrombpnet/results/chrombpnet/ATAC_PE/GM12878/nautilus_runs/GM12878_03.01.2022_bias_128_4_1234_0.4_fold_0/chrombpnet_model/dsqtls_interpret_small_new_1/bigwigs/count_shap_alt.bw")

# %%
import matplotlib.pyplot as plt
for i,r in data.iterrows():
    plt.figure()
    print(r)
    plt.plot(bw_ref.values(r[0],r[1]-250,r[1]+250), label="ref")
    plt.plot(bw_alt.values(r[0],r[1]-250,r[1]+250), label="alt")
    plt.legend()
    plt.show()
# Out:
# 0         chr9
# 1    136811747
# 2            A
# 3            G
# 4    rs2519112
# Name: 0, dtype: object
# 0          chr9
# 1     135991219
# 2             G
# 3             A
# 4    rs74734156
# Name: 1, dtype: object
# 0          chr7
# 1     108237224
# 2             G
# 3             T
# 4    rs76144775
# Name: 2, dtype: object
# 0          chr7
# 1     102107697
# 2             C
# 3             G
# 4    rs11761361
# Name: 3, dtype: object
# 0         chr6
# 1     10965119
# 2            T
# 3            G
# 4    rs7753995
# Name: 4, dtype: object
# 0         chr6
# 1      3435114
# 2            A
# 3            T
# 4    rs4959833
# Name: 5, dtype: object
# 0          chr5
# 1     150618993
# 2             T
# 3             C
# 4    rs72794132
# Name: 6, dtype: object
# 0          chr5
# 1     137937318
# 2             G
# 3             A
# 4    rs11242436
# Name: 7, dtype: object
# 0         chr5
# 1     79398016
# 2            T
# 3            A
# 4    rs2438627
# ...
