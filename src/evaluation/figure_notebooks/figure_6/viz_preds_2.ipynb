# %%
import pyBigWig as pw
import matplotlib.pyplot as plt
import numpy as np

# %%
ddtype="profile"
#dsqtls_interpret_small
#dnase_orig_dsqtls_interpret_small
#atac_dsqtls_interpret_small
method="dsqtls_interpret_small"
ref = pw.open("/mnt/lab_data2/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/nautilus_runs/over_fitting_test/"+method+"//bigwigs/"+ddtype+"_ref.bw")
alt = pw.open("/mnt/lab_data2/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/nautilus_runs/over_fitting_test/"+method+"//bigwigs/"+ddtype+"_alt.bw")

plt.plot(ref.values("chr2", 133340261-500 , 133340261+500), alpha=0.5, c="black")
plt.plot(alt.values("chr2", 133340261-500 , 133340261+500), alpha=0.5, c="red")

# %%
#dsqtls_interpret_small
#dnase_orig_dsqtls_interpret_small
#atac_dsqtls_interpret_small
method="dnase_orig_dsqtls_interpret_small"
ref = pw.open("/mnt/lab_data2/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/nautilus_runs/over_fitting_test/"+method+"//bigwigs/"+ddtype+"_ref.bw")
alt = pw.open("/mnt/lab_data2/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/nautilus_runs/over_fitting_test/"+method+"//bigwigs/"+ddtype+"_alt.bw")

plt.plot(ref.values("chr2", 133340261-500 , 133340261+500), alpha=0.5, c="black")
plt.plot(alt.values("chr2", 133340261-500 , 133340261+500), alpha=0.5, c="red")

# %%
method="atac_dsqtls_interpret_small"
ref = pw.open("/mnt/lab_data2/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/nautilus_runs/over_fitting_test/"+method+"//bigwigs/"+ddtype+"_ref.bw")
alt = pw.open("/mnt/lab_data2/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/nautilus_runs/over_fitting_test/"+method+"//bigwigs/"+ddtype+"_alt.bw")

plt.plot(ref.values("chr2", 133340261-500 , 133340261+500), alpha=0.5, c="black")
plt.plot(alt.values("chr2", 133340261-500 , 133340261+500), alpha=0.5, c="red")

print(np.sum(np.nan_to_num(ref.values("chr2", 133340261-500 , 133340261+500))))
print(np.sum(np.nan_to_num(alt.values("chr2", 133340261-500 , 133340261+500))))
# Out:
# 852.4286767691374
# 2522.5807397663593

# %%
enf_preds_ref=pw.open("/mnt/lab_data2/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/nautilus_runs/over_fitting_test/enformer_dsqtls_interpret_small/ref_output.bw")
enf_preds_alt=pw.open("/mnt/lab_data2/anusri/chrombpnet/results/chrombpnet/DNASE_SE/GM12878/nautilus_runs/over_fitting_test/enformer_dsqtls_interpret_small/alt_output.bw")

# %%
#0.36, 0.60 atac

# %%
plt.plot(enf_preds_ref.values("chr2", 133340261-114688//2 , 133340261+114688//2), alpha=0.5, c="black")
plt.plot(enf_preds_alt.values("chr2", 133340261-114688//2 , 133340261+114688//2), alpha=0.5, c="red")

# %%
plt.plot(enf_preds_ref.values("chr2", 133340261-1000 , 133340261+1000), alpha=0.5, c="black")
plt.plot(enf_preds_alt.values("chr2", 133340261-1000 , 133340261+1000), alpha=0.5, c="red")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-05a096c15aa9> in <module>
# ----> 1 plt.plot(enf_preds_ref.values("chr2", 133340261-1000 , 133340261+1000), alpha=0.5, c="black")
#       2 plt.plot(enf_preds_alt.values("chr2", 133340261-1000 , 133340261+1000), alpha=0.5, c="red")
#
# NameError: name 'plt' is not defined

# %%
np.log(150/100)
# Out:
# 0.4054651081081644

# %%
np.log(1050/1000)
# Out:
# 0.04879016416943205
